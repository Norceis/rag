# %%
from pathlib import Path
from tqdm import tqdm
import re
from loggers.loggers import get_custom_logger
from bs4 import BeautifulSoup

raw_dataset_dir = Path("../../data/raw_dataset/html")

# %% [markdown]
# # Metadata

# %%
parsing_logger = get_custom_logger(name='parsing_logger', log_path="../../logs/parsing.log")
# everything_in_pre_pattern = r'<pre>(.*?)<span class="h1">'

patterns = {
    "updates_pattern": r"(Updates(?: RFC's)?:\s*(.*?)\n)",
    "obsoletes_pattern": r"Obsoletes:?+\s*(.*?)\n",
    "category_pattern": r"\b(?:Categories?|Category):?\s*(.*?)\n",
    "issn_pattern": r"ISSN:?+\s*(.*?)\n",
    "updated_by_pattern": r"Updated by:?+\s*(.*?)\n",
    # "bcp_pattern": r"BCP:?+\s*(.*?)\n",
    "NIC_pattern": r"NIC:?+\s*(.*?)\n",
    "obsoleted_by_pattern": r"Obsoleted by:?+\s*(.*?)\n",
    "related_rfcs_pattern": r"\b(?:Related\s*(?:RFCs|Functional\s*Documents?)?|References)\s*:\s*(.*?)(?:\n|$)"
}

pattern_contents = {
    "updates_pattern": [],  # needs numbers only (excluding MONTH 4digit number)
    "obsoletes_pattern": [],  # needs numbers only (excluding MONTH 4digit number)
    "category_pattern": [],  # needs all words before 3 or more spaces
    "issn_pattern": [],  # 4 digit - 4 digit
    "updated_by_pattern": [],  # needs numbers only
    # "bcp_pattern": [],  # needs numbers only (first)
    "NIC_pattern": [],  # needs numbers only (excluding MONTH 4digit number)
    "obsoleted_by_pattern": [],  # needs numbers only (excluding MONTH 4digit number)
    "related_rfcs_pattern": [],  # needs numbers only (excluding MONTH 4digit number)
}

# html_file = Path("../../data/raw_dataset/rfc1720.html")
for html_file in tqdm(raw_dataset_dir.glob("*.html"), desc="Processing RFCs", unit="file"):
    with html_file.open('r', encoding='utf-8') as file:
        html_content = file.read()

        for pattern_name, pattern in patterns.items():
            match = re.search(pattern, html_content, re.DOTALL)

            matching_element = match.group(1) if match else None
            if matching_element:
                # print(html_file)
                # print(matching_element)
                pattern_contents[pattern_name].append(matching_element)
# Out:
# Processing RFCs: 9266file [00:27, 337.58file/s]

# %%
pattern_contents['updates_pattern']
# Out:
# ['Updates: RFC <a href="./rfc732">732</a>                                           February 1988\n',
#  'Updates: RFCs <a href="./rfc1034">1034</a>, <a href="./rfc1035">1035</a>                                      April 1989\n',
#  'Updates:  RFC <a href="./rfc976">976</a>                                          December 1989\n',
#  'Updates: RFCs <a href="./rfc822">822</a>, <a href="./rfc987">987</a>, <a href="./rfc1026">1026</a>                               December 1989\n',
#  'Updates: RFCs <a href="./rfc822">822</a>, <a href="./rfc987">987</a>, <a href="./rfc1026">1026</a>, <a href="./rfc1138">1138</a>                            March 1990\n',
#  'Updates: RFC <a href="./rfc908">908</a>                                              R. Hinden\n',
#  'Updates: <a href="./rfc99">99</a>\n',
#  'Updates: RFCs <a href="./rfc1034">1034</a>, <a href="./rfc1035">1035</a>                                      L. Mamakos\n',
#  'Updates: RFC <a href="./rfc907">907</a>                                              April 1991\n',
#  'Updates: RFCs <a href="./rfc98">98</a>, <a href="./rfc101">101</a>\n',
#  'Updates: RFCs <a href="./rfc1229">1229</a>, <a href="./rfc1230">1230</a>, <a href="./rfc1231">1231</a>, <a href="./rfc1232">1232</a>, <a href="./rfc1233">1233</a>                    June 1991\n',
#  'Updates: none\n',
#  'Updates: RFC <a href="./rfc1115">1115</a>                                             April 1992\n',
#  'Updates: RFC <a href="./rfc822">822</a>\n',
#  'Updates: RFCs <a href="./rfc1034">1034</a>, <a href="./rfc1035">1035</a>                                       July 1992\n',
#  'Updates: RFCs <a href="./rfc1248">1248</a>, <a href="./rfc1247">1247</a>, <a href="./rfc1195">1195</a>,                                July 1992\n',
#  'Updates: <a href="./rfc110">110</a>\n',
#  'Updates: RFC <a href="./rfc1058">1058</a>                                           January 1993\n',
#  'Updates: <a href="./rfc951">951</a>\n',
#  'Updates: none\n',
#  'Updates:  <a href="./rfc123">123</a>, <a href="./rfc145">145</a>                                            3 May 1971\n',
#  'Updates: <a href="./rfc123">123</a>\n',
#  'Updates: none\n',
#  'Updates:  #140\n',
#  'Updates: <a href="./rfc1327">1327</a>                                                   S. Kille\n',
#  'Updates: <a href="./rfc1328">1328</a>                                               J. Romaguera\n',
#  'Updates: <a href="./rfc951">951</a>\n',
#  'Updates: <a href="./rfc1285">1285</a>                                SNMP Research, Incorporated\n',
#  'Updates: <a href="./rfc1271">1271</a>                                             September 1993\n',
#  'Updates: None\n',
#  'Updates: <a href="./rfc951">951</a>                                                October 1993\n',
#  'Updates: #107\n',
#  'Updates: <a href="./rfc951">951</a>                                                October 1993\n',
#  'Updates: None\n',
#  'Updates: <a href="./rfc1548">1548</a>                                               January 1994\n',
#  'Updates: <a href="./rfc1408">1408</a>                                               January 1994\n',
#  'Updates: <a href="./rfc1521">1521</a>                                                 March 1994\n',
#  'Updates: None\n',
#  'Updates: <a href="./rfc1141">1141</a>                                                   May 1994\n',
#  'Updates:  None\n',
#  'Updates: updates to existing information on NIR Tools may be sent by\n',
#  'Updates: None\n',
#  'Updates: <a href="./rfc114">114</a>                                               Will Crowther\n',
#  'Updates: <a href="./rfc904">RFC-904</a>, pp. 16\n',
#  'Updates: <a href="./rfc114">114</a>                                    Eric Harslem, Rand\n',
#  'Updates: <a href="./rfc1058">1058</a>\n',
#  'Updates:     None\n',
#  'Updates: <a href="./rfc1748">1748</a>                                                  E. Decker\n',
#  'Updates: <a href="./rfc125">125</a>\n',
#  'Updates: <a href="./rfc1350">1350</a>                                                  A. Harkin\n',
#  'Updates: <a href="./rfc1350">1350</a>                                                  A. Harkin\n',
#  'Updates: <a href="./rfc1350">1350</a>                                                  A. Harkin\n',
#  'Updates: <a href="./rfc1350">1350</a>                                                  A. Harkin\n',
#  'Updates:  <a href="./rfc107">107</a>\n',
#  'Updates: none\n',
#  'Updates: <a href="./rfc904">RFC-904</a>, page 16\n',
#  'Updates: <a href="./rfc1602">1602</a>, <a href="./rfc1603">1603</a>                                        November 1995\n',
#  'Updates: <a href="./rfc1034">1034</a>, <a href="./rfc1035">1035</a>                                             P. Vixie\n',
#  'Updates: None\n',
#  'Updates: <a href="./rfc1939">1939</a>                                                  June 1996\n',
#  'Updates: none\n',
#  'Updates:  None\n',
#  'Updates:  RFC #193\n',
#  'Updates: <a href="./rfc1034">1034</a>, <a href="./rfc1035">1035</a>                                              R. Bush\n',
#  'Updates: <a href="./rfc1035">1035</a>                                                August 1996\n',
#  'Updates: <a href="./rfc1035">1035</a>                                                August 1996\n',
#  'Updates: <a href="./rfc1213">1213</a>                                              November 1996\n',
#  'Updates: <a href="./rfc1213">1213</a>                                              November 1996\n',
#  'Updates: <a href="./rfc1213">1213</a>                                              November 1996\n',
#  'Updates: <a href="./rfc1035">1035</a>, <a href="./rfc1183">1183</a>                                             P. Vixie\n',
#  'Updates: <a href="./rfc1034">1034</a>, <a href="./rfc1035">1035</a>                                           C. Kaufman\n',
#  'Updates:       [<a href="#ref-21" title="&quot;son-of-RFC1036&quot;">21</a>], non-standard\n',
#  'Updates: none\n',
#  'Updates: <a href="./rfc207">207</a>\n',
#  'Updates:  None\n',
#  'Updates: <a href="./rfc1035">1035</a>                                                S. Thomson\n',
#  'Updates: <a href="./rfc1035">1035</a>                                                 April 1997\n',
#  'Updates: <a href="./rfc1883">1883</a>                                                   May 1997\n',
#  'Updates: none\n',
#  'Updates: RFCs <a href="./rfc1661">1661</a>, <a href="./rfc1962">1962</a>                                        May 1997\n',
#  'Updates: <a href="./rfc822">822</a>\n',
#  'Updates:  RFC <a href="./rfc105">105</a>, <a href="./rfc122">RFC 122</a>               Univ. of California\n',
#  'Updates:  none\n',
#  'Updates: <a href="./rfc1034">1034</a>, <a href="./rfc1035">1035</a>, <a href="./rfc1123">1123</a>                                        R. Bush\n',
#  'Updates: <a href="./rfc1806">1806</a>                                                  S. Dorner\n',
#  'Updates: <a href="./rfc2045">2045</a>, <a href="./rfc2047">2047</a>, <a href="./rfc2183">2183</a>                                     K. Moore\n',
#  'Updates: None\n',
#  'Updates: <a href="./rfc959">959</a>                                                     S. Lunt\n',
#  'Updates: <a href="./rfc2045">2045</a>, <a href="./rfc2047">2047</a>, <a href="./rfc2183">2183</a>                                     K. Moore\n',
#  'Updates: <a href="./rfc1112">1112</a>                                                November 1997\n',
#  'Updates:  none\n',
#  'Updates:  RFC #74\n',
#  'Updates: RFC <a href="./rfc113">113</a>\n',
#  'Updates:  RFC #70\n',
#  'Updates: <a href="./rfc2002">2002</a>                                                   S. Glass\n',
#  'Updates: <a href="./rfc1987">1987</a>                                            R. Hinden, Nokia\n',
#  'Updates: <a href="./rfc1034">1034</a>, <a href="./rfc1035">1035</a>                                            March 1998\n',
#  'Updates: #204, #212, #222\n',
#  'Updates: <a href="./rfc1350">1350</a>                                                  A. Harkin\n',
#  'Updates: <a href="./rfc1350">1350</a>                                                  A. Harkin\n',
#  'Updates: <a href="./rfc1350">1350</a>                                                  A. Harkin\n',
#  'Updates: None\n',
#  'Updates: <a href="./rfc1738">1738</a>, <a href="./rfc1808">1808</a>                                        L. Masinter\n',
#  'Updates: RFC #171, RFC #172\n',
#  'Updates: <a href="./rfc1808">1808</a>, <a href="./rfc1738">1738</a>                                          R. Fielding\n',
#  'Updates:  none\n',
#  'Updates: none\n',
#  'Updates: <a href="./rfc2222">2222</a>                                               October 1998\n',
#  'Updates: <a href="./rfc1939">1939</a>                                                  C. Newman\n',
#  'Updates: <a href="./rfc2284">2284</a>, <a href="./rfc1994">1994</a>, <a href="./rfc1570">1570</a>\n',
#  'Updates:  None\n',
#  'Updates:  None\n',
#  'Updates: <a href="./rfc2181">2181</a>, <a href="./rfc1035">1035</a>, <a href="./rfc1034">1034</a>\n',
#  'Updates: <a href="./rfc1149">1149</a>                                           1 April 1999\n',
#  'Updates: <a href="./rfc252">252</a>                                            October 26, 1971\n',
#  'Updates: <a href="./rfc1778">1778</a>                                               T. Howes\n',
#  'Updates:  None\n',
#  'Updates: <a href="./rfc2165">2165</a>                                          Sun Microsystems\n',
#  'Updates: <a href="./rfc2165">2165</a>                                                  J. Kempf\n',
#  'Updates: 1806                                                  S\n',
#  'Updates:  none\n',
#  'Updates: <a href="./rfc959">959</a>                                                   July 1999\n',
#  'Updates: <a href="./rfc1812">1812</a>                                                August 1999\n',
#  'Updates: <a href="./rfc2046">2046</a>                                                August 1999\n',
#  'Updates:  RFC <a href="./rfc255">255</a>\n',
#  'Updates: RFC #266\n',
#  'Updates:  <a href="./rfc122">122</a>, <a href="./rfc238">238</a>, <a href="./rfc172">172</a>\n',
#  'Updates:  None\n',
#  'Updates: <a href="./rfc2533">2533</a>                                            December 1999\n',
#  'Updates: <a href="./rfc2205">2205</a>                                                January 2000\n',
#  'Updates: <a href="./rfc959">959</a>                                                     SPYRUS\n',
#  'Updates: <a href="./rfc2290">2290</a>                                                  C. Perkins\n',
#  'Updates: <a href="./rfc1966">1966</a>                                                 R. Chandra\n',
#  'Updates: <a href="./rfc1459">1459</a>\n',
#  'Updates: <a href="./rfc1459">1459</a>\n',
#  'Updates: <a href="./rfc1459">1459</a>\n',
#  'Updates: <a href="./rfc1459">1459</a>\n',
#  'Updates: <a href="./rfc2616">2616</a>                                                S. Lawrence\n',
#  'Updates: <a href="./rfc1123">1123</a>\n',
#  'Updates: <a href="./rfc1035">1035</a>                                                     NAI Labs\n',
#  'Updates:        None\n',
#  'Updates: <a href="./rfc1894">1894</a>                                                   June 2000\n',
#  'Updates: None\n',
#  'Updates: <a href="./rfc2866">2866</a>                                      Microsoft Corporation\n',
#  'Updates: RFC <a href="./rfc2865">2865</a>                                              D. Leifer\n',
#  'Updates: RFC #267\n',
#  'Updates: <a href="./rfc1205">1205</a>                                            IBM Corporation\n',
#  'Updates: <a href="./rfc287">287</a>\n',
#  'Updates: RFC <a href="./rfc243">243</a>                                        January 11, 1972\n',
#  'Updates: <a href="./rfc2168">2168</a>                                                   R. Daniel\n',
#  'Updates: None                                     Dave Liddle, Owens Ill.\n',
#  'Updates:  RFC <a href="./rfc288">288</a>\n',
#  'Updates: <a href="./rfc2535">2535</a>                                             September 2000\n',
#  'Updates: <a href="./rfc2533">2533</a>                                                 L. Masinter\n',
#  'Updates: RFC <a href="./rfc265">265</a>\n',
#  'Updates: none\n',
#  'Updates: <a href="./rfc2535">2535</a>, <a href="./rfc2136">2136</a>                                        November 2000\n',
#  'Updates: <a href="./rfc2535">2535</a>                                              November 2000\n',
#  'Updates:  None\n',
#  'Updates: <a href="./rfc2048">2048</a>                                               simonstl.com\n',
#  'Updates:   none\n',
#  'Updates: <a href="./rfc2118">2118</a>                                              cisco Systems\n',
#  'Updates: <a href="./rfc2747">2747</a>                                                   L. Zhang\n',
#  'Updates: <a href="./rfc1858">1858</a>                                                  June 2001\n',
#  'Updates: <a href="./rfc306">306</a>\n',
#  'Updates: <a href="./rfc2874">2874</a>, <a href="./rfc2772">2772</a>, <a href="./rfc2766">2766</a>, <a href="./rfc2553">2553</a>, <a href="./rfc1886">1886</a>\n',
#  'Updates: <a href="./rfc2015">2015</a>                                               D. Del Torto\n',
#  'Updates: <a href="./rfc2474">2474</a>, <a href="./rfc2401">2401</a>, <a href="./rfc793">793</a>                                        S. Floyd\n',
#  'Updates: RFC <a href="./rfc315">315</a>\n',
#  'Updates: <a href="./rfc2846">2846</a>\n',
#  'Updates: <a href="./rfc2846">2846</a>\n',
#  'Updates: <a href="./rfc1715">1715</a>                                                 C. Huitema\n',
#  'Updates: <a href="./rfc2608">2608</a>                                               January 2002\n',
#  'Updates: <a href="./rfc2874">2874</a>, <a href="./rfc2535">2535</a>\n',
#  'Updates: <a href="./rfc1332">1332</a>                                                 April 2002\n',
#  'Updates:  RFC #319\n',
#  'Updates: <a href="./rfc2474">2474</a>, <a href="./rfc2475">2475</a>, <a href="./rfc2597">2597</a>                                     April 2002\n',
#  'Updates: <a href="./rfc2543">2543</a>                                                  June 2002\n',
#  'Updates: <a href="./rfc2327">2327</a>                                               G. Camarillo\n',
#  'Updates:  RFC #326\n',
#  'Updates: <a href="./rfc2960">2960</a>                                                 R. Stewart\n',
#  'Updates:  RFC #330\n',
#  'Updates: none                                                    BBN/IMP\n',
#  'Updates: <a href="./rfc2673">2673</a>, <a href="./rfc2874">2874</a>                                              B. Fink\n',
#  'Updates: <a href="./rfc2673">2673</a>, <a href="./rfc2874">2874</a>                                          August 2002\n',
#  'Updates: <a href="./rfc2910">2910</a>, <a href="./rfc2911">2911</a>                                           R. Herriot\n',
#  'Updates: <a href="./rfc2910">2910</a>                                                   H. Lewis\n',
#  'Updates: <a href="./rfc2910">2910</a>, <a href="./rfc2911">2911</a>                                           R. Herriot\n',
#  'Updates: <a href="./rfc2581">2581</a>                                                       ICIR\n',
#  'Updates: <a href="./rfc2895">2895</a>                                        Cisco Systems, Inc.\n',
#  'Updates: <a href="./rfc2131">2131</a>                                                S. Cheshire\n',
#  'Updates: <a href="./rfc2276">2276</a>                                               October 2002\n',
#  'Updates:  RFC #332\n',
#  'Updates: <a href="./rfc1035">1035</a>                                              November 2002\n',
#  'Updates: <a href="./rfc1958">1958</a>                                              December 2002\n',
#  'Updates:  RFC #342\n',
#  'Updates: <a href="./rfc2132">2132</a>                                                S. Cheshire\n',
#  'Updates: <a href="./rfc3032">3032</a>                                                   B. Akyol\n',
#  'Updates: <a href="./rfc2535">2535</a>                                                    S. Rose\n',
#  'Updates: <a href="./rfc3204">3204</a>                                               January 2003\n',
#  'Updates: <a href="./rfc3060">3060</a>                                               January 2003\n',
#  'Updates: <a href="./rfc2910">2910</a>                                            High North Inc.\n',
#  'Updates: RFC #344\n',
#  'Updates: <a href="./rfc2246">2246</a>                                                 M. Nystrom\n',
#  'Updates:\nObsoletes:\n',
#  'Updates: <a href="./rfc2865">2865</a>                                                  July 2003\n',
#  'Updates: <a href="./rfc2869">2869</a>                                                 P. Calhoun\n',
#  'Updates: <a href="./rfc2710">2710</a>                                             September 2003\n',
#  'Updates:  RFC #353\n',
#  'Updates: <a href="./rfc3555">3555</a>                                                   Qualcomm\n',
#  'Updates: <a href="./rfc2370">2370</a>                                           Juniper Networks\n',
#  'Updates: <a href="./rfc2832">2832</a>                                           S. Yalamanchilli\n',
#  'Updates: <a href="./rfc2845">2845</a>                                                  J. Gilroy\n',
#  'Updates:\nObsoletes:\n',
#  'Updates: <a href="./rfc2535">2535</a>                                              November 2003\n',
#  'Updates: <a href="./rfc3090">3090</a>, <a href="./rfc3008">3008</a>, <a href="./rfc2535">2535</a>, <a href="./rfc1035">1035</a>\n',
#  'Updates: <a href="./rfc959">959</a>                                                  March 2007\n',
#  'Updates:  RFC #362\n',
#  'Updates: <a href="./rfc2705">2705</a>                                              Cisco Systems\n',
#  'Updates: <a href="./rfc3435">3435</a>                                              Cisco Systems\n',
#  'Updates: <a href="./rfc2026">2026</a>\n',
#  'Updates: <a href="./rfc2028">2028</a>, <a href="./rfc2026">2026</a>\n',
#  'Updates: <a href="./rfc2026">2026</a>                                              February 2004\n',
#  'Updates: <a href="./rfc366">366</a>\n',
#  'Updates:\n\n                              COMMENTS ON\n',
#  'Updates: <a href="./rfc2434">2434</a>\n',
#  'Updates: <a href="./rfc2798">2798</a>                                              February 2004\n',
#  'Updates:  RFC #367\n',
#  'Updates: <a href="./rfc2827">2827</a>                                                  P. Savola\n',
#  'Updates: <a href="./rfc3658">3658</a>, <a href="./rfc2535">2535</a>                                             May 2004\n',
#  'Updates: <a href="./rfc3755">3755</a>, <a href="./rfc2535">2535</a>                                          J. Schlyter\n',
#  'Updates: <a href="./rfc3095">3095</a>                                                 April 2004\n',
#  'Updates:  RFC #370\n',
#  'Updates: <a href="./rfc2251">2251</a>                                                K. Zeilenga\n',
#  'Updates: <a href="./rfc3461">3461</a>, <a href="./rfc2046">2046</a>                                  Lucent Technologies\n',
#  'Updates: <a href="./rfc3057">3057</a>                                                     S. Rao\n',
#  'Updates: <a href="./rfc2710">2710</a>                                                       LIP6\n',
#  'Updates: <a href="./rfc3755">3755</a>, <a href="./rfc2535">2535</a>\n',
#  'Updates: RFC <a href="./rfc354">354</a>                                  August 18, 1972\n',
#  'Updates: <a href="./rfc3261">3261</a>                                                  July 2004\n',
#  'Updates:\nObsoletes:\n',
#  'Updates: <a href="./rfc1793">1793</a>                                                   A. Zinin\n',
#  'Updates: <a href="./rfc3461">3461</a>                                                  T. Hansen\n',
#  'Updates: <a href="./rfc3463">3463</a>                                             September 2004\n',
#  'Updates: <a href="./rfc378">378</a> NIC: 11583\n',
#  'Updates: <a href="./rfc3710">3710</a>, <a href="./rfc2026">2026</a>\n',
#  'Updates: <a href="./rfc2418">2418</a>                                               October 2004\n',
#  'Updates: <a href="./rfc3209">3209</a>, <a href="./rfc2205">2205</a>                                              J. Lang\n',
#  'Updates: <a href="./rfc3458">3458</a>                                               October 2004\n',
#  'Updates:  RFC #381\n',
#  'Updates: <a href="./rfc2132">2132</a>                                              November 2004\n',
#  'Updates:\nObsoletes:\n',
#  'Updates: <a href="./rfc3306">3306</a>                                                B. Haberman\n',
#  'Updates:  RFC <a href="./rfc474">474</a>\n',
#  'Updates: <a href="./rfc3427">3427</a>                                              December 2004\n',
#  'Updates: <a href="./rfc3427">3427</a>                                              December 2004\n',
#  'Updates: <a href="./rfc2980">2980</a>\n',
#  'Updates: <a href="./rfc2026">2026</a>\n',
#  'Updates: <a href="./rfc2028">2028</a>, <a href="./rfc2026">2026</a>\n',
#  'Updates: <a href="./rfc3720">3720</a>                                                 R. Elliott\n',
#  'Updates: <a href="./rfc1738">1738</a>                                               Day Software\n',
#  'Updates:  <a href="./rfc122">122</a>                                   Sept. 26, 1972\n',
#  'Updates: <a href="./rfc2911">2911</a>, <a href="./rfc2910">2910</a>                                    Xerox Corporation\n',
#  'Updates: <a href="./rfc2911">2911</a>                                                T. Hastings\n',
#  'Updates: <a href="./rfc391">391</a>                                             18 October 1972\n',
#  'Updates: <a href="./rfc3473">3473</a>                                              February 2005\n',
#  'Updates:  RFC #387                                    October 23, 1972\n',
#  'Updates: <a href="./rfc2725">2725</a>, <a href="./rfc2622">2622</a>                                             J. Damas\n',
#  'Updates: <a href="./rfc3312">3312</a>                                                 P. Kyzivat\n',
#  'Updates: <a href="./rfc1034">1034</a>, <a href="./rfc1035">1035</a>, <a href="./rfc2136">2136</a>, <a href="./rfc2181">2181</a>, <a href="./rfc2308">2308</a>, <a href="./rfc3225">3225</a>,                   M. Larson\n',
#  'Updates: <a href="./rfc1034">1034</a>, <a href="./rfc1035">1035</a>, <a href="./rfc2136">2136</a>, <a href="./rfc2181">2181</a>, <a href="./rfc2308">2308</a>, <a href="./rfc3225">3225</a>,                   M. Larson\n',
#  'Updates: <a href="./rfc1034">1034</a>, <a href="./rfc1035">1035</a>, <a href="./rfc2136">2136</a>, <a href="./rfc2181">2181</a>, <a href="./rfc2308">2308</a>, <a href="./rfc3225">3225</a>,                   M. Larson\n',
#  'Updates: <a href="./rfc3279">3279</a>                                                 B. Kaliski\n',
#  'Updates: <a href="./rfc3703">3703</a>                                                   A. Reyes\n',
#  'Updates: <a href="./rfc2409">2409</a>                                                   May 2005\n',
#  'Updates: <a href="./rfc3106">3106</a>                                                  June 2005\n',
#  'Updates: <a href="./rfc1964">1964</a>                                                  Microsoft\n',
#  'Updates: RFC <a href="./rfc400">400</a>\n',
#  'Updates: RFC <a href="./rfc354">354</a>, <a href="./rfc385">RFC 385</a>                               29 November 1972\n',
#  'Updates: <a href="./rfc3032">3032</a>                                             September 2005\n',
#  'Updates: <a href="./rfc2072">2072</a>                                                    E. Lear\n',
#  'Updates: <a href="./rfc3471">3471</a>, <a href="./rfc3472">3472</a>, <a href="./rfc3473">3473</a>                               Juniper Networks\n',
#  'Updates: <a href="./rfc3630">3630</a>                                           Juniper Networks\n',
#  'Updates: <a href="./rfc3784">3784</a>                                           Juniper Networks\n',
#  'Updates:  RFC #413\n',
#  'Updates: RFC #389\n',
#  'Updates: <a href="./rfc2748">2748</a>                                                Intel Corp.\n',
#  'Updates:  <a href="./rfc122">122</a>                                  Dec.  15, 1972\n',
#  'Updates: <a href="./rfc2461">2461</a>                                                  D. Thaler\n',
#  'Updates: <a href="./rfc3261">3261</a>                                               January 2006\n',
#  'Updates: <a href="./rfc3280">3280</a>                                                 R. Housley\n',
#  'Updates: <a href="./rfc3471">3471</a>                                               January 2006\n',
#  'Updates: <a href="./rfc1034">1034</a>, <a href="./rfc1035">1035</a>, <a href="./rfc2181">2181</a>                                   January 2006\n',
#  'Updates: <a href="./rfc2131">2131</a>, <a href="./rfc2132">2132</a>, <a href="./rfc3315">3315</a>                                 B. Sommerfield\n',
#  'Updates: <a href="./rfc4346">4346</a>                                               RSA Security\n',
#  'Updates: <a href="./rfc4071">4071</a>                                                         UO\n',
#  'Updates: <a href="./rfc1122">1122</a>                                                 G. Swallow\n',
#  'Updates: <a href="./rfc381">381</a>,406\n',
#  'Updates: <a href="./rfc3209">3209</a>, <a href="./rfc3473">3473</a>                                     D. Papadimitriou\n',
#  'Updates: <a href="./rfc4175">4175</a>                                              February 2006\n',
#  'Updates: <a href="./rfc4348">4348</a>\n',
#  'Updates: RFC <a href="./rfc422">422</a>\n',
#  'Updates: <a href="./rfc2780">2780</a>                                              Cisco Systems\n',
#  'Updates: <a href="./rfc2088">2088</a>, <a href="./rfc2342">2342</a>, <a href="./rfc3501">3501</a>, <a href="./rfc3502">3502</a>, <a href="./rfc3516">3516</a>                           C. Daboo\n',
#  'Updates: <a href="./rfc3501">3501</a>                                                   May 2006\n',
#  'Updates: <a href="./rfc3463">3463</a>                                                   May 2006\n',
#  'Updates: <a href="./rfc3501">3501</a>, <a href="./rfc3502">3502</a>                                           April 2006\n',
#  'Updates: <a href="./rfc434">434</a>\n',
#  'Updates: <a href="./rfc4035">4035</a>, <a href="./rfc4034">4034</a>                                             J. Ihren\n',
#  'Updates: <a href="./rfc3306">3306</a>                                                   H-J. Kim\n',
#  'Updates: <a href="./rfc3279">3279</a>                                        D. Shefanovski, Ed.\n',
#  'Updates: <a href="./rfc2205">2205</a>                                              Cisco Systems\n',
#  'Updates: <a href="./rfc3273">3273</a>\n',
#  'Updates: <a href="./rfc3698">3698</a>\n',
#  'Updates: <a href="./rfc2247">2247</a>, <a href="./rfc2798">2798</a>, <a href="./rfc2377">2377</a>\n',
#  'Updates: <a href="./rfc2247">2247</a>, <a href="./rfc2798">2798</a>\n',
#  'Updates: <a href="./rfc4120">4120</a>                                              K. Jaganathan\n',
#  'Updates: <a href="./rfc1888">1888</a>, <a href="./rfc4048">4048</a>                                             Ericsson\n',
#  'Updates: <a href="./rfc3501">3501</a>                                                    S. Hole\n',
#  'Updates: RFC <a href="./rfc453">453</a>\n',
#  'Updates: <a href="./rfc4145">4145</a>                                                  July 2006\n',
#  'Updates: <a href="./rfc4364">4364</a>                                          P. Pillay-Esnault\n',
#  'Updates: <a href="./rfc3972">3972</a>                                                   J. Arkko\n',
#  'Updates: <a href="./rfc1034">1034</a>, <a href="./rfc2672">2672</a>                                            July 2006\n',
#  'Updates: <a href="./rfc3376">3376</a>, <a href="./rfc3810">3810</a>                                              B. Cain\n',
#  'Updates: <a href="./rfc2595">2595</a>                                                August 2006\n',
#  'Updates: <a href="./rfc3555">3555</a>                                    Universitaet Bremen TZI\n',
#  'Updates: <a href="./rfc3280">3280</a>                                               S. Santesson\n',
#  'Updates: <a href="./rfc3174">3174</a>                                                  T. Hansen\n',
#  'Updates: <a href="./rfc2980">2980</a>                                               K. Murchison\n',
#  'Updates: <a href="./rfc2980">2980</a>                                               K. Murchison\n',
#  'Updates: <a href="./rfc4346">4346</a>                                             September 2006\n',
#  'Updates: <a href="./rfc4346">4346</a>                                                    J. Ball\n',
#  'Updates: <a href="./rfc4364">4364</a>                                           Juniper Networks\n',
#  'Updates: <a href="./rfc3344">3344</a>                                        Cisco Systems, Inc.\n',
#  'Updates: <a href="./rfc4733">4733</a>                                                     Nortel\n',
#  'Updates: <a href="./rfc3830">3830</a>                                                 L. Dondeti\n',
#  'Updates: <a href="./rfc3978">3978</a>\n',
#  'Updates: <a href="./rfc3473">3473</a>                                              December 2006\n',
#  'Updates: <a href="./rfc3558">3558</a>                                                  R. Kapoor\n',
#  'Updates: <a href="./rfc3417">3417</a>                                                 Consultant\n',
#  'Updates: <a href="./rfc3641">3641</a>                                               January 2007\n',
#  'Updates: <a href="./rfc3095">3095</a>, <a href="./rfc3241">3241</a>, <a href="./rfc3843">3843</a>, <a href="./rfc4019">4019</a>, <a href="./rfc4362">4362</a>                       G. Pelletier\n',
#  'Updates: RFC <a href="./rfc455">455</a>\n',
#  'Updates: <a href="./rfc2453">2453</a>                                                       NIST\n',
#  'Updates: <a href="./rfc2132">2132</a>                                                  P. Eggert\n',
#  'Updates: <a href="./rfc4181">4181</a>\n',
#  'Updates: <a href="./rfc3720">3720</a>                                                 April 2007\n',
#  'Updates: <a href="./rfc3852">3852</a>                                                 April 2007\n',
#  'Updates: <a href="./rfc3463">3463</a>, <a href="./rfc3464">3464</a>                                         G. Vaudreuil\n',
#  'Updates: <a href="./rfc3471">3471</a>                                            Y. Rekhter, Ed.\n',
#  'Updates: <a href="./rfc3473">3473</a>, <a href="./rfc4872">4872</a>                                           I. Bryskin\n',
#  'Updates: <a href="./rfc3209">3209</a>, <a href="./rfc3473">3473</a>                                   Old Dog Consulting\n',
#  'Updates: <a href="./rfc3776">3776</a>                                                  F. Dupont\n',
#  'Updates: <a href="./rfc3979">3979</a>\n',
#  'Updates: <a href="./rfc792">792</a>, <a href="./rfc4443">4443</a>                                                D. Gan\n',
#  'Updates: <a href="./rfc3320">3320</a>, <a href="./rfc3321">3321</a>, <a href="./rfc3485">3485</a>                    Siemens/Roke Manor Research\n',
#  'Updates: <a href="./rfc3967">3967</a>                                                        MIT\n',
#  'Updates: <a href="./rfc3261">3261</a>                                                  June 2007\n',
#  'Updates: <a href="./rfc3463">3463</a>                                              Isode Limited\n',
#  'Updates: RFC #482\n',
#  'Updates: <a href="./rfc3473">3473</a>                                                  A. Farrel\n',
#  'Updates: <a href="./rfc3972">3972</a>                                                   J. Arkko\n',
#  'Updates: <a href="./rfc3981">3981</a>                                                August 2007\n',
#  'Updates: <a href="./rfc4120">4120</a>                                                August 2007\n',
#  'Updates: <a href="./rfc3312">3312</a>                                              Cisco Systems\n',
#  'Updates: <a href="./rfc3501">3501</a>                                             September 2007\n',
#  'Updates: <a href="./rfc2449">2449</a>                                     Oryx Mail Systems GmbH\n',
#  'Updates: <a href="./rfc2634">2634</a>                                                August 2007\n',
#  'Updates: <a href="./rfc3720">3720</a>                                               October 2007\n',
#  'Updates: <a href="./rfc4601">4601</a>                                                     SWITCH\n',
#  'Updates: <a href="./rfc2961">2961</a>, <a href="./rfc3473">3473</a>                                        Cisco Systems\n',
#  'Updates: <a href="./rfc3777">3777</a>                                               October 2007\n',
#  'Updates: <a href="./rfc2865">2865</a>, <a href="./rfc2866">2866</a>, <a href="./rfc2869">2869</a>, <a href="./rfc3579">3579</a>                                 A. DeKok\n',
#  'Updates: <a href="./rfc3852">3852</a>                                             November 2007\n',
#  'Updates: <a href="./rfc497">497</a>\n',
#  'Updates: <a href="./rfc4467">4467</a>                                           Sun Microsystems\n',
#  'Updates: <a href="./rfc2460">2460</a>, <a href="./rfc4294">4294</a>                                            P. Savola\n',
#  'Updates: <a href="./rfc4233">4233</a>                                               K. Morneault\n',
#  'Updates: <a href="./rfc4119">4119</a>                                                     Andrew\n',
#  'Updates: RFC <a href="./rfc459">459</a>\n',
#  'Updates: <a href="./rfc2046">2046</a>                                                  M. Duerst\n',
#  'Updates: <a href="./rfc3209">3209</a>, <a href="./rfc3473">3473</a>                                          A. Ayyangar\n',
#  'Updates: <a href="./rfc5229">5229</a>                                             Sendmail, Inc.\n',
#  'Updates: <a href="./rfc3501">3501</a>                                              March 2008\n',
#  'Updates: <a href="./rfc4788">4788</a>                                                     Q. Xie\n',
#  'Updates: <a href="./rfc854">854</a>\n',
#  'Updates: <a href="./rfc509">509</a>\n',
#  'Updates: <a href="./rfc826">826</a>                                                   July 2008\n',
#  'Updates: <a href="./rfc5228">5228</a>                                               January 2008\n',
#  'Updates: <a href="./rfc2780">2780</a>                                         Harvard University\n',
#  'Updates: <a href="./rfc4733">4733</a>                                                  T. Taylor\n',
#  'Updates: <a href="./rfc4492">4492</a>                                                 RTFM, Inc.\n',
#  'Updates: <a href="./rfc3748">3748</a>                                      Microsoft Corporation\n',
#  'Updates: <a href="./rfc3463">3463</a>, <a href="./rfc4468">4468</a>, <a href="./rfc4954">4954</a>                                      June 2008\n',
#  'Updates: <a href="./rfc2193">2193</a>                                              Isode Limited\n',
#  'Updates: <a href="./rfc4306">4306</a>                                                  D. McGrew\n',
#  'Updates: <a href="./rfc5247">5247</a>                                                 L. Dondeti\n',
#  'Updates: <a href="./rfc1195">1195</a>\n',
#  'Updates: <a href="./rfc1195">1195</a>                                     Extreme Networks, Inc.\n',
#  'Updates: <a href="./rfc5305">5305</a>                                               October 2008\n',
#  'Updates: <a href="./rfc1123">1123</a>\n',
#  'Updates: <a href="./rfc4021">4021</a>\n',
#  'Updates: <a href="./rfc3032">3032</a>, <a href="./rfc4023">4023</a>                                          R. Aggarwal\n',
#  'Updates: <a href="./rfc2045">2045</a>, <a href="./rfc2822">2822</a>                                       September 2008\n',
#  'Updates: <a href="./rfc2821">2821</a>, <a href="./rfc2822">2822</a>, <a href="./rfc4952">4952</a>                                          CNNIC\n',
#  'Updates: <a href="./rfc3461">3461</a>, <a href="./rfc3464">3464</a>, <a href="./rfc3798">3798</a>                               A. Melnikov, Ed.\n',
#  'Updates: <a href="./rfc3966">3966</a>                                                 V. Gurbani\n',
#  'Updates: <a href="./rfc2153">2153</a>\n',
#  'Updates: <a href="./rfc3411">3411</a>                                             September 2008\n',
#  'Updates: <a href="./rfc4342">4342</a>                                  University College London\n',
#  'Updates: <a href="./rfc2113">2113</a>, <a href="./rfc3175">3175</a>                                          A. McDonald\n',
#  'Updates: <a href="./rfc3265">3265</a>                                                 A.B. Roach\n',
#  'Updates: <a href="./rfc2026">2026</a>                                              November 2008\n',
#  'Updates: RFC <a href="./rfc522">522</a>\n',
#  'Updates: <a href="./rfc3261">3261</a>                                                S. Lawrence\n',
#  'Updates: <a href="./rfc1183">1183</a>, <a href="./rfc3597">3597</a>\n',
#  'Updates: <a href="./rfc2203">2203</a>                                              February 2009\n',
#  'Updates: <a href="./rfc3209">3209</a>, <a href="./rfc3473">3473</a>                                              Alcatel\n',
#  'Updates: <a href="./rfc5228">5228</a>\n',
#  'Updates: <a href="./rfc3834">3834</a>                                                  M. Haardt\n',
#  'Updates: <a href="./rfc4187">4187</a>                                                   Ericsson\n',
#  'Updates: <a href="./rfc2181">2181</a>                                                R. van Mook\n',
#  'Updates: <a href="./rfc4749">4749</a>                                               January 2009\n',
#  'Updates: <a href="./rfc3032">3032</a>, <a href="./rfc3270">3270</a>, <a href="./rfc3272">3272</a>, <a href="./rfc3443">3443</a>, <a href="./rfc3469">3469</a>,                          R. Asati\n',
#  'Updates: <a href="./rfc5267">5267</a>                                                    C. King\n',
#  'Updates: <a href="./rfc3279">3279</a>                                                   D. Brown\n',
#  'Updates: <a href="./rfc4119">4119</a>                                         Andrew Corporation\n',
#  'Updates: <a href="./rfc826">826</a>, <a href="./rfc951">951</a>, <a href="./rfc1044">1044</a>, <a href="./rfc1329">1329</a>, <a href="./rfc2131">2131</a>,                        C. Pignataro\n',
#  'Updates: <a href="./rfc3550">3550</a>, <a href="./rfc3711">3711</a>, <a href="./rfc4585">4585</a>                                    Ericsson AB\n',
#  'Updates: <a href="./rfc5545">5545</a>\n',
#  'Updates: <a href="./rfc4469">4469</a>, <a href="./rfc4467">4467</a>                                         S. Maes, Ed.\n',
#  'Updates: <a href="./rfc2743">2743</a>                                                   May 2009\n',
#  'Updates: <a href="./rfc538">538</a>                                              13 August 1973\n',
#  'Updates: <a href="./rfc5036">5036</a>                                        Cisco Systems, Inc.\n',
#  'Updates: <a href="./rfc4880">4880</a>\n',
#  'Updates: <a href="./rfc3032">3032</a>, <a href="./rfc4385">4385</a>, <a href="./rfc5085">5085</a>                                 Alcatel-Lucent\n',
#  'Updates: <a href="./rfc3411">3411</a>, <a href="./rfc3412">3412</a>, <a href="./rfc3414">3414</a>, <a href="./rfc3417">3417</a>                         J. Schoenwaelder\n',
#  'Updates: <a href="./rfc5092">5092</a>                                                  June 2009\n',
#  'Updates: <a href="./rfc4340">4340</a>                                             September 2009\n',
#  'Updates: <a href="./rfc4340">4340</a>                                             September 2009\n',
#  'Updates: <a href="./rfc5357">5357</a>                                                 K. Hedayat\n',
#  'Updates: RFC <a href="./rfc495">495</a>\n',
#  'Updates: <a href="./rfc3204">3204</a>, <a href="./rfc3261">3261</a>, <a href="./rfc3459">3459</a>                                 September 2009\n',
#  'Updates: <a href="./rfc3261">3261</a>, <a href="./rfc3327">3327</a>                                         R. Mahy, Ed.\n',
#  'Updates: <a href="./rfc3261">3261</a>, <a href="./rfc3608">3608</a>                                         October 2009\n',
#  'Updates: <a href="./rfc3777">3777</a>\n',
#  'Updates: <a href="./rfc3931">3931</a>, <a href="./rfc4349">4349</a>, <a href="./rfc4454">4454</a>, <a href="./rfc4591">4591</a>, <a href="./rfc4719">4719</a>                      Cisco Systems\n',
#  'Updates: <a href="./rfc2026">2026</a>                                                    Tekelec\n',
#  'Updates: RFC <a href="./rfc556">556</a>\n',
#  'Updates: <a href="./rfc1833">1833</a>                                               January 2010\n',
#  'Updates: <a href="./rfc4871">4871</a>                                                August 2009\n',
#  'Updates: <a href="./rfc3777">3777</a>\n',
#  'Updates: <a href="./rfc4138">4138</a>                                                    M. Kojo\n',
#  'Updates: <a href="./rfc4791">4791</a>, <a href="./rfc4918">4918</a>                                       September 2009\n',
#  'Updates: <a href="./rfc3640">3640</a>                                                  S. Doehla\n',
#  'Updates: <a href="./rfc2328">2328</a>                                                  V. Manral\n',
#  'Updates: <a href="./rfc3209">3209</a>                                        Cisco Systems, Inc.\n',
#  'Updates: <a href="./rfc3588">3588</a>                                              H. Tschofenig\n',
#  'Updates: 1939" header should be added.\n',
#  'Updates: <a href="./rfc2460">2460</a>                                              December 2009\n',
#  'Updates: <a href="./rfc3265">3265</a>, <a href="./rfc3969">3969</a>                                            R. Sparks\n',
#  'Updates: <a href="./rfc3588">3588</a>                                                   M. Jones\n',
#  'Updates: <a href="./rfc1166">1166</a>                                                  M. Cotton\n',
#  'Updates: <a href="./rfc3501">3501</a>                                                  C. Newman\n',
#  'Updates: <a href="./rfc2223">2223</a>, <a href="./rfc4844">4844</a>                                          For the IAB\n',
#  'Updates: <a href="./rfc2026">2026</a>, <a href="./rfc3710">3710</a>                                        December 2009\n',
#  'Updates: <a href="./rfc4846">4846</a>                                                 J. Halpern\n',
#  'Updates: <a href="./rfc4846">4846</a>                                              December 2009\n',
#  'Updates: <a href="./rfc5246">5246</a>, <a href="./rfc4366">4366</a>, <a href="./rfc4347">4347</a>, <a href="./rfc4346">4346</a>, <a href="./rfc2246">2246</a>                             M. Ray\n',
#  'Updates: <a href="./rfc3370">3370</a>                                               January 2010\n',
#  'Updates: <a href="./rfc4055">4055</a>                                                   D. Brown\n',
#  'Updates: <a href="./rfc3279">3279</a>                                               S. Santesson\n',
#  'Updates: <a href="./rfc3550">3550</a>, <a href="./rfc3551">3551</a>                                        M. Westerlund\n',
#  'Updates: <a href="./rfc2780">2780</a>                                                   D. Meyer\n',
#  'Updates: <a href="./rfc4776">4776</a>                                                 March 2010\n',
#  'Updates: <a href="./rfc2616">2616</a>, <a href="./rfc2818">2818</a>                                           April 2010\n',
#  'Updates: <a href="./rfc3630">3630</a>                                           Juniper Networks\n',
#  'Updates: <a href="./rfc566">566</a>\n',
#  'Updates: <a href="./rfc4601">4601</a>                                                   S. Islam\n',
#  'Updates: <a href="./rfc959">959</a>                                                   A. Hoenes\n',
#  'Updates: <a href="./rfc3161">3161</a>                                                    N. Pope\n',
#  'Updates: RFC #579\n',
#  'Updates: <a href="./rfc1183">1183</a>                                                 April 2010\n',
#  'Updates: <a href="./rfc4542">4542</a>, <a href="./rfc4594">4594</a>                                        Cisco Systems\n',
#  'Updates: <a href="./rfc2460">2460</a>                                                 S. Bradner\n',
#  'Updates: <a href="./rfc5191">5191</a>                                                   A. Yegin\n',
#  'Updates: <a href="./rfc3325">3325</a>                                                 April 2010\n',
#  'Updates: <a href="./rfc5246">5246</a>                                                 R. Housley\n',
#  'Updates: <a href="./rfc1122">1122</a>                                           Juniper Networks\n',
#  'Updates: <a href="./rfc3492">3492</a>\n',
#  'Updates: <a href="./rfc4120">4120</a>                                                 S. Hartman\n',
#  'Updates: <a href="./rfc3261">3261</a>                                                S. Lawrence\n',
#  'Updates: <a href="./rfc1034">1034</a>, <a href="./rfc1035">1035</a>                                       A. Hoenes, Ed.\n',
#  'Updates: <a href="./rfc5357">5357</a>                                                   M. Chiba\n',
#  'Updates: <a href="./rfc4861">4861</a>                                        Cisco Systems, Inc.\n',
#  'Updates: <a href="./rfc2205">2205</a>                                                  J. Manner\n',
#  'Updates: <a href="./rfc4291">4291</a>                                               M. Kawashima\n',
#  'Updates: <a href="./rfc3261">3261</a>                                          B. Carpenter, Ed.\n',
#  'Updates: <a href="./rfc5544">5544</a>                                                August 2010\n',
#  'Updates: <a href="./rfc5256">5256</a>                                                  July 2010\n',
#  'Updates: <a href="./rfc1035">1035</a>, <a href="./rfc1123">1123</a>                                          August 2010\n',
#  'Updates: <a href="./rfc2986">2986</a>                                                August 2010\n',
#  'Updates: <a href="./rfc4287">4287</a>\n',
#  'Updates: <a href="./rfc4380">4380</a>                                                S. Krishnan\n',
#  'Updates: <a href="./rfc2866">2866</a>                                                August 2010\n',
#  'Updates: <a href="./rfc5996">5996</a>                                              H. Tschofenig\n',
#  'Updates: <a href="./rfc4202">4202</a>, <a href="./rfc4203">4203</a>, <a href="./rfc4206">4206</a>, <a href="./rfc4874">4874</a>, <a href="./rfc4974">4974</a>, <a href="./rfc5307">5307</a>               Alcatel-Lucent\n',
#  'Updates: <a href="./rfc3471">3471</a>, <a href="./rfc3473">3473</a>, <a href="./rfc3945">3945</a>, <a href="./rfc4202">4202</a>, <a href="./rfc4203">4203</a>, <a href="./rfc5307">5307</a>                     D. Fedyk\n',
#  'Updates: <a href="./rfc3471">3471</a>, <a href="./rfc3473">3473</a>                                         October 2010\n',
#  'Updates: RFC # 586\n',
#  'Updates: <a href="./rfc4033">4033</a>, <a href="./rfc4034">4034</a>, <a href="./rfc4035">4035</a>                                  November 2010\n',
#  'Updates: <a href="./rfc3261">3261</a>                                           T. Zourzouvillys\n',
#  'Updates: <a href="./rfc5357">5357</a>                                                  AT&amp;T Labs\n',
#  'Updates: <a href="./rfc3168">3168</a>, <a href="./rfc4301">4301</a>, <a href="./rfc4774">4774</a>                                  November 2010\n',
#  'Updates: <a href="./rfc2980">2980</a>, <a href="./rfc3977">3977</a>\n',
#  'Updates: <a href="./rfc3550">3550</a>                                                 T. Schierl\n',
#  'Updates: <a href="./rfc4291">4291</a>                                                 C. Huitema\n',
# ...
#  'Updates: <a href="./rfc6514">6514</a>                                                   T. Morin\n',
#  'Updates: <a href="./rfc5246">5246</a>, <a href="./rfc6347">6347</a>                                         Google, Inc.\n',
#  'Updates: <a href="./rfc2622">2622</a>, <a href="./rfc4012">4012</a>                                          B. Haberman\n',
#  'Updates: <a href="./rfc7315">7315</a>                                                  June 2016\n',
#  'Updates: <a href="./rfc2246">2246</a>, <a href="./rfc4346">4346</a>, <a href="./rfc4492">4492</a>, <a href="./rfc5246">5246</a>                              August 2016\n',
#  'Updates:  RFCs <a href="./rfc777">777</a>, <a href="./rfc760">760</a>\n',
#  'Updates: <a href="./rfc6613">6613</a>                                                August 2016\n',
#  'Updates: <a href="./rfc7530">7530</a>                                                  P. Shivam\n',
#  'Updates: <a href="./rfc6455">6455</a>\n',
#  'Updates: <a href="./rfc5838">5838</a>                                                  A. Lindem\n',
#  'Updates: <a href="./rfc6110">6110</a>                                                August 2016\n',
#  'Updates: <a href="./rfc4791">4791</a>, <a href="./rfc5545">5545</a>, <a href="./rfc6638">6638</a>                                    M. Douglass\n',
#  'Updates: <a href="./rfc5727">5727</a>                                                      Cisco\n',
#  'Updates: <a href="./rfc7252">7252</a>                                             Z. Shelby, Ed.\n',
#  'Updates: <a href="./rfc7315">7315</a>                                                   Ericsson\n',
#  'Updates: <a href="./rfc4975">4975</a>, <a href="./rfc4976">4976</a>                                                 Xura\n',
#  'Updates: <a href="./rfc7178">7178</a>                                                   M. Umair\n',
#  'Updates: <a href="./rfc5764">5764</a>                                               G. Salgueiro\n',
#  'Updates: <a href="./rfc3263">3263</a>                                               G. Salgueiro\n',
#  'Updates: <a href="./rfc7186">7186</a>                                        Ecole Polytechnique\n',
#  'Updates: <a href="./rfc5545">5545</a>                                               October 2016\n',
#  'Updates: <a href="./rfc6513">6513</a>, <a href="./rfc6514">6514</a>                                       K. Subramanian\n',
#  'Updates: <a href="./rfc7322">7322</a>                                              December 2016\n',
#  'Updates: <a href="./rfc7401">7401</a>                                     University of Helsinki\n',
#  'Updates: <a href="./rfc6790">6790</a>                                                 G. Swallow\n',
#  'Updates: <a href="./rfc1034">1034</a>, <a href="./rfc2308">2308</a>                                             S. Huque\n',
#  'Updates: <a href="./rfc4944">4944</a>                                                  R. Cragie\n',
#  'Updates: <a href="./rfc4861">4861</a>                                               B. Carpenter\n',
#  'Updates: <a href="./rfc1122">1122</a>                                          C. Pignataro, Ed.\n',
#  'Updates: <a href="./rfc5761">5761</a>                                              November 2016\n',
#  'Updates: <a href="./rfc2328">2328</a>                                     Juniper Networks, Inc.\n',
#  'Updates: <a href="./rfc2865">2865</a>, <a href="./rfc3162">3162</a>, <a href="./rfc4072">4072</a>, <a href="./rfc6158">6158</a>, <a href="./rfc6572">6572</a>, <a href="./rfc7268">7268</a>                 January 2017\n',
#  'Updates: <a href="./rfc4120">4120</a>, <a href="./rfc4121">4121</a>, <a href="./rfc4556">4556</a>                                     S. Hartman\n',
#  'Updates: <a href="./rfc2464">2464</a>, <a href="./rfc2467">2467</a>, <a href="./rfc2470">2470</a>, <a href="./rfc2491">2491</a>, <a href="./rfc2492">2492</a>,                         A. Cooper\n',
#  'Updates: <a href="./rfc4944">4944</a>, <a href="./rfc6282">6282</a>                                        G. Montenegro\n',
#  'Updates: <a href="./rfc3967">3967</a>\n',
#  'Updates: <a href="./rfc7344">7344</a>                                                 P. Wouters\n',
#  'Updates: <a href="./rfc5104">5104</a>                                                Vidyo, Inc.\n',
#  'Updates: <a href="./rfc3550">3550</a>                                                   V. Singh\n',
#  'Updates: <a href="./rfc2736">2736</a>                                                   May 2017\n',
#  'Updates: <a href="./rfc1738">1738</a>                                              February 2017\n',
#  'Updates: <a href="./rfc2046">2046</a>, <a href="./rfc3461">3461</a>                                        February 2017\n',
#  'Updates: <a href="./rfc3550">3550</a>, <a href="./rfc4585">4585</a>                                        M. Westerlund\n',
#  'Updates: <a href="./rfc6830">6830</a>                                                     Orange\n',
#  'Updates: <a href="./rfc4458">4458</a>                                                  M. Barnes\n',
#  'Updates: <a href="./rfc4120">4120</a>                                                  N. Kinder\n',
#  'Updates: <a href="./rfc6325">6325</a>, <a href="./rfc7177">7177</a>                                             M. Umair\n',
#  'Updates: <a href="./rfc4642">4642</a>\n',
#  'Updates: <a href="./rfc7240">7240</a>                                                 April 2017\n',
#  'Updates: <a href="./rfc5931">5931</a>                                                 April 2017\n',
#  'Updates: <a href="./rfc5766">5766</a>                                                      Cisco\n',
#  'Updates: <a href="./rfc2119">2119</a>\n',
#  'Updates: <a href="./rfc5661">5661</a>, <a href="./rfc7862">7862</a>                                            July 2017\n',
#  'Updates: <a href="./rfc2026">2026</a>                                                   May 2017\n',
#  'Updates: <a href="./rfc6890">6890</a>                                                        PTI\n',
#  'Updates: <a href="./rfc4035">4035</a>                                                    A. Kato\n',
#  'Updates: <a href="./rfc4486">4486</a>                                                   J. Heitz\n',
#  'Updates: <a href="./rfc8205">8205</a>                                                  S. Murphy\n',
#  'Updates: <a href="./rfc7935">7935</a>                                                O. Borchert\n',
#  'Updates: <a href="./rfc6487">6487</a>                                                  S. Turner\n',
#  'Updates: <a href="./rfc6810">6810</a>                                                 R. Austein\n',
#  'Updates: <a href="./rfc4271">4271</a>                                                J. Snijders\n',
#  'Updates: <a href="./rfc3261">3261</a>, <a href="./rfc3325">3325</a>, <a href="./rfc3515">3515</a>, <a href="./rfc3892">3892</a>, <a href="./rfc4508">4508</a>,                       August 2017\n',
#  'Updates: <a href="./rfc7473">7473</a>                                           Juniper Networks\n',
#  'Updates: <a href="./rfc7271">7271</a>                                                       ETRI\n',
#  'Updates: Courgette", September 2016,\n',
#  'Updates: <a href="./rfc5444">5444</a>                                                C. Dearlove\n',
#  'Updates: <a href="./rfc7296">7296</a>\n',
#  'Updates: <a href="./rfc6325">6325</a>, <a href="./rfc7177">7177</a>, <a href="./rfc7780">7780</a>                                D. Eastlake 3rd\n',
#  'Updates: <a href="./rfc6716">6716</a>                                                     K. Vos\n',
#  'Updates: <a href="./rfc6749">6749</a>                                              Ping Identity\n',
#  'Updates: <a href="./rfc5440">5440</a>                                             Telefonica I+D\n',
#  'Updates: <a href="./rfc5368">5368</a>, <a href="./rfc5621">5621</a>, <a href="./rfc6442">6442</a>                                       Ericsson\n',
#  'Updates: <a href="./rfc4250">4250</a>, <a href="./rfc4253">4253</a>                                        December 2017\n',
#  'Updates: <a href="./rfc4419">4419</a>                                                 M. Baushke\n',
#  'Updates: <a href="./rfc4090">4090</a>                                             R. Gandhi, Ed.\n',
#  'Updates: <a href="./rfc6376">6376</a>                                               January 2018\n',
#  'Updates: <a href="./rfc6455">6455</a>                                               January 2018\n',
#  'Updates: <a href="./rfc4251">4251</a>, <a href="./rfc4252">4252</a>, <a href="./rfc4253">4253</a>, <a href="./rfc4254">4254</a>                               March 2018\n',
#  'Updates: <a href="./rfc7858">7858</a>                                                 D. Gillmor\n',
#  'Updates: <a href="./rfc3168">3168</a>, <a href="./rfc4341">4341</a>, <a href="./rfc4342">4342</a>, <a href="./rfc5622">5622</a>, <a href="./rfc6679">6679</a>                       January 2018\n',
#  'Updates: <a href="./rfc1939">1939</a>, <a href="./rfc2595">2595</a>, <a href="./rfc3501">3501</a>, <a href="./rfc5068">5068</a>, <a href="./rfc6186">6186</a>, <a href="./rfc6409">6409</a>                    C. Newman\n',
#  'Updates: <a href="./rfc5537">5537</a>                                              February 2018\n',
#  'Updates: <a href="./rfc7385">7385</a>                                                      Cisco\n',
#  'Updates: <a href="./rfc7437">7437</a>\n',
#  'Updates: <a href="./rfc4861">4861</a>                                                J. Korhonen\n',
#  'Updates: <a href="./rfc7641">7641</a>, <a href="./rfc7959">7959</a>                                             S. Lemay\n',
#  'Updates: <a href="./rfc4252">4252</a>, <a href="./rfc4253">4253</a>                                           March 2018\n',
#  'Updates: <a href="./rfc4884">4884</a>                                           Juniper Networks\n',
#  'Updates: <a href="./rfc7385">7385</a>                                          S. Sivabalan, Ed.\n',
#  'Updates: <a href="./rfc7950">7950</a>                                           J. Schoenwaelder\n',
#  'Updates: <a href="./rfc5440">5440</a>                                                    D. King\n',
#  'Updates: <a href="./rfc5485">5485</a>                                                 March 2018\n',
#  'Updates: <a href="./rfc3471">3471</a>, <a href="./rfc3473">3473</a>, <a href="./rfc6205">6205</a>                                 V. Beeram, Ed.\n',
#  'Updates: <a href="./rfc6325">6325</a>                                        Huawei Technologies\n',
#  'Updates: <a href="./rfc5340">5340</a>, <a href="./rfc5838">5838</a>                                        Cisco Systems\n',
#  'Updates: <a href="./rfc7788">7788</a>                                                   T. Lemon\n',
#  'Updates: <a href="./rfc6325">6325</a>, <a href="./rfc7177">7177</a>                                               Huawei\n',
#  'Updates: <a href="./rfc4874">4874</a>                                            G. Swallow, Ed.\n',
#  'Updates: <a href="./rfc4761">4761</a>                                                 S. Boutros\n',
#  'Updates: <a href="./rfc5280">5280</a>                                             W. Chuang, Ed.\n',
#  'Updates: <a href="./rfc5280">5280</a>                                                   May 2018\n',
#  'Updates: <a href="./rfc4861">4861</a>                                                  July 2018\n',
#  'Updates: <a href="./rfc3961">3961</a>, <a href="./rfc4120">4120</a>                                Microsoft Corporation\n',
#  'Updates: <a href="./rfc5661">5661</a>                                                August 2018\n',
#  'Updates: <a href="./rfc2474">2474</a>                                                August 2018\n',
#  'Updates: <a href="./rfc3501">3501</a>                                                August 2018\n',
#  'Updates: <a href="./rfc6455">6455</a>                                             September 2018\n',
#  'Updates: <a href="./rfc5705">5705</a>, <a href="./rfc6066">6066</a>\n',
#  'Updates: <a href="./rfc3749">3749</a>, <a href="./rfc5077">5077</a>, <a href="./rfc4680">4680</a>, <a href="./rfc5246">5246</a>, <a href="./rfc5705">5705</a>,                         S. Turner\n',
#  'Updates: <a href="./rfc6066">6066</a>                                                August 2018\n',
#  'Updates: <a href="./rfc6376">6376</a>                                             September 2018\n',
#  'Updates: <a href="./rfc2330">2330</a>                                                  J. Fabini\n',
#  'Updates: <a href="./rfc4448">4448</a>                                                     Huawei\n',
#  'Updates: <a href="./rfc3501">3501</a>                                             September 2018\n',
#  'Updates: <a href="./rfc6811">6811</a>                                             September 2018\n',
#  'Updates: <a href="./rfc1034">1034</a>, <a href="./rfc1035">1035</a>                                       O. Gudmundsson\n',
#  'Updates: <a href="./rfc7845">7845</a>                                                 M. Graczyk\n',
#  'Updates: <a href="./rfc1035">1035</a>, <a href="./rfc7766">7766</a>                                          S. Cheshire\n',
#  'Updates: <a href="./rfc5502">5502</a>                                              February 2019\n',
#  'Updates: <a href="./rfc2308">2308</a>                                                K. Fujiwara\n',
#  'Updates: <a href="./rfc6775">6775</a>                                                E. Nordmark\n',
#  'Updates: <a href="./rfc5286">5286</a>                                           U. Chunduri, Ed.\n',
#  'Updates: <a href="./rfc7484">7484</a>                                                       ARIN\n',
#  'Updates: <a href="./rfc6241">6241</a>, <a href="./rfc7950">7950</a>                                     J. Schoenwaelder\n',
#  'Updates: <a href="./rfc8040">8040</a>                                           J. Schoenwaelder\n',
#  'Updates: <a href="./rfc6514">6514</a>, <a href="./rfc6625">6625</a>, <a href="./rfc7524">7524</a>, <a href="./rfc7582">7582</a>, <a href="./rfc7900">7900</a>                              Nokia\n',
#  'Updates: <a href="./rfc4090">4090</a>, <a href="./rfc7551">7551</a>                                              H. Shah\n',
#  'Updates: <a href="./rfc4724">4724</a>                                                R. Fernando\n',
#  'Updates: <a href="./rfc7598">7598</a>                                                     Q. Sun\n',
#  'Updates: <a href="./rfc4656">4656</a>, <a href="./rfc5357">5357</a>                                       G. Mirsky, Ed.\n',
#  'Updates: <a href="./rfc2782">2782</a>, <a href="./rfc3263">3263</a>, <a href="./rfc3529">3529</a>, <a href="./rfc3620">3620</a>, <a href="./rfc3832">3832</a>,\n',
#  'Updates: <a href="./rfc5176">5176</a>, <a href="./rfc5580">5580</a>                                          J. Korhonen\n',
#  'Updates: <a href="./rfc5880">5880</a>                                                    D. Ward\n',
#  'Updates: <a href="./rfc7175">7175</a>, <a href="./rfc7177">7177</a>                                        S. Pallagatti\n',
#  'Updates: <a href="./rfc5905">5905</a>                                          Boston University\n',
#  'Updates: <a href="./rfc5230">5230</a>, <a href="./rfc5435">5435</a>                                             FastMail\n',
#  'Updates: <a href="./rfc7683">7683</a>                                                August 2019\n',
#  'Updates: <a href="./rfc7432">7432</a>                                            S. Mohanty, Ed.\n',
#  'Updates: <a href="./rfc7530">7530</a>                                                  D. Noveck\n',
#  'Updates: <a href="./rfc3261">3261</a>, <a href="./rfc3428">3428</a>, <a href="./rfc4975">4975</a>                                     R. Housley\n',
#  'Updates: <a href="./rfc3219">3219</a>                                                  T. Hardie\n',
#  ...]

# %%
from dataset.regexes import NUMBERS_PATTERN

for entry in tqdm(pattern_contents['updates_pattern'], desc="Processing stuff", unit="file"):
    pattern = NUMBERS_PATTERN
    correct_entry = entry.split('    ')[0]
    match = re.findall(pattern, correct_entry, re.DOTALL)
    print(f'{entry, correct_entry, match}\n\n')
# Out:
# Processing stuff: 100%|██████████| 1170/1170 [00:00<00:00, 97514.82file/s]
# ('Updates: RFC <a href="./rfc732">732</a>                                           February 1988\n', 'Updates: RFC <a href="./rfc732">732</a>', ['732'])
#
#
# ('Updates: RFCs <a href="./rfc1034">1034</a>, <a href="./rfc1035">1035</a>                                      April 1989\n', 'Updates: RFCs <a href="./rfc1034">1034</a>, <a href="./rfc1035">1035</a>', ['1034', '1035'])
#
#
# ('Updates:  RFC <a href="./rfc976">976</a>                                          December 1989\n', 'Updates:  RFC <a href="./rfc976">976</a>', ['976'])
#
#
# ('Updates: RFCs <a href="./rfc822">822</a>, <a href="./rfc987">987</a>, <a href="./rfc1026">1026</a>                               December 1989\n', 'Updates: RFCs <a href="./rfc822">822</a>, <a href="./rfc987">987</a>, <a href="./rfc1026">1026</a>', ['822', '987', '1026'])
#
#
# ('Updates: RFCs <a href="./rfc822">822</a>, <a href="./rfc987">987</a>, <a href="./rfc1026">1026</a>, <a href="./rfc1138">1138</a>                            March 1990\n', 'Updates: RFCs <a href="./rfc822">822</a>, <a href="./rfc987">987</a>, <a href="./rfc1026">1026</a>, <a href="./rfc1138">1138</a>', ['822', '987', '1026', '1138'])
#
#
# ('Updates: RFC <a href="./rfc908">908</a>                                              R. Hinden\n', 'Updates: RFC <a href="./rfc908">908</a>', ['908'])
#
#
# ('Updates: <a href="./rfc99">99</a>\n', 'Updates: <a href="./rfc99">99</a>\n', ['99'])
#
#
# ('Updates: RFCs <a href="./rfc1034">1034</a>, <a href="./rfc1035">1035</a>                                      L. Mamakos\n', 'Updates: RFCs <a href="./rfc1034">1034</a>, <a href="./rfc1035">1035</a>', ['1034', '1035'])
#
#
# ('Updates: RFC <a href="./rfc907">907</a>                                              April 1991\n', 'Updates: RFC <a href="./rfc907">907</a>', ['907'])
#
#
# ('Updates: RFCs <a href="./rfc98">98</a>, <a href="./rfc101">101</a>\n', 'Updates: RFCs <a href="./rfc98">98</a>, <a href="./rfc101">101</a>\n', ['98', '101'])
#
#
# ('Updates: RFCs <a href="./rfc1229">1229</a>, <a href="./rfc1230">1230</a>, <a href="./rfc1231">1231</a>, <a href="./rfc1232">1232</a>, <a href="./rfc1233">1233</a>                    June 1991\n', 'Updates: RFCs <a href="./rfc1229">1229</a>, <a href="./rfc1230">1230</a>, <a href="./rfc1231">1231</a>, <a href="./rfc1232">1232</a>, <a href="./rfc1233">1233</a>', ['1229', '1230', '1231', '1232', '1233'])
#
#
# ('Updates: none\n', 'Updates: none\n', [])
#
#
# ('Updates: RFC <a href="./rfc1115">1115</a>                                             April 1992\n', 'Updates: RFC <a href="./rfc1115">1115</a>', ['1115'])
#
#
# ('Updates: RFC <a href="./rfc822">822</a>\n', 'Updates: RFC <a href="./rfc822">822</a>\n', ['822'])
#
#
# ('Updates: RFCs <a href="./rfc1034">1034</a>, <a href="./rfc1035">1035</a>                                       July 1992\n', 'Updates: RFCs <a href="./rfc1034">1034</a>, <a href="./rfc1035">1035</a>', ['1034', '1035'])
#
#
# ('Updates: RFCs <a href="./rfc1248">1248</a>, <a href="./rfc1247">1247</a>, <a href="./rfc1195">1195</a>,                                July 1992\n', 'Updates: RFCs <a href="./rfc1248">1248</a>, <a href="./rfc1247">1247</a>, <a href="./rfc1195">1195</a>,', ['1248', '1247', '1195'])
#
#
# ('Updates: <a href="./rfc110">110</a>\n', 'Updates: <a href="./rfc110">110</a>\n', ['110'])
#
#
# ('Updates: RFC <a href="./rfc1058">1058</a>                                           January 1993\n', 'Updates: RFC <a href="./rfc1058">1058</a>', ['1058'])
#
#
# ('Updates: <a href="./rfc951">951</a>\n', 'Updates: <a href="./rfc951">951</a>\n', ['951'])
#
#
# ('Updates: none\n', 'Updates: none\n', [])
#
#
# ('Updates:  <a href="./rfc123">123</a>, <a href="./rfc145">145</a>                                            3 May 1971\n', 'Updates:  <a href="./rfc123">123</a>, <a href="./rfc145">145</a>', ['123', '145'])
#
#
# ('Updates: <a href="./rfc123">123</a>\n', 'Updates: <a href="./rfc123">123</a>\n', ['123'])
#
#
# ('Updates: none\n', 'Updates: none\n', [])
#
#
# ('Updates:  #140\n', 'Updates:  #140\n', ['140'])
#
#
# ('Updates: <a href="./rfc1327">1327</a>                                                   S. Kille\n', 'Updates: <a href="./rfc1327">1327</a>', ['1327'])
#
#
# ('Updates: <a href="./rfc1328">1328</a>                                               J. Romaguera\n', 'Updates: <a href="./rfc1328">1328</a>', ['1328'])
#
#
# ('Updates: <a href="./rfc951">951</a>\n', 'Updates: <a href="./rfc951">951</a>\n', ['951'])
#
#
# ('Updates: <a href="./rfc1285">1285</a>                                SNMP Research, Incorporated\n', 'Updates: <a href="./rfc1285">1285</a>', ['1285'])
#
#
# ('Updates: <a href="./rfc1271">1271</a>                                             September 1993\n', 'Updates: <a href="./rfc1271">1271</a>', ['1271'])
#
#
# ('Updates: None\n', 'Updates: None\n', [])
#
#
# ('Updates: <a href="./rfc951">951</a>                                                October 1993\n', 'Updates: <a href="./rfc951">951</a>', ['951'])
#
#
# ('Updates: #107\n', 'Updates: #107\n', ['107'])
#
#
# ('Updates: <a href="./rfc951">951</a>                                                October 1993\n', 'Updates: <a href="./rfc951">951</a>', ['951'])
#
#
# ('Updates: None\n', 'Updates: None\n', [])
#
#
# ('Updates: <a href="./rfc1548">1548</a>                                               January 1994\n', 'Updates: <a href="./rfc1548">1548</a>', ['1548'])
#
#
# ('Updates: <a href="./rfc1408">1408</a>                                               January 1994\n', 'Updates: <a href="./rfc1408">1408</a>', ['1408'])
#
#
# ('Updates: <a href="./rfc1521">1521</a>                                                 March 1994\n', 'Updates: <a href="./rfc1521">1521</a>', ['1521'])
#
#
# ('Updates: None\n', 'Updates: None\n', [])
#
#
# ('Updates: <a href="./rfc1141">1141</a>                                                   May 1994\n', 'Updates: <a href="./rfc1141">1141</a>', ['1141'])
#
#
# ('Updates:  None\n', 'Updates:  None\n', [])
#
#
# ('Updates: updates to existing information on NIR Tools may be sent by\n', 'Updates: updates to existing information on NIR Tools may be sent by\n', [])
#
#
# ('Updates: None\n', 'Updates: None\n', [])
#
#
# ('Updates: <a href="./rfc114">114</a>                                               Will Crowther\n', 'Updates: <a href="./rfc114">114</a>', ['114'])
#
#
# ('Updates: <a href="./rfc904">RFC-904</a>, pp. 16\n', 'Updates: <a href="./rfc904">RFC-904</a>, pp. 16\n', ['904', '16'])
#
#
# ('Updates: <a href="./rfc114">114</a>                                    Eric Harslem, Rand\n', 'Updates: <a href="./rfc114">114</a>', ['114'])
#
#
# ('Updates: <a href="./rfc1058">1058</a>\n', 'Updates: <a href="./rfc1058">1058</a>\n', ['1058'])
#
#
# ('Updates:     None\n', 'Updates:', [])
#
#
# ('Updates: <a href="./rfc1748">1748</a>                                                  E. Decker\n', 'Updates: <a href="./rfc1748">1748</a>', ['1748'])
#
#
# ('Updates: <a href="./rfc125">125</a>\n', 'Updates: <a href="./rfc125">125</a>\n', ['125'])
#
#
# ('Updates: <a href="./rfc1350">1350</a>                                                  A. Harkin\n', 'Updates: <a href="./rfc1350">1350</a>', ['1350'])
#
#
# ('Updates: <a href="./rfc1350">1350</a>                                                  A. Harkin\n', 'Updates: <a href="./rfc1350">1350</a>', ['1350'])
#
#
# ('Updates: <a href="./rfc1350">1350</a>                                                  A. Harkin\n', 'Updates: <a href="./rfc1350">1350</a>', ['1350'])
#
#
# ('Updates: <a href="./rfc1350">1350</a>                                                  A. Harkin\n', 'Updates: <a href="./rfc1350">1350</a>', ['1350'])
#
#
# ('Updates:  <a href="./rfc107">107</a>\n', 'Updates:  <a href="./rfc107">107</a>\n', ['107'])
#
#
# ('Updates: none\n', 'Updates: none\n', [])
#
#
# ('Updates: <a href="./rfc904">RFC-904</a>, page 16\n', 'Updates: <a href="./rfc904">RFC-904</a>, page 16\n', ['904', '16'])
#
#
# ('Updates: <a href="./rfc1602">1602</a>, <a href="./rfc1603">1603</a>                                        November 1995\n', 'Updates: <a href="./rfc1602">1602</a>, <a href="./rfc1603">1603</a>', ['1602', '1603'])
#
#
# ('Updates: <a href="./rfc1034">1034</a>, <a href="./rfc1035">1035</a>                                             P. Vixie\n', 'Updates: <a href="./rfc1034">1034</a>, <a href="./rfc1035">1035</a>', ['1034', '1035'])
#
#
# ('Updates: None\n', 'Updates: None\n', [])
#
#
# ('Updates: <a href="./rfc1939">1939</a>                                                  June 1996\n', 'Updates: <a href="./rfc1939">1939</a>', ['1939'])
#
#
# ('Updates: none\n', 'Updates: none\n', [])
#
#
# ('Updates:  None\n', 'Updates:  None\n', [])
#
#
# ('Updates:  RFC #193\n', 'Updates:  RFC #193\n', ['193'])
#
#
# ('Updates: <a href="./rfc1034">1034</a>, <a href="./rfc1035">1035</a>                                              R. Bush\n', 'Updates: <a href="./rfc1034">1034</a>, <a href="./rfc1035">1035</a>', ['1034', '1035'])
#
#
# ('Updates: <a href="./rfc1035">1035</a>                                                August 1996\n', 'Updates: <a href="./rfc1035">1035</a>', ['1035'])
#
#
# ('Updates: <a href="./rfc1035">1035</a>                                                August 1996\n', 'Updates: <a href="./rfc1035">1035</a>', ['1035'])
#
#
# ('Updates: <a href="./rfc1213">1213</a>                                              November 1996\n', 'Updates: <a href="./rfc1213">1213</a>', ['1213'])
#
#
# ('Updates: <a href="./rfc1213">1213</a>                                              November 1996\n', 'Updates: <a href="./rfc1213">1213</a>', ['1213'])
#
#
# ('Updates: <a href="./rfc1213">1213</a>                                              November 1996\n', 'Updates: <a href="./rfc1213">1213</a>', ['1213'])
#
#
# ('Updates: <a href="./rfc1035">1035</a>, <a href="./rfc1183">1183</a>                                             P. Vixie\n', 'Updates: <a href="./rfc1035">1035</a>, <a href="./rfc1183">1183</a>', ['1035', '1183'])
#
#
# ('Updates: <a href="./rfc1034">1034</a>, <a href="./rfc1035">1035</a>                                           C. Kaufman\n', 'Updates: <a href="./rfc1034">1034</a>, <a href="./rfc1035">1035</a>', ['1034', '1035'])
#
#
# ('Updates:       [<a href="#ref-21" title="&quot;son-of-RFC1036&quot;">21</a>], non-standard\n', 'Updates:', [])
#
#
# ('Updates: none\n', 'Updates: none\n', [])
#
#
# ('Updates: <a href="./rfc207">207</a>\n', 'Updates: <a href="./rfc207">207</a>\n', ['207'])
#
#
# ('Updates:  None\n', 'Updates:  None\n', [])
#
#
# ('Updates: <a href="./rfc1035">1035</a>                                                S. Thomson\n', 'Updates: <a href="./rfc1035">1035</a>', ['1035'])
#
#
# ('Updates: <a href="./rfc1035">1035</a>                                                 April 1997\n', 'Updates: <a href="./rfc1035">1035</a>', ['1035'])
#
#
# ('Updates: <a href="./rfc1883">1883</a>                                                   May 1997\n', 'Updates: <a href="./rfc1883">1883</a>', ['1883'])
#
#
# ('Updates: none\n', 'Updates: none\n', [])
#
#
# ('Updates: RFCs <a href="./rfc1661">1661</a>, <a href="./rfc1962">1962</a>                                        May 1997\n', 'Updates: RFCs <a href="./rfc1661">1661</a>, <a href="./rfc1962">1962</a>', ['1661', '1962'])
#
#
# ('Updates: <a href="./rfc822">822</a>\n', 'Updates: <a href="./rfc822">822</a>\n', ['822'])
#
#
# ('Updates:  RFC <a href="./rfc105">105</a>, <a href="./rfc122">RFC 122</a>               Univ. of California\n', 'Updates:  RFC <a href="./rfc105">105</a>, <a href="./rfc122">RFC 122</a>', ['105', '122'])
#
#
# ('Updates:  none\n', 'Updates:  none\n', [])
#
#
# ('Updates: <a href="./rfc1034">1034</a>, <a href="./rfc1035">1035</a>, <a href="./rfc1123">1123</a>                                        R. Bush\n', 'Updates: <a href="./rfc1034">1034</a>, <a href="./rfc1035">1035</a>, <a href="./rfc1123">1123</a>', ['1034', '1035', '1123'])
#
#
# ('Updates: <a href="./rfc1806">1806</a>                                                  S. Dorner\n', 'Updates: <a href="./rfc1806">1806</a>', ['1806'])
#
#
# ('Updates: <a href="./rfc2045">2045</a>, <a href="./rfc2047">2047</a>, <a href="./rfc2183">2183</a>                                     K. Moore\n', 'Updates: <a href="./rfc2045">2045</a>, <a href="./rfc2047">2047</a>, <a href="./rfc2183">2183</a>', ['2045', '2047', '2183'])
#
#
# ('Updates: None\n', 'Updates: None\n', [])
#
#
# ('Updates: <a href="./rfc959">959</a>                                                     S. Lunt\n', 'Updates: <a href="./rfc959">959</a>', ['959'])
#
#
# ('Updates: <a href="./rfc2045">2045</a>, <a href="./rfc2047">2047</a>, <a href="./rfc2183">2183</a>                                     K. Moore\n', 'Updates: <a href="./rfc2045">2045</a>, <a href="./rfc2047">2047</a>, <a href="./rfc2183">2183</a>', ['2045', '2047', '2183'])
#
#
# ('Updates: <a href="./rfc1112">1112</a>                                                November 1997\n', 'Updates: <a href="./rfc1112">1112</a>', ['1112'])
#
#
# ('Updates:  none\n', 'Updates:  none\n', [])
#
#
# ('Updates:  RFC #74\n', 'Updates:  RFC #74\n', ['74'])
#
#
# ('Updates: RFC <a href="./rfc113">113</a>\n', 'Updates: RFC <a href="./rfc113">113</a>\n', ['113'])
#
#
# ('Updates:  RFC #70\n', 'Updates:  RFC #70\n', ['70'])
#
#
# ('Updates: <a href="./rfc2002">2002</a>                                                   S. Glass\n', 'Updates: <a href="./rfc2002">2002</a>', ['2002'])
#
#
# ('Updates: <a href="./rfc1987">1987</a>                                            R. Hinden, Nokia\n', 'Updates: <a href="./rfc1987">1987</a>', ['1987'])
#
#
# ('Updates: <a href="./rfc1034">1034</a>, <a href="./rfc1035">1035</a>                                            March 1998\n', 'Updates: <a href="./rfc1034">1034</a>, <a href="./rfc1035">1035</a>', ['1034', '1035'])
#
#
# ('Updates: #204, #212, #222\n', 'Updates: #204, #212, #222\n', ['204', '212', '222'])
#
#
# ('Updates: <a href="./rfc1350">1350</a>                                                  A. Harkin\n', 'Updates: <a href="./rfc1350">1350</a>', ['1350'])
#
#
# ('Updates: <a href="./rfc1350">1350</a>                                                  A. Harkin\n', 'Updates: <a href="./rfc1350">1350</a>', ['1350'])
#
#
# ('Updates: <a href="./rfc1350">1350</a>                                                  A. Harkin\n', 'Updates: <a href="./rfc1350">1350</a>', ['1350'])
#
#
# ('Updates: None\n', 'Updates: None\n', [])
#
#
# ('Updates: <a href="./rfc1738">1738</a>, <a href="./rfc1808">1808</a>                                        L. Masinter\n', 'Updates: <a href="./rfc1738">1738</a>, <a href="./rfc1808">1808</a>', ['1738', '1808'])
#
#
# ('Updates: RFC #171, RFC #172\n', 'Updates: RFC #171, RFC #172\n', ['171', '172'])
#
#
# ('Updates: <a href="./rfc1808">1808</a>, <a href="./rfc1738">1738</a>                                          R. Fielding\n', 'Updates: <a href="./rfc1808">1808</a>, <a href="./rfc1738">1738</a>', ['1808', '1738'])
#
#
# ('Updates:  none\n', 'Updates:  none\n', [])
#
#
# ('Updates: none\n', 'Updates: none\n', [])
#
#
# ('Updates: <a href="./rfc2222">2222</a>                                               October 1998\n', 'Updates: <a href="./rfc2222">2222</a>', ['2222'])
#
#
# ('Updates: <a href="./rfc1939">1939</a>                                                  C. Newman\n', 'Updates: <a href="./rfc1939">1939</a>', ['1939'])
#
#
# ('Updates: <a href="./rfc2284">2284</a>, <a href="./rfc1994">1994</a>, <a href="./rfc1570">1570</a>\n', 'Updates: <a href="./rfc2284">2284</a>, <a href="./rfc1994">1994</a>, <a href="./rfc1570">1570</a>\n', ['2284', '1994', '1570'])
#
#
# ('Updates:  None\n', 'Updates:  None\n', [])
#
#
# ('Updates:  None\n', 'Updates:  None\n', [])
#
#
# ('Updates: <a href="./rfc2181">2181</a>, <a href="./rfc1035">1035</a>, <a href="./rfc1034">1034</a>\n', 'Updates: <a href="./rfc2181">2181</a>, <a href="./rfc1035">1035</a>, <a href="./rfc1034">1034</a>\n', ['2181', '1035', '1034'])
#
#
# ('Updates: <a href="./rfc1149">1149</a>                                           1 April 1999\n', 'Updates: <a href="./rfc1149">1149</a>', ['1149'])
#
#
# ('Updates: <a href="./rfc252">252</a>                                            October 26, 1971\n', 'Updates: <a href="./rfc252">252</a>', ['252'])
#
#
# ('Updates: <a href="./rfc1778">1778</a>                                               T. Howes\n', 'Updates: <a href="./rfc1778">1778</a>', ['1778'])
#
#
# ('Updates:  None\n', 'Updates:  None\n', [])
#
#
# ('Updates: <a href="./rfc2165">2165</a>                                          Sun Microsystems\n', 'Updates: <a href="./rfc2165">2165</a>', ['2165'])
#
#
# ('Updates: <a href="./rfc2165">2165</a>                                                  J. Kempf\n', 'Updates: <a href="./rfc2165">2165</a>', ['2165'])
#
#
# ('Updates: 1806                                                  S\n', 'Updates: 1806', ['1806'])
#
#
# ('Updates:  none\n', 'Updates:  none\n', [])
#
#
# ('Updates: <a href="./rfc959">959</a>                                                   July 1999\n', 'Updates: <a href="./rfc959">959</a>', ['959'])
#
#
# ('Updates: <a href="./rfc1812">1812</a>                                                August 1999\n', 'Updates: <a href="./rfc1812">1812</a>', ['1812'])
#
#
# ('Updates: <a href="./rfc2046">2046</a>                                                August 1999\n', 'Updates: <a href="./rfc2046">2046</a>', ['2046'])
#
#
# ('Updates:  RFC <a href="./rfc255">255</a>\n', 'Updates:  RFC <a href="./rfc255">255</a>\n', ['255'])
#
#
# ('Updates: RFC #266\n', 'Updates: RFC #266\n', ['266'])
#
#
# ('Updates:  <a href="./rfc122">122</a>, <a href="./rfc238">238</a>, <a href="./rfc172">172</a>\n', 'Updates:  <a href="./rfc122">122</a>, <a href="./rfc238">238</a>, <a href="./rfc172">172</a>\n', ['122', '238', '172'])
#
#
# ('Updates:  None\n', 'Updates:  None\n', [])
#
#
# ('Updates: <a href="./rfc2533">2533</a>                                            December 1999\n', 'Updates: <a href="./rfc2533">2533</a>', ['2533'])
#
#
# ('Updates: <a href="./rfc2205">2205</a>                                                January 2000\n', 'Updates: <a href="./rfc2205">2205</a>', ['2205'])
#
#
# ('Updates: <a href="./rfc959">959</a>                                                     SPYRUS\n', 'Updates: <a href="./rfc959">959</a>', ['959'])
#
#
# ('Updates: <a href="./rfc2290">2290</a>                                                  C. Perkins\n', 'Updates: <a href="./rfc2290">2290</a>', ['2290'])
#
#
# ('Updates: <a href="./rfc1966">1966</a>                                                 R. Chandra\n', 'Updates: <a href="./rfc1966">1966</a>', ['1966'])
#
#
# ('Updates: <a href="./rfc1459">1459</a>\n', 'Updates: <a href="./rfc1459">1459</a>\n', ['1459'])
#
#
# ('Updates: <a href="./rfc1459">1459</a>\n', 'Updates: <a href="./rfc1459">1459</a>\n', ['1459'])
#
#
# ('Updates: <a href="./rfc1459">1459</a>\n', 'Updates: <a href="./rfc1459">1459</a>\n', ['1459'])
#
#
# ('Updates: <a href="./rfc1459">1459</a>\n', 'Updates: <a href="./rfc1459">1459</a>\n', ['1459'])
#
#
# ('Updates: <a href="./rfc2616">2616</a>                                                S. Lawrence\n', 'Updates: <a href="./rfc2616">2616</a>', ['2616'])
#
#
# ('Updates: <a href="./rfc1123">1123</a>\n', 'Updates: <a href="./rfc1123">1123</a>\n', ['1123'])
#
#
# ('Updates: <a href="./rfc1035">1035</a>                                                     NAI Labs\n', 'Updates: <a href="./rfc1035">1035</a>', ['1035'])
#
#
# ('Updates:        None\n', 'Updates:', [])
#
#
# ('Updates: <a href="./rfc1894">1894</a>                                                   June 2000\n', 'Updates: <a href="./rfc1894">1894</a>', ['1894'])
#
#
# ('Updates: None\n', 'Updates: None\n', [])
#
#
# ('Updates: <a href="./rfc2866">2866</a>                                      Microsoft Corporation\n', 'Updates: <a href="./rfc2866">2866</a>', ['2866'])
#
#
# ('Updates: RFC <a href="./rfc2865">2865</a>                                              D. Leifer\n', 'Updates: RFC <a href="./rfc2865">2865</a>', ['2865'])
#
#
# ('Updates: RFC #267\n', 'Updates: RFC #267\n', ['267'])
#
#
# ('Updates: <a href="./rfc1205">1205</a>                                            IBM Corporation\n', 'Updates: <a href="./rfc1205">1205</a>', ['1205'])
#
#
# ('Updates: <a href="./rfc287">287</a>\n', 'Updates: <a href="./rfc287">287</a>\n', ['287'])
#
#
# ('Updates: RFC <a href="./rfc243">243</a>                                        January 11, 1972\n', 'Updates: RFC <a href="./rfc243">243</a>', ['243'])
#
#
# ('Updates: <a href="./rfc2168">2168</a>                                                   R. Daniel\n', 'Updates: <a href="./rfc2168">2168</a>', ['2168'])
#
#
# ('Updates: None                                     Dave Liddle, Owens Ill.\n', 'Updates: None', [])
#
#
# ('Updates:  RFC <a href="./rfc288">288</a>\n', 'Updates:  RFC <a href="./rfc288">288</a>\n', ['288'])
#
#
# ('Updates: <a href="./rfc2535">2535</a>                                             September 2000\n', 'Updates: <a href="./rfc2535">2535</a>', ['2535'])
#
#
# ('Updates: <a href="./rfc2533">2533</a>                                                 L. Masinter\n', 'Updates: <a href="./rfc2533">2533</a>', ['2533'])
#
#
# ('Updates: RFC <a href="./rfc265">265</a>\n', 'Updates: RFC <a href="./rfc265">265</a>\n', ['265'])
#
#
# ('Updates: none\n', 'Updates: none\n', [])
#
#
# ('Updates: <a href="./rfc2535">2535</a>, <a href="./rfc2136">2136</a>                                        November 2000\n', 'Updates: <a href="./rfc2535">2535</a>, <a href="./rfc2136">2136</a>', ['2535', '2136'])
#
#
# ('Updates: <a href="./rfc2535">2535</a>                                              November 2000\n', 'Updates: <a href="./rfc2535">2535</a>', ['2535'])
#
#
# ('Updates:  None\n', 'Updates:  None\n', [])
#
#
# ('Updates: <a href="./rfc2048">2048</a>                                               simonstl.com\n', 'Updates: <a href="./rfc2048">2048</a>', ['2048'])
#
#
# ('Updates:   none\n', 'Updates:   none\n', [])
#
#
# ('Updates: <a href="./rfc2118">2118</a>                                              cisco Systems\n', 'Updates: <a href="./rfc2118">2118</a>', ['2118'])
#
#
# ('Updates: <a href="./rfc2747">2747</a>                                                   L. Zhang\n', 'Updates: <a href="./rfc2747">2747</a>', ['2747'])
#
#
# ('Updates: <a href="./rfc1858">1858</a>                                                  June 2001\n', 'Updates: <a href="./rfc1858">1858</a>', ['1858'])
#
#
# ('Updates: <a href="./rfc306">306</a>\n', 'Updates: <a href="./rfc306">306</a>\n', ['306'])
#
#
# ('Updates: <a href="./rfc2874">2874</a>, <a href="./rfc2772">2772</a>, <a href="./rfc2766">2766</a>, <a href="./rfc2553">2553</a>, <a href="./rfc1886">1886</a>\n', 'Updates: <a href="./rfc2874">2874</a>, <a href="./rfc2772">2772</a>, <a href="./rfc2766">2766</a>, <a href="./rfc2553">2553</a>, <a href="./rfc1886">1886</a>\n', ['2874', '2772', '2766', '2553', '1886'])
#
#
# ('Updates: <a href="./rfc2015">2015</a>                                               D. Del Torto\n', 'Updates: <a href="./rfc2015">2015</a>', ['2015'])
#
#
# ('Updates: <a href="./rfc2474">2474</a>, <a href="./rfc2401">2401</a>, <a href="./rfc793">793</a>                                        S. Floyd\n', 'Updates: <a href="./rfc2474">2474</a>, <a href="./rfc2401">2401</a>, <a href="./rfc793">793</a>', ['2474', '2401', '793'])
#
#
# ('Updates: RFC <a href="./rfc315">315</a>\n', 'Updates: RFC <a href="./rfc315">315</a>\n', ['315'])
#
#
# ('Updates: <a href="./rfc2846">2846</a>\n', 'Updates: <a href="./rfc2846">2846</a>\n', ['2846'])
#
#
# ('Updates: <a href="./rfc2846">2846</a>\n', 'Updates: <a href="./rfc2846">2846</a>\n', ['2846'])
#
#
# ('Updates: <a href="./rfc1715">1715</a>                                                 C. Huitema\n', 'Updates: <a href="./rfc1715">1715</a>', ['1715'])
#
#
# ('Updates: <a href="./rfc2608">2608</a>                                               January 2002\n', 'Updates: <a href="./rfc2608">2608</a>', ['2608'])
#
#
# ('Updates: <a href="./rfc2874">2874</a>, <a href="./rfc2535">2535</a>\n', 'Updates: <a href="./rfc2874">2874</a>, <a href="./rfc2535">2535</a>\n', ['2874', '2535'])
#
#
# ('Updates: <a href="./rfc1332">1332</a>                                                 April 2002\n', 'Updates: <a href="./rfc1332">1332</a>', ['1332'])
#
#
# ('Updates:  RFC #319\n', 'Updates:  RFC #319\n', ['319'])
#
#
# ('Updates: <a href="./rfc2474">2474</a>, <a href="./rfc2475">2475</a>, <a href="./rfc2597">2597</a>                                     April 2002\n', 'Updates: <a href="./rfc2474">2474</a>, <a href="./rfc2475">2475</a>, <a href="./rfc2597">2597</a>', ['2474', '2475', '2597'])
#
#
# ('Updates: <a href="./rfc2543">2543</a>                                                  June 2002\n', 'Updates: <a href="./rfc2543">2543</a>', ['2543'])
#
#
# ('Updates: <a href="./rfc2327">2327</a>                                               G. Camarillo\n', 'Updates: <a href="./rfc2327">2327</a>', ['2327'])
#
#
# ('Updates:  RFC #326\n', 'Updates:  RFC #326\n', ['326'])
#
#
# ('Updates: <a href="./rfc2960">2960</a>                                                 R. Stewart\n', 'Updates: <a href="./rfc2960">2960</a>', ['2960'])
#
#
# ('Updates:  RFC #330\n', 'Updates:  RFC #330\n', ['330'])
#
#
# ('Updates: none                                                    BBN/IMP\n', 'Updates: none', [])
#
#
# ('Updates: <a href="./rfc2673">2673</a>, <a href="./rfc2874">2874</a>                                              B. Fink\n', 'Updates: <a href="./rfc2673">2673</a>, <a href="./rfc2874">2874</a>', ['2673', '2874'])
#
#
# ('Updates: <a href="./rfc2673">2673</a>, <a href="./rfc2874">2874</a>                                          August 2002\n', 'Updates: <a href="./rfc2673">2673</a>, <a href="./rfc2874">2874</a>', ['2673', '2874'])
#
#
# ('Updates: <a href="./rfc2910">2910</a>, <a href="./rfc2911">2911</a>                                           R. Herriot\n', 'Updates: <a href="./rfc2910">2910</a>, <a href="./rfc2911">2911</a>', ['2910', '2911'])
#
#
# ('Updates: <a href="./rfc2910">2910</a>                                                   H. Lewis\n', 'Updates: <a href="./rfc2910">2910</a>', ['2910'])
#
#
# ('Updates: <a href="./rfc2910">2910</a>, <a href="./rfc2911">2911</a>                                           R. Herriot\n', 'Updates: <a href="./rfc2910">2910</a>, <a href="./rfc2911">2911</a>', ['2910', '2911'])
#
#
# ('Updates: <a href="./rfc2581">2581</a>                                                       ICIR\n', 'Updates: <a href="./rfc2581">2581</a>', ['2581'])
#
#
# ('Updates: <a href="./rfc2895">2895</a>                                        Cisco Systems, Inc.\n', 'Updates: <a href="./rfc2895">2895</a>', ['2895'])
#
#
# ('Updates: <a href="./rfc2131">2131</a>                                                S. Cheshire\n', 'Updates: <a href="./rfc2131">2131</a>', ['2131'])
#
#
# ('Updates: <a href="./rfc2276">2276</a>                                               October 2002\n', 'Updates: <a href="./rfc2276">2276</a>', ['2276'])
#
#
# ('Updates:  RFC #332\n', 'Updates:  RFC #332\n', ['332'])
#
#
# ('Updates: <a href="./rfc1035">1035</a>                                              November 2002\n', 'Updates: <a href="./rfc1035">1035</a>', ['1035'])
#
#
# ('Updates: <a href="./rfc1958">1958</a>                                              December 2002\n', 'Updates: <a href="./rfc1958">1958</a>', ['1958'])
#
#
# ('Updates:  RFC #342\n', 'Updates:  RFC #342\n', ['342'])
#
#
# ('Updates: <a href="./rfc2132">2132</a>                                                S. Cheshire\n', 'Updates: <a href="./rfc2132">2132</a>', ['2132'])
#
#
# ('Updates: <a href="./rfc3032">3032</a>                                                   B. Akyol\n', 'Updates: <a href="./rfc3032">3032</a>', ['3032'])
#
#
# ('Updates: <a href="./rfc2535">2535</a>                                                    S. Rose\n', 'Updates: <a href="./rfc2535">2535</a>', ['2535'])
#
#
# ('Updates: <a href="./rfc3204">3204</a>                                               January 2003\n', 'Updates: <a href="./rfc3204">3204</a>', ['3204'])
#
#
# ('Updates: <a href="./rfc3060">3060</a>                                               January 2003\n', 'Updates: <a href="./rfc3060">3060</a>', ['3060'])
#
#
# ('Updates: <a href="./rfc2910">2910</a>                                            High North Inc.\n', 'Updates: <a href="./rfc2910">2910</a>', ['2910'])
#
#
# ('Updates: RFC #344\n', 'Updates: RFC #344\n', ['344'])
#
#
# ('Updates: <a href="./rfc2246">2246</a>                                                 M. Nystrom\n', 'Updates: <a href="./rfc2246">2246</a>', ['2246'])
#
#
# ('Updates:\nObsoletes:\n', 'Updates:\nObsoletes:\n', [])
#
#
# ('Updates: <a href="./rfc2865">2865</a>                                                  July 2003\n', 'Updates: <a href="./rfc2865">2865</a>', ['2865'])
#
#
# ('Updates: <a href="./rfc2869">2869</a>                                                 P. Calhoun\n', 'Updates: <a href="./rfc2869">2869</a>', ['2869'])
#
#
# ('Updates: <a href="./rfc2710">2710</a>                                             September 2003\n', 'Updates: <a href="./rfc2710">2710</a>', ['2710'])
#
#
# ('Updates:  RFC #353\n', 'Updates:  RFC #353\n', ['353'])
#
#
# ('Updates: <a href="./rfc3555">3555</a>                                                   Qualcomm\n', 'Updates: <a href="./rfc3555">3555</a>', ['3555'])
#
#
# ('Updates: <a href="./rfc2370">2370</a>                                           Juniper Networks\n', 'Updates: <a href="./rfc2370">2370</a>', ['2370'])
#
#
# ('Updates: <a href="./rfc2832">2832</a>                                           S. Yalamanchilli\n', 'Updates: <a href="./rfc2832">2832</a>', ['2832'])
#
#
# ('Updates: <a href="./rfc2845">2845</a>                                                  J. Gilroy\n', 'Updates: <a href="./rfc2845">2845</a>', ['2845'])
#
#
# ('Updates:\nObsoletes:\n', 'Updates:\nObsoletes:\n', [])
#
#
# ('Updates: <a href="./rfc2535">2535</a>                                              November 2003\n', 'Updates: <a href="./rfc2535">2535</a>', ['2535'])
#
#
# ('Updates: <a href="./rfc3090">3090</a>, <a href="./rfc3008">3008</a>, <a href="./rfc2535">2535</a>, <a href="./rfc1035">1035</a>\n', 'Updates: <a href="./rfc3090">3090</a>, <a href="./rfc3008">3008</a>, <a href="./rfc2535">2535</a>, <a href="./rfc1035">1035</a>\n', ['3090', '3008', '2535', '1035'])
#
#
# ('Updates: <a href="./rfc959">959</a>                                                  March 2007\n', 'Updates: <a href="./rfc959">959</a>', ['959'])
#
#
# ('Updates:  RFC #362\n', 'Updates:  RFC #362\n', ['362'])
#
#
# ('Updates: <a href="./rfc2705">2705</a>                                              Cisco Systems\n', 'Updates: <a href="./rfc2705">2705</a>', ['2705'])
#
#
# ('Updates: <a href="./rfc3435">3435</a>                                              Cisco Systems\n', 'Updates: <a href="./rfc3435">3435</a>', ['3435'])
#
#
# ('Updates: <a href="./rfc2026">2026</a>\n', 'Updates: <a href="./rfc2026">2026</a>\n', ['2026'])
#
#
# ('Updates: <a href="./rfc2028">2028</a>, <a href="./rfc2026">2026</a>\n', 'Updates: <a href="./rfc2028">2028</a>, <a href="./rfc2026">2026</a>\n', ['2028', '2026'])
#
#
# ('Updates: <a href="./rfc2026">2026</a>                                              February 2004\n', 'Updates: <a href="./rfc2026">2026</a>', ['2026'])
#
#
# ('Updates: <a href="./rfc366">366</a>\n', 'Updates: <a href="./rfc366">366</a>\n', ['366'])
#
#
# ('Updates:\n\n                              COMMENTS ON\n', 'Updates:\n\n', [])
#
#
# ('Updates: <a href="./rfc2434">2434</a>\n', 'Updates: <a href="./rfc2434">2434</a>\n', ['2434'])
#
#
# ('Updates: <a href="./rfc2798">2798</a>                                              February 2004\n', 'Updates: <a href="./rfc2798">2798</a>', ['2798'])
#
#
# ('Updates:  RFC #367\n', 'Updates:  RFC #367\n', ['367'])
#
#
# ('Updates: <a href="./rfc2827">2827</a>                                                  P. Savola\n', 'Updates: <a href="./rfc2827">2827</a>', ['2827'])
#
#
# ('Updates: <a href="./rfc3658">3658</a>, <a href="./rfc2535">2535</a>                                             May 2004\n', 'Updates: <a href="./rfc3658">3658</a>, <a href="./rfc2535">2535</a>', ['3658', '2535'])
#
#
# ('Updates: <a href="./rfc3755">3755</a>, <a href="./rfc2535">2535</a>                                          J. Schlyter\n', 'Updates: <a href="./rfc3755">3755</a>, <a href="./rfc2535">2535</a>', ['3755', '2535'])
#
#
# ('Updates: <a href="./rfc3095">3095</a>                                                 April 2004\n', 'Updates: <a href="./rfc3095">3095</a>', ['3095'])
#
#
# ('Updates:  RFC #370\n', 'Updates:  RFC #370\n', ['370'])
#
#
# ('Updates: <a href="./rfc2251">2251</a>                                                K. Zeilenga\n', 'Updates: <a href="./rfc2251">2251</a>', ['2251'])
#
#
# ('Updates: <a href="./rfc3461">3461</a>, <a href="./rfc2046">2046</a>                                  Lucent Technologies\n', 'Updates: <a href="./rfc3461">3461</a>, <a href="./rfc2046">2046</a>', ['3461', '2046'])
#
#
# ('Updates: <a href="./rfc3057">3057</a>                                                     S. Rao\n', 'Updates: <a href="./rfc3057">3057</a>', ['3057'])
#
#
# ('Updates: <a href="./rfc2710">2710</a>                                                       LIP6\n', 'Updates: <a href="./rfc2710">2710</a>', ['2710'])
#
#
# ('Updates: <a href="./rfc3755">3755</a>, <a href="./rfc2535">2535</a>\n', 'Updates: <a href="./rfc3755">3755</a>, <a href="./rfc2535">2535</a>\n', ['3755', '2535'])
#
#
# ('Updates: RFC <a href="./rfc354">354</a>                                  August 18, 1972\n', 'Updates: RFC <a href="./rfc354">354</a>', ['354'])
#
#
# ('Updates: <a href="./rfc3261">3261</a>                                                  July 2004\n', 'Updates: <a href="./rfc3261">3261</a>', ['3261'])
#
#
# ('Updates:\nObsoletes:\n', 'Updates:\nObsoletes:\n', [])
#
#
# ('Updates: <a href="./rfc1793">1793</a>                                                   A. Zinin\n', 'Updates: <a href="./rfc1793">1793</a>', ['1793'])
#
#
# ('Updates: <a href="./rfc3461">3461</a>                                                  T. Hansen\n', 'Updates: <a href="./rfc3461">3461</a>', ['3461'])
#
#
# ('Updates: <a href="./rfc3463">3463</a>                                             September 2004\n', 'Updates: <a href="./rfc3463">3463</a>', ['3463'])
#
#
# ('Updates: <a href="./rfc378">378</a> NIC: 11583\n', 'Updates: <a href="./rfc378">378</a> NIC: 11583\n', ['378'])
#
#
# ('Updates: <a href="./rfc3710">3710</a>, <a href="./rfc2026">2026</a>\n', 'Updates: <a href="./rfc3710">3710</a>, <a href="./rfc2026">2026</a>\n', ['3710', '2026'])
#
#
# ('Updates: <a href="./rfc2418">2418</a>                                               October 2004\n', 'Updates: <a href="./rfc2418">2418</a>', ['2418'])
#
#
# ('Updates: <a href="./rfc3209">3209</a>, <a href="./rfc2205">2205</a>                                              J. Lang\n', 'Updates: <a href="./rfc3209">3209</a>, <a href="./rfc2205">2205</a>', ['3209', '2205'])
#
#
# ('Updates: <a href="./rfc3458">3458</a>                                               October 2004\n', 'Updates: <a href="./rfc3458">3458</a>', ['3458'])
#
#
# ('Updates:  RFC #381\n', 'Updates:  RFC #381\n', ['381'])
#
#
# ('Updates: <a href="./rfc2132">2132</a>                                              November 2004\n', 'Updates: <a href="./rfc2132">2132</a>', ['2132'])
#
#
# ('Updates:\nObsoletes:\n', 'Updates:\nObsoletes:\n', [])
#
#
# ('Updates: <a href="./rfc3306">3306</a>                                                B. Haberman\n', 'Updates: <a href="./rfc3306">3306</a>', ['3306'])
#
#
# ('Updates:  RFC <a href="./rfc474">474</a>\n', 'Updates:  RFC <a href="./rfc474">474</a>\n', ['474'])
#
#
# ('Updates: <a href="./rfc3427">3427</a>                                              December 2004\n', 'Updates: <a href="./rfc3427">3427</a>', ['3427'])
#
#
# ('Updates: <a href="./rfc3427">3427</a>                                              December 2004\n', 'Updates: <a href="./rfc3427">3427</a>', ['3427'])
#
#
# ('Updates: <a href="./rfc2980">2980</a>\n', 'Updates: <a href="./rfc2980">2980</a>\n', ['2980'])
#
#
# ('Updates: <a href="./rfc2026">2026</a>\n', 'Updates: <a href="./rfc2026">2026</a>\n', ['2026'])
#
#
# ('Updates: <a href="./rfc2028">2028</a>, <a href="./rfc2026">2026</a>\n', 'Updates: <a href="./rfc2028">2028</a>, <a href="./rfc2026">2026</a>\n', ['2028', '2026'])
#
#
# ('Updates: <a href="./rfc3720">3720</a>                                                 R. Elliott\n', 'Updates: <a href="./rfc3720">3720</a>', ['3720'])
#
#
# ('Updates: <a href="./rfc1738">1738</a>                                               Day Software\n', 'Updates: <a href="./rfc1738">1738</a>', ['1738'])
#
#
# ('Updates:  <a href="./rfc122">122</a>                                   Sept. 26, 1972\n', 'Updates:  <a href="./rfc122">122</a>', ['122'])
#
#
# ('Updates: <a href="./rfc2911">2911</a>, <a href="./rfc2910">2910</a>                                    Xerox Corporation\n', 'Updates: <a href="./rfc2911">2911</a>, <a href="./rfc2910">2910</a>', ['2911', '2910'])
#
#
# ('Updates: <a href="./rfc2911">2911</a>                                                T. Hastings\n', 'Updates: <a href="./rfc2911">2911</a>', ['2911'])
#
#
# ('Updates: <a href="./rfc391">391</a>                                             18 October 1972\n', 'Updates: <a href="./rfc391">391</a>', ['391'])
#
#
# ('Updates: <a href="./rfc3473">3473</a>                                              February 2005\n', 'Updates: <a href="./rfc3473">3473</a>', ['3473'])
#
#
# ('Updates:  RFC #387                                    October 23, 1972\n', 'Updates:  RFC #387', ['387'])
#
#
# ('Updates: <a href="./rfc2725">2725</a>, <a href="./rfc2622">2622</a>                                             J. Damas\n', 'Updates: <a href="./rfc2725">2725</a>, <a href="./rfc2622">2622</a>', ['2725', '2622'])
#
#
# ('Updates: <a href="./rfc3312">3312</a>                                                 P. Kyzivat\n', 'Updates: <a href="./rfc3312">3312</a>', ['3312'])
#
#
# ('Updates: <a href="./rfc1034">1034</a>, <a href="./rfc1035">1035</a>, <a href="./rfc2136">2136</a>, <a href="./rfc2181">2181</a>, <a href="./rfc2308">2308</a>, <a href="./rfc3225">3225</a>,                   M. Larson\n', 'Updates: <a href="./rfc1034">1034</a>, <a href="./rfc1035">1035</a>, <a href="./rfc2136">2136</a>, <a href="./rfc2181">2181</a>, <a href="./rfc2308">2308</a>, <a href="./rfc3225">3225</a>,', ['1034', '1035', '2136', '2181', '2308', '3225'])
#
#
# ('Updates: <a href="./rfc1034">1034</a>, <a href="./rfc1035">1035</a>, <a href="./rfc2136">2136</a>, <a href="./rfc2181">2181</a>, <a href="./rfc2308">2308</a>, <a href="./rfc3225">3225</a>,                   M. Larson\n', 'Updates: <a href="./rfc1034">1034</a>, <a href="./rfc1035">1035</a>, <a href="./rfc2136">2136</a>, <a href="./rfc2181">2181</a>, <a href="./rfc2308">2308</a>, <a href="./rfc3225">3225</a>,', ['1034', '1035', '2136', '2181', '2308', '3225'])
#
#
# ('Updates: <a href="./rfc1034">1034</a>, <a href="./rfc1035">1035</a>, <a href="./rfc2136">2136</a>, <a href="./rfc2181">2181</a>, <a href="./rfc2308">2308</a>, <a href="./rfc3225">3225</a>,                   M. Larson\n', 'Updates: <a href="./rfc1034">1034</a>, <a href="./rfc1035">1035</a>, <a href="./rfc2136">2136</a>, <a href="./rfc2181">2181</a>, <a href="./rfc2308">2308</a>, <a href="./rfc3225">3225</a>,', ['1034', '1035', '2136', '2181', '2308', '3225'])
#
#
# ('Updates: <a href="./rfc3279">3279</a>                                                 B. Kaliski\n', 'Updates: <a href="./rfc3279">3279</a>', ['3279'])
#
#
# ('Updates: <a href="./rfc3703">3703</a>                                                   A. Reyes\n', 'Updates: <a href="./rfc3703">3703</a>', ['3703'])
#
#
# ('Updates: <a href="./rfc2409">2409</a>                                                   May 2005\n', 'Updates: <a href="./rfc2409">2409</a>', ['2409'])
#
#
# ('Updates: <a href="./rfc3106">3106</a>                                                  June 2005\n', 'Updates: <a href="./rfc3106">3106</a>', ['3106'])
#
#
# ('Updates: <a href="./rfc1964">1964</a>                                                  Microsoft\n', 'Updates: <a href="./rfc1964">1964</a>', ['1964'])
#
#
# ('Updates: RFC <a href="./rfc400">400</a>\n', 'Updates: RFC <a href="./rfc400">400</a>\n', ['400'])
#
#
# ('Updates: RFC <a href="./rfc354">354</a>, <a href="./rfc385">RFC 385</a>                               29 November 1972\n', 'Updates: RFC <a href="./rfc354">354</a>, <a href="./rfc385">RFC 385</a>', ['354', '385'])
#
#
# ('Updates: <a href="./rfc3032">3032</a>                                             September 2005\n', 'Updates: <a href="./rfc3032">3032</a>', ['3032'])
#
#
# ('Updates: <a href="./rfc2072">2072</a>                                                    E. Lear\n', 'Updates: <a href="./rfc2072">2072</a>', ['2072'])
#
#
# ('Updates: <a href="./rfc3471">3471</a>, <a href="./rfc3472">3472</a>, <a href="./rfc3473">3473</a>                               Juniper Networks\n', 'Updates: <a href="./rfc3471">3471</a>, <a href="./rfc3472">3472</a>, <a href="./rfc3473">3473</a>', ['3471', '3472', '3473'])
#
#
# ('Updates: <a href="./rfc3630">3630</a>                                           Juniper Networks\n', 'Updates: <a href="./rfc3630">3630</a>', ['3630'])
#
#
# ('Updates: <a href="./rfc3784">3784</a>                                           Juniper Networks\n', 'Updates: <a href="./rfc3784">3784</a>', ['3784'])
#
#
# ('Updates:  RFC #413\n', 'Updates:  RFC #413\n', ['413'])
#
#
# ('Updates: RFC #389\n', 'Updates: RFC #389\n', ['389'])
#
#
# ('Updates: <a href="./rfc2748">2748</a>                                                Intel Corp.\n', 'Updates: <a href="./rfc2748">2748</a>', ['2748'])
#
#
# ('Updates:  <a href="./rfc122">122</a>                                  Dec.  15, 1972\n', 'Updates:  <a href="./rfc122">122</a>', ['122'])
#
#
# ('Updates: <a href="./rfc2461">2461</a>                                                  D. Thaler\n', 'Updates: <a href="./rfc2461">2461</a>', ['2461'])
#
#
# ('Updates: <a href="./rfc3261">3261</a>                                               January 2006\n', 'Updates: <a href="./rfc3261">3261</a>', ['3261'])
#
#
# ('Updates: <a href="./rfc3280">3280</a>                                                 R. Housley\n', 'Updates: <a href="./rfc3280">3280</a>', ['3280'])
#
#
# ('Updates: <a href="./rfc3471">3471</a>                                               January 2006\n', 'Updates: <a href="./rfc3471">3471</a>', ['3471'])
#
#
# ('Updates: <a href="./rfc1034">1034</a>, <a href="./rfc1035">1035</a>, <a href="./rfc2181">2181</a>                                   January 2006\n', 'Updates: <a href="./rfc1034">1034</a>, <a href="./rfc1035">1035</a>, <a href="./rfc2181">2181</a>', ['1034', '1035', '2181'])
#
#
# ('Updates: <a href="./rfc2131">2131</a>, <a href="./rfc2132">2132</a>, <a href="./rfc3315">3315</a>                                 B. Sommerfield\n', 'Updates: <a href="./rfc2131">2131</a>, <a href="./rfc2132">2132</a>, <a href="./rfc3315">3315</a>', ['2131', '2132', '3315'])
#
#
# ('Updates: <a href="./rfc4346">4346</a>                                               RSA Security\n', 'Updates: <a href="./rfc4346">4346</a>', ['4346'])
#
#
# ('Updates: <a href="./rfc4071">4071</a>                                                         UO\n', 'Updates: <a href="./rfc4071">4071</a>', ['4071'])
#
#
# ('Updates: <a href="./rfc1122">1122</a>                                                 G. Swallow\n', 'Updates: <a href="./rfc1122">1122</a>', ['1122'])
#
#
# ('Updates: <a href="./rfc381">381</a>,406\n', 'Updates: <a href="./rfc381">381</a>,406\n', ['381', '406'])
#
#
# ('Updates: <a href="./rfc3209">3209</a>, <a href="./rfc3473">3473</a>                                     D. Papadimitriou\n', 'Updates: <a href="./rfc3209">3209</a>, <a href="./rfc3473">3473</a>', ['3209', '3473'])
#
#
# ('Updates: <a href="./rfc4175">4175</a>                                              February 2006\n', 'Updates: <a href="./rfc4175">4175</a>', ['4175'])
#
#
# ('Updates: <a href="./rfc4348">4348</a>\n', 'Updates: <a href="./rfc4348">4348</a>\n', ['4348'])
#
#
# ('Updates: RFC <a href="./rfc422">422</a>\n', 'Updates: RFC <a href="./rfc422">422</a>\n', ['422'])
#
#
# ('Updates: <a href="./rfc2780">2780</a>                                              Cisco Systems\n', 'Updates: <a href="./rfc2780">2780</a>', ['2780'])
#
#
# ('Updates: <a href="./rfc2088">2088</a>, <a href="./rfc2342">2342</a>, <a href="./rfc3501">3501</a>, <a href="./rfc3502">3502</a>, <a href="./rfc3516">3516</a>                           C. Daboo\n', 'Updates: <a href="./rfc2088">2088</a>, <a href="./rfc2342">2342</a>, <a href="./rfc3501">3501</a>, <a href="./rfc3502">3502</a>, <a href="./rfc3516">3516</a>', ['2088', '2342', '3501', '3502', '3516'])
#
#
# ('Updates: <a href="./rfc3501">3501</a>                                                   May 2006\n', 'Updates: <a href="./rfc3501">3501</a>', ['3501'])
#
#
# ('Updates: <a href="./rfc3463">3463</a>                                                   May 2006\n', 'Updates: <a href="./rfc3463">3463</a>', ['3463'])
#
#
# ('Updates: <a href="./rfc3501">3501</a>, <a href="./rfc3502">3502</a>                                           April 2006\n', 'Updates: <a href="./rfc3501">3501</a>, <a href="./rfc3502">3502</a>', ['3501', '3502'])
#
#
# ('Updates: <a href="./rfc434">434</a>\n', 'Updates: <a href="./rfc434">434</a>\n', ['434'])
#
#
# ('Updates: <a href="./rfc4035">4035</a>, <a href="./rfc4034">4034</a>                                             J. Ihren\n', 'Updates: <a href="./rfc4035">4035</a>, <a href="./rfc4034">4034</a>', ['4035', '4034'])
#
#
# ('Updates: <a href="./rfc3306">3306</a>                                                   H-J. Kim\n', 'Updates: <a href="./rfc3306">3306</a>', ['3306'])
#
#
# ('Updates: <a href="./rfc3279">3279</a>                                        D. Shefanovski, Ed.\n', 'Updates: <a href="./rfc3279">3279</a>', ['3279'])
#
#
# ('Updates: <a href="./rfc2205">2205</a>                                              Cisco Systems\n', 'Updates: <a href="./rfc2205">2205</a>', ['2205'])
#
#
# ('Updates: <a href="./rfc3273">3273</a>\n', 'Updates: <a href="./rfc3273">3273</a>\n', ['3273'])
#
#
# ('Updates: <a href="./rfc3698">3698</a>\n', 'Updates: <a href="./rfc3698">3698</a>\n', ['3698'])
#
#
# ('Updates: <a href="./rfc2247">2247</a>, <a href="./rfc2798">2798</a>, <a href="./rfc2377">2377</a>\n', 'Updates: <a href="./rfc2247">2247</a>, <a href="./rfc2798">2798</a>, <a href="./rfc2377">2377</a>\n', ['2247', '2798', '2377'])
#
#
# ('Updates: <a href="./rfc2247">2247</a>, <a href="./rfc2798">2798</a>\n', 'Updates: <a href="./rfc2247">2247</a>, <a href="./rfc2798">2798</a>\n', ['2247', '2798'])
#
#
# ('Updates: <a href="./rfc4120">4120</a>                                              K. Jaganathan\n', 'Updates: <a href="./rfc4120">4120</a>', ['4120'])
#
#
# ('Updates: <a href="./rfc1888">1888</a>, <a href="./rfc4048">4048</a>                                             Ericsson\n', 'Updates: <a href="./rfc1888">1888</a>, <a href="./rfc4048">4048</a>', ['1888', '4048'])
#
#
# ('Updates: <a href="./rfc3501">3501</a>                                                    S. Hole\n', 'Updates: <a href="./rfc3501">3501</a>', ['3501'])
#
#
# ('Updates: RFC <a href="./rfc453">453</a>\n', 'Updates: RFC <a href="./rfc453">453</a>\n', ['453'])
#
#
# ('Updates: <a href="./rfc4145">4145</a>                                                  July 2006\n', 'Updates: <a href="./rfc4145">4145</a>', ['4145'])
#
#
# ('Updates: <a href="./rfc4364">4364</a>                                          P. Pillay-Esnault\n', 'Updates: <a href="./rfc4364">4364</a>', ['4364'])
#
#
# ('Updates: <a href="./rfc3972">3972</a>                                                   J. Arkko\n', 'Updates: <a href="./rfc3972">3972</a>', ['3972'])
#
#
# ('Updates: <a href="./rfc1034">1034</a>, <a href="./rfc2672">2672</a>                                            July 2006\n', 'Updates: <a href="./rfc1034">1034</a>, <a href="./rfc2672">2672</a>', ['1034', '2672'])
#
#
# ('Updates: <a href="./rfc3376">3376</a>, <a href="./rfc3810">3810</a>                                              B. Cain\n', 'Updates: <a href="./rfc3376">3376</a>, <a href="./rfc3810">3810</a>', ['3376', '3810'])
#
#
# ('Updates: <a href="./rfc2595">2595</a>                                                August 2006\n', 'Updates: <a href="./rfc2595">2595</a>', ['2595'])
#
#
# ('Updates: <a href="./rfc3555">3555</a>                                    Universitaet Bremen TZI\n', 'Updates: <a href="./rfc3555">3555</a>', ['3555'])
#
#
# ...
#
#
# ('Updates: <a href="./rfc5705">5705</a>, <a href="./rfc6066">6066</a>\n', 'Updates: <a href="./rfc5705">5705</a>, <a href="./rfc6066">6066</a>\n', ['5705', '6066'])
#
#
# ('Updates: <a href="./rfc3749">3749</a>, <a href="./rfc5077">5077</a>, <a href="./rfc4680">4680</a>, <a href="./rfc5246">5246</a>, <a href="./rfc5705">5705</a>,                         S. Turner\n', 'Updates: <a href="./rfc3749">3749</a>, <a href="./rfc5077">5077</a>, <a href="./rfc4680">4680</a>, <a href="./rfc5246">5246</a>, <a href="./rfc5705">5705</a>,', ['3749', '5077', '4680', '5246', '5705'])
#
#
# ('Updates: <a href="./rfc6066">6066</a>                                                August 2018\n', 'Updates: <a href="./rfc6066">6066</a>', ['6066'])
#
#
# ('Updates: <a href="./rfc6376">6376</a>                                             September 2018\n', 'Updates: <a href="./rfc6376">6376</a>', ['6376'])
#
#
# ('Updates: <a href="./rfc2330">2330</a>                                                  J. Fabini\n', 'Updates: <a href="./rfc2330">2330</a>', ['2330'])
#
#
# ('Updates: <a href="./rfc4448">4448</a>                                                     Huawei\n', 'Updates: <a href="./rfc4448">4448</a>', ['4448'])
#
#
# ('Updates: <a href="./rfc3501">3501</a>                                             September 2018\n', 'Updates: <a href="./rfc3501">3501</a>', ['3501'])
#
#
# ('Updates: <a href="./rfc6811">6811</a>                                             September 2018\n', 'Updates: <a href="./rfc6811">6811</a>', ['6811'])
#
#
# ('Updates: <a href="./rfc1034">1034</a>, <a href="./rfc1035">1035</a>                                       O. Gudmundsson\n', 'Updates: <a href="./rfc1034">1034</a>, <a href="./rfc1035">1035</a>', ['1034', '1035'])
#
#
# ('Updates: <a href="./rfc7845">7845</a>                                                 M. Graczyk\n', 'Updates: <a href="./rfc7845">7845</a>', ['7845'])
#
#
# ('Updates: <a href="./rfc1035">1035</a>, <a href="./rfc7766">7766</a>                                          S. Cheshire\n', 'Updates: <a href="./rfc1035">1035</a>, <a href="./rfc7766">7766</a>', ['1035', '7766'])
#
#
# ('Updates: <a href="./rfc5502">5502</a>                                              February 2019\n', 'Updates: <a href="./rfc5502">5502</a>', ['5502'])
#
#
# ('Updates: <a href="./rfc2308">2308</a>                                                K. Fujiwara\n', 'Updates: <a href="./rfc2308">2308</a>', ['2308'])
#
#
# ('Updates: <a href="./rfc6775">6775</a>                                                E. Nordmark\n', 'Updates: <a href="./rfc6775">6775</a>', ['6775'])
#
#
# ('Updates: <a href="./rfc5286">5286</a>                                           U. Chunduri, Ed.\n', 'Updates: <a href="./rfc5286">5286</a>', ['5286'])
#
#
# ('Updates: <a href="./rfc7484">7484</a>                                                       ARIN\n', 'Updates: <a href="./rfc7484">7484</a>', ['7484'])
#
#
# ('Updates: <a href="./rfc6241">6241</a>, <a href="./rfc7950">7950</a>                                     J. Schoenwaelder\n', 'Updates: <a href="./rfc6241">6241</a>, <a href="./rfc7950">7950</a>', ['6241', '7950'])
#
#
# ('Updates: <a href="./rfc8040">8040</a>                                           J. Schoenwaelder\n', 'Updates: <a href="./rfc8040">8040</a>', ['8040'])
#
#
# ('Updates: <a href="./rfc6514">6514</a>, <a href="./rfc6625">6625</a>, <a href="./rfc7524">7524</a>, <a href="./rfc7582">7582</a>, <a href="./rfc7900">7900</a>                              Nokia\n', 'Updates: <a href="./rfc6514">6514</a>, <a href="./rfc6625">6625</a>, <a href="./rfc7524">7524</a>, <a href="./rfc7582">7582</a>, <a href="./rfc7900">7900</a>', ['6514', '6625', '7524', '7582', '7900'])
#
#
# ('Updates: <a href="./rfc4090">4090</a>, <a href="./rfc7551">7551</a>                                              H. Shah\n', 'Updates: <a href="./rfc4090">4090</a>, <a href="./rfc7551">7551</a>', ['4090', '7551'])
#
#
# ('Updates: <a href="./rfc4724">4724</a>                                                R. Fernando\n', 'Updates: <a href="./rfc4724">4724</a>', ['4724'])
#
#
# ('Updates: <a href="./rfc7598">7598</a>                                                     Q. Sun\n', 'Updates: <a href="./rfc7598">7598</a>', ['7598'])
#
#
# ('Updates: <a href="./rfc4656">4656</a>, <a href="./rfc5357">5357</a>                                       G. Mirsky, Ed.\n', 'Updates: <a href="./rfc4656">4656</a>, <a href="./rfc5357">5357</a>', ['4656', '5357'])
#
#
# ('Updates: <a href="./rfc2782">2782</a>, <a href="./rfc3263">3263</a>, <a href="./rfc3529">3529</a>, <a href="./rfc3620">3620</a>, <a href="./rfc3832">3832</a>,\n', 'Updates: <a href="./rfc2782">2782</a>, <a href="./rfc3263">3263</a>, <a href="./rfc3529">3529</a>, <a href="./rfc3620">3620</a>, <a href="./rfc3832">3832</a>,\n', ['2782', '3263', '3529', '3620', '3832'])
#
#
# ('Updates: <a href="./rfc5176">5176</a>, <a href="./rfc5580">5580</a>                                          J. Korhonen\n', 'Updates: <a href="./rfc5176">5176</a>, <a href="./rfc5580">5580</a>', ['5176', '5580'])
#
#
# ('Updates: <a href="./rfc5880">5880</a>                                                    D. Ward\n', 'Updates: <a href="./rfc5880">5880</a>', ['5880'])
#
#
# ('Updates: <a href="./rfc7175">7175</a>, <a href="./rfc7177">7177</a>                                        S. Pallagatti\n', 'Updates: <a href="./rfc7175">7175</a>, <a href="./rfc7177">7177</a>', ['7175', '7177'])
#
#
# ('Updates: <a href="./rfc5905">5905</a>                                          Boston University\n', 'Updates: <a href="./rfc5905">5905</a>', ['5905'])
#
#
# ('Updates: <a href="./rfc5230">5230</a>, <a href="./rfc5435">5435</a>                                             FastMail\n', 'Updates: <a href="./rfc5230">5230</a>, <a href="./rfc5435">5435</a>', ['5230', '5435'])
#
#
# ('Updates: <a href="./rfc7683">7683</a>                                                August 2019\n', 'Updates: <a href="./rfc7683">7683</a>', ['7683'])
#
#
# ('Updates: <a href="./rfc7432">7432</a>                                            S. Mohanty, Ed.\n', 'Updates: <a href="./rfc7432">7432</a>', ['7432'])
#
#
# ('Updates: <a href="./rfc7530">7530</a>                                                  D. Noveck\n', 'Updates: <a href="./rfc7530">7530</a>', ['7530'])
#
#
# ('Updates: <a href="./rfc3261">3261</a>, <a href="./rfc3428">3428</a>, <a href="./rfc4975">4975</a>                                     R. Housley\n', 'Updates: <a href="./rfc3261">3261</a>, <a href="./rfc3428">3428</a>, <a href="./rfc4975">4975</a>', ['3261', '3428', '4975'])
#
#
# ('Updates: <a href="./rfc3219">3219</a>                                                  T. Hardie\n', 'Updates: <a href="./rfc3219">3219</a>', ['3219'])
#
#
# ('Updates: <a href="./rfc3326">3326</a>                                                  June 2019\n', 'Updates: <a href="./rfc3326">3326</a>', ['3326'])
#
#
# ('Updates: <a href="./rfc7935">7935</a>                                                       NIST\n', 'Updates: <a href="./rfc7935">7935</a>', ['7935'])
#
#
# ('Updates: <a href="./rfc8029">8029</a>                                                 G. Swallow\n', 'Updates: <a href="./rfc8029">8029</a>', ['8029'])
#
#
# ('Updates: <a href="./rfc7252">7252</a>                                               F. Palombini\n', 'Updates: <a href="./rfc7252">7252</a>', ['7252'])
#
#
# ('Updates: <a href="./rfc4761">4761</a>                                           Juniper Networks\n', 'Updates: <a href="./rfc4761">4761</a>', ['4761'])
#
#
# ('Updates: <a href="./rfc7230">7230</a>, <a href="./rfc7595">7595</a>\n', 'Updates: <a href="./rfc7230">7230</a>, <a href="./rfc7595">7595</a>\n', ['7230', '7595'])
#
#
# ('Updates: <a href="./rfc6376">6376</a>, <a href="./rfc7208">7208</a>, <a href="./rfc7489">7489</a>                                      June 2019\n', 'Updates: <a href="./rfc6376">6376</a>, <a href="./rfc7208">7208</a>, <a href="./rfc7489">7489</a>', ['6376', '7208', '7489'])
#
#
# ('Updates: <a href="./rfc5788">5788</a>                                                  C. Newman\n', 'Updates: <a href="./rfc5788">5788</a>', ['5788'])
#
#
# ('Updates: <a href="./rfc4594">4594</a>, <a href="./rfc8325">8325</a>\n', 'Updates: <a href="./rfc4594">4594</a>, <a href="./rfc8325">8325</a>\n', ['4594', '8325'])
#
#
# ('Updates: <a href="./rfc4556">4556</a>                                                     L. Zhu\n', 'Updates: <a href="./rfc4556">4556</a>', ['4556'])
#
#
# ('Updates: <a href="./rfc1997">1997</a>                                                    R. Bush\n', 'Updates: <a href="./rfc1997">1997</a>', ['1997'])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:  RFC <a href="./rfc881">881</a>\n', 'Updates:  RFC <a href="./rfc881">881</a>\n', ['881'])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:  RFC <a href="./rfc897">897</a>, <a href="./rfc881">RFC 881</a>\n', 'Updates:  RFC <a href="./rfc897">897</a>, <a href="./rfc881">RFC 881</a>\n', ['897', '881'])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])
#
#
# ('Updates:</dt>\n', 'Updates:</dt>\n', [])

# %%
from collections import Counter

counter = Counter()
categories = []
for entry in tqdm(pattern_contents['category_pattern'], desc="Processing stuff", unit="file"):
    correct_entry = entry.split('    ')[0]
    categories.append(correct_entry)
    # print(f'{entry, correct_entry}\n\n')

element_counts = Counter(categories)
sorted_elements = element_counts.most_common()

# Print each element and its count on a new line
for element, count in sorted_elements:
    print(f'Element: {element} ------- Count: {count}')
# Out:
# Processing stuff: 100%|██████████| 7981/7981 [00:00<00:00, 1141197.29file/s]
# Element: Standards Track ------- Count: 3688
# Element: Informational ------- Count: 2538
# Element: </dt> ------- Count: 809
# Element: Experimental ------- Count: 471
# Element: Best Current Practice ------- Count: 283
# Element: Historic ------- Count: 26
# Element: F, G.3 ------- Count: 14
# Element: B.1 ------- Count: 10
# Element: D.6 ------- Count: 5
# Element: Standard Track ------- Count: 5
# Element: D.4, D.7 ------- Count: 4
# Element: D.4, D.5, and D.7 ------- Count: 4
# Element: A.2 ------- Count: 3
# Element: D.1 ------- Count: 3
# Element: D.7 ------- Count: 3
# Element: D.3 ------- Count: 3
# Element: Proposed Standard ------- Count: 3
# Element: Updates: ------- Count: 3
# Element: G.3 ------- Count: 2
# Element: C.4 ------- Count: 2
# Element: G.2 ------- Count: 2
# Element: D ------- Count: 2
# Element: D.4 ------- Count: 2
# Element: F ------- Count: 2
# Element: Telnet ------- Count: 2
# Element: F. G.3 ------- Count: 2
# Element: TELNET ------- Count: 2
# Element: Protocols, TELNET ------- Count: 2
# Element: Socket Numbers ------- Count: 2
# Element: Users ------- Count: 2
# Element: D - Subsystem Level Protocol, where at ------- Count: 1
# Element: of Control Functions ------- Count: 1
# Element: A.5; ------- Count: 1
# Element: identified by Peggy Karp, Categorization ------- Count: 1
# Element: B.1, C.1, C.2, C.3, C.4, C.5] ------- Count: 1
# Element: C.2, D. ------- Count: 1
# Element: C.4, C.5, C.6, D.4, D.7, D.7] ------- Count: 1
# Element: ) index (e.g., "B.3") should always be ------- Count: 1
# Element: C.1, C.2, C.3, C.5 ------- Count: 1
# Element: D.1, D.3 ------- Count: 1
# Element: C1, C3, D1, H ------- Count: 1
# Element: of packets monitored and counted include: ------- Count: 1
# Element: G.5 ------- Count: 1
# Element: C.2, C.3, D.1, D.2, D.3 ------- Count: 1
# Element: C1, C3, C8</span> ------- Count: 1
# Element: B, C, C ------- Count: 1
# Element: D.6,I.1 ------- Count: 1
# Element: C and D ------- Count: 1
# Element: C.9 ------- Count: 1
# Element: September 1969 ------- Count: 1
# Element: D.7, G.3 ------- Count: 1
# Element: I.2 ------- Count: 1
# Element: D.2, D.3 ------- Count: 1
# Element: C3,C4,C5,C6,D7 ------- Count: 1
# Element: D.6, I.1 ------- Count: 1
# Element: A.5, D.7 ------- Count: 1
# Element: C.3, D.1 ------- Count: 1
# Element: A.5, C.3, D ------- Count: 1
# Element: B.l, C.2 ------- Count: 1
# Element: C.2, D.1, D.3, G.1 ------- Count: 1
# Element: D.3, G.3 ------- Count: 1
# Element: Updates: None ------- Count: 1
# Element: B.2, C.2 ------- Count: 1
# Element: C5 ------- Count: 1
# Element: Updates: RFC #171, RFC #172 ------- Count: 1
# Element: B.1, C.1, I.1 ------- Count: 1
# Element: T ------- Count: 1
# Element: Policy, Telnet ------- Count: 1
# Element: D5, D7 ------- Count: 1
# Element: Updates:  None ------- Count: 1
# Element: Stinkards Track ------- Count: 1
# Element: Worst Current Practice ------- Count: 1
# Element: B.1, C.2, I.1 ------- Count: 1
# Element: F, G, 3 ------- Count: 1
# Element: Documentation ------- Count: 1
# Element: File Transfer ------- Count: 1
# Element: Related: 7625, 7626, 7661, 7688, 7650, 7646 ------- Count: 1
# Element: A.5, O.7 ------- Count: 1
# Element: G.1 &amp; G.2 ------- Count: 1
# Element: A.2, D.4, D.7 ------- Count: 1
# Element: C or maybe D ------- Count: 1
# Element: Informational T. Hiller, P. McCann, H. Shiino, P. Walsh, Lucent ------- Count: 1
# Element: D3, D4, D7 ------- Count: 1
# Element: of Domains "/> ------- Count: 1
# Element: RJE ------- Count: 1
# Element: Standards ------- Count: 1
# Element: C9 (experimentation) ------- Count: 1
# Element: :  Echo Plex, Satellite ------- Count: 1
# Element: Standard Processes ------- Count: 1
# Element: : Standard Processes ------- Count: 1
# Element: : Socket Numbers ------- Count: 1
# Element: D.4, D.5, D.7 ------- Count: 1
# Element: Local Echoing, Remote Echoing, Satellite ------- Count: 1
# Element: Remote Controlled Echoing, Satellite, TELNET ------- Count: 1
# Element: Protocols, RJE ------- Count: 1
# Element: Obsoletes: ------- Count: 1
# Element: Informational Samuelson Law, Technology &amp; Public Policy Clinic ------- Count: 1
# Element: August 16, 1972 ------- Count: 1
# Element: D.6, F ------- Count: 1
# Element: B-1 ------- Count: 1
# Element: BBN:hzt ------- Count: 1
# Element: TELNET, Protocols, Echoing ------- Count: 1
# Element: TELNET, Protocols ------- Count: 1
# Element: Protocols, FTP ------- Count: 1
# Element: Protocols, TELNET, RCTE ------- Count: 1
# Element: Type ------- Count: 1
# Element: 13 ------- Count: 1
# Element: Security Assertion Markup Language (SAML) Attribute Types"/> ------- Count: 1
# Element: 18 ------- Count: 1
# Element: 1 ------- Count: 1
# Element: GOV  =  Government, any government related domains meeting the ------- Count: 1
# Element: of Protocol Functions . . . . . . . . . . . . . . .  <a href="#page-25">25</a> ------- Count: 1

# %%
from dataset.regexes import ISSN_CLEAN_PATTERN
for entry in tqdm(pattern_contents['issn_pattern'], desc="Processing stuff", unit="file"):
    pattern = ISSN_CLEAN_PATTERN
    correct_entry = entry.split('    ')[0]
    match = re.findall(pattern, correct_entry, re.DOTALL)
    print(f'{entry, correct_entry, match}\n\n')
# Out:
# Processing stuff: 100%|██████████| 3744/3744 [00:00<00:00, 197066.91file/s]
# ('0894-5926),', '0894-5926),', ['0894-5926'])
#
#
# ('0894-5926),', '0894-5926),', ['0894-5926'])
#
#
# ('1055-4769)', '1055-4769)', ['1055-4769'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('1201-0758.', '1201-0758.', ['1201-0758'])
#
#
# ('for serials.', 'for serials.', [])
#
#
# ('s,', 's,', [])
#
#
# ('and SICI) can be supported within the URN framework', 'and SICI) can be supported within the URN framework', [])
#
#
# ('and SICI) can be supported within the URN framework and the', 'and SICI) can be supported within the URN framework and the', [])
#
#
# ('s are both collections of identifiers used', 's are both collections of identifiers used', [])
#
#
# ('s,', 's,', [])
#
#
# ('(International Serial Standard Number) as URN (Uniform Resource Names) within an ISSN-URN Namespace "/>', '(International Serial Standard Number) as URN (Uniform Resource Names) within an ISSN-URN Namespace "/>', [])
#
#
# ('(International', '(International', [])
#
#
# ('and SICI) as URNs.  This document', 'and SICI) as URNs.  This document', [])
#
#
# ('and SICI) as URNs.', 'and SICI) as URNs.', [])
#
#
# ('as URN within an ISSN-URN', 'as URN within an ISSN-URN', [])
#
#
# (', phone numbers).  It is conceivable', ', phone numbers).  It is conceivable', [])
#
#
# ('1611-1044, Institute for', '1611-1044, Institute for', ['1611-1044'])
#
#
# ('(International Serial Standard Number) as URN (Uniform Resource Names) within an ISSN-URN Namespace&quot;">RFC3044</a>],', '(International Serial Standard Number) as URN (Uniform Resource Names) within an ISSN-URN Namespace&quot;">RFC3044</a>],', [])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                      NTT', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                      Cisco Systems, Inc.', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                           Aruba Networks', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                Panasonic', '2070-1721', ['2070-1721'])
#
#
# ("2070-1721                                   Saint Joseph's College", '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                            February 2010', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                P. Yegani', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                              I. Oueichek', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                           Beon Solutions', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                T. Kaiser', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                secunet Security Networks', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                           D. Noveck, Ed.', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                           D. Noveck, Ed.', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                               J. Glasgow', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                  Panasas', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                    Apple', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                    Apple', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                 H. Jeong', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                           Alcatel-Lucent', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                          Yale University', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                      Columbia University', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                   D. Ros', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                              G. Sharratt', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                           Alcatel Lucent', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                         Juniper Networks', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                      Cisco Systems, Inc.', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                   Nokia Siemens Networks', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                             January 2010', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                             January 2010', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                D. Ellard', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                       Old Dog Consulting', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                             January 2010', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                         Sun Microsystems', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                   Nokia Siemens Networks', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                    Nokia', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                    Cisco', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                   Google', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                               March 2010', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                 H. Lexow', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                L. Vegoda', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                    ICANN', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                           QUALCOMM, Inc.', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                              PhoneFactor', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                    M. Xu', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                   Y. Won', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                             Y. Ohba, Ed.', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                             January 2010', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                             January 2010', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                             Soaring Hawk', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                             January 2010', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                S. Turner', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                   K. Yiu', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                 link-lab', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                              K. Moriarty', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                             January 2010', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                  University of Cambridge', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                               April 2010', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                   Nokia Siemens Networks', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                               RTFM, Inc.', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                           Telecom Italia', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                           Alcatel-Lucent', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                      NTT', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                       The Boeing Company', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                         Folly Consulting', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                      LTU', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                               April 2010', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                    INRIA', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                          M. Arumaithurai', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                             J. Bournelle', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                              Orange Labs', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                 May 2010', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                  Juniper', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                              MTI Systems', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                               March 2010', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                               March 2010', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                               March 2010', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                H. Asaeda', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                 University of California', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                            Cisco Systems', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                  Juniper', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                  D. Kwon', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                               March 2010', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                 M. Siami', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                               March 2010', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                   Oracle', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                   Oryx Mail Systems GmbH', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                    BeThereBeSquare, Inc.', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                              Orange Labs', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                  Samsung', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                     Znyx', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                          NTT Corporation', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                            Znyx Networks', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                     CATR', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                             NTT PF Labs.', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                               March 2010', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                      Cisco Systems, Inc.', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                              S. Bardalai', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                             Unaffiliated', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                               March 2010', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                       BT', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                      Huawei Technologies', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                 G. Porcu', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                    INRIA', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                     LabN', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                          J. Reschke, Ed.', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                          C. Elliott, Ed.', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                          C. Elliott, Ed.', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                           Alcatel-Lucent', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                   Huawei', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                         Juniper Networks', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                   A. Roy', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                        Softarmor Systems', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                    Microsoft Corporation', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                             1 April 2010', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                             IBM Research', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                    Cisco', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                            S. Gundavelli', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                            S. Gundavelli', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                            Cisco Systems', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                          PGP Corporation', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                  Tekelec', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                   Nokia Siemens Networks', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                 Ericsson', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                              R. Penfield', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                      Booz Allen Hamilton', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                      Booz Allen Hamilton', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                               C. Bormann', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                         Juniper Networks', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                       Old Dog Consulting', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                               Consultant', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                AT&amp;T Labs', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                            Motorola Labs', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                  Ghent University - IBCN', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                  Yokogawa Electric Corp.', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                    Nokia', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                June 2010', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                 May 2010', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                 May 2010', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                  Samsung', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                    Nokia', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                    Softarmor Systems LLC', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                 May 2010', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                       Oracle Corporation', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                June 2010', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                June 2010', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                June 2010', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                June 2010', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                       BT', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                      Cisco Systems, Inc.', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                           France Telecom', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                         Extreme Networks', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                June 2010', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                            Cisco Systems', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                        Swedish Museum of Natural History', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                           VPN Consortium', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                June 2010', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                 Ericsson', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                          The Anti-Phishing Working Group', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                July 2010', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                               J. Burbank', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                              U. Delaware', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                      Cisco Systems, Inc.', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                 Ericsson', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                  Soaring Hawk Consulting', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                  Soaring Hawk Consulting', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                       Cygnacom Solutions', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                 National Security Agency', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                 Certicom', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                         Juniper Networks', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                  E. Chen', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                            D. Frost, Ed.', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                               A. Jeffrey', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                             Unaffiliated', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                        Bell Laboratories, Alcatel-Lucent', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                R. Bonica', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                     RTFM', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                   Oracle', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                             Hangzhou H3C Tech. Co., Ltd.', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                              Network Zen', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                 S. Kanno', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                           Cryptocom Ltd.', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                 National Security Agency', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                    MITRE', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                June 2010', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                       Cygnacom Solutions', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                              August 2010', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                           Vigil Security', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                  Entrust', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                             Oracle, Inc.', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                         Aalto University', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                             A. Narayanan', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                              Acme Packet', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                      Samsung Electronics', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                R. Koodli', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                              K. Lam, Ed.', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                  E. Gray', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                              August 2010', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                             B. Tate, Ed.', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                            M. Bocci, Ed.', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                   Huawei', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                            H. Tschofenig', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                              August 2010', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                     Taughannock Networks', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                    University of Glasgow', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                              August 2010', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                V. Zimmer', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                      RMR', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                               X. Fu, Ed.', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                   Nokia Siemens Networks', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                            University of Twente/Ericsson', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                 Ericsson', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                              P. Tarapore', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                           G. Karagiannis', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                      KIT', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                   S. Lee', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                 University of Goettingen', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                      NEC', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                      Cisco Systems, Inc.', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                           September 2010', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                      EMC', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                              J. Hoagland', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                  Afilias', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                            M. Westerlund', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                            Cisco Systems', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                   Y. Nir', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                               Y. Sheffer', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                      NTT', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                             October 2010', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                           Alcatel-Lucent', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                           Alcatel-Lucent', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                       Old Dog Consulting', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                       Old Dog Consulting', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                 National Security Agency', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                        Siemens Enterprise Communications', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                 Engineering Networks Ltd', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                      Cisco Systems, Inc.', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                              G. Armitage', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                           Tail-f Systems', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                      NSN', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                       Cygnacom Solutions', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                         BBN Technologies', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                           September 2010', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                             October 2010', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                               V. Gurbani', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                 VeriSign', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                           Vigil Security', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                           Vigil Security', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                              A. Johnston', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                             Huawei Technologies Co., Ltd', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                      Cisco Systems, Inc.', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                           Alcatel-Lucent', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                            A. Doria, Ed.', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                      ZTE', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                               ETH Zurich', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                    France Telecom Orange', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                            November 2010', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                               M. Bagnulo', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                          NTT Corporation', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                            November 2010', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                              S. Cheshire', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                             January 2011', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                 J. Mills', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                 Ericsson', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                        Netstar Logicalis', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                    Ciena', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                              jdrosen.net', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                           VeriSign, Inc.', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                             January 2011', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                    Elbrys Networks, Inc.', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                   Lab126', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                              J. Zawinski', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                            December 2010', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                            February 2011', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                    Skype', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                T. Nadeau', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                               V. Radoaca', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                AT&amp;T Labs', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                       University of Oslo', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                             January 2011', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                               A. Keranen', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                CableLabs', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                M. Duerst', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                              E. Rescorla', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                             J. Crowcroft', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                    Cisco', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                H. Kaplan', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                               H. Soliman', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                             N. Montavont', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                M. Salter', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                            February 2011', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                             January 2011', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                              IP Infusion', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                   Nokia Siemens Networks', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                             January 2011', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                          Vasona Networks', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                   Netnod', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                P. Kocher', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                            Cisco Systems', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                             C. Popoviciu', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                               L. Beloeil', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                            February 2011', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                  N. Mody', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                A. Shahin', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                        Painless Security', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                               April 2011', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                               March 2011', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                              K. Fujiwara', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                             J. Livingood', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                      Metaswitch Networks', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                              Network Zen', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                   PayPal', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                    Cisco', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                            The Royal Library, Copenhagen', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                          BAE Systems ATC', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                July 2011', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                July 2011', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                              A. Melnikov', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                      Huawei Technologies', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                              Ericsson AB', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                   Nortel', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                    CERTH', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                          F. Templin, Ed.', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                      ZTE', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                               March 2011', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                               March 2011', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                   C. Bao', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                 F. Baker', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                           Alcatel-Lucent', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                 Shinkuro', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                Infosys Technologies Ltd.', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                               March 2011', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                               March 2011', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                               March 2011', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                             Dover Beach Consulting, Inc.', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                    Nokia', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                   Google', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                            H. Tschofenig', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                        S. Perreault, Ed.', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                               V. Gurbani', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                               March 2011', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                              Network Zen', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                        Grotto Networking', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                         Juniper Networks', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                         Juniper Networks', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                               D. Rokicki', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                Microsoft', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                 S. Bajaj', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                               March 2011', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                               March 2011', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                      Stanford University', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                     AT&amp;T', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                            Cisco Systems', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                               M. Handley', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                 G. Muenz', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                 Tandberg', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                 May 2011', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                      Queensland University of Technology', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                    Avaya', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                      Huawei Technologies', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                  R. Dunn', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                            Cisco Systems', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                S. Turner', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                      UCL', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                C. Olvera', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                    Cisco', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                C. Donley', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                               March 2011', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                 LIX, Ecole Polytechnique', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                     SNIA', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                  D. Kwon', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                               April 2011', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                     Check Point Software', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                    Cisco', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                      Columbia University', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                     Advista Technologies', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                 H. Zhang', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                           G. Huston, Ed.', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                            Cisco Systems', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                  D. Wing', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                     link-lab &amp; FU Berlin', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                       Andrew Corporation', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                              D. McWalter', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                           Simon Josefsson Datakonsult AB', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                               Rainwillow', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                               Rainwillow', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                    T. Li', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                 May 2011', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                            Samsung Electronics Co., Ltd.', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                 May 2011', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                         Diversinet Corp.', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                        Resolute Networks', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                    J. Schoenwaelder, Ed.', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721                                                 Ericsson', '2070-1721', ['2070-1721'])
#
#
# ('2070-1721', '2070-1721', ['2070-1721'])
#
#
# ...
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])

# %%
from dataset.regexes import NIC_PATTERN
for entry in tqdm(pattern_contents['NIC_pattern'], desc="Processing stuff", unit="file"):
    pattern = NIC_PATTERN
    correct_entry = entry.split('    ')[0]
    match = re.findall(pattern, correct_entry, re.DOTALL)
    print(f'{entry, correct_entry, match}\n\n')
# Out:
# Processing stuff: 100%|██████████| 1353/1353 [00:00<00:00, 150348.21file/s]
# ('5761                                                26 February 1971', '5761', ['5761'])
#
#
# ('/NLS Service', '/NLS Service', [])
#
#
# ('AST, MULTICAST, AND BROADCAST                     55', 'AST, MULTICAST, AND BROADCAST', [])
#
#
# ('host table that', 'host table that', [])
#
#
# ('-50004, NIC-50005, NIC-50006,', '-50004, NIC-50005, NIC-50006,', ['50004', '50005', '50006'])
#
#
# ('5762                                              February 23, 1971', '5762', ['5762'])
#
#
# ('.  Other collections of older or', '.  Other collections of older or', [])
#
#
# ('DPH USE', 'DPH USE', [])
#
#
# ('4687), UCLA/NMC,', '4687), UCLA/NMC,', ['4687'])
#
#
# ('AL APPROACH', 'AL APPROACH', [])
#
#
# ('#5763                                            22, 23 February 1971', '#5763', ['5763'])
#
#
# (').', ').', [])
#
#
# ('5764', '5764', ['5764'])
#
#
# (')', ')', [])
#
#
# (') of Defense Data Network (DDN), and', ') of Defense Data Network (DDN), and', [])
#
#
# ('.', '.', [])
#
#
# (') in a single file (HOSTS.TXT) which', ') in a single file (HOSTS.TXT) which', [])
#
#
# ('.ARPA', '.ARPA', [])
#
#
# ('# 5768                                             J. Postel', '# 5768', ['5768'])
#
#
# ('OMPUTER AND WORKSTATION ATTACHMENT', 'OMPUTER AND WORKSTATION ATTACHMENT', [])
#
#
# ('KNAME = 1', 'KNAME = 1', ['1'])
#
#
# ('-39237, SRI-ARC, March', '-39237, SRI-ARC, March', ['39237'])
#
#
# ('<a href="./rfc822">RFC-822</a> standard', '<a href="./rfc822">RFC-822</a> standard', ['822'])
#
#
# ('KNAME = 1', 'KNAME = 1', ['1'])
#
#
# ('data base.  Four', 'data base.  Four', [])
#
#
# ('5776', '5776', ['5776'])
#
#
# ('.  Other collections of older or', '.  Other collections of older or', [])
#
#
# (').', ').', [])
#
#
# ('# 5806', '# 5806', ['5806'])
#
#
# ('November 1988', 'November 1988', ['1988'])
#
#
# ('5807                                                 25 March 1971', '5807', ['5807'])
#
#
# ('NAME    WhoIs Protocol                           Elective         954', 'NAME', [])
#
#
# ('5805                                                  24 March 1971', '5805', ['5805'])
#
#
# ('.ARPA:0.0" IAC SE', '.ARPA:0.0" IAC SE', ['0', '0'])
#
#
# (') of Defense Data Network (DDN), and offers', ') of Defense Data Network (DDN), and offers', [])
#
#
# ('5809                                                  25 March 1971', '5809', ['5809'])
#
#
# ('NAME    WhoIs Protocol                           Elective         954', 'NAME', [])
#
#
# (').', ').', [])
#
#
# ('#5815                                       31 March 71', '#5815', ['5815'])
#
#
# (').  Contact the SRI-NIC to be', ').  Contact the SRI-NIC to be', [])
#
#
# ('758, 755, 750, 739, 604, 503, 433, 349                       August 1989', '758, 755, 750, 739, 604, 503, 433, 349', ['758', '755', '750', '739', '604', '503', '433', '349'])
#
#
# ('.  (Apologies to Douglas Adams.)', '.  (Apologies to Douglas Adams.)', [])
#
#
# ('5816                                                  April 1, 1971', '5816', ['5816'])
#
#
# ('.DDN.MIL.', '.DDN.MIL.', [])
#
#
# ('-50004, NIC-50005, NIC-50006,', '-50004, NIC-50005, NIC-50006,', ['50004', '50005', '50006'])
#
#
# ('MAIL -- SMTP and <a href="./rfc822">RFC-822</a> ........................   <a href="#page-48">48</a>', 'MAIL -- SMTP and <a href="./rfc822">RFC-822</a> ........................   <a href="#page-48">48</a>', ['822', '48', '48'])
#
#
# ('ATIONS AGENCY (DCA)', 'ATIONS AGENCY (DCA)', [])
#
#
# ("'s", "'s", [])
#
#
# ("'s automatic mail server SERVICE, use", "'s automatic mail server SERVICE, use", [])
#
#
# ('5820                                   J. F. Heafner', '5820', ['5820'])
#
#
# ('NAME    WhoIs Protocol                           Elective         954', 'NAME', [])
#
#
# ("'s automatic mail server SERVICE, use", "'s automatic mail server SERVICE, use", [])
#
#
# ('ALLY DETAILED.', 'ALLY DETAILED.', [])
#
#
# ('5823                                                  16 April 1971', '5823', ['5823'])
#
#
# ('NAME)', 'NAME)', [])
#
#
# ('P   Subnetwork Independent Convergence Proto', 'P   Subnetwork Independent Convergence Proto', [])
#
#
# (') is responsible for registering network numbers, auto-', ') is responsible for registering network numbers, auto-', [])
#
#
# ('ALLY DETAILED.', 'ALLY DETAILED.', [])
#
#
# ('5822                              Stanford Research Institute (ARC)', '5822', ['5822'])
#
#
# (').  Contact the SRI-NIC to be', ').  Contact the SRI-NIC to be', [])
#
#
# ('#5825                                               UCLA', '#5825', ['5825'])
#
#
# ('.DDN.MIL.', '.DDN.MIL.', [])
#
#
# (').', ').', [])
#
#
# ('#5826                                                 7 April 1971', '#5826', ['5826'])
#
#
# ('(or to the', '(or to the', [])
#
#
# (').', ').', [])
#
#
# ('.DDN.MIL FTP Server 5Z(47)-6 at Fri 23-Jun-89 09:38-PDT', '.DDN.MIL FTP Server 5Z(47)-6 at Fri 23-Jun-89 09:38-PDT', ['47', '6', '23', '89', '09', '38'])
#
#
# ('at', 'at', [])
#
#
# ('5830                                                  16 April 1971', '5830', ['5830'])
#
#
# ('(Network Information', '(Network Information', [])
#
#
# ('(Data Network Identification Code), as specified in', '(Data Network Identification Code), as specified in', [])
#
#
# ('5831                                                 April 21, 1971', '5831', ['5831'])
#
#
# ('ATION SERVICES</span>', 'ATION SERVICES</span>', [])
#
#
# ('NAME    WhoIs Protocol                           Elective         954', 'NAME', [])
#
#
# ('at', 'at', [])
#
#
# ('.DDN.MIL host as PROTOCOLS:GOSIP-ORDER-INFO.TXT.  The file', '.DDN.MIL host as PROTOCOLS:GOSIP-ORDER-INFO.TXT.  The file', [])
#
#
# ('Network Information Center.  Originally there was only one,', 'Network Information Center.  Originally there was only one,', [])
#
#
# ('5833                                                  21 April 1971', '5833', ['5833'])
#
#
# ('ATIONS SERVICES (6.6) Form a support/working group on', 'ATIONS SERVICES (6.6) Form a support/working group on', ['6', '6'])
#
#
# ('5834                                                   26 April 1971', '5834', ['5834'])
#
#
# ('#5837                                                    20 April 71', '#5837', ['5837'])
#
#
# ('50004).  Also available online at the DDN NIC as', '50004).  Also available online at the DDN NIC as', ['50004'])
#
#
# ('NIC #5840                                       19 April 1971', 'NIC #5840', ['5840'])
#
#
# (') WHOIS database, or from the "root" account on one of the', ') WHOIS database, or from the "root" account on one of the', [])
#
#
# ('5841', '5841', ['5841'])
#
#
# ('NAME    WhoIs Protocol                           Elective        954', 'NAME', [])
#
#
# ('IETF-87/3P, July 1987.', 'IETF-87/3P, July 1987.', ['87', '1987'])
#
#
# ('SERVICES</span>', 'SERVICES</span>', [])
#
#
# ('#5843                                         UCLA', '#5843', ['5843'])
#
#
# ('AL:', 'AL:', [])
#
#
# ('s, but are', 's, but are', [])
#
#
# ('#5844                                                     21 April 71', '#5844', ['5844'])
#
#
# ('Services', 'Services', [])
#
#
# ('E (Network', 'E (Network', [])
#
#
# ('5845                                 J. F. Heafner-Rand', '5845', ['5845'])
#
#
# ('s..........................   <a href="#page-8">8</a>', 's..........................   <a href="#page-8">8</a>', ['8', '8'])
#
#
# (') also make the network easier and more attractive to', ') also make the network easier and more attractive to', [])
#
#
# ('OS based Cray machines with OS level 7.0 or greater.', 'OS based Cray machines with OS level 7.0 or greater.', ['7', '0'])
#
#
# (') and entries were placed in the Official', ') and entries were placed in the Official', [])
#
#
# ('ATION ("Hospital Chart").  The', 'ATION ("Hospital Chart").  The', [])
#
#
# ('Services', 'Services', [])
#
#
# ('5848                                                   22 April 1971', '5848', ['5848'])
#
#
# (') personnel, people interested in establishing', ') personnel, people interested in establishing', [])
#
#
# ('OS, is an ATT System V', 'OS, is an ATT System V', [])
#
#
# ('.  It is currently maintained at GSI', '.  It is currently maintained at GSI', [])
#
#
# (', which was for many years located at SRI International in', ', which was for many years located at SRI International in', [])
#
#
# (').  Contact the NIC to be added or', ').  Contact the NIC to be added or', [])
#
#
# ('#6708                                                       April 28, 1971', '#6708', ['6708'])
#
#
# ('at', 'at', [])
#
#
# ('ALLY DETAILED.', 'ALLY DETAILED.', [])
#
#
# ('6710                                                   27 April 1971', '6710', ['6710'])
#
#
# ('Information  ......................   <a href="#page-22">22</a>', 'Information  ......................   <a href="#page-22">22</a>', ['22', '22'])
#
#
# (') indicates that as of 2/25/92, 46 of', ') indicates that as of 2/25/92, 46 of', ['2', '25', '92', '46'])
#
#
# ('6711', '6711', ['6711'])
#
#
# ('Ident as used in the WhoIs (NICNAME) service.', 'Ident as used in the WhoIs (NICNAME) service.', [])
#
#
# ('AL  ENCODING  MODEL:     There   was   some', 'AL  ENCODING  MODEL:', [])
#
#
# ('S</span>', 'S</span>', [])
#
#
# ('6712                                                  29 April 1971', '6712', ['6712'])
#
#
# (') databases.  The', ') databases.  The', [])
#
#
# ('?', '?', [])
#
#
# ('6713                                                  29 April 1971', '6713', ['6713'])
#
#
# ('NAME    WhoIs Protocol                           Elective        954', 'NAME', [])
#
#
# ('8390 chip.', '8390 chip.', ['8390'])
#
#
# ('6714                                                   30 April 1971', '6714', ['6714'])
#
#
# ('.DDN.MIL. The instructions below explain how to use WHOIS', '.DDN.MIL. The instructions below explain how to use WHOIS', [])
#
#
# ('SEQUENCE ................................. <a href="#page-15">15</a>', 'SEQUENCE ................................. <a href="#page-15">15</a>', ['15', '15'])
#
#
# ('6715                                                       Vint Cerf', '6715', ['6715'])
#
#
# (') in a single file, called HOSTS.TXT,', ') in a single file, called HOSTS.TXT,', [])
#
#
# ('6717                                                     7 May 1971', '6717', ['6717'])
#
#
# ('Address:  nic.ddn.mil (192.112.36.5)', 'Address:  nic.ddn.mil (192.112.36.5)', ['192', '112', '36', '5'])
#
#
# ('See: Defense Data Network Network Information Center', 'See: Defense Data Network Network Information Center', [])
#
#
# (') databases.  This', ') databases.  This', [])
#
#
# ('- 6725                                         4 May 71', '- 6725', ['6725'])
#
#
# ('to the new Internet Registration Service, which is a part of an', 'to the new Internet Registration Service, which is a part of an', [])
#
#
# ('database a', 'database a', [])
#
#
# ('s..........................  <a href="#page-17">17</a>', 's..........................  <a href="#page-17">17</a>', ['17', '17'])
#
#
# ('6726                                                            Rand', '6726', ['6726'])
#
#
# ('NAME    WhoIs Protocol                           Elective        954', 'NAME', [])
#
#
# ('#6727                                        UCLA (NMC)', '#6727', ['6727'])
#
#
# ('#6728                                                     C. Kline', '#6728', ['6728'])
#
#
# ('AL ISSUES                                             10', 'AL ISSUES', [])
#
#
# ('6729                                                  30 April 1971', '6729', ['6729'])
#
#
# ('6739                                                     4 May 1971', '6739', ['6739'])
#
#
# ('S</span>', 'S</span>', [])
#
#
# ('P) sublayer) is an excellent', 'P) sublayer) is an excellent', [])
#
#
# ('K/USER combination.  It is strongly', 'K/USER combination.  It is strongly', [])
#
#
# ('6742                                              D.C. Wood, MITRE', '6742', ['6742'])
#
#
# ('6750', '6750', ['6750'])
#
#
# ('OS operating', 'OS operating', [])
#
#
# ('is', 'is', [])
#
#
# ('# 6751                                        7 May 1971', '# 6751', ['6751'])
#
#
# ("in a single file, called HOSTS.TXT, which was FTP'd by all", "in a single file, called HOSTS.TXT, which was FTP'd by all", [])
#
#
# (', the router vendors, and the network operators to implement', ', the router vendors, and the network operators to implement', [])
#
#
# ('handle', 'handle', [])
#
#
# ('# 6752                                         10 May 1971', '# 6752', ['6752'])
#
#
# ('.  The principal purpose of merging', '.  The principal purpose of merging', [])
#
#
# ('to', 'to', [])
#
#
# ('6754', '6754', ['6754'])
#
#
# (') or from the', ') or from the', [])
#
#
# ('#6755                                                     May 10, 1971', '#6755', ['6755'])
#
#
# (') indicates that as of 2/25/92, 46 of 126 class A network', ') indicates that as of 2/25/92, 46 of 126 class A network', ['2', '25', '92', '46', '126'])
#
#
# ('#6756                                                        SRAI', '#6756', ['6756'])
#
#
# ('AL ENCODING MODEL: There was some confusion, in', 'AL ENCODING MODEL: There was some confusion, in', [])
#
#
# ('status "/>', 'status "/>', [])
#
#
# (',', ',', [])
#
#
# ('Archives . . . . . . . . . . . . . . . . . . . . . . <a href="#page-13">13</a>', 'Archives . . . . . . . . . . . . . . . . . . . . . . <a href="#page-13">13</a>', ['13', '13'])
#
#
# ('#6759                                                   12 May 1971', '#6759', ['6759'])
#
#
# (') or from the', ') or from the', [])
#
#
# (',', ',', [])
#
#
# ('6760', '6760', ['6760'])
#
#
# ('address on a reconnect;', 'address on a reconnect;', [])
#
#
# ('E (Network', 'E (Network', [])
#
#
# ('6762                                                    12 May 1971', '6762', ['6762'])
#
#
# ('.  See <a href="#section-9">Section 9</a>, "Resources and', '.  See <a href="#section-9">Section 9</a>, "Resources and', ['9', '9'])
#
#
# ('6768                                                    19 May 1971', '6768', ['6768'])
#
#
# ('A . . . . . . . . . . . . . . . . . . . . . . . . . <a href="#page-10">10</a>', 'A . . . . . . . . . . . . . . . . . . . . . . . . . <a href="#page-10">10</a>', ['10', '10'])
#
#
# ('?', '?', [])
#
#
# ('and NOC computers, the', 'and NOC computers, the', [])
#
#
# ('?', '?', [])
#
#
# ('6771                                                    18 May 1971', '6771', ['6771'])
#
#
# (') or from the', ') or from the', [])
#
#
# ('Directory and Database Services provides a current-', 'Directory and Database Services provides a current-', [])
#
#
# ('s, as well as other applications looking for a', 's, as well as other applications looking for a', [])
#
#
# ('NAME/WHOIS&quot;">1</a>],', 'NAME/WHOIS&quot;">1</a>],', ['1'])
#
#
# ('#6772                                                    19 May 1971', '#6772', ['6772'])
#
#
# (') or from the', ') or from the', [])
#
#
# ('#6774                                               Computer Science', '#6774', ['6774'])
#
#
# ('#6775                                        UCLA - NMC', '#6775', ['6775'])
#
#
# ('s) to support TCP/IP on client PCs,', 's) to support TCP/IP on client PCs,', [])
#
#
# ('address on a reconnect;', 'address on a reconnect;', [])
#
#
# ('6778', '6778', ['6778'])
#
#
# ('ODE-major-minor', 'ODE-major-minor', [])
#
#
# ('ODE-1-1-UTF-7.', 'ODE-1-1-UTF-7.', ['1', '1', '7'])
#
#
# ('6779', '6779', ['6779'])
#
#
# ('6780                                                       Vint Cerf', '6780', ['6780'])
#
#
# ('#6784', '#6784', ['6784'])
#
#
# ('server in the USA, even if the NIC server is running', 'server in the USA, even if the NIC server is running', [])
#
#
# ('in making distribution of copies to non-site Network Participants', 'in making distribution of copies to non-site Network Participants', [])
#
#
# ('). It is worth noting that the central DSA services are only', '). It is worth noting that the central DSA services are only', [])
#
#
# ('databases, Various service', 'databases, Various service', [])
#
#
# ('6789                                                Computer Science', '6789', ['6789'])
#
#
# ('6790', '6790', ['6790'])
#
#
# ('Host Name Server', 'Host Name Server', [])
#
#
# ('), a', '), a', [])
#
#
# ('),', '),', [])
#
#
# ('6793                                                      Bob Braden', '6793', ['6793'])
#
#
# ('NAME/WHOIS" <a href="./rfc812">RFC 812</a>, SRI NIC, March 1982.', 'NAME/WHOIS" <a href="./rfc812">RFC 812</a>, SRI NIC, March 1982.', ['812', '1982'])
#
#
# ('November 1994', 'November 1994', ['1994'])
#
#
# ('DS.INTERNIC.NET', 'DS.INTERNIC.NET', [])
#
#
# ('Archives . . . . . . . . . . . . . . . . . . . . . . <a href="#page-14">14</a>', 'Archives . . . . . . . . . . . . . . . . . . . . . . <a href="#page-14">14</a>', ['14', '14'])
#
#
# ('6794                                        Bob Braden, UCLA', '6794', ['6794'])
#
#
# (') or from the', ') or from the', [])
#
#
# ('6795                                       4 June 1971', '6795', ['6795'])
#
#
# ('MAIL MODELS IN IMAP4</span>', 'MAIL MODELS IN IMAP4</span>', [])
#
#
# ('NAME ............................................. <a href="#page-17">17</a>', 'NAME ............................................. <a href="#page-17">17</a>', ['17', '17'])
#
#
# ('# 6799                                             Computer Science', '# 6799', ['6799'])
#
#
# ('7074                                     J. Heafner - Rand', '7074', ['7074'])
#
#
# ('E", "NICK", "NILE", "NINA", "NINE", "NOAH", "NODE",', 'E", "NICK", "NILE", "NINA", "NINE", "NOAH", "NODE",', [])
#
#
# ('allocates IP addresses in large chunks to', 'allocates IP addresses in large chunks to', [])
#
#
# ('#7100                                      R. Metcalfe, MIT', '#7100', ['7100'])
#
#
# ('E",  "NICK",  "NILE",  "NINA",  "NINE",  "NOAH",', 'E",  "NICK",  "NILE",  "NINA",  "NINE",  "NOAH",', [])
#
#
# ('7102', '7102', ['7102'])
#
#
# ('7118                                                  June 27, 1971', '7118', ['7118'])
#
#
# (') or from the', ') or from the', [])
#
#
# ('s/NOCs all over Europe  and', 's/NOCs all over Europe  and', [])
#
#
# ('No. 7119                                 22 June 1971', 'No. 7119', ['7119'])
#
#
# ('#7123                                                 25 June 1971', '#7123', ['7123'])
#
#
# (') or from the', ') or from the', [])
#
#
# ('#7124', '#7124', ['7124'])
#
#
# ('DS.INTERNIC.NET', 'DS.INTERNIC.NET', [])
#
#
# ('7126                                ARPA Network Information Center', '7126', ['7126'])
#
#
# ('7127                                                  July 21, 1971', '7127', ['7127'])
#
#
# ('NAME/WHOIS [HARR85] service is a TCP', 'NAME/WHOIS [HARR85] service is a TCP', [])
#
#
# ('WHOIS service [<a href="#ref-HARR85" title="&quot;NICNAME/WHOIS&quot;">HARR85</a>] is used to provide a very', 'WHOIS service [<a href="#ref-HARR85" title="&quot;NICNAME/WHOIS&quot;">HARR85</a>] is used to provide a very', [])
#
#
# ('7128                                                     6 July 1971', '7128', ['7128'])
#
#
# ('AL REFERENCE.  Although Son of 1036 largely', 'AL REFERENCE.  Although Son of 1036 largely', ['1036'])
#
#
# ('distribution of manuals and handbooks "/>', 'distribution of manuals and handbooks "/>', [])
#
#
# ('7130                                                   12 July 1971', '7130', ['7130'])
#
#
# ('#7131                          IBM Thomas J. Watson Research Center', '#7131', ['7131'])
#
#
# ('ODE", <a href="./rfc1642">RFC 1642</a>, Taligent,', 'ODE", <a href="./rfc1642">RFC 1642</a>, Taligent,', ['1642'])
#
#
# (',', ',', [])
#
#
# (') or from the', ') or from the', [])
#
#
# ('5668)                                15 July 1971', '5668)', ['5668'])
#
#
# ('ODE share common code points, but it is considered', 'ODE share common code points, but it is considered', [])
#
#
# ('7135                                                   13 July 1971', '7135', ['7135'])
#
#
# ('7136                            Augmentation Research Center', '7136', ['7136'])
#
#
# ('ATE DIRECTLY with that', 'ATE DIRECTLY with that', [])
#
#
# ('7137                                                   12 July 1971', '7137', ['7137'])
#
#
# (') or from the', ') or from the', [])
#
#
# ('7138                               J. Heafner - Rand', '7138', ['7138'])
#
#
# (', discussed further in <a href="#section-4">Section 4</a>.', ', discussed further in <a href="#section-4">Section 4</a>.', ['4', '4'])
#
#
# ('E", "NICK",  "NILE",  "NINA",  "NINE",  "NOAH",', 'E", "NICK",  "NILE",  "NINA",  "NINE",  "NOAH",', [])
#
#
# ('7139', '7139', ['7139'])
#
#
# ('Category: Informational                                         May 1996', 'Category: Informational', [])
#
#
# ('13', '13', ['13'])
#
#
# ('ODE-1-1" | "UNICODE-1-1-UTF-7" | "UNICODE-1-1-UTF-8"', 'ODE-1-1" | "UNICODE-1-1-UTF-7" | "UNICODE-1-1-UTF-8"', ['1', '1', '1', '1', '7', '1', '1', '8'])
#
#
# ('7140                                                   16 July, 1971', '7140', ['7140'])
#
#
# ('June 1996', 'June 1996', ['1996'])
#
#
# ('7141                                   July 20, 1971', '7141', ['7141'])
#
#
# ('# 7142                                      14 July 1971', '# 7142', ['7142'])
#
#
# ('AST_SOLICIT solicitations, retransmissions cease and the', 'AST_SOLICIT solicitations, retransmissions cease and the', [])
#
#
# ('#7149', '#7149', ['7149'])
#
#
# ('for his careful review', 'for his careful review', [])
#
#
# ('AL ANALYSIS', 'AL ANALYSIS', [])
#
#
# ('7151                                                   15 July 1971', '7151', ['7151'])
#
#
# ('7152                                               (Author unknown)', '7152', ['7152'])
#
#
# (') or from the', ') or from the', [])
#
#
# ('The Online Netskills Interactive Tutorial  . . . . . . <a href="#page-41">41</a>', 'The Online Netskills Interactive Tutorial  . . . . . . <a href="#page-41">41</a>', ['41', '41'])
#
#
# ('(first SRI-NIC and now InterNIC).  Ultimate responsibility for the', '(first SRI-NIC and now InterNIC).  Ultimate responsibility for the', [])
#
#
# ('#7155                                                     Jon Postel', '#7155', ['7155'])
#
#
# ('7168                                                 10 August 1971', '7168', ['7168'])
#
#
# ('7196                                                Comp. Sci.', '7196', ['7196'])
#
#
# ('ODE" title="&quot;The Unicode Standard -- Worldwide Character Encoding -- Version 1.0&quot;">UNICODE</a>], and ISO/IEC 10646-1:1993', 'ODE" title="&quot;The Unicode Standard -- Worldwide Character Encoding -- Version 1.0&quot;">UNICODE</a>], and ISO/IEC 10646-1:1993', ['1', '0', '10646', '1', '1993'])
#
#
# ('7172                                                  6 August 1971', '7172', ['7172'])
#
#
# ('BCP: 12                                                     D. Conrad', 'BCP: 12', ['12'])
#
#
# ('the same way other country domains are.', 'the same way other country domains are.', [])
#
#
# ('allocates IP addresses', 'allocates IP addresses', [])
#
#
# ('7176                                                  9 August 1971', '7176', ['7176'])
#
#
# ('#7178                                       August 9, 1971', '#7178', ['7178'])
#
#
# ('OL" title="&quot;The Multilingual World Wide Web&quot;">NICOL</a>].  A foremost consideration is', 'OL" title="&quot;The Multilingual World Wide Web&quot;">NICOL</a>].  A foremost consideration is', [])
#
#
# (', as well', ', as well', [])
#
#
# (', RIPE, or', ', RIPE, or', [])
#
#
# (', RIPE NCC,', ', RIPE NCC,', [])
#
#
# ('7181                                                  9 August 1971', '7181', ['7181'])
#
#
# ('7187                                                 13 August 1971', '7187', ['7187'])
#
#
# ('7189                                                    16 August 71', '7189', ['7189'])
#
#
# ('6785                                  August 1971', '6785', ['6785'])
#
#
# ('server. This URL', 'server. This URL', [])
#
#
# ('7192', '7192', ['7192'])
#
#
# ('s, geographical distribution of cluster', 's, geographical distribution of cluster', [])
#
#
# ('#7194                                          20 August 1971', '#7194', ['7194'])
#
#
# (',', ',', [])
#
#
# ('AST_HOPS,', 'AST_HOPS,', [])
#
#
# ('7195', '7195', ['7195'])
#
#
# (', September, 1981.', ', September, 1981.', ['1981'])
#
#
# ('#7545                                               30 August 1971', '#7545', ['7545'])
#
#
# (', and parts of the world not otherwise', ', and parts of the world not otherwise', [])
#
#
# ('NAME............................................. <a href="#page-19">19</a>', 'NAME............................................. <a href="#page-19">19</a>', ['19', '19'])
#
#
# ('ODE-2-0', 'ODE-2-0', ['2', '0'])
#
#
# ('ALLY DETAILED.  IT', 'ALLY DETAILED.  IT', [])
#
#
# ('7546', '7546', ['7546'])
#
#
# ('ODE, for example.  All responses must be in the', 'ODE, for example.  All responses must be in the', [])
#
#
# ('AST UDP DATAGRAMS....................................   <a href="#page-12">12</a>', 'AST UDP DATAGRAMS....................................   <a href="#page-12">12</a>', ['12', '12'])
#
#
# ('established a', 'established a', [])
#
#
# ('7547                                      James E. White', '7547', ['7547'])
#
#
# ('#7548                                       8 September 1971', '#7548', ['7548'])
#
#
# ('7549                                               3 September 1971', '7549', ['7549'])
#
#
# ('limitations)', 'limitations)', [])
#
#
# ('s, geographical distribution of cluster members, and the use of VC', 's, geographical distribution of cluster members, and the use of VC', [])
#
#
# (') or from the', ') or from the', [])
#
#
# ('AST DESTINATION D:', 'AST DESTINATION D:', [])
#
#
# ('7612                                                 25 August 1971', '7612', ['7612'])
#
#
# ('Databases" [<a href="./rfc1355" title="&quot;Privacy and Accuracy Issues in Network Information Center Databases&quot;">RFC-1355</a>],', 'Databases" [<a href="./rfc1355" title="&quot;Privacy and Accuracy Issues in Network Information Center Databases&quot;">RFC-1355</a>],', ['1355'])
#
#
# ('NAME/WHOIS [<a href="./rfc954" title="&quot;NICNAME/WHOIS&quot;">RFC-954</a>]', 'NAME/WHOIS [<a href="./rfc954" title="&quot;NICNAME/WHOIS&quot;">RFC-954</a>]', ['954'])
#
#
# ('7621                                              13 September 1971', '7621', ['7621'])
#
#
# ('7622                                14 September 1971', '7622', ['7622'])
#
#
# ('[SDS940/Genie]', '[SDS940/Genie]', [])
#
#
# ('#7623                                       14 September 1971', '#7623', ['7623'])
#
#
# ('K EROS WAVY:md5 499 ke1235:', 'K EROS WAVY:md5 499 ke1235:', ['499'])
#
#
# ('ODE-2" title="&quot;The Unicode Standard, Version 2.0&quot;">UNICODE-2</a>], or ISO 10646 [<a href="#ref-ISO-10646" title="&quot;Information Technology-- Universal Multiple-octet Coded Character Set (UCS).&quot;">ISO-10646</a>]', 'ODE-2" title="&quot;The Unicode Standard, Version 2.0&quot;">UNICODE-2</a>], or ISO 10646 [<a href="#ref-ISO-10646" title="&quot;Information Technology-- Universal Multiple-octet Coded Character Set (UCS).&quot;">ISO-10646</a>]', ['2', '2', '0', '2', '10646', '10646', '10646'])
#
#
# ('7624                                               13 September 1971', '7624', ['7624'])
#
#
# ('#7625                                               20 SEPT 71', '#7625', ['7625'])
#
#
# ('hardware (MAC-layer', 'hardware (MAC-layer', [])
#
#
# ('s of hosts, routers, and endpoints supporting MARSs or MCSs. The', 's of hosts, routers, and endpoints supporting MARSs or MCSs. The', [])
#
#
# ('7631                                             September 17, 1971', '7631', ['7631'])
#
#
# ('ODE" title="&quot;The Unicode Standard -- Version 2.0&quot;">UNICODE</a>], which further defines additional', 'ODE" title="&quot;The Unicode Standard -- Version 2.0&quot;">UNICODE</a>], which further defines additional', ['2', '0'])
#
#
# ('#7645                                    22 September 1971', '#7645', ['7645'])
#
#
# ('handles', 'handles', [])
#
#
# ('E",  "NICK",  "NILE",  "NINA",  "NINE",  "NOAH",', 'E",  "NICK",  "NILE",  "NINA",  "NINE",  "NOAH",', [])
#
#
# ('7646                                                      Computer Science', '7646', ['7646'])
#
#
# ('AST_HOPS socket option or the IPV6_MULTICAST_HOPS socket', 'AST_HOPS socket option or the IPV6_MULTICAST_HOPS socket', [])
#
#
# ('7647                                        24 September 1971', '7647', ['7647'])
#
#
# ('NAME    WhoIs Protocol                           Elective        954', 'NAME', [])
#
#
# ('ATION PROTOCOLS</span>', 'ATION PROTOCOLS</span>', [])
#
#
# ('7648                                  21 September 1971', '7648', ['7648'])
#
#
# ('ODE 2.0 CHARACTER DATABASE. - <a href="ftp://unicode.org/pub/2.0-Update/UnicodeData-2.0.14.txt">ftp://unicode.org/pub/2.0-</a>', 'ODE 2.0 CHARACTER DATABASE. - <a href="ftp://unicode.org/pub/2.0-Update/UnicodeData-2.0.14.txt">ftp://unicode.org/pub/2.0-</a>', ['2', '0', '2', '0', '2', '0', '14', '2', '0'])
#
#
# ('#7649', '#7649', ['7649'])
#
#
# ('of the device needing an IP-number allocated. This ensures a', 'of the device needing an IP-number allocated. This ensures a', [])
#
#
# ('#7650                                     Bob Metcalfe', '#7650', ['7650'])
#
#
# ('that provides interface', 'that provides interface', [])
#
#
# ('7651', '7651', ['7651'])
#
#
# ('NAME/WHOIS&quot;">WHOIS</a>]', 'NAME/WHOIS&quot;">WHOIS</a>]', [])
#
#
# ('7652                                             September 27, 1971', '7652', ['7652'])
#
#
# (')."', ')."', [])
#
#
# ('7661                                                       Computer Science', '7661', ['7661'])
#
#
# ('view of standard host names "/>', 'view of standard host names "/>', [])
#
#
# ('ODE" title="&quot;The Unicode Standard -- Version 2.0&quot;">UNICODE</a>] and Amendment 1 of [<a href="#ref-ISO-10646" title="Information Technology - Universal Multiple- Octet Coded Character Set (UCS) - Part 1: Architecture and Basic Multilingual Plane">ISO-10646</a>]) is also', 'ODE" title="&quot;The Unicode Standard -- Version 2.0&quot;">UNICODE</a>] and Amendment 1 of [<a href="#ref-ISO-10646" title="Information Technology - Universal Multiple- Octet Coded Character Set (UCS) - Part 1: Architecture and Basic Multilingual Plane">ISO-10646</a>]) is also', ['2', '0', '1', '10646', '1', '10646'])
#
#
# ('#7663                                                    September 29, 1971', '#7663', ['7663'])
#
#
# ('7625) "/>', '7625) "/>', ['7625'])
#
#
# ('#7665                                    30 September 1971', '#7665', ['7665'])
#
#
# ('NAME    WhoIs Protocol                           Elective        954', 'NAME', [])
#
#
# ('# 7671                                      29 September 1971', '# 7671', ['7671'])
#
#
# ('7672', '7672', ['7672'])
#
#
# ('KNAME Type Definition ................................<a href="#page-9">9</a>', 'KNAME Type Definition ................................<a href="#page-9">9</a>', ['9', '9'])
#
#
# ('7673                                         Yorktown Heights, N.Y.', '7673', ['7673'])
#
#
# ('KNAME:Bob', 'KNAME:Bob', [])
#
#
# ('7675', '7675', ['7675'])
#
#
# ('7687                                    October 5, 1971', '7687', ['7687'])
#
#
# ('AST_SOLICIT solicitations, retransmissions cease and the', 'AST_SOLICIT solicitations, retransmissions cease and the', [])
#
#
# ('7688                                     12 October 1971', '7688', ['7688'])
#
#
# ('ODE" title=" Addison-Wesley">UNICODE</a>]', 'ODE" title=" Addison-Wesley">UNICODE</a>]', [])
#
#
# ('7690', '7690', ['7690'])
#
#
# ('driver has access to a set of one or', 'driver has access to a set of one or', [])
#
#
# ('#7691                                         Computer Science', '#7691', ['7691'])
#
#
# ('NAME    WhoIs Protocol                                           954', 'NAME', [])
#
#
# ('No. 7692                                    13 October 1971', 'No. 7692', ['7692'])
#
#
# ('Directory and Database', 'Directory and Database', [])
#
#
# (', RIPE,', ', RIPE,', [])
#
#
# ('7696', '7696', ['7696'])
#
#
# ('AL SECURITY CONTROLS</span>', 'AL SECURITY CONTROLS</span>', [])
#
#
# ('#7694                               19 October 1971', '#7694', ['7694'])
#
#
# ('7695                                                   October 1971', '7695', ['7695'])
#
#
# (', APNIC,', ', APNIC,', [])
#
#
# ('7696', '7696', ['7696'])
#
#
# ('AST_HOPS,', 'AST_HOPS,', [])
#
#
# ('as it soon came to be known] so that it can be', 'as it soon came to be known] so that it can be', [])
#
#
# ('#7697                                            3 November 1971', '#7697', ['7697'])
#
#
# ('Directory', 'Directory', [])
#
#
# ('NAME    NICNAME/WHOIS                                           954', 'NAME', [])
#
#
# ('handles to', 'handles to', [])
#
#
# ('NAME/WHOIS', 'NAME/WHOIS', [])
#
#
# ('#7811                                         17 December 1971', '#7811', ['7811'])
#
#
# ('7812                                                      B. Braden', '7812', ['7812'])
#
#
# ('ODE', 'ODE', [])
#
#
# ('781                                           Bob Braden, UCLA', '781', ['781'])
#
#
# ('-handle DMM65.  NIC-handles are unique', '-handle DMM65.  NIC-handles are unique', [])
#
#
# ('#7814                                  8 November 1971', '#7814', ['7814'])
#
#
# (', RIPE and ARIN.  The address space', ', RIPE and ARIN.  The address space', [])
#
#
# (')."', ')."', [])
#
#
# ('#7815                                             22 November 1971', '#7815', ['7815'])
#
#
# ('#7816                                                Computer Science', '#7816', ['7816'])
#
#
# ('# 7817                                              6 December 71', '# 7817', ['7817'])
#
#
# ('ATIONS STANDARDS INSITITUTE', 'ATIONS STANDARDS INSITITUTE', [])
#
#
# ('KNAME = 1', 'KNAME = 1', ['1'])
#
#
# ('NO 7958) "/>', 'NO 7958) "/>', ['7958'])
#
#
# ('NAME    NICNAME/WHOIS                                            954', 'NAME', [])
#
#
# ('COMMERCE', 'COMMERCE', [])
#
#
# ('ATIONS SYSTEMS."', 'ATIONS SYSTEMS."', [])
#
#
# ('7819                                           3 January 1972', '7819', ['7819'])
#
#
# ('and RIPE), which in turn delegate address', 'and RIPE), which in turn delegate address', [])
#
#
# ('7837                                   18 October 1971', '7837', ['7837'])
#
#
# ('AST......................................................<a href="#page-16">16</a>', 'AST......................................................<a href="#page-16">16</a>', ['16', '16'])
#
#
# ('# 7901                                           1 November 1971', '# 7901', ['7901'])
#
#
# ('ODE_DN    OctetString contains the X.500 DN described in', 'ODE_DN', [])
#
#
# ('course "/>', 'course "/>', [])
#
#
# ('handles.  The "override-objects" meta-object contains the following', 'handles.  The "override-objects" meta-object contains the following', [])
#
#
# (', RIPE-NCC,', ', RIPE-NCC,', [])
#
#
# ('ATION', 'ATION', [])
#
#
# ('8056                          Eric Harslem, RAND', '8056', ['8056'])
#
#
# ('ODE" title="&quot;The Unicode Standard -- Version 3.0&quot;">UNICODE</a>] and ISO/IEC 10646 [<a href="#ref-ISO-10646" title="published as Amendment 1. Many other amendments are currently at various stages of standardization. A second edition is in preparation">ISO-10646</a>] jointly', 'ODE" title="&quot;The Unicode Standard -- Version 3.0&quot;">UNICODE</a>] and ISO/IEC 10646 [<a href="#ref-ISO-10646" title="published as Amendment 1. Many other amendments are currently at various stages of standardization. A second edition is in preparation">ISO-10646</a>] jointly', ['3', '0', '10646', '10646', '1', '10646'])
#
#
# ('IAN.', 'IAN.', [])
#
#
# ('2', '2', ['2'])
#
#
# ('NAME    NICNAME/WHOIS                                           954', 'NAME', [])
#
#
# ('COMMERCE SOFTWARE VENDORS', 'COMMERCE SOFTWARE VENDORS', [])
#
#
# ('8163                                                8 December 1971', '8163', ['8163'])
#
#
# ('K/USER', 'K/USER', [])
#
#
# ('K and SERVICE messages sent between servers.  Server', 'K and SERVICE messages sent between servers.  Server', [])
#
#
# ('8164                                               December 8, 1971', '8164', ['8164'])
#
#
# ('hardware (MAC-layer', 'hardware (MAC-layer', [])
#
#
# ('#8165                                                     DECEMBER 20, 1971', '#8165', ['8165'])
#
#
# ('BCeSB0aGUgd2F5LCB5b3Ugc2hvdWxkIHJlYWxseSBnZXQg', 'BCeSB0aGUgd2F5LCB5b3Ugc2hvdWxkIHJlYWxseSBnZXQg', [])
#
#
# ('8271                                              December 15, 1971', '8271', ['8271'])
#
#
# ('#8272                                             21 December 1971', '#8272', ['8272'])
#
#
# ('AL WORK OF THE', 'AL WORK OF THE', [])
#
#
# ('#8273                                              22 December 1971', '#8273', ['8273'])
#
#
# ('ODE_DN. The actual attribute data is formatted as an', 'ODE_DN. The actual attribute data is formatted as an', [])
#
#
# ('8274                                                January 6, 1972', '8274', ['8274'])
#
#
# (') on', ') on', [])
#
#
# ('7625.  This proposal was answered by a', '7625.  This proposal was answered by a', ['7625'])
#
#
# ('NAME/WHOIS Protocol"', 'NAME/WHOIS Protocol"', [])
#
#
# ('8300', '8300', ['8300'])
#
#
# ('NAME    NICNAME/WHOIS                                           954', 'NAME', [])
#
#
# (', and RIPE NCC which, in turn, allocate smaller', ', and RIPE NCC which, in turn, allocate smaller', [])
#
#
# ('8301                       (Area Code 914)- 945-1159', '8301', ['8301'])
#
#
# ('8302                                                Ira Cotton, MITRE', '8302', ['8302'])
#
#
# ('0000 010X XXXX X  2001:0400::/29 - 2001:05F8::/29   ARIN', '0000 010X XXXX X  2001:0400::/29 - 2001:05F8::/29   ARIN', ['0000', '2001', '0400', '29', '2001', '29'])
#
#
# ('#8303                                       18 January 1972', '#8303', ['8303'])
#
#
# ('8304', '8304', ['8304'])
#
#
# ('ODE-1-1-UTF-8" /', 'ODE-1-1-UTF-8" /', ['1', '1', '8'])
#
#
# ('NAME/WHOIS",', 'NAME/WHOIS",', [])
#
#
# ('8484                                                   January 1972', '8484', ['8484'])
#
#
# ('ATION LOST" notification.', 'ATION LOST" notification.', [])
#
#
# ('ODE', 'ODE', [])
#
#
# ('#8485                                 1/31/72', '#8485', ['8485'])
#
#
# ('8486', '8486', ['8486'])
#
#
# ('8487', '8487', ['8487'])
#
#
# ('7191', '7191', ['7191'])
#
#
# ('NAME    NICNAME/WHOIS                                            954', 'NAME', [])
#
#
# ('#9073                                        11 February 1972', '#9073', ['9073'])
#
#
# (', ARIN and RIPE databases.  Updates to this data should', ', ARIN and RIPE databases.  Updates to this data should', [])
#
#
# (') on       |', ') on', [])
#
#
# ('9074                                  Research Laboratory', '9074', ['9074'])
#
#
# ('8488', '8488', ['8488'])
#
#
# ('s).  The two control', 's).  The two control', [])
#
#
# ('9077                                              February 17, 1972', '9077', ['9077'])
#
#
# ('#9078                                        23 February 1972', '#9078', ['9078'])
#
#
# ('ATION LOST notification from the', 'ATION LOST notification from the', [])
#
#
# ('9257                                              February 15, 1972', '9257', ['9257'])
#
#
# ('9258                                              February 24, 1972', '9258', ['9258'])
#
#
# ('9259                                13 MARCH 1972', '9259', ['9259'])
#
#
# ('# 9260                                                MIT-MAC', '# 9260', ['9260'])
#
#
# ('-SE (.se registrar), CAIRN (a DARPA-', '-SE (.se registrar), CAIRN (a DARPA-', [])
#
#
# ('9261                                                  April 3, 1972', '9261', ['9261'])
#
#
# ('#9341                                         29 February 1972', '#9341', ['9341'])
#
#
# ('9342                                              22 March 1972', '9342', ['9342'])
#
#
# ('9343                                                  March 6, 1972', '9343', ['9343'])
#
#
# ('9344                                                  Ira Cotton', '9344', ['9344'])
#
#
# ('AST</span>', 'AST</span>', [])
#
#
# ('9345                                                  March 8, 1972', '9345', ['9345'])
#
#
# ('9346                                                            IBM', '9346', ['9346'])
#
#
# ('9347                                                 March 20, 1972', '9347', ['9347'])
#
#
# (', ARIN and RIPE-NCC) on policies for assigning IPv6 address', ', ARIN and RIPE-NCC) on policies for assigning IPv6 address', [])
#
#
# ('9348                                                  April 3, 1972', '9348', ['9348'])
#
#
# ('ODE_DN          OctetString contains the X.500 DN described', 'ODE_DN', [])
#
#
# ('9349                                                 March 21, 1972', '9349', ['9349'])
#
#
# (', ARIN and RIPE-NCC) on policies for assigning IPv6 address blocks', ', ARIN and RIPE-NCC) on policies for assigning IPv6 address blocks', [])
#
#
# ('9350                                                  27 March 1972', '9350', ['9350'])
#
#
# ('#9608                                              24 March 1972', '#9608', ['9608'])
#
#
# ('#9609                                                     UCLA-NMC', '#9609', ['9609'])
#
#
# ('9630                                                 March 23, 1972', '9630', ['9630'])
#
#
# ('#9631                                                   3 April 72', '#9631', ['9631'])
#
#
# ('# 9633                                        BBN', '# 9633', ['9633'])
#
#
# ('9261                                                 April 27, 1972', '9261', ['9261'])
#
#
# ('9635                                              29 April 72', '9635', ['9635'])
#
#
# ('9636', '9636', ['9636'])
#
#
# ('#9923                                        BBN', '#9923', ['9923'])
#
#
# ('NAME    NICNAME/WHOIS                                            954', 'NAME', [])
#
#
# ('#9924                                          19 April 1972', '#9924', ['9924'])
#
#
# (', ARIN and RIPE address allocation policy', ', ARIN and RIPE address allocation policy', [])
#
#
# ('AST       |        option-len             |', 'AST', [])
#
#
# ('#9925                                        BBN', '#9925', ['9925'])
#
#
# ('# 9926                                                    Dan Murphy', '# 9926', ['9926'])
#
#
# ('ATION_UP notification primitive to the', 'ATION_UP notification primitive to the', [])
#
#
# ('ATION_UP notification primitive to the', 'ATION_UP notification primitive to the', [])
#
#
# ('9927                                  1 May 1972', '9927', ['9927'])
#
#
# ('s and related driver and', 's and related driver and', [])
#
#
# ('#9928                                    Research Lab.', '#9928', ['9928'])
#
#
# ('9929                                                Ira Cotton', '9929', ['9929'])
#
#
# ('9931                                                    17 May 1972', '9931', ['9931'])
#
#
# ('9933                                    Sudbury, Mass.', '9933', ['9933'])
#
#
# ('#10421                                       BBN', '#10421', ['10421'])
#
#
# ('#10422                                                   19 May 1972', '#10422', ['10422'])
#
#
# ('ATIONS SYSTEMS".', 'ATIONS SYSTEMS".', [])
#
#
# ('#10423                                                   22 May 1972', '#10423', ['10423'])
#
#
# ('360/91 at CCN) "/>', '360/91 at CCN) "/>', ['360', '91'])
#
#
# (': 10425                                     30 May 72', ': 10425', ['10425'])
#
#
# ('NAME/WHOIS&quot;">WHOIS</a>] protocols have not been replaced (despite many', 'NAME/WHOIS&quot;">WHOIS</a>] protocols have not been replaced (despite many', [])
#
#
# ('10426                                      30 May 72', '10426', ['10426'])
#
#
# (': 10427                                     30 May 72', ': 10427', ['10427'])
#
#
# (': 10428                                     30 May 72', ': 10428', ['10428'])
#
#
# ('ODE" title="Version 3.2.0 is defined by The Unicode Standard">UNICODE</a>] is a coded character set containing tens of', 'ODE" title="Version 3.2.0 is defined by The Unicode Standard">UNICODE</a>] is a coded character set containing tens of', ['3', '2', '0'])
#
#
# ('ODE" title="&quot;The Unicode Standard&quot;">UNICODE</a>], Unicode code points are denoted', 'ODE" title="&quot;The Unicode Standard&quot;">UNICODE</a>], Unicode code points are denoted', [])
#
#
# ('AST_HOPS,', 'AST_HOPS,', [])
#
#
# ('10549                                                 18-May-72', '10549', ['10549'])
#
#
# ('10593                                                    5 June 1972', '10593', ['10593'])
#
#
# ('ATIONS MANAGEMENT NETWORK.  February, 2000.', 'ATIONS MANAGEMENT NETWORK.  February, 2000.', ['2000'])
#
#
# ('10594                                         UCLA', '10594', ['10594'])
#
#
# ('ODE_DN          X.500 Distinguished name as defined in <a href="./rfc2253">RFC</a>', 'ODE_DN', [])
#
#
# (') on transmission', ') on transmission', [])
#
#
# ('#10595                                                  12 June 1972', '#10595', ['10595'])
#
#
# ('ODE" title="MA">UNICODE</a>]', 'ODE" title="MA">UNICODE</a>]', [])
#
#
# ('10596                                                 July 8, 1972', '10596', ['10596'])
#
#
# ('AST_HOPS socket option or the IPV6_MULTICAST_HOPS socket', 'AST_HOPS socket option or the IPV6_MULTICAST_HOPS socket', [])
#
#
# ('AST       A gateway or direct route.', 'AST', [])
#
#
# ('# 10597                                           9 June 72', '# 10597', ['10597'])
#
#
# ('ATION SECURITY, also known as COMSEC) and', 'ATION SECURITY, also known as COMSEC) and', [])
#
#
# ('# 10598                           June 21, 1972', '# 10598', ['10598'])
#
#
# ('10599                                                 Will Crowther', '10599', ['10599'])
#
#
# (', ARIN, RIPE NCC, "IPv6 Address Allocation and', ', ARIN, RIPE NCC, "IPv6 Address Allocation and', [])
#
#
# ('#10601                                            22 June 1972', '#10601', ['10601'])
#
#
# ('October 2003', 'October 2003', ['2003'])
#
#
# ('10602', '10602', ['10602'])
#
#
# ('NAME    NICNAME/WHOIS                                            954', 'NAME', [])
#
#
# ('10603                                        5 July 1972', '10603', ['10603'])
#
#
# ('#10604                                      BBN', '#10604', ['10604'])
#
#
# ('ODE" title="&quot;The Unicode Standard -- Version 4.0&quot;">UNICODE</a>], which further defines additional', 'ODE" title="&quot;The Unicode Standard -- Version 4.0&quot;">UNICODE</a>], which further defines additional', ['4', '0'])
#
#
# ('9636                               8 August 1972', '9636', ['9636'])
#
#
# ('10606                                  July 11, 1972', '10606', ['10606'])
#
#
# ('AL SECURITY CONTROLS (11)', 'AL SECURITY CONTROLS (11)', ['11'])
#
#
# ('# 10607                           July 11, 1972', '# 10607', ['10607'])
#
#
# ('# 11013                                      BBN', '# 11013', ['11013'])
#
#
# ('called for the creation of an X.500 directory service for the', 'called for the creation of an X.500 directory service for the', ['500'])
#
#
# ('#11014                                                  19 July 1972', '#11014', ['11014'])
#
#
# ('"The response to the .TM registry has been overwhelming.', '"The response to the .TM registry has been overwhelming.', [])
#
#
# ('11015                                                  July 21, 1972', '11015', ['11015'])
#
#
# ('ODE)   |', 'ODE)   |', [])
#
#
# ('6801                                                   25 July 1972', '6801', ['6801'])
#
#
# ('#11017                                       BBN', '#11017', ['11017'])
#
#
# ('NAME    NICNAME/WHOIS                                            954', 'NAME', [])
#
#
# ('NAME/WHOIS&quot;">6</a>] protocol to include the use of whois', 'NAME/WHOIS&quot;">6</a>] protocol to include the use of whois', ['6'])
#
#
# ('11020                                           BBN', '11020', ['11020'])
#
#
# ('11022                                              (SRI-ARC)', '11022', ['11022'])
#
#
# ('Network Interface Card', 'Network Interface Card', [])
#
#
# (') for a TCP/IP network interface, except that', ') for a TCP/IP network interface, except that', [])
#
#
# ('11058                                          SU-AI', '11058', ['11058'])
#
#
# ('11099                                       19 July 1972', '11099', ['11099'])
#
#
# (', TWNIC, KRNIC, and JPNIC as well', ', TWNIC, KRNIC, and JPNIC as well', [])
#
#
# ('ODE4" title="&quot;The Unicode Standard - Version 4.0&quot;">UNICODE4</a>], especially <a href="#section-5.18">Section 5.18</a>, Subsection "Caseless', 'ODE4" title="&quot;The Unicode Standard - Version 4.0&quot;">UNICODE4</a>], especially <a href="#section-5.18">Section 5.18</a>, Subsection "Caseless', ['4', '0', '5', '18', '5', '18'])
#
#
# ('-SE', '-SE', [])
#
#
# ('ATION UP notification.', 'ATION UP notification.', [])
#
#
# ('# 11118                                         BBN', '# 11118', ['11118'])
#
#
# ('11119                                                AUGUST 10, 1972', '11119', ['11119'])
#
#
# (', APNIC, ARIN, LACNIC, and RIPE NCC.', ', APNIC, ARIN, LACNIC, and RIPE NCC.', [])
#
#
# ('#11120                                                10 August 1972', '#11120', ['11120'])
#
#
# ('Network Interface Card', 'Network Interface Card', [])
#
#
# ('11121                                                 AUGUST 11, 1972', '11121', ['11121'])
#
#
# ('AST, MULTICAST, AND BROADCAST', 'AST, MULTICAST, AND BROADCAST', [])
#
#
# ('NAME/WHOIS</span>', 'NAME/WHOIS</span>', [])
#
#
# ('ODE, you are on your', 'ODE, you are on your', [])
#
#
# ('11151                                  Bolt Beranek and Newman Inc.', '11151', ['11151'])
#
#
# ('11122                                          Lawrence McDaniel', '11122', ['11122'])
#
#
# ('11356', '11356', ['11356'])
#
#
# ('-SE', '-SE', [])
#
#
# ('P. Smith', 'P. Smith', [])
#
#
# ('11357                                                  MIT-MAC', '11357', ['11357'])
#
#
# ...
#
#
# ('ODE" title="&quot;The Unicode Standard&quot;">UNICODE</a>].', 'ODE" title="&quot;The Unicode Standard&quot;">UNICODE</a>].', [])
#
#
# ('T', 'T', [])
#
#
# ('ATIONS:  IFIP\'S INTERNATIONAL "NETWORK" OF EXPERTS</span>', 'ATIONS:  IFIP\'S INTERNATIONAL "NETWORK" OF EXPERTS</span>', [])
#
#
# ('5621                                                     J. Heafner', '5621', ['5621'])
#
#
# ('ATIONS (THE INTERNET NAME SERVICE PROTOCOLS)</span>', 'ATIONS (THE INTERNET NAME SERVICE PROTOCOLS)</span>', [])
#
#
# ('AST_HOPS):', 'AST_HOPS):', [])
#
#
# ('AST_HOPS:  The SET_IPV6_UNICAST_HOPS primitive sets the', 'AST_HOPS:  The SET_IPV6_UNICAST_HOPS primitive sets the', [])
#
#
# ('hostname table of 2-Dec-82.', 'hostname table of 2-Dec-82.', ['2', '82'])
#
#
# ('hostname table of 2-Dec-82.', 'hostname table of 2-Dec-82.', ['2', '82'])
#
#
# ('hostname table of 2-Dec-82.', 'hostname table of 2-Dec-82.', ['2', '82'])
#
#
# (', &lt;<a href="/cdn-cgi/l/email-protection" class="__cf_email__" data-cfemail="402c282f342b21002e29236e233a">[email&#160;protected]</a>&gt;', ', &lt;<a href="/cdn-cgi/l/email-protection" class="__cf_email__" data-cfemail="402c282f342b21002e29236e233a">[email&#160;protected]</a>&gt;', ['160'])
#
#
# ('Obsoletes: <a href="./rfc8022">8022</a>                                                A. Lindem', 'Obsoletes: <a href="./rfc8022">8022</a>', ['8022'])
#
#
# ('hostname table of 2-Dec-82.', 'hostname table of 2-Dec-82.', ['2', '82'])
#
#
# ('hostname table of 20-Dec-82.', 'hostname table of 20-Dec-82.', ['20', '82'])
#
#
# ('ISSN: 2070-1721                                              C. Martinez', 'ISSN: 2070-1721', ['2070', '1721'])
#
#
# ('KFLAG RECORD', 'KFLAG RECORD', [])
#
#
# ('hostname table of 31-Dec-82.', 'hostname table of 31-Dec-82.', ['31', '82'])
#
#
# ('hostname table of 31-Dec-82.', 'hostname table of 31-Dec-82.', ['31', '82'])
#
#
# ('Category: Standards Track                                       S. Jiang', 'Category: Standards Track', [])
#
#
# ('hostname table of 31-Dec-82.', 'hostname table of 31-Dec-82.', ['31', '82'])
#
#
# ('5620', '5620', ['5620'])
#
#
# ('APH USE', 'APH USE', [])
#
#
# ('-BIBLIO-791201,', '-BIBLIO-791201,', ['791201'])
#
#
# ('ODE" title="&quot;The Unicode Standard&quot;">UNICODE</a>] strings, however, has', 'ODE" title="&quot;The Unicode Standard&quot;">UNICODE</a>] strings, however, has', [])
#
#
# ('AST       |        option-len             |', 'AST', [])
#
#
# ('hostname table of 28-Jan-83.', 'hostname table of 28-Jan-83.', ['28', '83'])
#
#
# ('hostname table of 3-Feb-83.', 'hostname table of 3-Feb-83.', ['3', '83'])
#
#
# ('">CLINIC</a>]   Miller, B., Huang, L., Joseph, A., and J. Tygar, "I Know', '">CLINIC</a>]   Miller, B., Huang, L., Joseph, A., and J. Tygar, "I Know', [])
#
#
# ('hostname table of 3-Feb-83.', 'hostname table of 3-Feb-83.', ['3', '83'])
#
#
# ('hostname table of 18-Feb-83.', 'hostname table of 18-Feb-83.', ['18', '83'])
#
#
# ('hostname table of 24-Feb-83.', 'hostname table of 24-Feb-83.', ['24', '83'])
#
#
# ('Chile     | Chile       |', 'Chile', [])
#
#
# ('S FORMAT&quot;">ambix</a>].', 'S FORMAT&quot;">ambix</a>].', [])
#
#
# ('T', 'T', [])
#
#
# (']&lt;NETINFO&gt;HOSTS.TXT file,', ']&lt;NETINFO&gt;HOSTS.TXT file,', [])
#
#
# ('ODE-TR15">UNICODE-TR15</a>] for the full', 'ODE-TR15">UNICODE-TR15</a>] for the full', [])
#
#
# ('5624                                                28 December 1970', '5624', ['5624'])
#
#
# ('ISSN: 2070-1721                                                W. Kumari', 'ISSN: 2070-1721', ['2070', '1721'])
#
#
# (', APNIC, ARIN, LACNIC, and RIPE) that have been', ', APNIC, ARIN, LACNIC, and RIPE) that have been', [])
#
#
# ('March 2019', 'March 2019', ['2019'])
#
#
# ('18639                                            May 1983', '18639', ['18639'])
#
#
# ('Category: Standards Track                                        N. Kong', 'Category: Standards Track', [])
#
#
# ('Category: Standards Track                                        N. Kong', 'Category: Standards Track', [])
#
#
# ('18640                                            May 1983', '18640', ['18640'])
#
#
# ('15389                                            May 1983', '15389', ['15389'])
#
#
# ('s', 's', [])
#
#
# ('15390                                            May 1983', '15390', ['15390'])
#
#
# ('15392                                            May 1983', '15392', ['15392'])
#
#
# ('31154)                                  May 1983', '31154)', ['31154'])
#
#
# ('5631                                                        UCLA', '5631', ['5631'])
#
#
# ('16238                                            May 1983', '16238', ['16238'])
#
#
# ('16239                                            May 1983', '16239', ['16239'])
#
#
# ('-- in particular, Tomas Gavenciak --', '-- in particular, Tomas Gavenciak --', [])
#
#
# ('Obsoletes: <a href="./rfc7730">7730</a>                                                S. Weiler', 'Obsoletes: <a href="./rfc7730">7730</a>', ['7730'])
#
#
# ('means the', 'means the', [])
#
#
# ('|   v         ________                                  | NIC |', '|   v', [])
#
#
# ('</div>', '</div>', [])
#
#
# ('5632', '5632', ['5632'])
#
#
# ('.  Some of the items listed', '.  Some of the items listed', [])
#
#
# ('</div>', '</div>', [])
#
#
# ('T</div>', 'T</div>', [])
#
#
# ('host table of 17 August 1983.  TACs and', 'host table of 17 August 1983.  TACs and', ['17', '1983'])
#
#
# ('T:</dt>', 'T:</dt>', [])
#
#
# ('ODE" class="xref">UNICODE</a>]</span> as an address notation.  In', 'ODE" class="xref">UNICODE</a>]</span> as an address notation.  In', [])
#
#
# ('ODE" class="xref">UNICODE</a>]</span>.<a href="#section-3.1-4.2" class="pilcrow">¶</a>', 'ODE" class="xref">UNICODE</a>]</span>.<a href="#section-3.1-4.2" class="pilcrow">¶</a>', ['3', '1', '4', '2'])
#
#
# (')', ')', [])
#
#
# ('5668                                                       UCLA/CCN', '5668', ['5668'])
#
#
# ('in a booklet entitled "Internet Telnet', 'in a booklet entitled "Internet Telnet', [])
#
#
# (').', ').', [])
#
#
# (') and listed in a global', ') and listed in a global', [])
#
#
# ('NAME/WHOIS", <a href="./rfc812">RFC 812</a>, Network', 'NAME/WHOIS", <a href="./rfc812">RFC 812</a>, Network', ['812'])
#
#
# (', and hence are often absent from the host tables of ARPA', ', and hence are often absent from the host tables of ARPA', [])
#
#
# ('T) in Japan', 'T) in Japan', [])
#
#
# ('Host Name', 'Host Name', [])
#
#
# ('ORN-FGCS" class="xref">UNICORN-FGCS</a>]</span>.<a href="#section-1.1-2" class="pilcrow">¶</a></p>', 'ORN-FGCS" class="xref">UNICORN-FGCS</a>]</span>.<a href="#section-1.1-2" class="pilcrow">¶</a></p>', ['1', '1', '2'])
#
#
# ('5697                                                19 January 1971', '5697', ['5697'])
#
#
# ('</div>', '</div>', [])
#
#
# ('Offloads</a><a href="#section-toc.1-1.4.2.6.1" class="pilcrow">¶</a></p>', 'Offloads</a><a href="#section-toc.1-1.4.2.6.1" class="pilcrow">¶</a></p>', ['1', '1', '4', '2', '6', '1'])
#
#
# ('AST-LOOKUP</a>]</span>.<a href="#section-3.1-3" class="pilcrow">¶</a></p>', 'AST-LOOKUP</a>]</span>.<a href="#section-3.1-3" class="pilcrow">¶</a></p>', ['3', '1', '3'])
#
#
# ('ATTIC FIFTY STATERS, "𐅑")</span>.  (Note that all these single-character ', 'ATTIC FIFTY STATERS, "𐅑")</span>.  (Note that all these single-character ', [])
#
#
# ('T, Japan<a href="#section-2-2.1.1" class="pilcrow">¶</a></p>', 'T, Japan<a href="#section-2-2.1.1" class="pilcrow">¶</a></p>', ['2', '2', '1', '1'])
#
#
# (').  Each host is expected to obtain a', ').  Each host is expected to obtain a', [])
#
#
# ('Chile Lab\'s Implementation</a><a href="#section-toc.1-1.11.2.3.1" class="pilcrow">¶</a></p>', 'Chile Lab\'s Implementation</a><a href="#section-toc.1-1.11.2.3.1" class="pilcrow">¶</a></p>', ['1', '1', '11', '2', '3', '1'])
#
#
# ('s ("Smart Network Interface Cards") implementing SRv6. The USP flavor is used to remove the consumed SRH from the extension header chain before sending the packet to the host.<a href="#section-4.16.2-3" class="pilcrow">¶</a></p>', 's ("Smart Network Interface Cards") implementing SRv6. The USP flavor is used to remove the consumed SRH from the extension header chain before sending the packet to the host.<a href="#section-4.16.2-3" class="pilcrow">¶</a></p>', ['4', '16', '2', '3'])
#
#
# ('16239.', '16239.', ['16239'])
#
#
# (') chip is ', ') chip is ', [])
#
#
# ('5707', '5707', ['5707'])
#
#
# ('.  Some of the', '.  Some of the', [])
#
#
# ('in a booklet entitled "Internet', 'in a booklet entitled "Internet', [])
#
#
# (').  The RFC documents are stored as online', ').  The RFC documents are stored as online', [])
#
#
# ('AST-LOOKUP</a>]</span> is a proposed method that', 'AST-LOOKUP</a>]</span> is a proposed method that', [])
#
#
# ('ODE</a>]</span> (this differs from IMAP4rev1). Client', 'ODE</a>]</span> (this differs from IMAP4rev1). Client', [])
#
#
# (')<a href="#appendix-A-2.45.1" class="pilcrow">¶</a></p>', ')<a href="#appendix-A-2.45.1" class="pilcrow">¶</a></p>', ['2', '45', '1'])
#
#
# (', <span class="contact-name">Arturo L. Servin</span> of LACNIC,', ', <span class="contact-name">Arturo L. Servin</span> of LACNIC,', [])
#
#
# ('" as its identifying', '" as its identifying', [])
#
#
# ('</div>', '</div>', [])
#
#
# ('</div>', '</div>', [])
#
#
# ('</div>', '</div>', [])
#
#
# ('</div>', '</div>', [])
#
#
# ('AST_SOLICIT unicast NSes <span>[<a href="#RFC4861" class="xref">RFC4861</a>]</span> separated by RetransTimer milliseconds <span>[<a href="#RFC4861" class="xref">RFC4861</a>]</span> to the host link-layer address.<a href="#section-5.3.1-2.6" class="pilcrow">¶</a>', 'AST_SOLICIT unicast NSes <span>[<a href="#RFC4861" class="xref">RFC4861</a>]</span> separated by RetransTimer milliseconds <span>[<a href="#RFC4861" class="xref">RFC4861</a>]</span> to the host link-layer address.<a href="#section-5.3.1-2.6" class="pilcrow">¶</a>', ['5', '3', '1', '2', '6'])
#
#
# ('ATIONS), will send out another short message', 'ATIONS), will send out another short message', [])
#
#
# ('</div>', '</div>', [])
#
#
# (') Domain Registrar).', ') Domain Registrar).', [])
#
#
# (').  Each host is expected to obtain a', ').  Each host is expected to obtain a', [])
#
#
# ('" class="xref">APNIC</a>]</span>.', '" class="xref">APNIC</a>]</span>.', [])
#
#
# ('.  Some of the', '.  Some of the', [])
#
#
# ('T</div>', 'T</div>', [])
#
#
# ('ODE IDNA COMPATIBILITY PROCESSING</span>, <time datetime="2019-03" class="refDate">March 2019</time>, <span>&lt;<a href="https://www.unicode.org/reports/tr46/tr46-23.html">https://www.unicode.org/reports/tr46/tr46-23.html</a>&gt;</span>. </dd>', 'ODE IDNA COMPATIBILITY PROCESSING</span>, <time datetime="2019-03" class="refDate">March 2019</time>, <span>&lt;<a href="https://www.unicode.org/reports/tr46/tr46-23.html">https://www.unicode.org/reports/tr46/tr46-23.html</a>&gt;</span>. </dd>', ['2019', '03', '2019', '23', '23'])
#
#
# ('T</div>', 'T</div>', [])
#
#
# ('ITP APH USE', 'ITP APH USE', [])
#
#
# ('apability;', 'apability;', [])
#
#
# ('AST (12) Server Unicast Option</td>', 'AST (12) Server Unicast Option</td>', ['12'])
#
#
# ('P        Subnetwork Independent Convergence Protocol', 'P', [])
#
#
# ('ATION UP Notification</a></p>', 'ATION UP Notification</a></p>', [])
#
#
# ('T</div>', 'T</div>', [])
#
#
# ('ORN" class="xref">UNICORN</a>]</span>),', 'ORN" class="xref">UNICORN</a>]</span>),', [])
#
#
# ('T</div>', 'T</div>', [])
#
#
# ('</div>', '</div>', [])
#
#
# ('.', '.', [])
#
#
# ('T</div>', 'T</div>', [])
#
#
# (').', ').', [])
#
#
# ('</div>', '</div>', [])
#
#
# ('s), while others', 's), while others', [])
#
#
# ('T</div>', 'T</div>', [])
#
#
# ('E-CLASSES" class="cite xref">WIPO-NICE-CLASSES</a>]</span>.', 'E-CLASSES" class="cite xref">WIPO-NICE-CLASSES</a>]</span>.', [])
#
#
# ('), <span class="contact-name">YongJoon Joe</span> (LSware), <span class="contact-name">Peter E. Yee</span>', '), <span class="contact-name">YongJoon Joe</span> (LSware), <span class="contact-name">Peter E. Yee</span>', [])
#
#
# ('AL REQUIREMENTS"</span>, <span class="seriesInfo">ARINC 858P1</span>, <time datetime="2021-06" class="refDate">June 2021</time>, <span>&lt;<a href="https://standards.globalspec.com/std/14391274/858p1">https://standards.globalspec.com/std/14391274/858p1</a>&gt;</span>. </dd>', 'AL REQUIREMENTS"</span>, <span class="seriesInfo">ARINC 858P1</span>, <time datetime="2021-06" class="refDate">June 2021</time>, <span>&lt;<a href="https://standards.globalspec.com/std/14391274/858p1">https://standards.globalspec.com/std/14391274/858p1</a>&gt;</span>. </dd>', ['2021', '06', '2021', '14391274', '14391274'])
#
#
# ('to quantify the adoption of IPv6 by means of a script that', 'to quantify the adoption of IPv6 by means of a script that', [])
#
#
# ('AL NEEDS', 'AL NEEDS', [])
#
#
# ('5725                                                3 February 1971', '5725', ['5725'])
#
#
# (') vendor.<a href="#section-8.4-1" class="pilcrow">¶</a></p>', ') vendor.<a href="#section-8.4-1" class="pilcrow">¶</a></p>', ['8', '4', '1'])
#
#
# ('ATIONS -- COMPUTER APPLICATIONS', 'ATIONS -- COMPUTER APPLICATIONS', [])
#
#
# ('" class="cite xref">CLINIC</a>]</span> <span>[<a href="#HCJ16" class="cite xref">HCJ16</a>]</span>.', '" class="cite xref">CLINIC</a>]</span> <span>[<a href="#HCJ16" class="cite xref">HCJ16</a>]</span>.', [])
#
#
# ('<span>[<a href="#OPENNIC" class="cite xref">OPENNIC</a>]</span>), by using', '<span>[<a href="#OPENNIC" class="cite xref">OPENNIC</a>]</span>), by using', [])
#
#
# ('.  Some of the', '.  Some of the', [])
#
#
# ('</div>', '</div>', [])
#
#
# ('ITP APH USE', 'ITP APH USE', [])
#
#
# ('Labs, Universidad de Chile</div>', 'Labs, Universidad de Chile</div>', [])
#
#
# ('Labs, Universidad de Chile</div>', 'Labs, Universidad de Chile</div>', [])
#
#
# ('ATIONS AGENCY', 'ATIONS AGENCY', [])
#
#
# ('O I+D 6G-DATADRIVEN-04 project.<a href="#appendix-A-3" class="pilcrow">¶</a></p>', 'O I+D 6G-DATADRIVEN-04 project.<a href="#appendix-A-3" class="pilcrow">¶</a></p>', ['04', '3'])
#
#
# ('</div>', '</div>', [])
#
#
# ('"/>', '"/>', [])
#
#
# (', June, 1984.', ', June, 1984.', ['1984'])
#
#
# (') on behalf of the Defense', ') on behalf of the Defense', [])
#
#
# ('Internet Hostname Server is a TCP-based host information', 'Internet Hostname Server is a TCP-based host information', [])
#
#
# ('NAME/WHOIS "/>', 'NAME/WHOIS "/>', [])
#
#
# ('ATIONS</span>', 'ATIONS</span>', [])
#
#
# ('Internet host table.  A total of 555 samples were', 'Internet host table.  A total of 555 samples were', ['555'])
#
#
# ('5823),', '5823),', ['5823'])
#
#
# ('5739', '5739', ['5739'])
#
#
# ('.  Some of the', '.  Some of the', [])
#
#
# ('ITP APH USE', 'ITP APH USE', [])
#
#
# ('5740', '5740', ['5740'])
#
#
# ("to delegate UZOO.EDU to you, your database shouldn't", "to delegate UZOO.EDU to you, your database shouldn't", [])
#
#
# ('42444), USC/Information Sciences Institute,', '42444), USC/Information Sciences Institute,', ['42444'])
#
#
# (') online library using FTP.  Public access files may', ') online library using FTP.  Public access files may', [])
#
#
# ('<a href="./rfc822">RFC-822</a> standard message header; the recipient', '<a href="./rfc822">RFC-822</a> standard message header; the recipient', ['822'])
#
#
# ('-50004, NIC-50005, NIC-50006, (three volumes), SRI', '-50004, NIC-50005, NIC-50006, (three volumes), SRI', ['50004', '50005', '50006'])
#
#
# ('as an accepted Domain Defined', 'as an accepted Domain Defined', [])
#
#
# ('5758                                                22 February 1971', '5758', ['5758'])
#
#
# ('.  Other collections of older or obsolete', '.  Other collections of older or obsolete', [])
#
#
# ('DPH USE', 'DPH USE', [])
#
#
# ('<a href="./rfc984">RFC-984</a>.  The revision is based on discussion and comment from a', '<a href="./rfc984">RFC-984</a>.  The revision is based on discussion and comment from a', ['984'])
#
#
# ('ATIONS AND INFORMATION                   |', 'ATIONS AND INFORMATION', [])
#
#
# ('ATIONS AND INFORMATION                   |', 'ATIONS AND INFORMATION', [])
#
#
# ('.  Other collections of older or obsolete protocols are', '.  Other collections of older or obsolete protocols are', [])
#
#
# ('<a href="./rfc969">RFC-969</a>.  The protocol has been revised after extensive research', '<a href="./rfc969">RFC-969</a>.  The protocol has been revised after extensive research', ['969'])
#
#
# (') at SRI International has assumed responsibility for assignment of', ') at SRI International has assumed responsibility for assignment of', [])

# %%
for entry in tqdm(pattern_contents['obsoleted_by_pattern'], desc="Processing stuff", unit="file"):
    pattern = NUMBERS_PATTERN
    correct_entry = entry.split('    ')[0]
    match = re.findall(pattern, correct_entry, re.DOTALL)
    print(f'{entry, correct_entry, match}\n\n')
# Out:
# Processing stuff: 100%|██████████| 1327/1327 [00:00<00:00, 102114.29file/s]
# ('<a href="/rfc/rfc16" target="_blank">16</a>                                                 UNKNOWN</span><br /><span class="pre noprint docinfo">Updated by: <a href="/rfc/rfc24" target="_blank">24</a>, <a href="/rfc/rfc27" target="_blank">27</a>, <a href="/rfc/rfc30" target="_blank">30</a>                                                  </span><pre>Network Working Group                                           S. Crocker', '<a href="/rfc/rfc16" target="_blank">16</a>', ['16'])
#
#
# ('<a href="./rfc10">RFC 10</a>).', '<a href="./rfc10">RFC 10</a>).', ['10'])
#
#
# ('<a href="/rfc/rfc1812" target="_blank">1812</a>                                              HISTORIC</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                          R. Braden', '<a href="/rfc/rfc1812" target="_blank">1812</a>', ['1812'])
#
#
# ('<a href="/rfc/rfc1060" target="_blank">1060</a>                                              HISTORIC</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                        J. Reynolds', '<a href="/rfc/rfc1060" target="_blank">1060</a>', ['1060'])
#
#
# ('<a href="/rfc/rfc1062" target="_blank">1062</a>, <a href="/rfc/rfc1117" target="_blank">1117</a>, <a href="/rfc/rfc1166" target="_blank">1166</a>                                   UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                         S. Romano', '<a href="/rfc/rfc1062" target="_blank">1062</a>, <a href="/rfc/rfc1117" target="_blank">1117</a>, <a href="/rfc/rfc1166" target="_blank">1166</a>', ['1062', '1117', '1166'])
#
#
# ('<a href="/rfc/rfc1076" target="_blank">1076</a>                                               UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                          G. Trewitt', '<a href="/rfc/rfc1076" target="_blank">1076</a>', ['1076'])
#
#
# ('<a href="/rfc/rfc2156" target="_blank">2156</a>, <a href="/rfc/rfc1327" target="_blank">1327</a>                                         UNKNOWN</span><br /><span class="pre noprint docinfo">Updated by: <a href="/rfc/rfc1138" target="_blank">1138</a>, <a href="/rfc/rfc1148" target="_blank">1148</a>                                                  </span><pre>Network Working Group                                          S.E. Kille', '<a href="/rfc/rfc2156" target="_blank">2156</a>, <a href="/rfc/rfc1327" target="_blank">1327</a>', ['2156', '1327'])
#
#
# ('<a href="/rfc/rfc5536" target="_blank">5536</a>, <a href="/rfc/rfc5537" target="_blank">5537</a>                                         UNKNOWN</span><br /><span class="pre noprint docinfo">                                                            <span style=\'color: #C00;\'>Errata Exist</span></span><pre>Network Working Group                                          M. Horton', '<a href="/rfc/rfc5536" target="_blank">5536</a>, <a href="/rfc/rfc5537" target="_blank">5537</a>', ['5536', '5537'])
#
#
# ('<a href="/rfc/rfc1108" target="_blank">1108</a>                                               UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                       M. St. Johns', '<a href="/rfc/rfc1108" target="_blank">1108</a>', ['1108'])
#
#
# ('<a href="/rfc/rfc1113" target="_blank">1113</a>                                               UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                    J. Linn (BBNCC)', '<a href="/rfc/rfc1113" target="_blank">1113</a>', ['1113'])
#
#
# ('<a href="/rfc/rfc1084" target="_blank">1084</a>, <a href="/rfc/rfc1395" target="_blank">1395</a>, <a href="/rfc/rfc1497" target="_blank">1497</a>, <a href="/rfc/rfc1533" target="_blank">1533</a>                             UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                     P. Prindeville', '<a href="/rfc/rfc1084" target="_blank">1084</a>, <a href="/rfc/rfc1395" target="_blank">1395</a>, <a href="/rfc/rfc1497" target="_blank">1497</a>, <a href="/rfc/rfc1533" target="_blank">1533</a>', ['1084', '1395', '1497', '1533'])
#
#
# ('<a href="/rfc/rfc1057" target="_blank">1057</a>                                              HISTORIC</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                             Sun Microsystems, Inc.', '<a href="/rfc/rfc1057" target="_blank">1057</a>', ['1057'])
#
#
# ('<a href="/rfc/rfc1201" target="_blank">1201</a>                                              HISTORIC</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                    P. Prindeville', '<a href="/rfc/rfc1201" target="_blank">1201</a>', ['1201'])
#
#
# ('<a href="/rfc/rfc1112" target="_blank">1112</a>                                               UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                        S. Deering', '<a href="/rfc/rfc1112" target="_blank">1112</a>', ['1112'])
#
#
# ('<a href="/rfc/rfc1119" target="_blank">1119</a>, <a href="/rfc/rfc1305" target="_blank">1305</a>                                         UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                        D. Mills', '<a href="/rfc/rfc1119" target="_blank">1119</a>, <a href="/rfc/rfc1305" target="_blank">1305</a>', ['1119', '1305'])
#
#
# ('<a href="/rfc/rfc1340" target="_blank">1340</a>                                              HISTORIC</span><br /><span class="pre noprint docinfo">Updated by: <a href="/rfc/rfc1349" target="_blank">1349</a>                                                        </span><pre>Network Working Group                                        J. Reynolds', '<a href="/rfc/rfc1340" target="_blank">1340</a>', ['1340'])
#
#
# ('<a href="/rfc/rfc1117" target="_blank">1117</a>, <a href="/rfc/rfc1166" target="_blank">1166</a>                                         UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                         S. Romano', '<a href="/rfc/rfc1117" target="_blank">1117</a>, <a href="/rfc/rfc1166" target="_blank">1166</a>', ['1117', '1166'])
#
#
# ('<a href="/rfc/rfc1191" target="_blank">1191</a>                                               UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                      J.  Mogul', '<a href="/rfc/rfc1191" target="_blank">1191</a>', ['1191'])
#
#
# ('<a href="/rfc/rfc1176" target="_blank">1176</a>, <a href="/rfc/rfc1203" target="_blank">1203</a>                                         UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                         M. Crispin', '<a href="/rfc/rfc1176" target="_blank">1176</a>, <a href="/rfc/rfc1203" target="_blank">1203</a>', ['1176', '1203'])
#
#
# ('<a href="/rfc/rfc1155" target="_blank">1155</a>                                     INTERNET STANDARD</span><br /><span class="pre noprint docinfo">                                                            <span style=\'color: #C00;\'>Errata Exist</span></span><pre>Network Working Group                                            M. Rose', '<a href="/rfc/rfc1155" target="_blank">1155</a>', ['1155'])
#
#
# ('<a href="/rfc/rfc1156" target="_blank">1156</a>                                               UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                     K. McCloghrie', '<a href="/rfc/rfc1156" target="_blank">1156</a>', ['1156'])
#
#
# ('<a href="/rfc/rfc1098" target="_blank">1098</a>                                               UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                            J. Case', '<a href="/rfc/rfc1098" target="_blank">1098</a>', ['1098'])
#
#
# ('<a href="/rfc/rfc1323" target="_blank">1323</a>, <a href="/rfc/rfc2018" target="_blank">2018</a>, <a href="/rfc/rfc6247" target="_blank">6247</a>                                  HISTORIC</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                        V. Jacobson', '<a href="/rfc/rfc1323" target="_blank">1323</a>, <a href="/rfc/rfc2018" target="_blank">2018</a>, <a href="/rfc/rfc6247" target="_blank">6247</a>', ['1323', '2018', '6247'])
#
#
# ('<a href="/rfc/rfc7805" target="_blank">7805</a>                                              HISTORIC</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                          M. Lottor', '<a href="/rfc/rfc7805" target="_blank">7805</a>', ['7805'])
#
#
# ('<a href="/rfc/rfc1372" target="_blank">1372</a>                                               UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                         C. Hedrick', '<a href="/rfc/rfc1372" target="_blank">1372</a>', ['1372'])
#
#
# ('<a href="/rfc/rfc1225" target="_blank">1225</a>                                               UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                            M. Rose', '<a href="/rfc/rfc1225" target="_blank">1225</a>', ['1225'])
#
#
# ('<a href="/rfc/rfc1100" target="_blank">1100</a>                                              HISTORIC</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                          Internet Activities Board', '<a href="/rfc/rfc1100" target="_blank">1100</a>', ['1100'])
#
#
# ('<a href="/rfc/rfc1395" target="_blank">1395</a>, <a href="/rfc/rfc1497" target="_blank">1497</a>, <a href="/rfc/rfc1533" target="_blank">1533</a>                                   UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                       J. Reynolds', '<a href="/rfc/rfc1395" target="_blank">1395</a>, <a href="/rfc/rfc1497" target="_blank">1497</a>, <a href="/rfc/rfc1533" target="_blank">1533</a>', ['1395', '1497', '1533'])
#
#
# ('<a href="/rfc/rfc4789" target="_blank">4789</a>                                               UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                  M. Schoffstall', '<a href="/rfc/rfc4789" target="_blank">4789</a>', ['4789'])
#
#
# ('<a href="/rfc/rfc1189" target="_blank">1189</a>                                               UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                         U. Warrier', '<a href="/rfc/rfc1189" target="_blank">1189</a>', ['1189'])
#
#
# ('<a href="/rfc/rfc1157" target="_blank">1157</a>                                               UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                            J. Case', '<a href="/rfc/rfc1157" target="_blank">1157</a>', ['1157'])
#
#
# ('<a href="/rfc/rfc33" target="_blank">33</a>                                                 UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                         G. Deloche', '<a href="/rfc/rfc33" target="_blank">33</a>', ['33'])
#
#
# ('<a href="/rfc/rfc1130" target="_blank">1130</a>                                              HISTORIC</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                          Internet Activities Board', '<a href="/rfc/rfc1130" target="_blank">1130</a>', ['1130'])
#
#
# ('<a href="/rfc/rfc1188" target="_blank">1188</a>                                               UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                            D. Katz', '<a href="/rfc/rfc1188" target="_blank">1188</a>', ['1188'])
#
#
# ('<a href="/rfc/rfc1163" target="_blank">1163</a>                                          EXPERIMENTAL</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                        K. Lougheed', '<a href="/rfc/rfc1163" target="_blank">1163</a>', ['1163'])
#
#
# ('<a href="/rfc/rfc6247" target="_blank">6247</a>                                              HISTORIC</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                             R. Fox', '<a href="/rfc/rfc6247" target="_blank">6247</a>', ['6247'])
#
#
# ('<a href="/rfc/rfc6247" target="_blank">6247</a>                                              HISTORIC</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                        A. McKenzie', '<a href="/rfc/rfc6247" target="_blank">6247</a>', ['6247'])
#
#
# ('<a href="/rfc/rfc1543" target="_blank">1543</a>, <a href="/rfc/rfc2223" target="_blank">2223</a>                                   INFORMATIONAL</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                          J. Postel', '<a href="/rfc/rfc1543" target="_blank">1543</a>, <a href="/rfc/rfc2223" target="_blank">2223</a>', ['1543', '2223'])
#
#
# ('<a href="/rfc/rfc1421" target="_blank">1421</a>                                              HISTORIC</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                            J. Linn', '<a href="/rfc/rfc1421" target="_blank">1421</a>', ['1421'])
#
#
# ('<a href="/rfc/rfc1422" target="_blank">1422</a>                                              HISTORIC</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                            S. Kent', '<a href="/rfc/rfc1422" target="_blank">1422</a>', ['1422'])
#
#
# ('<a href="/rfc/rfc1423" target="_blank">1423</a>                                              HISTORIC</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                            J. Linn', '<a href="/rfc/rfc1423" target="_blank">1423</a>', ['1423'])
#
#
# ('<a href="/rfc/rfc1184" target="_blank">1184</a>                                     PROPOSED STANDARD</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                    Internet Engineering Task Force', '<a href="/rfc/rfc1184" target="_blank">1184</a>', ['1184'])
#
#
# ('<a href="/rfc/rfc1166" target="_blank">1166</a>                                         INFORMATIONAL</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                          S. Romano', '<a href="/rfc/rfc1166" target="_blank">1166</a>', ['1166'])
#
#
# ('<a href="/rfc/rfc1305" target="_blank">1305</a>                                     INTERNET STANDARD</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>RFC-1119 "Network Time Protocol (Version 2) Specification and', '<a href="/rfc/rfc1305" target="_blank">1305</a>', ['1305'])
#
#
# ('<a href="/rfc/rfc1160" target="_blank">1160</a>                                         INFORMATIONAL</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                            V. Cerf', '<a href="/rfc/rfc1160" target="_blank">1160</a>', ['1160'])
#
#
# ('<a href="/rfc/rfc1140" target="_blank">1140</a>                                              HISTORIC</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                          Internet Activities Board', '<a href="/rfc/rfc1140" target="_blank">1140</a>', ['1140'])
#
#
# ('<a href="/rfc/rfc1247" target="_blank">1247</a>                                     PROPOSED STANDARD</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>        <a href="./rfc1131">RFC-1131</a> "The OSPF Specification"', '<a href="/rfc/rfc1247" target="_blank">1247</a>', ['1247'])
#
#
# ('<a href="/rfc/rfc1171" target="_blank">1171</a>                                     PROPOSED STANDARD</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                         D. Perkins', '<a href="/rfc/rfc1171" target="_blank">1171</a>', ['1171'])
#
#
# ('<a href="/rfc/rfc2156" target="_blank">2156</a>, <a href="/rfc/rfc1327" target="_blank">1327</a>                                    EXPERIMENTAL</span><br /><span class="pre noprint docinfo">Updated by: <a href="/rfc/rfc1148" target="_blank">1148</a>                                            <span style=\'color: #C00;\'>Errata Exist</span></span><pre>Network Working Group                                           S. Kille', '<a href="/rfc/rfc2156" target="_blank">2156</a>, <a href="/rfc/rfc1327" target="_blank">1327</a>', ['2156', '1327'])
#
#
# ('<a href="/rfc/rfc1574" target="_blank">1574</a>, <a href="/rfc/rfc1575" target="_blank">1575</a>                               PROPOSED STANDARD</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                             IETF-OSI Working Group', '<a href="/rfc/rfc1574" target="_blank">1574</a>, <a href="/rfc/rfc1575" target="_blank">1575</a>', ['1574', '1575'])
#
#
# ('<a href="/rfc/rfc1200" target="_blank">1200</a>                                              HISTORIC</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                          Internet Activities Board', '<a href="/rfc/rfc1200" target="_blank">1200</a>', ['1200'])
#
#
# ('<a href="/rfc/rfc7142" target="_blank">7142</a>                                              HISTORIC</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                     D. Oran, Editor', '<a href="/rfc/rfc7142" target="_blank">7142</a>', ['7142'])
#
#
# ('<a href="/rfc/rfc1146" target="_blank">1146</a>, <a href="/rfc/rfc6247" target="_blank">6247</a>                                        HISTORIC</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                          J. Zweig', '<a href="/rfc/rfc1146" target="_blank">1146</a>, <a href="/rfc/rfc6247" target="_blank">6247</a>', ['1146', '6247'])
#
#
# ('<a href="/rfc/rfc6247" target="_blank">6247</a>                                              HISTORIC</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                          J. Zweig', '<a href="/rfc/rfc6247" target="_blank">6247</a>', ['6247'])
#
#
# ('<a href="/rfc/rfc1470" target="_blank">1470</a>                                         INFORMATIONAL</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>          Network Working Group                    R. Stine, Editor', '<a href="/rfc/rfc1470" target="_blank">1470</a>', ['1470'])
#
#
# ('<a href="/rfc/rfc2156" target="_blank">2156</a>, <a href="/rfc/rfc1327" target="_blank">1327</a>                                    EXPERIMENTAL</span><br /><span class="pre noprint docinfo">                                                            <span style=\'color: #C00;\'>Errata Exist</span></span><pre>Network Working Group                                           S. Kille', '<a href="/rfc/rfc2156" target="_blank">2156</a>, <a href="/rfc/rfc1327" target="_blank">1327</a>', ['2156', '1327'])
#
#
# ('<a href="/rfc/rfc6360" target="_blank">6360</a>                                              HISTORIC</span><br /><span class="pre noprint docinfo">                                                            <span style=\'color: #C00;\'>Errata Exist</span></span><pre>Network Working Group                                          G. Malkin', '<a href="/rfc/rfc6360" target="_blank">6360</a>', ['6360'])
#
#
# ('<a href="/rfc/rfc1505" target="_blank">1505</a>                                          EXPERIMENTAL</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                        D. Robinson', '<a href="/rfc/rfc1505" target="_blank">1505</a>', ['1505'])
#
#
# ('<a href="/rfc/rfc1213" target="_blank">1213</a>                                     PROPOSED STANDARD</span><br /><span class="pre noprint docinfo">                                                            <span style=\'color: #C00;\'>Errata Exist</span></span><pre>Network Working Group                                   M. Rose, Editor', '<a href="/rfc/rfc1213" target="_blank">1213</a>', ['1213'])
#
#
# ('<a href="/rfc/rfc1312" target="_blank">1312</a>                                          EXPERIMENTAL</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                          R. Nelson', '<a href="/rfc/rfc1312" target="_blank">1312</a>', ['1312'])
#
#
# ('<a href="/rfc/rfc1418" target="_blank">1418</a>                                          EXPERIMENTAL</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                   M. Rose, Editor', '<a href="/rfc/rfc1418" target="_blank">1418</a>', ['1418'])
#
#
# ('<a href="/rfc/rfc1238" target="_blank">1238</a>                                          EXPERIMENTAL</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                        Greg Satz', '<a href="/rfc/rfc1238" target="_blank">1238</a>', ['1238'])
#
#
# ('<a href="/rfc/rfc1267" target="_blank">1267</a>                                              HISTORIC</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                        K. Lougheed', '<a href="/rfc/rfc1267" target="_blank">1267</a>', ['1267'])
#
#
# ('<a href="/rfc/rfc1268" target="_blank">1268</a>                                              HISTORIC</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group              J. Honig, Cornell Univ. Theory Center', '<a href="/rfc/rfc1268" target="_blank">1268</a>', ['1268'])
#
#
# ('<a href="/rfc/rfc1331" target="_blank">1331</a>                                        DRAFT STANDARD</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                         D. Perkins', '<a href="/rfc/rfc1331" target="_blank">1331</a>', ['1331'])
#
#
# ('<a href="/rfc/rfc1331" target="_blank">1331</a>, <a href="/rfc/rfc1332" target="_blank">1332</a>                               PROPOSED STANDARD</span><br /><span class="pre noprint docinfo">                                                            <span style=\'color: #C00;\'>Errata Exist</span></span><pre>Network Working Group                                         D. Perkins', '<a href="/rfc/rfc1331" target="_blank">1331</a>, <a href="/rfc/rfc1332" target="_blank">1332</a>', ['1331', '1332'])
#
#
# ('<a href="/rfc/rfc1206" target="_blank">1206</a>                                         INFORMATIONAL</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                          G. Malkin', '<a href="/rfc/rfc1206" target="_blank">1206</a>', ['1206'])
#
#
# ('<a href="/rfc/rfc1323" target="_blank">1323</a>                                          EXPERIMENTAL</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                        V. Jacobson', '<a href="/rfc/rfc1323" target="_blank">1323</a>', ['1323'])
#
#
# ('<a href="/rfc/rfc1320" target="_blank">1320</a>                                         INFORMATIONAL</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                         R. Rivest', '<a href="/rfc/rfc1320" target="_blank">1320</a>', ['1320'])
#
#
# ('<a href="/rfc/rfc1819" target="_blank">1819</a>                                          EXPERIMENTAL</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                  CIP Working Group', '<a href="/rfc/rfc1819" target="_blank">1819</a>', ['1819'])
#
#
# ('<a href="/rfc/rfc1196" target="_blank">1196</a>, <a href="/rfc/rfc1288" target="_blank">1288</a>                                  DRAFT STANDARD</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                       D. Zimmerman', '<a href="/rfc/rfc1196" target="_blank">1196</a>, <a href="/rfc/rfc1288" target="_blank">1288</a>', ['1196', '1288'])
#
#
# ('<a href="/rfc/rfc1288" target="_blank">1288</a>                                        DRAFT STANDARD</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                       D. Zimmerman', '<a href="/rfc/rfc1288" target="_blank">1288</a>', ['1288'])
#
#
# ('RFC', 'RFC', [])
#
#
# ('<a href="/rfc/rfc1250" target="_blank">1250</a>                                              HISTORIC</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                          Internet Activities Board', '<a href="/rfc/rfc1250" target="_blank">1250</a>', ['1250'])
#
#
# ('<a href="/rfc/rfc1325" target="_blank">1325</a>                                         INFORMATIONAL</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                          G. Malkin', '<a href="/rfc/rfc1325" target="_blank">1325</a>', ['1325'])
#
#
# ('<a href="/rfc/rfc1255" target="_blank">1255</a>, <a href="/rfc/rfc1417" target="_blank">1417</a>                                   INFORMATIONAL</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                 The North American Directory Forum', '<a href="/rfc/rfc1255" target="_blank">1255</a>, <a href="/rfc/rfc1417" target="_blank">1417</a>', ['1255', '1417'])
#
#
# ('<a href="/rfc/rfc1638" target="_blank">1638</a>                                     PROPOSED STANDARD</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                   F. Baker, Editor', '<a href="/rfc/rfc1638" target="_blank">1638</a>', ['1638'])
#
#
# ('<a href="/rfc/rfc1460" target="_blank">1460</a>                                        DRAFT STANDARD</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                            M. Rose', '<a href="/rfc/rfc1460" target="_blank">1460</a>', ['1460'])
#
#
# ('<a href="/rfc/rfc1592" target="_blank">1592</a>                                          EXPERIMENTAL</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                       G. Carpenter', '<a href="/rfc/rfc1592" target="_blank">1592</a>', ['1592'])
#
#
# ('<a href="/rfc/rfc1573" target="_blank">1573</a>                                     PROPOSED STANDARD</span><br /><span class="pre noprint docinfo">Updated by: <a href="/rfc/rfc1239" target="_blank">1239</a>                                                        </span><pre>Network Working Group                              K. McCloghrie, Editor', '<a href="/rfc/rfc1573" target="_blank">1573</a>', ['1573'])
#
#
# ('<a href="/rfc/rfc165" target="_blank">165</a>                                                UNKNOWN</span><br /><span class="pre noprint docinfo">Updated by: <a href="/rfc/rfc127" target="_blank">127</a>, <a href="/rfc/rfc143" target="_blank">143</a>, <a href="/rfc/rfc148" target="_blank">148</a>                                               </span><pre>Network Working Group                                         S. Crocker', '<a href="/rfc/rfc165" target="_blank">165</a>', ['165'])
#
#
# ('<a href="/rfc/rfc1743" target="_blank">1743</a>, <a href="/rfc/rfc1748" target="_blank">1748</a>                               PROPOSED STANDARD</span><br /><span class="pre noprint docinfo">Updated by: <a href="/rfc/rfc1239" target="_blank">1239</a>                                                        </span><pre>Network Working Group                                      K. McCloghrie', '<a href="/rfc/rfc1743" target="_blank">1743</a>, <a href="/rfc/rfc1748" target="_blank">1748</a>', ['1743', '1748'])
#
#
# ('<a href="/rfc/rfc1406" target="_blank">1406</a>                                     PROPOSED STANDARD</span><br /><span class="pre noprint docinfo">Updated by: <a href="/rfc/rfc1239" target="_blank">1239</a>                                                        </span><pre>Network Working Group                                           F. Baker', '<a href="/rfc/rfc1406" target="_blank">1406</a>', ['1406'])
#
#
# ('<a href="/rfc/rfc1407" target="_blank">1407</a>                                     PROPOSED STANDARD</span><br /><span class="pre noprint docinfo">Updated by: <a href="/rfc/rfc1239" target="_blank">1239</a>                                                        </span><pre>Network Working Group                                            T. Cox', '<a href="/rfc/rfc1407" target="_blank">1407</a>', ['1407'])
#
#
# ('<a href="/rfc/rfc1629" target="_blank">1629</a>                                     PROPOSED STANDARD</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>    Network Working Group                            Richard Colella (NIST)', '<a href="/rfc/rfc1629" target="_blank">1629</a>', ['1629'])
#
#
# ('<a href="/rfc/rfc1742" target="_blank">1742</a>                                     PROPOSED STANDARD</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                             S. Waldbusser, Editor', '<a href="/rfc/rfc1742" target="_blank">1742</a>', ['1742'])
#
#
# ('<a href="/rfc/rfc2196" target="_blank">2196</a>                                         INFORMATIONAL</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                        P. Holbrook', '<a href="/rfc/rfc2196" target="_blank">2196</a>', ['2196'])
#
#
# ('<a href="/rfc/rfc1583" target="_blank">1583</a>                                        DRAFT STANDARD</span><br /><span class="pre noprint docinfo">Updated by: <a href="/rfc/rfc1349" target="_blank">1349</a>                                                        </span><pre>Network Working Group                                             J. Moy', '<a href="/rfc/rfc1583" target="_blank">1583</a>', ['1583'])
#
#
# ('<a href="/rfc/rfc1252" target="_blank">1252</a>                                     PROPOSED STANDARD</span><br /><span class="pre noprint docinfo">Updated by: <a href="/rfc/rfc1349" target="_blank">1349</a>                                                        </span><pre>Network Working Group                                          F. Baker', '<a href="/rfc/rfc1252" target="_blank">1252</a>', ['1252'])
#
#
# ('<a href="/rfc/rfc2200" target="_blank">2200</a>, <a href="/rfc/rfc1280" target="_blank">1280</a>                                        HISTORIC</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                          Internet Activities Board', '<a href="/rfc/rfc2200" target="_blank">2200</a>, <a href="/rfc/rfc1280" target="_blank">1280</a>', ['2200', '1280'])
#
#
# ('<a href="/rfc/rfc1336" target="_blank">1336</a>                                         INFORMATIONAL</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                          G. Malkin', '<a href="/rfc/rfc1336" target="_blank">1336</a>', ['1336'])
#
#
# ('<a href="/rfc/rfc1253" target="_blank">1253</a>                                     PROPOSED STANDARD</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                          F. Baker', '<a href="/rfc/rfc1253" target="_blank">1253</a>', ['1253'])
#
#
# ('<a href="/rfc/rfc1850" target="_blank">1850</a>                                     PROPOSED STANDARD</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                          F. Baker', '<a href="/rfc/rfc1850" target="_blank">1850</a>', ['1850'])
#
#
# ('<a href="/rfc/rfc1417" target="_blank">1417</a>                                         INFORMATIONAL</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                 The North American Directory Forum', '<a href="/rfc/rfc1417" target="_blank">1417</a>', ['1417'])
#
#
# ('<a href="/rfc/rfc1282" target="_blank">1282</a>                                         INFORMATIONAL</span><br /><span class="pre noprint docinfo">                                                            <span style=\'color: #C00;\'>Errata Exist</span></span><pre>Network Working Group                                          B. Kantor', '<a href="/rfc/rfc1282" target="_blank">1282</a>', ['1282'])
#
#
# ('<a href="/rfc/rfc4794" target="_blank">4794</a>                                              HISTORIC</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                          R. Hinden', '<a href="/rfc/rfc4794" target="_blank">4794</a>', ['4794'])
#
#
# ('<a href="/rfc/rfc1655" target="_blank">1655</a>                                              HISTORIC</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                         Y. Rekhter', '<a href="/rfc/rfc1655" target="_blank">1655</a>', ['1655'])
#
#
# ('<a href="/rfc/rfc4273" target="_blank">4273</a>                                     PROPOSED STANDARD</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                          S. Willis', '<a href="/rfc/rfc4273" target="_blank">4273</a>', ['4273'])
#
#
# ('<a href="/rfc/rfc145" target="_blank">145</a>                                                UNKNOWN</span><br /><span class="pre noprint docinfo">Updated by: <a href="/rfc/rfc151" target="_blank">151</a>                                                         </span><pre>Network Working Group                             J. Postel', '<a href="/rfc/rfc145" target="_blank">145</a>', ['145'])
#
#
# ('<a href="/rfc/rfc1757" target="_blank">1757</a>                                     PROPOSED STANDARD</span><br /><span class="pre noprint docinfo">Updated by: <a href="/rfc/rfc1513" target="_blank">1513</a>                                                        </span><pre>Network Working Group                                      S. Waldbusser', '<a href="/rfc/rfc1757" target="_blank">1757</a>', ['1757'])
#
#
# ('<a href="/rfc/rfc4524" target="_blank">4524</a>                                     PROPOSED STANDARD</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                          P. Barker', '<a href="/rfc/rfc4524" target="_blank">4524</a>', ['4524'])
#
#
# ('<a href="/rfc/rfc1360" target="_blank">1360</a>                                              HISTORIC</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                          Internet Activities Board', '<a href="/rfc/rfc1360" target="_blank">1360</a>', ['1360'])
#
#
# ('<a href="/rfc/rfc1418" target="_blank">1418</a>                                          EXPERIMENTAL</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                           M. Rose', '<a href="/rfc/rfc1418" target="_blank">1418</a>', ['1418'])
#
#
# ('<a href="/rfc/rfc1398" target="_blank">1398</a>                                     PROPOSED STANDARD</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                    J. Cook, Editor', '<a href="/rfc/rfc1398" target="_blank">1398</a>', ['1398'])
#
#
# ('<a href="/rfc/rfc1493" target="_blank">1493</a>, <a href="/rfc/rfc1525" target="_blank">1525</a>                               PROPOSED STANDARD</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                          E. Decker', '<a href="/rfc/rfc1493" target="_blank">1493</a>, <a href="/rfc/rfc1525" target="_blank">1525</a>', ['1493', '1525'])
#
#
# ('<a href="/rfc/rfc1559" target="_blank">1559</a>                                     PROPOSED STANDARD</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                         J. Saperia', '<a href="/rfc/rfc1559" target="_blank">1559</a>', ['1559'])
#
#
# ('<a href="/rfc/rfc1402" target="_blank">1402</a>                                         INFORMATIONAL</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                          J. Martin', '<a href="/rfc/rfc1402" target="_blank">1402</a>', ['1402'])
#
#
# ('<a href="/rfc/rfc1632" target="_blank">1632</a>                                         INFORMATIONAL</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                            R. Lang', '<a href="/rfc/rfc1632" target="_blank">1632</a>', ['1632'])
#
#
# ('<a href="/rfc/rfc2390" target="_blank">2390</a>                                     PROPOSED STANDARD</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                         T. Bradley', '<a href="/rfc/rfc2390" target="_blank">2390</a>', ['2390'])
#
#
# ('<a href="/rfc/rfc1490" target="_blank">1490</a>, <a href="/rfc/rfc2427" target="_blank">2427</a>                               PROPOSED STANDARD</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                         T. Bradley', '<a href="/rfc/rfc1490" target="_blank">1490</a>, <a href="/rfc/rfc2427" target="_blank">2427</a>', ['1490', '2427'])
#
#
# ('<a href="/rfc/rfc1417" target="_blank">1417</a>                                         INFORMATIONAL</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                 The North American Directory Forum', '<a href="/rfc/rfc1417" target="_blank">1417</a>', ['1417'])
#
#
# ('<a href="/rfc/rfc1420" target="_blank">1420</a>                                         INFORMATIONAL</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                         R. Wormley', '<a href="/rfc/rfc1420" target="_blank">1420</a>', ['1420'])
#
#
# ('<a href="/rfc/rfc1694" target="_blank">1694</a>                                     PROPOSED STANDARD</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                             T. Cox', '<a href="/rfc/rfc1694" target="_blank">1694</a>', ['1694'])
#
#
# ('<a href="/rfc/rfc5905" target="_blank">5905</a>                                        DRAFT STANDARD</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                           David L. Mills', '<a href="/rfc/rfc5905" target="_blank">5905</a>', ['5905'])
#
#
# ('<a href="/rfc/rfc1602" target="_blank">1602</a>                                         INFORMATIONAL</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                          Internet Activities Board', '<a href="/rfc/rfc1602" target="_blank">1602</a>', ['1602'])
#
#
# ('<a href="/rfc/rfc2115" target="_blank">2115</a>                                     PROPOSED STANDARD</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                           C. Brown', '<a href="/rfc/rfc2115" target="_blank">2115</a>', ['2115'])
#
#
# ('<a href="/rfc/rfc1658" target="_blank">1658</a>                                     PROPOSED STANDARD</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                 B. Stewart, Editor', '<a href="/rfc/rfc1658" target="_blank">1658</a>', ['1658'])
#
#
# ('<a href="/rfc/rfc1659" target="_blank">1659</a>                                     PROPOSED STANDARD</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                 B. Stewart, Editor', '<a href="/rfc/rfc1659" target="_blank">1659</a>', ['1659'])
#
#
# ('<a href="/rfc/rfc1660" target="_blank">1660</a>                                     PROPOSED STANDARD</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                 B. Stewart, Editor', '<a href="/rfc/rfc1660" target="_blank">1660</a>', ['1660'])
#
#
# ('<a href="/rfc/rfc6149" target="_blank">6149</a>                                              HISTORIC</span><br /><span class="pre noprint docinfo">                                                            <span style=\'color: #C00;\'>Errata Exist</span></span><pre>Network Working Group                                         B. Kaliski', '<a href="/rfc/rfc6149" target="_blank">6149</a>', ['6149'])
#
#
# ...
#
#
# ('<a href="/rfc/rfc1034" target="_blank">1034</a>, <a href="/rfc/rfc1035" target="_blank">1035</a>                                         UNKNOWN</span><br /><span class="pre noprint docinfo">Updated by: <a href="/rfc/rfc973" target="_blank">973</a>                                             <span style=\'color: #C00;\'>Errata Exist</span></span><pre>Network Working Group                                     P. Mockapetris', '<a href="/rfc/rfc1034" target="_blank">1034</a>, <a href="/rfc/rfc1035" target="_blank">1035</a>', ['1034', '1035'])
#
#
# ('<a href="/rfc/rfc1034" target="_blank">1034</a>, <a href="/rfc/rfc1035" target="_blank">1035</a>                                         UNKNOWN</span><br /><span class="pre noprint docinfo">Updated by: <a href="/rfc/rfc973" target="_blank">973</a>                                                         </span><pre>Network Working Group                                     P. Mockapetris', '<a href="/rfc/rfc1034" target="_blank">1034</a>, <a href="/rfc/rfc1035" target="_blank">1035</a>', ['1034', '1035'])
#
#
# ('<a href="/rfc/rfc930" target="_blank">930</a>                                                UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                     Marvin Solomon', '<a href="/rfc/rfc930" target="_blank">930</a>', ['930'])
#
#
# ('<a href="/rfc/rfc905" target="_blank">905</a>                                                UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                   ISO', '<a href="/rfc/rfc905" target="_blank">905</a>', ['905'])
#
#
# ('<a href="/rfc/rfc7805" target="_blank">7805</a>                                              HISTORIC</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                  John Nagle', '<a href="/rfc/rfc7805" target="_blank">7805</a>', ['7805'])
#
#
# ('<a href="/rfc/rfc923" target="_blank">923</a>                                               HISTORIC</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                        J. Reynolds', '<a href="/rfc/rfc923" target="_blank">923</a>', ['923'])
#
#
# ('<a href="/rfc/rfc924" target="_blank">924</a>                                                UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                        J. Reynolds', '<a href="/rfc/rfc924" target="_blank">924</a>', ['924'])
#
#
# ('This Document</a></p>', 'This Document</a></p>', [])
#
#
# ('<a href="/rfc/rfc931" target="_blank">931</a>                                                UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                       Mike StJohns', '<a href="/rfc/rfc931" target="_blank">931</a>', ['931'])
#
#
# ('<a href="/rfc/rfc937" target="_blank">937</a>                                                UNKNOWN</span><br /><span class="pre noprint docinfo">                                                            <span style=\'color: #C00;\'>Errata Exist</span></span><pre>Network Working Group                                     J. K. Reynolds', '<a href="/rfc/rfc937" target="_blank">937</a>', ['937'])
#
#
# ('<a href="/rfc/rfc943" target="_blank">943</a>                                               HISTORIC</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                        J. Reynolds', '<a href="/rfc/rfc943" target="_blank">943</a>', ['943'])
#
#
# ('<a href="/rfc/rfc944" target="_blank">944</a>                                                UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                        J. Reynolds', '<a href="/rfc/rfc944" target="_blank">944</a>', ['944'])
#
#
# ('<a href="/rfc/rfc994" target="_blank">994</a>                                                UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                                ISO', '<a href="/rfc/rfc994" target="_blank">994</a>', ['994'])
#
#
# ('<a href="/rfc/rfc1091" target="_blank">1091</a>                                               UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                     Marvin Solomon', '<a href="/rfc/rfc1091" target="_blank">1091</a>', ['1091'])
#
#
# ('<a href="/rfc/rfc1413" target="_blank">1413</a>                                               UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                       Mike StJohns', '<a href="/rfc/rfc1413" target="_blank">1413</a>', ['1413'])
#
#
# ('<a href="/rfc/rfc960" target="_blank">960</a>                                               HISTORIC</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                        J. Reynolds', '<a href="/rfc/rfc960" target="_blank">960</a>', ['960'])
#
#
# ('<a href="/rfc/rfc961" target="_blank">961</a>                                                UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                        J. Reynolds', '<a href="/rfc/rfc961" target="_blank">961</a>', ['961'])
#
#
# ('<a href="/rfc/rfc1039" target="_blank">1039</a>                                               UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                             Postel', '<a href="/rfc/rfc1039" target="_blank">1039</a>', ['1039'])
#
#
# ('<a href="/rfc/rfc1042" target="_blank">1042</a>                                               UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>---------</pre>', '<a href="/rfc/rfc1042" target="_blank">1042</a>', ['1042'])
#
#
# ('<a href="/rfc/rfc155" target="_blank">155</a>                                                UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>                                                                NIC 5731', '<a href="/rfc/rfc155" target="_blank">155</a>', ['155'])
#
#
# ('<a href="/rfc/rfc3912" target="_blank">3912</a>                                        DRAFT STANDARD</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                               K. Harrenstien (SRI)', '<a href="/rfc/rfc3912" target="_blank">3912</a>', ['3912'])
#
#
# ('<a href="/rfc/rfc1059" target="_blank">1059</a>, <a href="/rfc/rfc1119" target="_blank">1119</a>, <a href="/rfc/rfc1305" target="_blank">1305</a>                                   UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                         D.L. Mills', '<a href="/rfc/rfc1059" target="_blank">1059</a>, <a href="/rfc/rfc1119" target="_blank">1119</a>, <a href="/rfc/rfc1305" target="_blank">1305</a>', ['1059', '1119', '1305'])
#
#
# ('<a href="/rfc/rfc990" target="_blank">990</a>                                               HISTORIC</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                        J. Reynolds', '<a href="/rfc/rfc990" target="_blank">990</a>', ['990'])
#
#
# ('<a href="/rfc/rfc991" target="_blank">991</a>                                                UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                        J. Reynolds', '<a href="/rfc/rfc991" target="_blank">991</a>', ['991'])
#
#
# ('<a href="/rfc/rfc988" target="_blank">988</a>                                                UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                      S. E. Deering', '<a href="/rfc/rfc988" target="_blank">988</a>', ['988'])
#
#
# ('<a href="/rfc/rfc998" target="_blank">998</a>                                                UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                     David D. Clark', '<a href="/rfc/rfc998" target="_blank">998</a>', ['998'])
#
#
# ('<a href="/rfc/rfc1034" target="_blank">1034</a>, <a href="/rfc/rfc1035" target="_blank">1035</a>                                         UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                   Paul Mockapetris', '<a href="/rfc/rfc1034" target="_blank">1034</a>, <a href="/rfc/rfc1035" target="_blank">1035</a>', ['1034', '1035'])
#
#
# ('<a href="/rfc/rfc2821" target="_blank">2821</a>                                              HISTORIC</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                    Craig Partridge', '<a href="/rfc/rfc2821" target="_blank">2821</a>', ['2821'])
#
#
# ('<a href="/rfc/rfc3977" target="_blank">3977</a>                                     PROPOSED STANDARD</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                      Brian Kantor (U.C. San Diego)', '<a href="/rfc/rfc3977" target="_blank">3977</a>', ['3977'])
#
#
# ('<a href="/rfc/rfc1006" target="_blank">1006</a>                                               UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                  D. E. Cass (NRTC)', '<a href="/rfc/rfc1006" target="_blank">1006</a>', ['1006'])
#
#
# ('<a href="/rfc/rfc993" target="_blank">993</a>                                                UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                     David D. Clark', '<a href="/rfc/rfc993" target="_blank">993</a>', ['993'])
#
#
# ('<a href="/rfc/rfc1009" target="_blank">1009</a>                                               UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                   Network Technical Advisory Group', '<a href="/rfc/rfc1009" target="_blank">1009</a>', ['1009'])
#
#
# ('<a href="/rfc/rfc1069" target="_blank">1069</a>                                               UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                  Ross Callon (BBN)', '<a href="/rfc/rfc1069" target="_blank">1069</a>', ['1069'])
#
#
# ('<a href="/rfc/rfc2156" target="_blank">2156</a>, <a href="/rfc/rfc1327" target="_blank">1327</a>                                         UNKNOWN</span><br /><span class="pre noprint docinfo">Updated by: <a href="/rfc/rfc1026" target="_blank">1026</a>, <a href="/rfc/rfc1138" target="_blank">1138</a>, <a href="/rfc/rfc1148" target="_blank">1148</a>                                            </span><pre>UCL Technical Report 120', '<a href="/rfc/rfc2156" target="_blank">2156</a>, <a href="/rfc/rfc1327" target="_blank">1327</a>', ['2156', '1327'])
#
#
# ('<a href="/rfc/rfc1054" target="_blank">1054</a>, <a href="/rfc/rfc1112" target="_blank">1112</a>                                         UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                      S. E. Deering', '<a href="/rfc/rfc1054" target="_blank">1054</a>, <a href="/rfc/rfc1112" target="_blank">1112</a>', ['1054', '1112'])
#
#
# ('<a href="/rfc/rfc1040" target="_blank">1040</a>, <a href="/rfc/rfc1113" target="_blank">1113</a>                                         UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                   John Linn (BBNCC)', '<a href="/rfc/rfc1040" target="_blank">1040</a>, <a href="/rfc/rfc1113" target="_blank">1113</a>', ['1040', '1113'])
#
#
# ('<a href="/rfc/rfc1010" target="_blank">1010</a>                                              HISTORIC</span><br /><span class="pre noprint docinfo">Updated by: <a href="/rfc/rfc997" target="_blank">997</a>                                                         </span><pre>Network Working Group                                        J. Reynolds', '<a href="/rfc/rfc1010" target="_blank">1010</a>', ['1010'])
#
#
# ('<a href="/rfc/rfc1011" target="_blank">1011</a>                                               UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                        J. Reynolds', '<a href="/rfc/rfc1011" target="_blank">1011</a>', ['1011'])
#
#
# ('<a href="/rfc/rfc1056" target="_blank">1056</a>                                               UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                              David D. Clark (MIT)', '<a href="/rfc/rfc1056" target="_blank">1056</a>', ['1056'])
#
#
# ('<a href="/rfc/rfc1020" target="_blank">1020</a>, <a href="/rfc/rfc1117" target="_blank">1117</a>                                         UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                        J. Reynolds', '<a href="/rfc/rfc1020" target="_blank">1020</a>, <a href="/rfc/rfc1117" target="_blank">1117</a>', ['1020', '1117'])
#
#
# ('<a href="/rfc/rfc1000" target="_blank">1000</a>                                               UNKNOWN</span><br /><span class="pre noprint docinfo">                                                                        </span><pre>Network Working Group                                            A. Westine', '<a href="/rfc/rfc1000" target="_blank">1000</a>', ['1000'])

# %%
for entry in tqdm(pattern_contents['related_rfcs_pattern'], desc="Processing stuff", unit="file"):
    pattern = NUMBERS_PATTERN
    correct_entry = entry.split('    ')[0]
    match = re.findall(pattern, correct_entry, re.DOTALL)
    print(f'{entry, correct_entry, match}\n\n')
# Out:
# Processing stuff: 100%|██████████| 149/149 [00:00<00:00, 149474.12file/s]
# ('</span>', '</span>', [])
#
#
# ('[INTRO:9]  "A Protocol for Packet Network Intercommunication," V. Cerf', '[INTRO:9]  "A Protocol for Packet Network Intercommunication," V. Cerf', ['9'])
#
#
# ('Supported.', 'Supported.', [])
#
#
# ('Supported.', 'Supported.', [])
#
#
# ('Supported.', 'Supported.', [])
#
#
# ('<a href="./rfc129">RFC-129</a> (NIC-5845)', '<a href="./rfc129">RFC-129</a> (NIC-5845)', ['129', '5845'])
#
#
# ('IPMS.Heading.related-IPMs', 'IPMS.Heading.related-IPMs', [])
#
#
# ("Krol, Ed. (1992) The Whole Internet User's Guide and Catalog, 400", "Krol, Ed. (1992) The Whole Internet User's Guide and Catalog, 400", ['1992', '400'])
#
#
# ('As of the publication of this RFC, a version of [12], titled', 'As of the publication of this RFC, a version of [12], titled', ['12'])
#
#
# ('#147, #129</span>', '#147, #129</span>', ['147', '129'])
#
#
# ('134', '134', ['134'])
#
#
# ('109, 110, 105, 158', '109, 110, 105, 158', ['109', '110', '105', '158'])
#
#
# ('[<a id="ref-1">1</a>] IANA, "Class A Subnet Experiment", <a href="./rfc1797">RFC 1797</a>, USC/Information', '[<a id="ref-1">1</a>] IANA, "Class A Subnet Experiment", <a href="./rfc1797">RFC 1797</a>, USC/Information', ['1', '1', '1797'])
#
#
# ('Document #2                                    26 July 1971', 'Document #2', ['2'])
#
#
# ('<a href="./rfc822">RFC 822</a>: 4.6.3', '<a href="./rfc822">RFC 822</a>: 4.6.3', ['822', '4', '6', '3'])
#
#
# ('[<a id="ref-1">1</a>] "Enhanced Man-Machine Interface for Videotex and', '[<a id="ref-1">1</a>] "Enhanced Man-Machine Interface for Videotex and', ['1', '1'])
#
#
# ('Supported.', 'Supported.', [])
#
#
# ('===========', '===========', [])
#
#
# ('===========', '===========', [])
#
#
# ('#226', '#226', ['226'])
#
#
# ('#226, 229', '#226, 229', ['226', '229'])
#
#
# ('#226, 229, 236', '#226, 229, 236', ['226', '229', '236'])
#
#
# ('#226, 236, 239, 233, 237', '#226, 236, 239, 233, 237', ['226', '236', '239', '233', '237'])
#
#
# ('</span>', '</span>', [])
#
#
# ('RFC #246', 'RFC #246', ['246'])
#
#
# ('</span>', '</span>', [])
#
#
# ('Resource Notebook', 'Resource Notebook', [])
#
#
# ('7625, 7626, 7661, 7688, 7650, 7646', '7625, 7626, 7661, 7688, 7650, 7646', ['7625', '7626', '7661', '7688', '7650', '7646'])
#
#
# ('" fields as appropriate, as described below.', '" fields as appropriate, as described below.', [])
#
#
# ('282, 285                              Karl Kelley, U. of Ill.', '282, 285', ['282', '285'])
#
#
# ('line for that article, but does not', 'line for that article, but does not', [])
#
#
# ('None', 'None', [])
#
#
# ('113, 189', '113, 189', ['113', '189'])
#
#
# ('<a href="./rfc254">RFC 254</a>', '<a href="./rfc254">RFC 254</a>', ['254'])
#
#
# ('(in order of relevancy)', '(in order of relevancy)', [])
#
#
# ('information about the problem or solution', 'information about the problem or solution', [])
#
#
# ('<a href="./rfc139">RFC 139</a>, 158, and NIC 7104', '<a href="./rfc139">RFC 139</a>, 158, and NIC 7104', ['139', '158', '7104'])
#
#
# ('313', '313', ['313'])
#
#
# ('<a href="./rfc328">RFC 328</a>', '<a href="./rfc328">RFC 328</a>', ['328'])
#
#
# ('[<a id="ref-RFC2119">RFC2119</a>] Bradner, S., "Key Words for Use in RFCs to Indicate', '[<a id="ref-RFC2119">RFC2119</a>] Bradner, S., "Key Words for Use in RFCs to Indicate', [])
#
#
# ('<a href="./rfc328">RFC 328</a>                                 15 May 1972', '<a href="./rfc328">RFC 328</a>', ['328'])
#
#
# ("RFC's 1, 5, 51", "RFC's 1, 5, 51", ['1', '5', '51'])
#
#
# ('contains one or more references to the specification and', 'contains one or more references to the specification and', [])
#
#
# ("RFC's 322, 204", "RFC's 322, 204", ['322', '204'])
#
#
# ('<a href="./rfc346">RFC 346</a>', '<a href="./rfc346">RFC 346</a>', ['346'])
#
#
# ("RFC's 346, 355, 358, 318                      John McConnell", "RFC's 346, 355, 358, 318", ['346', '355', '358', '318'])
#
#
# ('NIC 6801', 'NIC 6801', ['6801'])
#
#
# ('RFC #292', 'RFC #292', ['292'])
#
#
# ('<a href="./rfc109">RFC 109</a>, 139, 158,318, and 328        3 October 1972', '<a href="./rfc109">RFC 109</a>, 139, 158,318, and 328', ['109', '139', '158', '318', '328'])
#
#
# (':bytes', ':bytes', [])
#
#
# ('122, 399', '122, 399', ['122', '399'])
#
#
# ('[<a id="ref-RFC1881">RFC1881</a>]   The IAB and IESG, "IPv6 Address Allocation Management",', '[<a id="ref-RFC1881">RFC1881</a>]   The IAB and IESG, "IPv6 Address Allocation Management",', [])
#
#
# ('36,318,333,435', '36,318,333,435', ['36', '318', '333', '435'])
#
#
# ('349', '349', ['349'])
#
#
# ('318, 357                                      5 January 1973', '318, 357', ['318', '357'])
#
#
# ('354,385,414,418                             15 January 1973', '354,385,414,418', ['354', '385', '414', '418'])
#
#
# ('"INVALID_KE_PAYLOAD and clarifications document" thread,', '"INVALID_KE_PAYLOAD and clarifications document" thread,', [])
#
#
# ('RFCs 354, 407,', 'RFCs 354, 407,', ['354', '407'])
#
#
# ('282, 258                                               MITRE', '282, 258', ['282', '258'])
#
#
# ('RFCs 473, 485', 'RFCs 473, 485', ['473', '485'])
#
#
# ('RFCs 318, 435; NIC 7104', 'RFCs 318, 435; NIC 7104', ['318', '435', '7104'])
#
#
# ('349, 433', '349, 433', ['349', '433'])
#
#
# ('[<a id="ref-RFC5092">RFC5092</a>] and [<a href="#ref-IMAP4" title="&quot;INTERNET MESSAGE ACCESS PROTOCOL - VERSION 4rev1&quot;">IMAP4</a>].', '[<a id="ref-RFC5092">RFC5092</a>] and [<a href="#ref-IMAP4" title="&quot;INTERNET MESSAGE ACCESS PROTOCOL - VERSION 4rev1&quot;">IMAP4</a>].', [])
#
#
# ('contains one or more references to the specification and the', 'contains one or more references to the specification and the', [])
#
#
# ('header data will cause', 'header data will cause', [])
#
#
# ('RFCs 454, 513,                                     BBN-TENEX', 'RFCs 454, 513,', ['454', '513'])
#
#
# ('" fields as appropriate', '" fields as appropriate', [])
#
#
# ('512, 516, 533', '512, 516, 533', ['512', '516', '533'])
#
#
# ('<a href="./rfc520">RFC 520</a>', '<a href="./rfc520">RFC 520</a>', ['520'])
#
#
# ('For normative and informative references.  Do not restart', 'For normative and informative references.  Do not restart', [])
#
#
# ('524', '524', ['524'])
#
#
# ('" field of the notification message MAY be set to', '" field of the notification message MAY be set to', [])
#
#
# ('<a href="./rfc531">RFC 531</a>,369. 519', '<a href="./rfc531">RFC 531</a>,369. 519', ['531', '369', '519'])
#
#
# ('<a href="./rfc5456">RFC 5456</a> (this document)', '<a href="./rfc5456">RFC 5456</a> (this document)', ['5456'])
#
#
# ('Resent-Date:', 'Resent-Date:', [])
#
#
# ('" SP [CFWS] msg-id *(CFWS msg-id)', '" SP [CFWS] msg-id *(CFWS msg-id)', [])
#
#
# ('<a href="./rfc5538">RFC 5538</a>, [<a href="./rfc4642" title="&quot;Using Transport Layer Security (TLS) with Network News Transfer Protocol (NNTP)&quot;">RFC4642</a>], [<a href="#ref-GILMAN" title="&quot;The \'news\' URL scheme&quot;">GILMAN</a>]', '<a href="./rfc5538">RFC 5538</a>, [<a href="./rfc4642" title="&quot;Using Transport Layer Security (TLS) with Network News Transfer Protocol (NNTP)&quot;">RFC4642</a>], [<a href="#ref-GILMAN" title="&quot;The \'news\' URL scheme&quot;">GILMAN</a>]', ['5538'])
#
#
# ('(DHC JBP <a href="./rfc539">RFC 539</a> -- 17644,3g:gy)', '(DHC JBP <a href="./rfc539">RFC 539</a> -- 17644,3g:gy)', ['539'])
#
#
# ('<a href="./rfc392">RFC 392</a>, 415', '<a href="./rfc392">RFC 392</a>, 415', ['392', '415'])
#
#
# ('RFCs 513, 529', 'RFCs 513, 529', ['513', '529'])
#
#
# ('<a href="./rfc357">RFC 357</a>, <a href="./rfc560">RFC 560</a>', '<a href="./rfc357">RFC 357</a>, <a href="./rfc560">RFC 560</a>', ['357', '560'])
#
#
# ('a) split references into informative/normative references', 'a) split references into informative/normative references', [])
#
#
# ('<a href="./rfc524">RFC 524</a>, 539, 555', '<a href="./rfc524">RFC 524</a>, 539, 555', ['524', '539', '555'])
#
#
# ('see <a href="#section-5">Section 5</a>.', 'see <a href="#section-5">Section 5</a>.', ['5', '5'])
#
#
# ('This document and <a href="./rfc5228">RFC 5228</a> [<a href="#ref-SIEVE" title="&quot;Sieve: An Email Filtering Language&quot;">SIEVE</a>].', 'This document and <a href="./rfc5228">RFC 5228</a> [<a href="#ref-SIEVE" title="&quot;Sieve: An Email Filtering Language&quot;">SIEVE</a>].', ['5228'])
#
#
# ('<a href="./rfc560">RFC 560</a>, <a href="./rfc563">RFC 563</a>                                   MITRE-TIP', '<a href="./rfc560">RFC 560</a>, <a href="./rfc563">RFC 563</a>', ['560', '563'])
#
#
# ('NIC # 20812', 'NIC # 20812', [])
#
#
# ('Host-to-host Protocol           NIC 8246', 'Host-to-host Protocol', [])
#
#
# ('<a href="./rfc6068">RFC 6068</a>', '<a href="./rfc6068">RFC 6068</a>', ['6068'])
#
#
# ('RFC #607, RFC #542', 'RFC #607, RFC #542', ['607', '542'])
#
#
# ('See the References section', 'See the References section', [])
#
#
# ('S. Burleigh, "Compressed Bundle Header Encoding (CBHE)",', 'S. Burleigh, "Compressed Bundle Header Encoding (CBHE)",', [])
#
#
# ('see <a href="./rfc6270#section-5">Section&nbsp;5 of RFC 6270</a>', 'see <a href="./rfc6270#section-5">Section&nbsp;5 of RFC 6270</a>', ['5', '5', '6270'])
#
#
# ('[<a id="ref-1">1</a>] Kleinrock, L. and H. Opderbeck.  "On a Possible Lockup condition', '[<a id="ref-1">1</a>] Kleinrock, L. and H. Opderbeck.  "On a Possible Lockup condition', ['1', '1'])
#
#
# ('" header fields', '" header fields', [])
#
#
# ('See <a href="./rfc6694#section-6">Section&nbsp;6 of RFC 6694</a>.', 'See <a href="./rfc6694#section-6">Section&nbsp;6 of RFC 6694</a>.', ['6', '6', '6694'])
#
#
# ('This specification, particularly Sections <a href="#section-6.2.7">6.2.7</a>, <a href="#section-8.5.2">8.5.2</a>,', 'This specification, particularly Sections <a href="#section-6.2.7">6.2.7</a>, <a href="#section-8.5.2">8.5.2</a>,', ['6', '2', '7', '6', '2', '7', '8', '5', '2', '8', '5', '2'])
#
#
# ('[<a href="./rfc4627" title="&quot;The application/json Media Type for JavaScript Object Notation (JSON)&quot;">RFC4627</a>]', '[<a href="./rfc4627" title="&quot;The application/json Media Type for JavaScript Object Notation (JSON)&quot;">RFC4627</a>]', [])
#
#
# ('"         unstructured CRLF /', '"', [])
#
#
# ('" fields may be excised, which', '" fields may be excised, which', [])
#
#
# ('354, 385, 630, 542, 640.', '354, 385, 630, 542, 640.', ['354', '385', '630', '542', '640'])
#
#
# ('As specified in this document', 'As specified in this document', [])
#
#
# ('<a href="./rfc6940">RFC 6940</a>', '<a href="./rfc6940">RFC 6940</a>', ['6940'])
#
#
# ('References to other RFCs or documents outside the IETF,', 'References to other RFCs or documents outside the IETF,', [])
#
#
# ('[<a href="./rfc7049">RFC7049</a>]', '[<a href="./rfc7049">RFC7049</a>]', [])
#
#
# ('[<a href="./rfc7052">RFC7052</a>]', '[<a href="./rfc7052">RFC7052</a>]', [])
#
#
# ('<a href="./rfc7064">RFC 7064</a>', '<a href="./rfc7064">RFC 7064</a>', ['7064'])
#
#
# ('<a href="./rfc7065">RFC 7065</a>', '<a href="./rfc7065">RFC 7065</a>', ['7065'])
#
#
# ('[<a href="./rfc0793" title="&quot;Transmission Control Protocol&quot;">RFC0793</a>] [<a href="./rfc3168" title="&quot;The Addition of Explicit Congestion Notification (ECN) to IP&quot;">RFC3168</a>] [<a href="./rfc3540" title="&quot;Robust Explicit Congestion Notification (ECN) Signaling with Nonces&quot;">RFC3540</a>]', '[<a href="./rfc0793" title="&quot;Transmission Control Protocol&quot;">RFC0793</a>] [<a href="./rfc3168" title="&quot;The Addition of Explicit Congestion Notification (ECN) to IP&quot;">RFC3168</a>] [<a href="./rfc3540" title="&quot;Robust Explicit Congestion Notification (ECN) Signaling with Nonces&quot;">RFC3540</a>]', [])
#
#
# ('[ISO/IEC.7498-1:1994]', '[ISO/IEC.7498-1:1994]', ['7498', '1', '1994'])
#
#
# ('RFC #680', 'RFC #680', ['680'])
#
#
# ('The contents of this field identify other correspondence which', 'The contents of this field identify other correspondence which', [])
#
#
# ('[<a href="./rfc7176" title="&quot;Transparent Interconnection of Lots of Links (TRILL) Use of IS-IS&quot;">RFC7176</a>], [<a href="./rfc7357">RFC7357</a>]', '[<a href="./rfc7176" title="&quot;Transparent Interconnection of Lots of Links (TRILL) Use of IS-IS&quot;">RFC7176</a>], [<a href="./rfc7357">RFC7357</a>]', [])
#
#
# ('Thornburgh, M., "Adobe\'s Secure Real-Time Media Flow Protocol",', 'Thornburgh, M., "Adobe\'s Secure Real-Time Media Flow Protocol",', [])
#
#
# ('RFCs 2910, 2911, and 7472; IEEE-ISTO PWG 5100.12.', 'RFCs 2910, 2911, and 7472; IEEE-ISTO PWG 5100.12.', ['2910', '2911', '7472', '5100', '12'])
#
#
# ('Crispin, Mark:', 'Crispin, Mark:', [])
#
#
# ('[<a href="./rfc7512">RFC7512</a>]', '[<a href="./rfc7512">RFC7512</a>]', [])
#
#
# ('None.', 'None.', [])
#
#
# ('Include full citations for all referenced documents.  Scheme', 'Include full citations for all referenced documents.  Scheme', [])
#
#
# ('URIs or other references to documentation', 'URIs or other references to documentation', [])
#
#
# ('&lt;<a href="http://fletcher.github.io/MultiMarkdown-4/syntax">http://fletcher.github.io/MultiMarkdown-4/syntax</a>&gt;', '&lt;<a href="http://fletcher.github.io/MultiMarkdown-4/syntax">http://fletcher.github.io/MultiMarkdown-4/syntax</a>&gt;', ['4', '4'])
#
#
# ('<a href="./rfc2326">RFC 2326</a>, <a href="./rfc3986">RFC 3986</a>, <a href="./rfc3987">RFC 3987</a>, and <a href="./rfc7826">RFC 7826</a>', '<a href="./rfc2326">RFC 2326</a>, <a href="./rfc3986">RFC 3986</a>, <a href="./rfc3987">RFC 3987</a>, and <a href="./rfc7826">RFC 7826</a>', ['2326', '3986', '3987', '7826'])
#
#
# ('This document.', 'This document.', [])
#
#
# ('<a href="./rfc7973">RFC 7973</a> (this document)', '<a href="./rfc7973">RFC 7973</a> (this document)', ['7973'])
#
#
# ('This seems too complex to handle at this meeting, so for now send', 'This seems too complex to handle at this meeting, so for now send', [])
#
#
# ('This RFC', 'This RFC', [])
#
#
# ('[<a href="./rfc7464" title="&quot;JavaScript Object Notation (JSON) Text Sequences&quot;">RFC7464</a>], <a href="./rfc8091">RFC 8091</a>', '[<a href="./rfc7464" title="&quot;JavaScript Object Notation (JSON) Text Sequences&quot;">RFC7464</a>], <a href="./rfc8091">RFC 8091</a>', ['8091'])
#
#
# ('<a href="./rfc811">RFC 811</a>, 796', '<a href="./rfc811">RFC 811</a>, 796', ['811', '796'])
#
#
# ('None.', 'None.', [])
#
#
# ('This contains a pointer to the public specification for', 'This contains a pointer to the public specification for', [])
#
#
# ('[<a href="./rfc7357" title="&quot;Transparent Interconnection of Lots of Links (TRILL): End Station Address Distribution Information (ESADI) Protocol&quot;">RFC7357</a>] [<a href="./rfc8171">RFC8171</a>]', '[<a href="./rfc7357" title="&quot;Transparent Interconnection of Lots of Links (TRILL): End Station Address Distribution Information (ESADI) Protocol&quot;">RFC7357</a>] [<a href="./rfc8171">RFC8171</a>]', [])
#
#
# ('[<a id="ref-IEEE-1588-2008">IEEE-1588-2008</a>] IEEE Standard for A Precision Clock', '[<a id="ref-IEEE-1588-2008">IEEE-1588-2008</a>] IEEE Standard for A Precision Clock', ['1588', '2008', '1588', '2008'])
#
#
# ('<a href="./rfc8323#section-8.4">Section&nbsp;8.4 in RFC 8323</a>', '<a href="./rfc8323#section-8.4">Section&nbsp;8.4 in RFC 8323</a>', ['8', '4', '8', '4', '8323'])
#
#
# ('<a href="./rfc7519#section-3">Section&nbsp;3 of [RFC7519]</a>, <a href="./rfc8417#section-7.2">Section&nbsp;7.2 of [RFC8417]</a>', '<a href="./rfc7519#section-3">Section&nbsp;3 of [RFC7519]</a>, <a href="./rfc8417#section-7.2">Section&nbsp;7.2 of [RFC8417]</a>', ['3', '3', '7', '2', '7', '2'])
#
#
# ('[<a href="./rfc6455" title="&quot;The WebSocket Protocol&quot;">RFC6455</a>] [<a href="./rfc8441">RFC8441</a>]', '[<a href="./rfc6455" title="&quot;The WebSocket Protocol&quot;">RFC6455</a>] [<a href="./rfc8441">RFC8441</a>]', [])
#
#
# ('[<a href="./rfc1952" title="&quot;GZIP file format specification version 4.3&quot;">RFC1952</a>] [<a href="./rfc6713" title="&quot;The \'application/zlib\' and \'application/gzip\' Media Types&quot;">RFC6713</a>]', '[<a href="./rfc1952" title="&quot;GZIP file format specification version 4.3&quot;">RFC1952</a>] [<a href="./rfc6713" title="&quot;The \'application/zlib\' and \'application/gzip\' Media Types&quot;">RFC6713</a>]', ['4', '3'])
#
#
# ('&lt;<a href="/cdn-cgi/l/email-protection" class="__cf_email__" data-cfemail="197f78727c37282c2b282d2e2c2f2c2e372c2d2e202e597c61787469757c377a7674">[email&#160;protected]</a>&gt;', '&lt;<a href="/cdn-cgi/l/email-protection" class="__cf_email__" data-cfemail="197f78727c37282c2b282d2e2c2f2c2e372c2d2e202e597c61787469757c377a7674">[email&#160;protected]</a>&gt;', ['160'])
#
#
# ('<a href="./rfc8589">RFC 8589</a>', '<a href="./rfc8589">RFC 8589</a>', ['8589'])
#
#
# ('asMessageIds".', 'asMessageIds".', [])
#
#
# ('[<a href="./rfc8205" title="&quot;BGPsec Protocol Specification&quot;">RFC8205</a>] describes the details of BGPsec,', '[<a href="./rfc8205" title="&quot;BGPsec Protocol Specification&quot;">RFC8205</a>] describes the details of BGPsec,', [])
#
#
# ('RFC 8742<a href="#section-6.3-4.1" class="pilcrow">¶</a>', 'RFC 8742<a href="#section-6.3-4.1" class="pilcrow">¶</a>', ['8742', '6', '3', '4', '1'])
#
#
# ('<a href="./rfc821">RFC 821</a>  Postel, J., "Simple Mail Transfer Protocol", <a href="./rfc821">RFC 821</a>, Network', '<a href="./rfc821">RFC 821</a>  Postel, J., "Simple Mail Transfer Protocol", <a href="./rfc821">RFC 821</a>, Network', ['821', '821'])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('</dt>', '</dt>', [])
#
#
# ('Supported.', 'Supported.', [])

# %% [markdown]
# # Titles

# %%
titles_logger = get_custom_logger(name='titles_logger', log_path="../../logs/titles.log", format="%(message)s")
from dataset.regexes import COLON_SPACE_PATTERN
for html_file in tqdm(raw_dataset_dir.glob("*.html"), desc="Processing RFCs", unit="file"):
    with html_file.open('r', encoding='utf-8') as file:
        html_content = file.read()

        soup = BeautifulSoup(html_content, 'html.parser')
        title_tag = soup.title
        if title_tag:
            title_content = title_tag.text
            match = re.search(COLON_SPACE_PATTERN, title_content, re.DOTALL)
            match_phrase = match.group(1) if match else None
            # print(match_phrase)
            titles_logger.info(match_phrase)
        # else:
            # titles_logger.error(f'No title tag found in the HTML {html_file}')
# Out:
# Processing RFCs: 9266file [03:36, 42.87file/s]

# %% [markdown]
# # Page content

# %%
test_file = Path('../../data/raw_dataset/txt/rfc1720.txt')
with test_file.open('r', encoding='utf-8') as file:
    html_content = file.read()

# %%
soup = BeautifulSoup(html_content, 'html.parser')


def extract_visible_text(soup):
    texts = soup.find_all(string=True)
    visible_texts = []
    for text in texts:
        if text.parent.name not in ['style', 'script', 'head', 'title', 'meta', '[document]']:
            visible_texts.append(text)
    return ' '.join(visible_texts).strip(), visible_texts


visible_text, visible_texts_not_joined = extract_visible_text(soup)
print(visible_texts_not_joined)
# Out:
# []

# %%
from unstructured.partition.auto import partition

elements = partition(filename=test_file)
print("\n\n".join([str(el) for el in elements]))
# Out:
# Network Working Group                        Internet Architecture Board Request for Comments: 1720                             J. Postel, Editor Obsoletes: RFCs 1610, 1600, 1540, 1500,                    November 1994 1410, 1360, 1280, 1250, 1100, 1083, 1130, 1140, 1200 STD: 1 Category: Standards Track
#
# INTERNET OFFICIAL PROTOCOL STANDARDS
#
# Status of this Memo
#
# This memo describes the state of standardization of protocols used in the Internet as determined by the Internet Architecture Board (IAB). This memo is an Internet Standard. Distribution of this memo is unlimited.
#
# Table of Contents
#
# Introduction . . . . . . . . . . . . . . . . . . . . . . . . . . 2 1. The Standardization Process  . . . . . . . . . . . . . . . . 3 2. The Request for Comments Documents . . . . . . . . . . . . . 5 3. Other Reference Documents  . . . . . . . . . . . . . . . . . 6 3.1. Assigned Numbers . . . . . . . . . . . . . . . . . . . . . 6 3.2. Gateway Requirements . . . . . . . . . . . . . . . . . . . 6 3.3. Host Requirements  . . . . . . . . . . . . . . . . . . . . 6 3.4. The MIL-STD Documents  . . . . . . . . . . . . . . . . . . 6 4. Explanation of Terms . . . . . . . . . . . . . . . . . . . . 7 4.1. Definitions of Protocol State (Maturity Level) . . . . . . 8 4.1.1. Standard Protocol  . . . . . . . . . . . . . . . . . . . 8 4.1.2. Draft Standard Protocol  . . . . . . . . . . . . . . . . 9 4.1.3. Proposed Standard Protocol . . . . . . . . . . . . . . . 9 4.1.4. Experimental Protocol  . . . . . . . . . . . . . . . . . 9 4.1.5. Informational Protocol . . . . . . . . . . . . . . . . . 9 4.1.6. Historic Protocol  . . . . . . . . . . . . . . . . . . . 9 4.2. Definitions of Protocol Status (Requirement Level) . . . 9 4.2.1. Required Protocol  . . . . . . . . . . . . . . . . . . 10 4.2.2. Recommended Protocol . . . . . . . . . . . . . . . . . 10 4.2.3. Elective Protocol  . . . . . . . . . . . . . . . . . . 10 4.2.4. Limited Use Protocol . . . . . . . . . . . . . . . . . 10 4.2.5. Not Recommended Protocol . . . . . . . . . . . . . . . 10 5. The Standards Track  . . . . . . . . . . . . . . .
#
# . . . . 10 5.1. The RFC Processing Decision Table  . . . . . . . . . . . 10 5.2. The Standards Track Diagram  . . . . . . . . . . . . . . 12 6. The Protocols  . . . . . . . . . . . . . . . . . . . . . . 14 6.1. Recent Changes . . . . . . . . . . . . . . . . . . . . . 14
#
# Internet Architecture Board                                     [Page 1]
#
# RFC 1720                   Internet Standards              November 1994
#
# 6.1.1. New RFCs . . . . . . . . . . . . . . . . . . . . . . . 14 6.1.2. Other Changes  . . . . . . . . . . . . . . . . . . . . 23 6.2. Standard Protocols . . . . . . . . . . . . . . . . . . . 24 6.3. Network-Specific Standard Protocols  . . . . . . . . . . 26 6.4. Draft Standard Protocols . . . . . . . . . . . . . . . . 27 6.5. Proposed Standard Protocols  . . . . . . . . . . . . . . 28 6.6. Telnet Options . . . . . . . . . . . . . . . . . . . . . 31 6.7. Experimental Protocols . . . . . . . . . . . . . . . . . 32 6.8. Informational Protocols  . . . . . . . . . . . . . . . . 33 6.9. Historic Protocols . . . . . . . . . . . . . . . . . . . 34 6.10  Obsolete Protocols . . . . . . . . . . . . . . . . . . . 36 7. Contacts . . . . . . . . . . . . . . . . . . . . . . . . . 37 7.1. IAB, IETF, and IRTF Contacts . . . . . . . . . . . . . . 37 7.1.1. Internet Architecture Board (IAB) Contact  . . . . . . 37 7.1.2. Internet Engineering Task Force (IETF) Contact . . . . 38 7.1.3. Internet Research Task Force (IRTF) Contact  . . . . . 39 7.2. Internet Assigned Numbers Authority (IANA) Contact . . . 39 7.3. Request for Comments Editor Contact  . . . . . . . . . . 40 7.4. Network Information Center Contact . . . . . . . . . . . 40 7.5. Sources for Requests for Comments  . . . . . . . . . . . 41 8. Security Considerations  . . . . . . . . . . . . . . . . . 41 9. Author's Address . . . . . . . . . . . . . . . . . . . . . 41
#
# Introduction
#
# A discussion of the standardization process and the RFC document series is presented first, followed by an explanation of the terms. Sections 6.2 - 6.10 contain the lists of protocols in each stage of standardization. Finally are pointers to references and contacts for further information.
#
# This memo is intended to be issued approximately quarterly; please be sure the copy you are reading is current. Current copies may be obtained from the Network Information Center (INTERNIC) or from the Internet Assigned Numbers Authority (IANA) (see the contact information at the end of this memo). Do not use this edition after 1-Mar-95.
#
# See Section 6.1 for a description of recent changes. In the official lists in sections 6.2 - 6.10, an asterisk (*) next to a protocol denotes that it is new to this document or has been moved from one protocol level to another, or differs from the previous edition of this document.
#
# Internet Architecture Board                                     [Page 2]
#
# RFC 1720                   Internet Standards              November 1994
#
# 1. The Standardization Process
#
# The Internet Architecture Board maintains this list of documents that define standards for the Internet protocol suite. See RFC-1601 for the charter of the IAB and RFC-1160 for an explanation of the role and organization of the IAB and its subsidiary groups, the Internet Engineering Task Force (IETF) and the Internet Research Task Force (IRTF). Each of these groups has a steering group called the IESG and IRSG, respectively. The IETF develops these standards with the goal of co-ordinating the evolution of the Internet protocols; this co-ordination has become quite important as the Internet protocols are increasingly in general commercial use. The definitive description of the Internet standards process is found in RFC-1602.
#
# The majority of Internet protocol development and standardization activity takes place in the working groups of the IETF.
#
# Protocols which are to become standards in the Internet go through a series of states or maturity levels (proposed standard, draft standard, and standard) involving increasing amounts of scrutiny and testing. When a protocol completes this process it is assigned a STD number (see RFC-1311). At each step, the Internet Engineering Steering Group (IESG) of the IETF must make a recommendation for advancement of the protocol.
#
# To allow time for the Internet community to consider and react to standardization proposals, a minimum delay of 6 months before a proposed standard can be advanced to a draft standard and 4 months before a draft standard can be promoted to standard.
#
# It is general practice that no proposed standard can be promoted to draft standard without at least two independent implementations (and the recommendation of the IESG). Promotion from draft standard to standard generally requires operational experience and demonstrated interoperability of two or more implementations (and the recommendation of the IESG).
#
# In cases where there is uncertainty as to the proper decision concerning a protocol a special review committee may be appointed consisting of experts from the IETF, IRTF and the IAB with the purpose of recommending an explicit action.
#
# Advancement of a protocol to proposed standard is an important step since it marks a protocol as a candidate for eventual standardization (it puts the protocol "on the standards track"). Advancement to draft standard is a major step which warns the community that, unless major objections are raised or flaws are discovered, the protocol is likely to be advanced to standard in six months.
#
# Internet Architecture Board                                     [Page 3]
#
# RFC 1720                   Internet Standards              November 1994
#
# Some protocols have been superseded by better ones or are otherwise unused. Such protocols are still documented in this memorandum with the designation "historic".
#
# Because it is useful to document the results of early protocol research and development work, some of the RFCs document protocols which are still in an experimental condition. The protocols are designated "experimental" in this memorandum. They appear in this report as a convenience to the community and not as evidence of their standardization.
#
# Other protocols, such as those developed by other standards organizations, or by particular vendors, may be of interest or may be recommended for use in the Internet. The specifications of such protocols may be published as RFCs for the convenience of the Internet community. These protocols are labeled "informational" in this memorandum.
#
# In addition to the working groups of the IETF, protocol development and experimentation may take place as a result of the work of the research groups of the Internet Research Task Force, or the work of other individuals interested in Internet protocol development. The the documentation of such experimental work in the RFC series is encouraged, but none of this work is considered to be on the track for standardization until the IESG has made a recommendation to advance the protocol to the proposed standard state.
#
# A few protocols have achieved widespread implementation without the approval of the IESG. For example, some vendor protocols have become very important to the Internet community even though they have not been recommended by the IESG. However, the IAB strongly recommends that the standards process be used in the evolution of the protocol suite to maximize interoperability (and to prevent incompatible protocol requirements from arising). The use of the terms "standard", "draft standard", and "proposed standard" are reserved in any RFC or other publication of Internet protocols to only those protocols which the IESG has approved.
#
# In addition to a state (like "Proposed Standard"), a protocol is also assigned a status, or requirement level, in this document. The possible requirement levels ("Required", "Recommended", "Elective", "Limited Use", and "Not Recommended") are defined in Section 4.2. When a protocol is on the standards track, that is in the proposed standard, draft standard, or standard state (see Section 5), the status shown in Section 6 is the current status.
#
# Few protocols are required to be implemented in all systems; this is because there is such a variety of possible systems, for example,
#
# Internet Architecture Board                                     [Page 4]
#
# RFC 1720                   Internet Standards              November 1994
#
# gateways, routers, terminal servers, workstations, and multi-user hosts. The requirement level shown in this document is only a one word label, which may not be sufficient to characterize the implementation requirements for a protocol in all situations. For some protocols, this document contains an additional status paragraph (an applicability statement). In addition, more detailed status information may be contained in separate requirements documents (see Section 3).
#
# 2. The Request for Comments Documents
#
# The documents called Request for Comments (or RFCs) are the working notes of the "Network Working Group", that is the Internet research and development community. A document in this series may be on essentially any topic related to computer communication, and may be anything from a meeting report to the specification of a standard.
#
# Notice:
#
# All standards are published as RFCs, but not all RFCs specify standards.
#
# Anyone can submit a document for publication as an RFC. Submissions must be made via electronic mail to the RFC Editor (see the contact information at the end of this memo, and see RFC 1543).
#
# While RFCs are not refereed publications, they do receive technical review from the task forces, individual technical experts, or the RFC Editor, as appropriate.
#
# The RFC series comprises a wide range of documents, ranging from informational documents of general interests to specifications of standard Internet protocols. In cases where submission is intended to document a proposed standard, draft standard, or standard protocol, the RFC Editor will publish the document only with the approval of the IESG. For documents describing experimental work, the RFC Editor will notify the IESG before publication, allowing for the possibility of review by the relevant IETF working group or IRTF research group and provide those comments to the author. See Section 5.1 for more detail.
#
# Once a document is assigned an RFC number and published, that RFC is never revised or re-issued with the same number. There is never a question of having the most recent version of a particular RFC. However, a protocol (such as File Transfer Protocol (FTP)) may be improved and re-documented many times in several different RFCs. It is important to verify that you have the most recent RFC on a particular protocol. This "Internet Official Protocol Standards"
#
# Internet Architecture Board                                     [Page 5]
#
# RFC 1720                   Internet Standards              November 1994
#
# memo is the reference for determining the correct RFC for the current specification of each protocol.
#
# The RFCs are available from the INTERNIC, and a number of other sites. For more information about obtaining RFCs, see Sections 7.4 and 7.5.
#
# 3. Other Reference Documents
#
# There are three other reference documents of interest in checking the current status of protocol specifications and standardization. These are the Assigned Numbers, the Gateway Requirements, and the Host Requirements. Note that these documents are revised and updated at different times; in case of differences between these documents, the most recent must prevail.
#
# Also, one should be aware of the MIL-STD publications on IP, TCP, Telnet, FTP, and SMTP. These are described in Section 3.4.
#
# 3.1. Assigned Numbers
#
# The "Assigned Numbers" document lists the assigned values of the parameters used in the various protocols. For example, IP protocol codes, TCP port numbers, Telnet Option Codes, ARP hardware types, and Terminal Type names. Assigned Numbers was most recently issued as RFC-1700.
#
# 3.2. Gateway Requirements
#
# This document reviews the specifications that apply to gateways and supplies guidance and clarification for any ambiguities. Gateway Requirements is RFC-1009. A working group of the IETF is actively preparing a revision.
#
# 3.3. Host Requirements
#
# This pair of documents reviews and updates the specifications that apply to hosts, and it supplies guidance and clarification for any ambiguities. Host Requirements was issued as RFC-1122 and RFC-1123.
#
# 3.4. The MIL
#
#
#
# STD Documents
#
# The Internet community specifications for IP (RFC-791) and TCP (RFC- 793) and the DoD MIL-STD specifications are intended to describe exactly the same protocols. Any difference in the protocols specified by these sets of documents should be reported to DISA and to the IESG. The RFCs and the MIL-STDs for IP and TCP differ in style and level of detail. It is strongly advised that the two sets
#
# Internet Architecture Board                                     [Page 6]
#
# RFC 1720                   Internet Standards              November 1994
#
# of documents be used together, along with RFC-1122 and RFC-1123.
#
# The Internet and the DoD MIL-STD specifications for the FTP, SMTP, and Telnet protocols are essentially the same documents (RFCs 765, 821, 854). The MIL-STD versions have been edited slightly. Note that the current Internet specification for FTP is RFC-959 (as modified by RFC-1123).
#
# Note that these MIL-STD are now somewhat out of date. The Gateway Requirements (RFC-1009) and Host Requirements (RFC-1122, RFC-1123) take precedence over both earlier RFCs and the MIL-STDs.
#
# Internet Protocol (IP)                      MIL-STD-1777 Transmission Control Protocol (TCP)         MIL-STD-1778 File Transfer Protocol (FTP)                MIL-STD-1780 Simple Mail Transfer Protocol (SMTP)        MIL-STD-1781 Telnet Protocol and Options (TELNET)        MIL-STD-1782
#
# These documents are available from the Naval Publications and Forms Center. Requests can be initiated by telephone, telegraph, or mail; however, it is preferred that private industry use form DD1425, if possible.
#
# Naval Publications and Forms Center, Code 3015 5801 Tabor Ave Philadelphia, PA 19120 Phone: 1-215-697-3321 (order tape) 1-215-697-4834 (conversation)
#
# 4. Explanation of Terms
#
# There are two independent categorization of protocols. The first is the "maturity level" or STATE of standardization, one of "standard", "draft standard", "proposed standard", "experimental", "informational" or "historic". The second is the "requirement level" or STATUS of this protocol, one of "required", "recommended", "elective", "limited use", or "not recommended".
#
# The status or requirement level is difficult to portray in a one word label. These status labels should be considered only as an indication, and a further description, or applicability statement, should be consulted.
#
# When a protocol is advanced to proposed standard or draft standard, it is labeled with a current status.
#
# Internet Architecture Board                                     [Page 7]
#
# RFC 1720                   Internet Standards              November 1994
#
# At any given time a protocol occupies a cell of the following matrix. Protocols are likely to be in cells in about the following proportions (indicated by the relative number of Xs). A new protocol is most likely to start in the (proposed standard, elective) cell, or the (experimental, not recommended) cell.
#
# S T A T U S Req   Rec   Ele   Lim   Not +-----+-----+-----+-----+-----+ Std     |  X  | XXX | XXX |     |     | S           +-----+-----+-----+-----+-----+ Draft   |  X  |  X  | XXX |     |     | T           +-----+-----+-----+-----+-----+ Prop    |     |  X  | XXX |     |     | A           +-----+-----+-----+-----+-----+ Info    |     |     |     |     |     | T           +-----+-----+-----+-----+-----+ Expr    |     |     |     | XXX |     | E           +-----+-----+-----+-----+-----+ Hist    |     |     |     |     | XXX | +-----+-----+-----+-----+-----+
#
# What is a "system"?
#
# Some protocols are particular to hosts and some to gateways; a few protocols are used in both. The definitions of the terms below will refer to a "system" which is either a host or a gateway (or both). It should be clear from the context of the particular protocol which types of systems are intended.
#
# 4.1. Definitions of Protocol State
#
# Every protocol listed in this document is assigned to a "maturity level" or STATE of standardization: "standard", "draft standard", "proposed standard", "experimental", or "historic".
#
# 4.1.1. Standard Protocol
#
# The IESG has established this as an official standard protocol for the Internet. These protocols are assigned STD numbers (see RFC- 1311). These are separated into two groups: (1) IP protocol and above, protocols that apply to the whole Internet; and (2) network-specific protocols, generally specifications of how to do IP on particular types of networks.
#
# Internet Architecture Board                                     [Page 8]
#
# RFC 1720                   Internet Standards              November 1994
#
# 4.1.2. Draft Standard Protocol
#
# The IESG is actively considering this protocol as a possible Standard Protocol. Substantial and widespread testing and comment are desired. Comments and test results should be submitted to the IESG. There is a possibility that changes will be made in a Draft Standard Protocol before it becomes a Standard Protocol.
#
# 4.1.3. Proposed Standard Protocol
#
# These are protocol proposals that may be considered by the IESG for standardization in the future. Implementation and testing by several groups is desirable. Revision of the protocol specification is likely.
#
# 4.1.4. Experimental Protocol
#
# A system should not implement an experimental protocol unless it is participating in the experiment and has coordinated its use of the protocol with the developer of the protocol.
#
# Typically, experimental protocols are those that are developed as part of an ongoing research project not related to an operational service offering. While they may be proposed as a service protocol at a later stage, and thus become proposed standard, draft standard, and then standard protocols, the designation of a protocol as experimental may sometimes be meant to suggest that the protocol, although perhaps mature, is not intended for operational use.
#
# 4.1.5. Informational Protocol
#
# Protocols developed by other standard organizations, or vendors, or that are for other reasons outside the purview of the IESG, may be published as RFCs for the convenience of the Internet community as informational protocols.
#
# 4.1.6. Historic Protocol
#
# These are protocols that are unlikely to ever become standards in the Internet either because they have been superseded by later developments or due to lack of interest.
#
# 4.2. Definitions of Protocol Status
#
# This document lists a "requirement level" or STATUS for each protocol. The status is one of "required", "recommended", "elective", "limited use", or "not recommended".
#
# Internet Architecture Board                                     [Page 9]
#
# RFC 1720                   Internet Standards              November 1994
#
# 4.2.1. Required Protocol
#
# A system must implement the required protocols.
#
# 4.2.2. Recommended Protocol
#
# A system should implement the recommended protocols.
#
# 4.2.3. Elective Protocol
#
# A system may or may not implement an elective protocol. The general notion is that if you are going to do something like this, you must do exactly this. There may be several elective protocols in a general area, for example, there are several electronic mail protocols, and several routing protocols.
#
# 4.2.4. Limited Use Protocol
#
# These protocols are for use in limited circumstances. This may be because of their experimental state, specialized nature, limited functionality, or historic state.
#
# 4.2.5. Not Recommended Protocol
#
# These protocols are not recommended for general use. This may be because of their limited functionality, specialized nature, or experimental or historic state.
#
# 5. The Standards Track
#
# This section discusses in more detail the procedures used by the RFC Editor and the IESG in making decisions about the labeling and publishing of protocols as standards.
#
# 5.1. The RFC Processing Decision Table
#
# Here is the current decision table for processing submissions by the RFC Editor. The processing depends on who submitted it, and the status they want it to have.
#
# Internet Architecture Board                                    [Page 10]
#
# RFC 1720                   Internet Standards              November 1994
#
# +==========================================================+ |**************|               S O U R C E                 | +==========================================================+ | Desired      |    IAB   |   IESG   |   IRSG   |  Other   | | Status       |          |          |          |          | +==========================================================+ |              |          |          |          |          | | Standard     |  Bogus   |  Publish |  Bogus   |  Bogus   | | or           |   (2)    |   (1)    |   (2)    |   (2)    | | Draft        |          |          |          |          | | Standard     |          |          |          |          | +--------------+----------+----------+----------+----------+ |              |          |          |          |          | |              |  Refer   |  Publish |  Refer   |  Refer   | | Proposed     |   (3)    |   (1)    |   (3)    |   (3)    |
#
# | Standard     |          |          |          |          | |              |          |          |          |          | +--------------+----------+----------+----------+----------+ |              |          |          |          |          | |              |  Notify  |  Publish |  Notify  |  Notify  | | Experimental |   (4)    |   (1)    |   (4)    |   (4)    | | Protocol     |          |          |          |          | |              |          |          |          |          | +--------------+----------+----------+----------+----------+ |              |          |          |          |          | | Information  |  Publish |  Publish |Discretion|Discretion| | or Opinion   |   (1)    |   (1)    |   (5)    |   (5)    | | Paper        |          |          |          |          | |              |          |          |          |          | +==========================================================+
#
# (1) Publish.
#
# (2) Bogus. Inform the source of the rules. RFCs specifying Standard, or Draft Standard must come from the IESG, only.
#
# (3) Refer to an Area Director for review by a WG. Expect to see the document again only after approval by the IESG.
#
# (4) Notify both the IESG and IRSG. If no concerns are raised in two weeks then do Discretion (5), else RFC Editor to resolve the concerns or do Refer (3).
#
# (5) RFC Editor's discretion. The RFC Editor decides if a review is needed and if so by whom. RFC Editor decides to publish or not.
#
# Internet Architecture Board                                    [Page 11]
#
# RFC 1720                   Internet Standards              November 1994
#
# Of course, in all cases the RFC Editor can request or make minor changes for style, format, and presentation purposes.
#
# The IESG has designated the IESG Secretary as its agent for forwarding documents with IESG approval and for registering concerns in response to notifications (4) to the RFC Editor. Documents from Area Directors or Working Group Chairs may be considered in the same way as documents from "other".
#
# 5.2. The Standards Track Diagram
#
# There is a part of the STATUS and STATE categorization that is called the standards track. Actually, only the changes of state are significant to the progression along the standards track, though the status assignments may change as well.
#
# The states illustrated by single line boxes are temporary states, those illustrated by double line boxes are long term states. A protocol will normally be expected to remain in a temporary state for several months (minimum six months for proposed standard, minimum four months for draft standard). A protocol may be in a long term state for many years.
#
# A protocol may enter the standards track only on the recommendation of the IESG; and may move from one state to another along the track only on the recommendation of the IESG. That is, it takes action by the IESG to either start a protocol on the track or to move it along.
#
# Generally, as the protocol enters the standards track a decision is made as to the eventual STATUS, requirement level or applicability (elective, recommended, or required) the protocol will have, although a somewhat less stringent current status may be assigned, and it then is placed in the the proposed standard STATE with that status. So the initial placement of a protocol is into state 1. At any time the STATUS decision may be revisited.
#
# Internet Architecture Board                                    [Page 12]
#
# RFC 1720                   Internet Standards              November 1994
#
# | +<----------------------------------------------+ |                                               ^ V    0                                          |    4 +-----------+                                   +===========+ |   enter   |-->----------------+-------------->|experiment | +-----------+                   |               +=====+=====+ |                     | V    1                | +-----------+               V | proposed  |-------------->+ +--->+-----+-----+               | |          |                     | |          V    2                | +<---+-----+-----+               V | draft std |-------------->+ +--->+-----+-----+               | |          |                     | |          V    3                | +<---+=====+=====+               V | standard  |-------------->+ +=====+=====+               | | V    5 +=====+=====+ | historic  | +===========+
#
# The transition from proposed standard (1) to draft standard (2) can only be by action of the IESG and only after the protocol has been proposed standard (1) for at least six months.
#
# The transition from draft standard (2) to standard (3) can only be by action of the IESG and only after the protocol has been draft standard (2) for at least four months.
#
# Occasionally, the decision may be that the protocol is not ready for standardization and will be assigned to the experimental state (4). This is off the standards track, and the protocol may be resubmitted to enter the standards track after further work. There are other paths into the experimental and historic states that do not involve IESG action.
#
# Sometimes one protocol is replaced by another and thus becomes historic, or it may happen that a protocol on the standards track is in a sense overtaken by another protocol (or other events) and becomes historic (state 5).
#
# Internet Architecture Board                                    [Page 13]
#
# RFC 1720                   Internet Standards              November 1994
#
# 6. The Protocols
#
# Subsection 6.1 lists recent RFCs and other changes. Subsections 6.2 - 6.10 list the standards in groups by protocol state.
#
# 6.1. Recent Changes
#
# 6.1.1. New RFCs:
#
# 1725
#
#
#
# Post Office Protocol
#
#
#
# Version 3
#
# A Draft Standard protocol.
#
# 1724 - RIP Version 2 MIB Extension
#
# A Draft Standard protocol.
#
# 1723
#
#
#
# RIP Version 2
#
#
#
# Carrying Additional Information
#
# A Draft Standard protocol.
#
# 1722 - RIP Version 2 Protocol Applicability Statement
#
# A Draft Standard protocol.
#
# 1721 - RIP Version 2 Protocol Analysis
#
# This is an information document and does not specify any level of standard.
#
# 1720
#
#
#
# Internet Official Protocol Standards
#
# This memo.
#
# 1719
#
#
#
# Not yet issued.
#
# 1718 - The Tao of IETF - A Guide for New Attendees of the Internet Engineering Task Force
#
# This is an information document and does not specify any level of standard.
#
# 1717 - The PPP Multilink Protocol (MP)
#
# A Proposed Standard protocol.
#
# Internet Architecture Board                                    [Page 14]
#
# RFC 1720                   Internet Standards              November 1994
#
# 1716 - Towards Requirements for IP Routers
#
# This is an information document and does not specify any level of standard.
#
# 1715 - The H Ratio for Address Assignment Efficiency
#
# This is an information document and does not specify any level of standard.
#
# 1714
#
#
#
# Referral Whois Protocol (RWhois)
#
# This is an information document and does not specify any level of standard.
#
# 1713
#
#
#
# Tools for DNS debugging
#
# This is an information document and does not specify any level of standard.
#
# 1712 - DNS Encoding of Geographical Location
#
# An Experimental protocol.
#
# 1711
#
#
#
# Classifications in E
#
#
#
# mail Routing
#
# This is an information document and does not specify any level of standard.
#
# 1710 - Simple Internet Protocol Plus White Paper
#
# This is an information document and does not specify any level of standard.
#
# 1709
#
#
#
# K
#
#
#
# 12 Internetworking Guidelines
#
# This is an information document and does not specify any level of standard.
#
# 1708 - NTP PICS PROFORMA - For the Network Time Protocol Version 3
#
# This is an information document and does not specify any level of standard.
#
# 1707 - CATNIP: Common Architecture for the Internet
#
# This is an information document and does not specify any level of standard.
#
# Internet Architecture Board                                    [Page 15]
#
# RFC 1720                   Internet Standards              November 1994
#
# 1706
#
#
#
# DNS NSAP Resource Records
#
# This is an information document and does not specify any level of standard.
#
# 1705 - Six Virtual Inches to the Left: The Problem with IPng
#
# This is an information document and does not specify any level of standard.
#
# 1704
#
#
#
# On Internet Authentication
#
# This is an information document and does not specify any level of standard.
#
# 1703 - Principles of Operation for the TPC.INT Subdomain: Radio Paging -- Technical Procedures
#
# This is an information document and does not specify any level of standard.
#
# 1702 - Generic Routing Encapsulation over IPv4 networks
#
# This is an information document and does not specify any level of standard.
#
# 1701
#
#
#
# Generic Routing Encapsulation (GRE)
#
# This is an information document and does not specify any level of standard.
#
# 1700
#
#
#
# Assigned Numbers
#
# A status report on the parameters (i.e., numbers and keywords) used in protocols in the Internet community.
#
# 1699
#
#
#
# Not yet issued.
#
# 1698 - Octet Sequences for Upper-Layer OSI to Support Basic Communications Applications
#
# This is an information document and does not specify any level of standard.
#
# 1697 - Relational Database Management System (RDBMS) Management Information Base (MIB) using SMIv2
#
# A Proposed Standard protocol.
#
# Internet Architecture Board                                    [Page 16]
#
# RFC 1720                   Internet Standards              November 1994
#
# 1696 - Modem Management Information Base (MIB) using SMIv2
#
# A Proposed Standard protocol.
#
# 1695 - Definitions of Managed Objects for ATM Management Version 8.0 using SMIv2
#
# A Proposed Standard protocol.
#
# 1694 - Definitions of Managed Objects for SMDS Interfaces using SMIv2
#
# A Draft Standard protocol.
#
# 1693 - An Extension to TCP : Partial Order Service
#
# An Experimental protocol.
#
# 1692
#
#
#
# Transport Multiplexing Protocol (TMux)
#
# This is an information document and does not specify any level of standard.
#
# 1691 - The Document Architecture for the Cornell Digital Library
#
# This is an information document and does not specify any level of standard.
#
# 1690 - Introducing the Internet Engineering and Planning Group (IEPG)
#
# This is an information document and does not specify any level of standard.
#
# 1689 - A Status Report on Networked Information Retrieval: Tools and Groups
#
# This is an information document and does not specify any level of standard.
#
# 1688
#
#
#
# IPng Mobility Considerations
#
# This is an information document and does not specify any level of standard.
#
# Internet Architecture Board                                    [Page 17]
#
# RFC 1720                   Internet Standards              November 1994
#
# 1687 -  A Large Corporate User's View of IPng
#
# This is an information document and does not specify any level of standard.
#
# 1686 - IPng Requirements: A Cable Television Industry Viewpoint
#
# This is an information document and does not specify any level of standard.
#
# 1685
#
#
#
# Writing X.400 O/R Names
#
# This is an information document and does not specify any level of standard.
#
# 1684 - Introduction to White Pages Services based on X.500
#
# This is an information document and does not specify any level of standard.
#
# 1683
#
#
#
# Multiprotocol Interoperability In IPng
#
# This is an information document and does not specify any level of standard.
#
# 1682 - IPng BSD Host Implementation Analysis
#
# This is an information document and does not specify any level of standard.
#
# 1681 - On Many Addresses per Host
#
# This is an information document and does not specify any level of standard.
#
# 1680 - IPng Support for ATM Services
#
# This is an information document and does not specify any level of standard.
#
# 1679 - HPN Working Group Input to the IPng Requirements Solicitation
#
# This is an information document and does not specify any level of standard.
#
# Internet Architecture Board                                    [Page 18]
#
# RFC 1720                   Internet Standards              November 1994
#
# 1678 - IPng Requirements of Large Corporate Networks
#
# This is an information document and does not specify any level of standard.
#
# 1677 - Tactical Radio Frequency Communication Requirments for IPng
#
# This is an information document and does not specify any level of standard.
#
# 1676 - INFN Requirements for an IPng
#
# This is an information document and does not specify any level of standard.
#
# 1675
#
#
#
# Security Concerns for IPng
#
# This is an information document and does not specify any level of standard.
#
# 1674 - Electric Power Research Institute Comments on IPng
#
# This is an information document and does not specify any level of standard.
#
# 1673 - Electric Power Research Institute Comments on IPng
#
# This is an information document and does not specify any level of standard.
#
# 1672
#
#
#
# Accounting Requirements for IPng
#
# This is an information document and does not specify any level of standard.
#
# 1671 - IPng White Paper on Transition and Other Considerations
#
# This is an information document and does not specify any level of standard.
#
# 1670 - Input to IPng Engineering Considerations
#
# This is an information document and does not specify any level of standard.
#
# Internet Architecture Board                                    [Page 19]
#
# RFC 1720                   Internet Standards              November 1994
#
# 1669 - Market Viability as a IPng Criteria
#
# This is an information document and does not specify any level of standard.
#
# 1668 - Unified Routing Requirements for IPng
#
# This is an information document and does not specify any level of standard.
#
# 1667 - Modeling and Simulation Requirements for IPng
#
# This is an information document and does not specify any level of standard.
#
# 1666 - Definitions of Managed Objects for SNA NAUs using SMIv2
#
# A Proposed Standard protocol.
#
# 1665 - Definitions of Managed Objects for SNA NAUs using SMIv2
#
# A Proposed Standard protocol.
#
# 1664 - Using the Internet DNS to Distribute RFC1327 Mail Address Mapping Tables
#
# An Experimental protocol.
#
# 1663
#
#
#
# PPP Reliable Transmission
#
# A Proposed Standard protocol.
#
# 1662
#
#
#
# The Point
#
#
#
# to
#
#
#
# Point Protocol (PPP)
#
# A Standard protocol.
#
# 1661
#
#
#
# The Point
#
#
#
# to
#
#
#
# Point Protocol (PPP)
#
# A Standard protocol.
#
# 1660 - Definitions of Managed Objects for Parallel-printer-like Hardware Devices using SMIv2
#
# A Draft Standard protocol.
#
# Internet Architecture Board                                    [Page 20]
#
# RFC 1720                   Internet Standards              November 1994
#
# 1659 - Definitions of Managed Objects for RS-232-like Hardware Devices using SMIv2
#
# A Draft Standard protocol.
#
# 1658 - Definitions of Managed Objects for Character Stream Devices using SMIv2
#
# A Draft Standard protocol.
#
# 1657 - Definitions of Managed Objects for the Fourth Version of the Border Gateway Protocol (BGP-4) using SMIv2
#
# A Proposed Standard protocol.
#
# 1656 - BGP-4 Protocol Document Roadmap and Implementation Experience
#
# This is an information document and does not specify any level of standard.
#
# 1655 - Application of the Border Gateway Protocol in the Internet
#
# A Proposed Standard protocol.
#
# 1654 - A Border Gateway Protocol 4 (BGP-4)
#
# A Proposed Standard protocol.
#
# 1653 - SMTP Service Extension for Message Size Declaration
#
# A Draft Standard protocol.
#
# 1652 - SMTP Service Extension for 8bit-MIMEtransport
#
# A Draft Standard protocol.
#
# 1651
#
#
#
# SMTP Service Extensions
#
# A Draft Standard protocol.
#
# 1650 - Definitions of Managed Objects for the Ethernet-like Interface Types using SMIv2
#
# A Proposed Standard protocol.
#
# Internet Architecture Board                                    [Page 21]
#
# RFC 1720                   Internet Standards              November 1994
#
# 1649 - Operational Requirements for X.400 Management Domains in the GO-MHS Community
#
# This is an information document and does not specify any level of standard.
#
# 1648 - Postmaster Convention for X.400 Operations
#
# A Proposed Standard protocol.
#
# 1647
#
#
#
# TN3270 Enhancements
#
# A Proposed Standard protocol.
#
# 1646 - TN3270 Extensions for LUname and Printer Selection
#
# This is an information document and does not specify any level of standard.
#
# 1645
#
#
#
# Simple Network Paging Protocol
#
#
#
# Version 2
#
# This is an information document and does not specify any level of standard.
#
# 1644 - T/TCP -- TCP Extensions for Transactions Functional Specification
#
# An Experimental protocol.
#
# 1643 - Definitions of Managed Objects for the Ethernet-like Interface Type
#
# A Standard protocol.
#
# 1642 - UTF-7 - A Mail-Safe Transformation Format of Unicode
#
# An Experimental protocol.
#
# 1641
#
#
#
# Using Unicode with MIME
#
# An Experimental protocol.
#
# Internet Architecture Board                                    [Page 22]
#
# RFC 1720                   Internet Standards              November 1994
#
# 6.1.2. Other Changes:
#
# The following are changes to protocols listed in the previous edition.
#
# 904
#
#
#
# Exterior Gateway Protocol
#
# Moved to Historic.
#
# Internet Architecture Board                                    [Page 23]
#
# RFC 1720                   Internet Standards              November 1994
#
# 6.2. Standard Protocols
#
# Protocol   Name                                      Status    RFC STD * ========   =====================================     ======== ==== === = --------   Internet Official Protocol Standards      Req      1720   1 --------   Assigned Numbers                          Req      1700   2 --------   Host Requirements - Communications        Req      1122   3 --------   Host Requirements - Applications          Req      1123   3 --------   Gateway Requirements                      Req      1009   4 IP         Internet Protocol                         Req       791   5 as amended by:-------- --------     IP Subnet Extension                     Req       950   5 --------     IP Broadcast Datagrams                  Req       919   5 --------     IP Broadcast Datagrams with Subnets     Req       922   5 ICMP       Internet Control Message Protocol         Req       792   5 IGMP       Internet Group Multicast Protocol         Rec      1112   5 UDP        User Datagram Protocol                    Rec       768   6 TCP        Transmission Control Protocol             Rec       793   7 TELNET     Telnet Protocol                           Rec   854,855   8 FTP        File Transfer Protocol                    Rec       959   9 SMTP       Simple Mail Transfer Protocol             Rec       821  10 MAIL       Format of Electronic Mail Messages        Rec       822  11 CONTENT    Content Type Header Field                 Rec      1049  11 NTPV2      Network Time
#
# Protocol (Version 2)         Rec      1119  12 DOMAIN     Domain Name System                        Rec 1034,1035  13 DNS-MX     Mail Routing and the Domain System        Rec       974  14 SNMP       Simple Network Management Protocol        Rec      1157  15 SMI        Structure of Management Information       Rec      1155  16 Concise-MIB Concise MIB Definitions                  Rec      1212  16 MIB-II     Management Information Base-II            Rec      1213  17 NETBIOS    NetBIOS Service Protocols                 Ele 1001,1002  19 ECHO       Echo Protocol                             Rec       862  20 DISCARD    Discard Protocol                          Ele       863  21 CHARGEN    Character Generator Protocol              Ele       864  22 QUOTE      Quote of the Day Protocol                 Ele       865  23 USERS      Active Users Protocol                     Ele       866  24 DAYTIME    Daytime Protocol                          Ele       867  25 TIME       Time Server Protocol                      Ele       868  26 TFTP       Trivial File Transfer Protocol            Ele      1350  33 RIP        Routing Information Protocol              Ele      1058  34 TP-TCP     ISO Transport Service on top of the TCP   Ele      1006  35 ETHER-MIB  Ethernet MIB                              Ele      1643  50* PPP        Point-to-Point Protocol (PPP)             Ele      1661  51* PPP-HDLC   PPP in HDLC Framing                       Ele      1662  51*
#
# [Note: an asterisk at the end of a line indicates a change from the previous edition of this document.]
#
# Internet Architecture Board                                    [Page 24]
#
# RFC 1720                   Internet Standards              November 1994
#
# Applicability Statements:
#
# IGMP -- The Internet Architecture Board intends to move towards general adoption of IP multicasting, as a more efficient solution than broadcasting for many applications. The host interface has been standardized in RFC-1112; however, multicast-routing gateways are in the experimental stage and are not widely available. An Internet host should support all of RFC-1112, except for the IGMP protocol itself which is optional; see RFC-1122 for more details. Even without IGMP, implementation of RFC-1112 will provide an important advance: IP-layer access to local network multicast addressing. It is expected that IGMP will become recommended for all hosts and gateways at some future date.
#
# SMI, MIB-II SNMP -- The Internet Architecture Board recommends that all IP and TCP implementations be network manageable. At the current time, this implies implementation of the Internet MIB-II (RFC-1213), and at least the recommended management protocol SNMP (RFC-1157).
#
# RIP -- The Routing Information Protocol (RIP) is widely implemented and used in the Internet. However, both implementors and users should be aware that RIP has some serious technical limitations as a routing protocol. The IETF is currently developing several candidates for a new standard "open" routing protocol with better properties than RIP. The IAB urges the Internet community to track these developments, and to implement the new protocol when it is standardized; improved Internet service will result for many users.
#
# TP-TCP -- As OSI protocols become more widely implemented and used, there will be an increasing need to support interoperation with the TCP/IP protocols. The Internet Engineering Task Force is formulating strategies for interoperation. RFC-1006 provides one interoperation mode, in which TCP/IP is used to emulate TP0 in order to support OSI applications. Hosts that wish to run OSI connection-oriented applications in this mode should use the procedure described in RFC- 1006. In the future, the IAB expects that a major portion of the Internet will support both TCP/IP and OSI (inter-)network protocols in parallel, and it will then be possible to run OSI applications across the Internet using full OSI protocol "stacks".
#
# Internet Architecture Board                                    [Page 25]
#
# RFC 1720                   Internet Standards              November 1994
#
# 6.3. Network
#
#
#
# Specific Standard Protocols
#
# All Network-Specific Standards have Elective status.
#
# Protocol   Name                                    State    RFC   STD * ========   =====================================   =====   =====  === = IP-ATM     Classical IP and ARP over ATM            Prop   1577 IP-FR      Multiprotocol over Frame Relay           Draft  1490 ATM-ENCAP  Multiprotocol Encapsulation over ATM     Prop   1483 IP-TR-MC   IP Multicast over Token-Ring LANs        Prop   1469 IP-FDDI    Transmission of IP and ARP over FDDI Net Std    1390    36 IP-HIPPI   IP and ARP on HIPPI                      Prop   1374 IP-X.25    X.25 and ISDN in the Packet Mode         Draft  1356 IP-SMDS    IP Datagrams over the SMDS Service       Prop   1209 IP-FDDI    Internet Protocol on FDDI Networks       Draft  1188 ARP        Address Resolution Protocol              Std     826    37 RARP       A Reverse Address Resolution Protocol    Std     903    38 IP-ARPA    Internet Protocol on ARPANET             Std BBN1822    39 IP-WB      Internet Protocol on Wideband Network    Std     907    40 IP-E       Internet Protocol on Ethernet Networks   Std     894    41 IP-EE      Internet Protocol on Exp.
#
# Ethernet Nets  Std     895    42 IP-IEEE    Internet Protocol on IEEE 802            Std    1042    43 IP-DC      Internet Protocol on DC Networks         Std     891    44 IP-HC      Internet Protocol on Hyperchannel        Std    1044    45 IP-ARC     Transmitting IP Traffic over ARCNET Nets Std    1201    46 IP-SLIP    Transmission of IP over Serial Lines     Std    1055    47 IP-NETBIOS Transmission of IP over NETBIOS          Std    1088    48 IP-IPX     Transmission of 802.2 over IPX Networks  Std    1132    49
#
# [Note: an asterisk at the end of a line indicates a change from the previous edition of this document.]
#
# Applicability Statements:
#
# ...
#
# Internet Architecture Board                                    [Page 32]
#
# RFC 1720                   Internet Standards              November 1994
#
# MPP        Message Posting Protocol                                1204 ST-II      Stream Protocol                                         1190 SNMP-BULK  Bulk Table Retrieval with the SNMP                      1187 DNS-RR     New DNS RR Definitions                                  1183 IMAP2      Interactive Mail Access Protocol                        1176 NTP-OSI    NTP over OSI Remote Operations                          1165 DMF-MAIL   Digest Message Format for Mail                          1153 RDP        Reliable Data Protocol                              908,1151 TCP-ACO    TCP Alternate Checksum Option                           1146 --------   Mapping full 822 to Restricted 822                      1137 IP-DVMRP   IP Distance Vector Multicast Routing                    1075 VMTP       Versatile Message Transaction Protocol                  1045 COOKIE-JAR Authentication Scheme                                   1004 NETBLT     Bulk Data Transfer Protocol                              998 IRTP       Internet Reliable Transaction Protocol                   938 LDP        Loader Debugger Protocol                                 909 RLP        Resource Location Protocol                               887 NVP-II     Network Voice Protocol                              ISI-memo PVP        Packet Video Protocol                               ISI-memo
#
# [Note: an asterisk at the end of a line indicates a change from the previous edition of this document.]
#
# 6.8. Informational Protocols
#
# Information protocols have no status.
#
# Protocol   Name                                                     RFC =======    ====================================                    ===== RWHOIS     Referral Whois Protocol                                 1714* DNS-NSAP   DNS NSAP Resource Records                               1706* RADIO-PAGE TPC.INT Subdomain: Radio Paging -- Technical Procedures 1703* GRE-IPv4   Generic Routing Encapsulation over IPv4                 1702* GRE        Generic Routing Encapsulatio                            1701* TMUX       Transport Multiplexing Protocol                         1692* SNPP       Simple Network Paging Protocol - Version 2              1645* IPXWAN     Novell IPX Over Various WAN Media                       1634 ADSNA-IP   Advanced SNA/IP: A
#
# Simple SNA Transport Protocol        1538 AUBR       Appletalk Update-Based Routing Protocol...              1504 TACACS     Terminal Access Control Protocol                        1492 SUN-NFS    Network File System Protocol                            1094 SUN-RPC    Remote Procedure Call Protocol Version 2                1057 GOPHER     The Internet Gopher Protocol                            1436 -------    Data Link Switching: Switch-to-Switch Protocol          1434 LISTSERV   Listserv Distribute Protocol                            1429 -------    Replication Requirements                                1275 PCMAIL     Pcmail Transport Protocol                               1056 MTP        Multicast Transport Protocol                            1301
#
# Internet Architecture Board                                    [Page 33]
#
# RFC 1720                   Internet Standards              November 1994
#
# BSD Login  BSD Login                                               1282 DIXIE      DIXIE Protocol Specification                            1249 IP-X.121   IP to X.121 Address Mapping for DDN                     1236 OSI-HYPER  OSI and LLC1 on HYPERchannel                            1223 HAP2       Host Access Protocol                                    1221 SUBNETASGN On the Assignment of Subnet Numbers                     1219 SNMP-TRAPS Defining Traps for use with SNMP                        1215 DAS        Directory Assistance Service                            1202 MD4        MD4 Message Digest Algorithm                            1186 LPDP       Line Printer Daemon Protocol                            1179
#
# [Note: an asterisk at the end of a line indicates a change from the previous edition of this document.]
#
# 6.9. Historic Protocols
#
# All Historic protocols have Not Recommended status.
#
# Protocol   Name                                                RFC  STD ========   =====================================              ===== === EGP        Exterior Gateway Protocol                 Rec       904  18* SNMP-MUX   SNMP MUX Protocol and MIB                          1227 OIM-MIB-II OSI Internet Management: MIB-II                    1214 IMAP3      Interactive Mail Access Protocol Version 3         1203 SUN-RPC    Remote Procedure Call Protocol Version 1           1050 802.4-MIP  IEEE 802.4 Token Bus MIB                           1230 CMOT       Common Management Information Services             1189 --------   Mail Privacy: Procedures                           1113 --------   Mail Privacy: Key Management                       1114 --------   Mail Privacy: Algorithms                           1115 NFILE      A File Access Protocol                             1037 HOSTNAME   HOSTNAME Protocol                                   953 SFTP       Simple File Transfer Protocol
#
# 913 SUPDUP     SUPDUP Protocol                                     734 BGP        Border Gateway Protocol                       1163,1164 MIB-I      MIB-I                                              1156 SGMP       Simple Gateway Monitoring Protocol                 1028 HEMS       High Level Entity Management Protocol              1021 STATSRV    Statistics Server                                   996 POP2       Post Office Protocol, Version 2                     937 RATP       Reliable Asynchronous Transfer Protocol             916 HFEP       Host - Front End Protocol                           929 THINWIRE   Thinwire Protocol                                   914 HMP        Host Monitoring Protocol                            869 GGP        Gateway Gateway Protocol                            823 RTELNET    Remote Telnet Service                               818 CLOCK      DCNET Time Server Protocol                          778 MPM        Internet Message Protocol                           759
#
# Internet Architecture Board                                    [Page 34]
#
# RFC 1720                   Internet Standards              November 1994
#
# NETRJS     Remote Job Service                                  740 NETED      Network Standard Text Editor                        569 RJE        Remote Job Entry                                    407 XNET       Cross Net Debugger                              IEN-158 NAMESERVER Host Name Server Protocol                       IEN-116 MUX        Multiplexing Protocol                            IEN-90 GRAPHICS   Graphics Protocol                             NIC-24308
#
# [Note: an asterisk at the end of a line indicates a change from the previous edition of this document.]
#
# Internet Architecture Board                                    [Page 35]
#
# RFC 1720                   Internet Standards              November 1994
#
# 6.10. Obsolete Protocols
#
# Some of the protocols listed in this memo are described in RFCs that are obsoleted by newer RFCs. "Obsolete" or "obsoleted" is not an official state or status of protocols. This subsection is for information only.
#
# While it may seem to be obviously wrong to have an obsoleted RFC in the list of standards, there may be cases when an older standard is in the process of being replaced. This process may take a year or two.
#
# For example, the Network Time Protocol (NTP) [RFC 1119] is in its version 2 a full Standard, and in its version 3 is a Draft Standard [RFC 1305]. Once version 3 is a full Standard, version 2 will be made Historic.
#
# Many obsoleted protocols are of little interest and are dropped from this memo altogether. Some obsoleted protocols have received enough recognition that it seems appropriate to list them under their current status and with the following reference to their current replacement.
#
# RFC            RFC   Status     Title                               * ====           ====  =========  =================================== = 1305 obsoletes 1119  Std  /Rec  Network Time Protocol (Version 2) 1533 obsoletes 1497  Draft/Rec  Bootstrap Protocol 1331 obsoletes 1171  Draft/Ele  Point to Point Protocol 1574 obsoletes 1139  Prop /Ele  Echo for ISO-8473 1573 obsoletes 1229  Prop /Ele  Extensions to the Generic-IF MIB 1559 obsoletes 1289  Prop /Ele  DECNET MIB 1548 obsoletes 1331  Prop /Ele  Point-to-Point Protocol (PPP) 1541 obsoletes 1531  Prop /Ele  Dynamic Host Configuration Protocol 1592 obsoletes 1228  Exper/Lim  SNMP Distributed Program Interface 1528 obsoletes 1486  Exper/Lim  An Experiment in Remote Printing 1320 obsoletes 1186  Info /     MD4 Message Digest Algorithm 1057 obsoletes 1050  Hist /Not  Remote Procedure Call Version 1 1421 obsoletes 1113  Hist /Not  Mail Privacy: Procedures 1422 obsoletes 1114  Hist /Not  Mail Privacy: Key Management 1423 obsoletes 1115  Hist /Not  Mail Privacy: Algorithms 1267 obsoletes 1163  Hist /Not  Border Gateway Protocol 1268 obsoletes 1164  Hist /Not  Border Gateway Protocol
#
# Thanks to Lynn Wheeler of Britton Lee for compiling the information in this subsection.
#
# [Note: an asterisk at the end of a line indicates a change from the previous edition of this document.]
#
# Internet Architecture Board                                    [Page 36]
#
# RFC 1720                   Internet Standards              November 1994
#
# 7. Contacts
#
# 7.1. IAB, IETF, and IRTF Contacts
#
# 7.1.1. Internet Architecture Board (IAB) Contact
#
# Please send your comments about this list of protocols and especially about the Draft Standard Protocols to the Internet Architecture Board care of Abel Winerib, IAB Executive Director.
#
# Contacts:
#
# Abel Winerib Executive Director of the IAB Intel, JF2-64 2111 NE 25th Avenue Hillsboro, OR 97124
#
# 1
#
#
#
# 503
#
#
#
# 696
#
#
#
# 8972
#
# AWeinrib@ibeam.intel.com
#
# Christian Huitema
#
# Chair of the IAB
#
# INRIA, Sophia
#
#
#
# Antipolis
#
# 2004 Route des Lucioles
#
# BP 109
#
# F
#
#
#
# 06561 Valbonne Cedex
#
# France
#
# +33 93 65 77 15
#
# Christian.Huitema@MIRSA.INRIA.FR
#
# 7.1.2. Internet Engineering Task Force (IETF) Contact
#
# Contacts:
#
# Paul Mockapetris Chair of the IETF USC/Information Sciences Institute 4676 Admiralty Way Marina del Rey, CA 90292-6695
#
# 1
#
#
#
# 310
#
#
#
# 822
#
#
#
# 1511
#
# pvm@ISI.EDU
#
# Internet Architecture Board                                    [Page 37]
#
# RFC 1720                   Internet Standards              November 1994
#
# John Stewart IESG Secretary Corporation for National Research Initiatives 1895 Preston White Drive, Suite 100 Reston, VA 22091
#
# 1
#
#
#
# 703
#
#
#
# 620
#
#
#
# 8990
#
# jstewart@CNRI.RESTON.VA.US
#
# Steve Coya Executive Director of the IETF Corporation for National Research Initiatives 1895 Preston White Drive, Suite 100 Reston, VA 22091
#
# 1
#
#
#
# 703
#
#
#
# 620
#
#
#
# 8990
#
# scoya@CNRI.RESTON.VA.US
#
# 7.1.3. Internet Research Task Force (IRTF) Contact
#
# Contact:
#
# Jon Postel Chair of the IRTF USC/Information Sciences Institute 4676 Admiralty Way Marina del Rey, CA  90292-6695
#
# 1
#
#
#
# 310
#
#
#
# 822
#
#
#
# 1511
#
# Postel@ISI.EDU
#
# Internet Architecture Board                                    [Page 38]
#
# RFC 1720                   Internet Standards              November 1994
#
# 7.2. Internet Assigned Numbers Authority Contact
#
# Contact:
#
# Joyce K. Reynolds Internet Assigned Numbers Authority USC/Information Sciences Institute 4676 Admiralty Way Marina del Rey, CA  90292-6695
#
# 1
#
#
#
# 310
#
#
#
# 822
#
#
#
# 1511
#
# IANA@ISI.EDU
#
# The protocol standards are managed by the Internet Assigned Numbers Authority.
#
# Please refer to the document "Assigned Numbers" (RFC-1700) for further information about the status of protocol documents. There are two documents that summarize the requirements for host and gateways in the Internet, "Host Requirements" (RFC-1122 and RFC-1123) and "Gateway Requirements" (RFC-1009).
#
# How to obtain the most recent edition of this "Internet Official Protocol Standards" memo:
#
# The file "in-notes/std/std1.txt" may be copied via FTP from the FTP.ISI.EDU computer using the FTP username "anonymous" and FTP password "guest".
#
# Internet Architecture Board                                    [Page 39]
#
# RFC 1720                   Internet Standards              November 1994
#
# 7.3. Request for Comments Editor Contact
#
# Contact:
#
# Jon Postel RFC Editor USC/Information Sciences Institute 4676 Admiralty Way Marina del Rey, CA  90292-6695
#
# 1
#
#
#
# 310
#
#
#
# 822
#
#
#
# 1511
#
# RFC
#
#
#
# Editor@ISI.EDU
#
# Documents may be submitted via electronic mail to the RFC Editor for consideration for publication as RFC. If you are not familiar with the format or style requirements please request the "Instructions for RFC Authors". In general, the style of any recent RFC may be used as a guide.
#
# 7.4. The Network Information Center and Requests for Comments Distribution Contact
#
# RFC's may be obtained from DS.INTERNIC.NET via FTP, WAIS, and electronic mail. Through FTP, RFC's are stored as rfc/rfcnnnn.txt or rfc/rfcnnnn.ps where 'nnnn' is the RFC number. Login as "anonymous" and provide your e-mail address as the password. Through WAIS, you may use either your local WAIS client or telnet to DS.INTERNIC.NET and login as "wais" (no password required) to access a WAIS client. Help information and a tutorial for using WAIS are available online. The WAIS database to search is "rfcs".
#
# Directory and Database Services also provides a mail server interface. Send a mail message to mailserv@ds.internic.net and include any of the following commands in the message body:
#
# document-by-name rfcnnnn      where 'nnnn' is the RFC number The text version is sent.
#
# file /ftp/rfc/rfcnnnn.yyy     where 'nnnn' is the RFC number. and 'yyy' is 'txt' or 'ps'.
#
# help                          to get information on how to use the mailserver.
#
# The InterNIC directory and database services collection of resource listings, internet documents such as RFCs, FYIs, STDs, and Internet Drafts, and publicly accessible databases are also
#
# Internet Architecture Board                                    [Page 40]
#
# RFC 1720                   Internet Standards              November 1994
#
# now available via Gopher. All our collections are WAIS indexed and can be searched from the Gopher menu.
#
# To access the InterNIC Gopher Servers, please connect to "internic.net" port 70.
#
# Contact: admin@ds.internic.net
#
# 7.5. Sources for Requests for Comments
#
# Details on many sources of RFCs via FTP or EMAIL may be obtained by sending an EMAIL message to "rfc-info@ISI.EDU" with the message body "help: ways_to_get_rfcs". For example:
#
# To: rfc
#
#
#
# info@ISI.EDU
#
# Subject: getting rfcs
#
# help: ways_to_get_rfcs
#
# 8. Security Considerations
#
# Security issues are not addressed in this memo.
#
# 9. Author's Address
#
# Jon Postel USC/Information Sciences Institute 4676 Admiralty Way Marina del Rey, CA 90292
#
# Phone: 310
#
#
#
# 822
#
#
#
# 1511
#
# Fax:   310
#
#
#
# 823
#
#
#
# 6714
#
# Email: Postel@ISI.EDU
#
# Internet Architecture Board                                    [Page 41]

# %%
pattern = r'RFC \d+ .* (?:January|February|March|April|May|June|July|August|September|October|November|December) \d{4}'

with open(test_file, 'r') as file:
    lines = file.readlines()

raw_text = ''
for line in lines:
    if '[Page' in line:
        continue
    if re.findall(pattern, line):
        continue
    raw_text += line.strip()
    print(line.strip())
# Out:
# Network Working Group                        Internet Architecture Board
# Request for Comments: 1720                             J. Postel, Editor
# Obsoletes: RFCs 1610, 1600, 1540, 1500,                    November 1994
# 1410, 1360, 1280, 1250, 1100, 1083,
# 1130, 1140, 1200
# STD: 1
# Category: Standards Track
#
#
# INTERNET OFFICIAL PROTOCOL STANDARDS
#
#
# Status of this Memo
#
# This memo describes the state of standardization of protocols used in
# the Internet as determined by the Internet Architecture Board (IAB).
# This memo is an Internet Standard.  Distribution of this memo is
# unlimited.
#
# Table of Contents
#
# Introduction . . . . . . . . . . . . . . . . . . . . . . . . . . 2
# 1.  The Standardization Process  . . . . . . . . . . . . . . . . 3
# 2.  The Request for Comments Documents . . . . . . . . . . . . . 5
# 3.  Other Reference Documents  . . . . . . . . . . . . . . . . . 6
# 3.1.  Assigned Numbers . . . . . . . . . . . . . . . . . . . . . 6
# 3.2.  Gateway Requirements . . . . . . . . . . . . . . . . . . . 6
# 3.3.  Host Requirements  . . . . . . . . . . . . . . . . . . . . 6
# 3.4.  The MIL-STD Documents  . . . . . . . . . . . . . . . . . . 6
# 4.  Explanation of Terms . . . . . . . . . . . . . . . . . . . . 7
# 4.1.  Definitions of Protocol State (Maturity Level) . . . . . . 8
# 4.1.1.  Standard Protocol  . . . . . . . . . . . . . . . . . . . 8
# 4.1.2.  Draft Standard Protocol  . . . . . . . . . . . . . . . . 9
# 4.1.3.  Proposed Standard Protocol . . . . . . . . . . . . . . . 9
# 4.1.4.  Experimental Protocol  . . . . . . . . . . . . . . . . . 9
# 4.1.5.  Informational Protocol . . . . . . . . . . . . . . . . . 9
# 4.1.6.  Historic Protocol  . . . . . . . . . . . . . . . . . . . 9
# 4.2.  Definitions of Protocol Status (Requirement Level) . . .   9
# 4.2.1.  Required Protocol  . . . . . . . . . . . . . . . . . .  10
# 4.2.2.  Recommended Protocol . . . . . . . . . . . . . . . . .  10
# 4.2.3.  Elective Protocol  . . . . . . . . . . . . . . . . . .  10
# 4.2.4.  Limited Use Protocol . . . . . . . . . . . . . . . . .  10
# 4.2.5.  Not Recommended Protocol . . . . . . . . . . . . . . .  10
# 5.  The Standards Track  . . . . . . . . . . . . . . . . . . .  10
# 5.1.  The RFC Processing Decision Table  . . . . . . . . . . .  10
# 5.2.  The Standards Track Diagram  . . . . . . . . . . . . . .  12
# 6.  The Protocols  . . . . . . . . . . . . . . . . . . . . . .  14
# 6.1.  Recent Changes . . . . . . . . . . . . . . . . . . . . .  14
#
#
#
#
#
#
# 6.1.1.  New RFCs . . . . . . . . . . . . . . . . . . . . . . .  14
# 6.1.2.  Other Changes  . . . . . . . . . . . . . . . . . . . .  23
# 6.2.  Standard Protocols . . . . . . . . . . . . . . . . . . .  24
# 6.3.  Network-Specific Standard Protocols  . . . . . . . . . .  26
# 6.4.  Draft Standard Protocols . . . . . . . . . . . . . . . .  27
# 6.5.  Proposed Standard Protocols  . . . . . . . . . . . . . .  28
# 6.6.  Telnet Options . . . . . . . . . . . . . . . . . . . . .  31
# 6.7.  Experimental Protocols . . . . . . . . . . . . . . . . .  32
# 6.8.  Informational Protocols  . . . . . . . . . . . . . . . .  33
# 6.9.  Historic Protocols . . . . . . . . . . . . . . . . . . .  34
# 6.10  Obsolete Protocols . . . . . . . . . . . . . . . . . . .  36
# 7.  Contacts . . . . . . . . . . . . . . . . . . . . . . . . .  37
# 7.1.  IAB, IETF, and IRTF Contacts . . . . . . . . . . . . . .  37
# 7.1.1.  Internet Architecture Board (IAB) Contact  . . . . . .  37
# 7.1.2.  Internet Engineering Task Force (IETF) Contact . . . .  38
# 7.1.3.  Internet Research Task Force (IRTF) Contact  . . . . .  39
# 7.2.  Internet Assigned Numbers Authority (IANA) Contact . . .  39
# 7.3.  Request for Comments Editor Contact  . . . . . . . . . .  40
# 7.4.  Network Information Center Contact . . . . . . . . . . .  40
# 7.5.  Sources for Requests for Comments  . . . . . . . . . . .  41
# 8.  Security Considerations  . . . . . . . . . . . . . . . . .  41
# 9.  Author's Address . . . . . . . . . . . . . . . . . . . . .  41
#
# Introduction
#
# A discussion of the standardization process and the RFC document
# series is presented first, followed by an explanation of the terms.
# Sections 6.2 - 6.10 contain the lists of protocols in each stage of
# standardization.  Finally are pointers to references and contacts for
# further information.
#
# This memo is intended to be issued approximately quarterly; please be
# sure the copy you are reading is current.  Current copies may be
# obtained from the Network Information Center (INTERNIC) or from the
# Internet Assigned Numbers Authority (IANA) (see the contact
# information at the end of this memo).  Do not use this edition after
# 1-Mar-95.
#
# See Section 6.1 for a description of recent changes.  In the official
# lists in sections 6.2 - 6.10, an asterisk (*) next to a protocol
# denotes that it is new to this document or has been moved from one
# protocol level to another, or differs from the previous edition of
# this document.
#
#
#
#
#
#
#
#
#
#
#
# 1.  The Standardization Process
#
# The Internet Architecture Board maintains this list of documents that
# define standards for the Internet protocol suite.  See RFC-1601 for
# the charter of the IAB and RFC-1160 for an explanation of the role
# and organization of the IAB and its subsidiary groups, the Internet
# Engineering Task Force (IETF) and the Internet Research Task Force
# (IRTF).  Each of these groups has a steering group called the IESG
# and IRSG, respectively.  The IETF develops these standards with the
# goal of co-ordinating the evolution of the Internet protocols; this
# co-ordination has become quite important as the Internet protocols
# are increasingly in general commercial use.  The definitive
# description of the Internet standards process is found in RFC-1602.
#
# The majority of Internet protocol development and standardization
# activity takes place in the working groups of the IETF.
#
# Protocols which are to become standards in the Internet go through a
# series of states or maturity levels (proposed standard, draft
# standard, and standard) involving increasing amounts of scrutiny and
# testing.  When a protocol completes this process it is assigned a STD
# number (see RFC-1311).  At each step, the Internet Engineering
# Steering Group (IESG) of the IETF must make a recommendation for
# advancement of the protocol.
#
# To allow time for the Internet community to consider and react to
# standardization proposals, a minimum delay of 6 months before a
# proposed standard can be advanced to a draft standard and 4 months
# before a draft standard can be promoted to standard.
#
# It is general practice that no proposed standard can be promoted to
# draft standard without at least two independent implementations (and
# the recommendation of the IESG).  Promotion from draft standard to
# standard generally requires operational experience and demonstrated
# interoperability of two or more implementations (and the
# recommendation of the IESG).
#
# In cases where there is uncertainty as to the proper decision
# concerning a protocol a special review committee may be appointed
# consisting of experts from the IETF, IRTF and the IAB with the
# purpose of recommending an explicit action.
#
# Advancement of a protocol to proposed standard is an important step
# since it marks a protocol as a candidate for eventual standardization
# (it puts the protocol "on the standards track").  Advancement to
# draft standard is a major step which warns the community that, unless
# major objections are raised or flaws are discovered, the protocol is
# likely to be advanced to standard in six months.
#
#
#
#
#
#
# Some protocols have been superseded by better ones or are otherwise
# unused.  Such protocols are still documented in this memorandum with
# the designation "historic".
#
# Because it is useful to document the results of early protocol
# research and development work, some of the RFCs document protocols
# which are still in an experimental condition.  The protocols are
# designated "experimental" in this memorandum.  They appear in this
# report as a convenience to the community and not as evidence of their
# standardization.
#
# Other protocols, such as those developed by other standards
# organizations, or by particular vendors, may be of interest or may be
# recommended for use in the Internet.  The specifications of such
# protocols may be published as RFCs for the convenience of the
# Internet community.  These protocols are labeled "informational" in
# this memorandum.
#
# In addition to the working groups of the IETF, protocol development
# and experimentation may take place as a result of the work of the
# research groups of the Internet Research Task Force, or the work of
# other individuals interested in Internet protocol development.  The
# the documentation of such experimental work in the RFC series is
# encouraged, but none of this work is considered to be on the track
# for standardization until the IESG has made a recommendation to
# advance the protocol to the proposed standard state.
#
# A few protocols have achieved widespread implementation without the
# approval of the IESG.  For example, some vendor protocols have become
# very important to the Internet community even though they have not
# been recommended by the IESG.  However, the IAB strongly recommends
# that the standards process be used in the evolution of the protocol
# suite to maximize interoperability (and to prevent incompatible
# protocol requirements from arising).  The use of the terms
# "standard", "draft standard", and "proposed standard" are reserved in
# any RFC or other publication of Internet protocols to only those
# protocols which the IESG has approved.
#
# In addition to a state (like "Proposed Standard"), a protocol is also
# assigned a status, or requirement level, in this document.  The
# possible requirement levels ("Required", "Recommended", "Elective",
# "Limited Use", and "Not Recommended") are defined in Section 4.2.
# When a protocol is on the standards track, that is in the proposed
# standard, draft standard, or standard state (see Section 5), the
# status shown in Section 6 is the current status.
#
# Few protocols are required to be implemented in all systems; this is
# because there is such a variety of possible systems, for example,
#
#
#
#
#
#
# gateways, routers, terminal servers, workstations, and multi-user
# hosts.  The requirement level shown in this document is only a one
# word label, which may not be sufficient to characterize the
# implementation requirements for a protocol in all situations.  For
# some protocols, this document contains an additional status paragraph
# (an applicability statement).  In addition, more detailed status
# information may be contained in separate requirements documents (see
# Section 3).
#
# 2.  The Request for Comments Documents
#
# The documents called Request for Comments (or RFCs) are the working
# notes of the "Network Working Group", that is the Internet research
# and development community.  A document in this series may be on
# essentially any topic related to computer communication, and may be
# anything from a meeting report to the specification of a standard.
#
# Notice:
#
# All standards are published as RFCs, but not all RFCs specify
# standards.
#
# Anyone can submit a document for publication as an RFC.  Submissions
# must be made via electronic mail to the RFC Editor (see the contact
# information at the end of this memo, and see RFC 1543).
#
# While RFCs are not refereed publications, they do receive technical
# review from the task forces, individual technical experts, or the RFC
# Editor, as appropriate.
#
# The RFC series comprises a wide range of documents, ranging from
# informational documents of general interests to specifications of
# standard Internet protocols.  In cases where submission is intended
# to document a proposed standard, draft standard, or standard
# protocol, the RFC Editor will publish the document only with the
# approval of the IESG.  For documents describing experimental work,
# the RFC Editor will notify the IESG before publication, allowing for
# the possibility of review by the relevant IETF working group or IRTF
# research group and provide those comments to the author.  See Section
# 5.1 for more detail.
#
# Once a document is assigned an RFC number and published, that RFC is
# never revised or re-issued with the same number.  There is never a
# question of having the most recent version of a particular RFC.
# However, a protocol (such as File Transfer Protocol (FTP)) may be
# improved and re-documented many times in several different RFCs.  It
# is important to verify that you have the most recent RFC on a
# particular protocol.  This "Internet Official Protocol Standards"
#
#
#
#
#
#
# memo is the reference for determining the correct RFC for the current
# specification of each protocol.
#
# The RFCs are available from the INTERNIC, and a number of other
# sites.  For more information about obtaining RFCs, see Sections 7.4
# and 7.5.
#
# 3.  Other Reference Documents
#
# There are three other reference documents of interest in checking the
# current status of protocol specifications and standardization.  These
# are the Assigned Numbers, the Gateway Requirements, and the Host
# Requirements.  Note that these documents are revised and updated at
# different times; in case of differences between these documents, the
# most recent must prevail.
#
# Also, one should be aware of the MIL-STD publications on IP, TCP,
# Telnet, FTP, and SMTP.  These are described in Section 3.4.
#
# 3.1.  Assigned Numbers
#
# The "Assigned Numbers" document lists the assigned values of the
# parameters used in the various protocols.  For example, IP protocol
# codes, TCP port numbers, Telnet Option Codes, ARP hardware types, and
# Terminal Type names.  Assigned Numbers was most recently issued as
# RFC-1700.
#
# 3.2.  Gateway Requirements
#
# This document reviews the specifications that apply to gateways and
# supplies guidance and clarification for any ambiguities.  Gateway
# Requirements is RFC-1009.  A working group of the IETF is actively
# preparing a revision.
#
# 3.3.  Host Requirements
#
# This pair of documents reviews and updates the specifications that
# apply to hosts, and it supplies guidance and clarification for any
# ambiguities.  Host Requirements was issued as RFC-1122 and RFC-1123.
#
# 3.4.  The MIL-STD Documents
#
# The Internet community specifications for IP (RFC-791) and TCP (RFC-
# 793) and the DoD MIL-STD specifications are intended to describe
# exactly the same protocols.  Any difference in the protocols
# specified by these sets of documents should be reported to DISA and
# to the IESG.  The RFCs and the MIL-STDs for IP and TCP differ in
# style and level of detail.  It is strongly advised that the two sets
#
#
#
#
#
#
# of documents be used together, along with RFC-1122 and RFC-1123.
#
# The Internet and the DoD MIL-STD specifications for the FTP, SMTP,
# and Telnet protocols are essentially the same documents (RFCs 765,
# 821, 854).  The MIL-STD versions have been edited slightly.  Note
# that the current Internet specification for FTP is RFC-959 (as
# modified by RFC-1123).
#
# Note that these MIL-STD are now somewhat out of date.  The Gateway
# Requirements (RFC-1009) and Host Requirements (RFC-1122, RFC-1123)
# take precedence over both earlier RFCs and the MIL-STDs.
#
# Internet Protocol (IP)                      MIL-STD-1777
# Transmission Control Protocol (TCP)         MIL-STD-1778
# File Transfer Protocol (FTP)                MIL-STD-1780
# Simple Mail Transfer Protocol (SMTP)        MIL-STD-1781
# Telnet Protocol and Options (TELNET)        MIL-STD-1782
#
# These documents are available from the Naval Publications and Forms
# Center.  Requests can be initiated by telephone, telegraph, or mail;
# however, it is preferred that private industry use form DD1425, if
# possible.
#
# Naval Publications and Forms Center, Code 3015
# 5801 Tabor Ave
# Philadelphia, PA 19120
# Phone: 1-215-697-3321 (order tape)
# 1-215-697-4834 (conversation)
#
# 4.  Explanation of Terms
#
# There are two independent categorization of protocols.  The first is
# the "maturity level" or STATE of standardization, one of "standard",
# "draft standard", "proposed standard", "experimental",
# "informational" or "historic".  The second is the "requirement level"
# or STATUS of this protocol, one of "required", "recommended",
# "elective", "limited use", or "not recommended".
#
# The status or requirement level is difficult to portray in a one word
# label.  These status labels should be considered only as an
# indication, and a further description, or applicability statement,
# should be consulted.
#
# When a protocol is advanced to proposed standard or draft standard,
# it is labeled with a current status.
#
#
#
#
#
#
#
#
#
# At any given time a protocol occupies a cell of the following matrix.
# Protocols are likely to be in cells in about the following
# proportions (indicated by the relative number of Xs).  A new protocol
# is most likely to start in the (proposed standard, elective) cell, or
# the (experimental, not recommended) cell.
#
# S T A T U S
# Req   Rec   Ele   Lim   Not
# +-----+-----+-----+-----+-----+
# Std     |  X  | XXX | XXX |     |     |
# S           +-----+-----+-----+-----+-----+
# Draft   |  X  |  X  | XXX |     |     |
# T           +-----+-----+-----+-----+-----+
# Prop    |     |  X  | XXX |     |     |
# A           +-----+-----+-----+-----+-----+
# Info    |     |     |     |     |     |
# T           +-----+-----+-----+-----+-----+
# Expr    |     |     |     | XXX |     |
# E           +-----+-----+-----+-----+-----+
# Hist    |     |     |     |     | XXX |
# +-----+-----+-----+-----+-----+
#
# What is a "system"?
#
# Some protocols are particular to hosts and some to gateways; a few
# protocols are used in both.  The definitions of the terms below
# will refer to a "system" which is either a host or a gateway (or
# both).  It should be clear from the context of the particular
# protocol which types of systems are intended.
#
# 4.1.  Definitions of Protocol State
#
# Every protocol listed in this document is assigned to a "maturity
# level" or STATE of standardization: "standard", "draft standard",
# "proposed standard", "experimental", or "historic".
#
# 4.1.1.  Standard Protocol
#
# The IESG has established this as an official standard protocol for
# the Internet.  These protocols are assigned STD numbers (see RFC-
# 1311).  These are separated into two groups: (1) IP protocol and
# above, protocols that apply to the whole Internet; and (2)
# network-specific protocols, generally specifications of how to do
# IP on particular types of networks.
#
#
#
#
#
#
#
#
#
#
# 4.1.2.  Draft Standard Protocol
#
# The IESG is actively considering this protocol as a possible
# Standard Protocol.  Substantial and widespread testing and comment
# are desired.  Comments and test results should be submitted to the
# IESG.  There is a possibility that changes will be made in a Draft
# Standard Protocol before it becomes a Standard Protocol.
#
# 4.1.3.  Proposed Standard Protocol
#
# These are protocol proposals that may be considered by the IESG
# for standardization in the future.  Implementation and testing by
# several groups is desirable.  Revision of the protocol
# specification is likely.
#
# 4.1.4.  Experimental Protocol
#
# A system should not implement an experimental protocol unless it
# is participating in the experiment and has coordinated its use of
# the protocol with the developer of the protocol.
#
# Typically, experimental protocols are those that are developed as
# part of an ongoing research project not related to an operational
# service offering.  While they may be proposed as a service
# protocol at a later stage, and thus become proposed standard,
# draft standard, and then standard protocols, the designation of a
# protocol as experimental may sometimes be meant to suggest that
# the protocol, although perhaps mature, is not intended for
# operational use.
#
# 4.1.5.  Informational Protocol
#
# Protocols developed by other standard organizations, or vendors,
# or that are for other reasons outside the purview of the IESG, may
# be published as RFCs for the convenience of the Internet community
# as informational protocols.
#
# 4.1.6.  Historic Protocol
#
# These are protocols that are unlikely to ever become standards in
# the Internet either because they have been superseded by later
# developments or due to lack of interest.
#
# 4.2.  Definitions of Protocol Status
#
# This document lists a "requirement level" or STATUS for each
# protocol.  The status is one of "required", "recommended",
# "elective", "limited use", or "not recommended".
#
#
#
#
#
#
# 4.2.1.  Required Protocol
#
# A system must implement the required protocols.
#
# 4.2.2.  Recommended Protocol
#
# A system should implement the recommended protocols.
#
# 4.2.3.  Elective Protocol
#
# A system may or may not implement an elective protocol. The
# general notion is that if you are going to do something like this,
# you must do exactly this.  There may be several elective protocols
# in a general area, for example, there are several electronic mail
# protocols, and several routing protocols.
#
# 4.2.4.  Limited Use Protocol
#
# These protocols are for use in limited circumstances.  This may be
# because of their experimental state, specialized nature, limited
# functionality, or historic state.
#
# 4.2.5.  Not Recommended Protocol
#
# These protocols are not recommended for general use.  This may be
# because of their limited functionality, specialized nature, or
# experimental or historic state.
#
# 5.  The Standards Track
#
# This section discusses in more detail the procedures used by the RFC
# Editor and the IESG in making decisions about the labeling and
# publishing of protocols as standards.
#
# 5.1.  The RFC Processing Decision Table
#
# Here is the current decision table for processing submissions by the
# RFC Editor.  The processing depends on who submitted it, and the
# status they want it to have.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# +==========================================================+
# |**************|               S O U R C E                 |
# +==========================================================+
# | Desired      |    IAB   |   IESG   |   IRSG   |  Other   |
# | Status       |          |          |          |          |
# +==========================================================+
# |              |          |          |          |          |
# | Standard     |  Bogus   |  Publish |  Bogus   |  Bogus   |
# | or           |   (2)    |   (1)    |   (2)    |   (2)    |
# | Draft        |          |          |          |          |
# | Standard     |          |          |          |          |
# +--------------+----------+----------+----------+----------+
# |              |          |          |          |          |
# |              |  Refer   |  Publish |  Refer   |  Refer   |
# | Proposed     |   (3)    |   (1)    |   (3)    |   (3)    |
# | Standard     |          |          |          |          |
# |              |          |          |          |          |
# +--------------+----------+----------+----------+----------+
# |              |          |          |          |          |
# |              |  Notify  |  Publish |  Notify  |  Notify  |
# | Experimental |   (4)    |   (1)    |   (4)    |   (4)    |
# | Protocol     |          |          |          |          |
# |              |          |          |          |          |
# +--------------+----------+----------+----------+----------+
# |              |          |          |          |          |
# | Information  |  Publish |  Publish |Discretion|Discretion|
# | or Opinion   |   (1)    |   (1)    |   (5)    |   (5)    |
# | Paper        |          |          |          |          |
# |              |          |          |          |          |
# +==========================================================+
#
# (1) Publish.
#
# (2) Bogus.  Inform the source of the rules.  RFCs specifying
# Standard, or Draft Standard must come from the IESG, only.
#
# (3) Refer to an Area Director for review by a WG.  Expect to see
# the document again only after approval by the IESG.
#
# (4) Notify both the IESG and IRSG.  If no concerns are raised in
# two weeks then do Discretion (5), else RFC Editor to resolve
# the concerns or do Refer (3).
#
# (5) RFC Editor's discretion.  The RFC Editor decides if a review
# is needed and if so by whom.  RFC Editor decides to publish or
# not.
#
#
#
#
#
#
#
#
# Of course, in all cases the RFC Editor can request or make minor
# changes for style, format, and presentation purposes.
#
# The IESG has designated the IESG Secretary as its agent for
# forwarding documents with IESG approval and for registering concerns
# in response to notifications (4) to the RFC Editor.  Documents from
# Area Directors or Working Group Chairs may be considered in the same
# way as documents from "other".
#
# 5.2.  The Standards Track Diagram
#
# There is a part of the STATUS and STATE categorization that is called
# the standards track.  Actually, only the changes of state are
# significant to the progression along the standards track, though the
# status assignments may change as well.
#
# The states illustrated by single line boxes are temporary states,
# those illustrated by double line boxes are long term states.  A
# protocol will normally be expected to remain in a temporary state for
# several months (minimum six months for proposed standard, minimum
# four months for draft standard).  A protocol may be in a long term
# state for many years.
#
# A protocol may enter the standards track only on the recommendation
# of the IESG; and may move from one state to another along the track
# only on the recommendation of the IESG.  That is, it takes action by
# the IESG to either start a protocol on the track or to move it along.
#
# Generally, as the protocol enters the standards track a decision is
# made as to the eventual STATUS, requirement level or applicability
# (elective, recommended, or required) the protocol will have, although
# a somewhat less stringent current status may be assigned, and it then
# is placed in the the proposed standard STATE with that status.  So
# the initial placement of a protocol is into state 1.  At any time the
# STATUS decision may be revisited.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# |
# +<----------------------------------------------+
# |                                               ^
# V    0                                          |    4
# +-----------+                                   +===========+
# |   enter   |-->----------------+-------------->|experiment |
# +-----------+                   |               +=====+=====+
# |                     |
# V    1                |
# +-----------+               V
# | proposed  |-------------->+
# +--->+-----+-----+               |
# |          |                     |
# |          V    2                |
# +<---+-----+-----+               V
# | draft std |-------------->+
# +--->+-----+-----+               |
# |          |                     |
# |          V    3                |
# +<---+=====+=====+               V
# | standard  |-------------->+
# +=====+=====+               |
# |
# V    5
# +=====+=====+
# | historic  |
# +===========+
#
# The transition from proposed standard (1) to draft standard (2) can
# only be by action of the IESG and only after the protocol has been
# proposed standard (1) for at least six months.
#
# The transition from draft standard (2) to standard (3) can only be by
# action of the IESG and only after the protocol has been draft
# standard (2) for at least four months.
#
# Occasionally, the decision may be that the protocol is not ready for
# standardization and will be assigned to the experimental state (4).
# This is off the standards track, and the protocol may be resubmitted
# to enter the standards track after further work.  There are other
# paths into the experimental and historic states that do not involve
# IESG action.
#
# Sometimes one protocol is replaced by another and thus becomes
# historic, or it may happen that a protocol on the standards track is
# in a sense overtaken by another protocol (or other events) and
# becomes historic (state 5).
#
#
#
#
#
#
#
# 6.  The Protocols
#
# Subsection 6.1 lists recent RFCs and other changes.  Subsections 6.2
# - 6.10 list the standards in groups by protocol state.
#
# 6.1.  Recent Changes
#
# 6.1.1.  New RFCs:
#
# 1725 - Post Office Protocol - Version 3
#
# A Draft Standard protocol.
#
# 1724 - RIP Version 2 MIB Extension
#
# A Draft Standard protocol.
#
# 1723 - RIP Version 2 - Carrying Additional Information
#
# A Draft Standard protocol.
#
# 1722 - RIP Version 2 Protocol Applicability Statement
#
# A Draft Standard protocol.
#
# 1721 - RIP Version 2 Protocol Analysis
#
# This is an information document and does not specify any
# level of standard.
#
# 1720 - Internet Official Protocol Standards
#
# This memo.
#
# 1719 - Not yet issued.
#
# 1718 - The Tao of IETF - A Guide for New Attendees of the Internet
# Engineering Task Force
#
# This is an information document and does not specify any
# level of standard.
#
# 1717 - The PPP Multilink Protocol (MP)
#
# A Proposed Standard protocol.
#
#
#
#
#
#
#
#
#
# 1716 - Towards Requirements for IP Routers
#
# This is an information document and does not specify any
# level of standard.
#
# 1715 - The H Ratio for Address Assignment Efficiency
#
# This is an information document and does not specify any
# level of standard.
#
# 1714 - Referral Whois Protocol (RWhois)
#
# This is an information document and does not specify any
# level of standard.
#
# 1713 - Tools for DNS debugging
#
# This is an information document and does not specify any
# level of standard.
#
# 1712 - DNS Encoding of Geographical Location
#
# An Experimental protocol.
#
# 1711 - Classifications in E-mail Routing
#
# This is an information document and does not specify any
# level of standard.
#
# 1710 - Simple Internet Protocol Plus White Paper
#
# This is an information document and does not specify any
# level of standard.
#
# 1709 - K-12 Internetworking Guidelines
#
# This is an information document and does not specify any
# level of standard.
#
# 1708 - NTP PICS PROFORMA - For the Network Time Protocol Version 3
#
# This is an information document and does not specify any
# level of standard.
#
# 1707 - CATNIP: Common Architecture for the Internet
#
# This is an information document and does not specify any
# level of standard.
#
#
#
#
#
#
# 1706 - DNS NSAP Resource Records
#
# This is an information document and does not specify any
# level of standard.
#
# 1705 - Six Virtual Inches to the Left: The Problem with IPng
#
# This is an information document and does not specify any
# level of standard.
#
# 1704 - On Internet Authentication
#
# This is an information document and does not specify any
# level of standard.
#
# 1703 - Principles of Operation for the TPC.INT Subdomain: Radio
# Paging -- Technical Procedures
#
# This is an information document and does not specify any
# level of standard.
#
# 1702 - Generic Routing Encapsulation over IPv4 networks
#
# This is an information document and does not specify any
# level of standard.
#
# 1701 - Generic Routing Encapsulation (GRE)
#
# This is an information document and does not specify any
# level of standard.
#
# 1700 - Assigned Numbers
#
# A status report on the parameters (i.e., numbers and
# keywords) used in protocols in the Internet community.
#
# 1699 - Not yet issued.
#
# 1698 - Octet Sequences for Upper-Layer OSI to Support Basic
# Communications Applications
#
# This is an information document and does not specify any
# level of standard.
#
# 1697 - Relational Database Management System (RDBMS) Management
# Information Base (MIB) using SMIv2
#
# A Proposed Standard protocol.
#
#
#
#
#
#
# 1696 - Modem Management Information Base (MIB) using SMIv2
#
# A Proposed Standard protocol.
#
# 1695 - Definitions of Managed Objects for ATM Management Version
# 8.0 using SMIv2
#
# A Proposed Standard protocol.
#
# 1694 - Definitions of Managed Objects for SMDS Interfaces using
# SMIv2
#
# A Draft Standard protocol.
#
# 1693 - An Extension to TCP : Partial Order Service
#
# An Experimental protocol.
#
# 1692 - Transport Multiplexing Protocol (TMux)
#
# This is an information document and does not specify any
# level of standard.
#
# 1691 - The Document Architecture for the Cornell Digital Library
#
# This is an information document and does not specify any
# level of standard.
#
# 1690 - Introducing the Internet Engineering and Planning Group
# (IEPG)
#
# This is an information document and does not specify any
# level of standard.
#
# 1689 - A Status Report on Networked Information Retrieval: Tools
# and Groups
#
# This is an information document and does not specify any
# level of standard.
#
# 1688 - IPng Mobility Considerations
#
# This is an information document and does not specify any
# level of standard.
#
#
#
#
#
#
#
#
#
#
# 1687 -  A Large Corporate User's View of IPng
#
# This is an information document and does not specify any
# level of standard.
#
# 1686 - IPng Requirements: A Cable Television Industry Viewpoint
#
# This is an information document and does not specify any
# level of standard.
#
# 1685 - Writing X.400 O/R Names
#
# This is an information document and does not specify any
# level of standard.
#
# 1684 - Introduction to White Pages Services based on X.500
#
# This is an information document and does not specify any
# level of standard.
#
# 1683 - Multiprotocol Interoperability In IPng
#
# This is an information document and does not specify any
# level of standard.
#
# 1682 - IPng BSD Host Implementation Analysis
#
# This is an information document and does not specify any
# level of standard.
#
# 1681 - On Many Addresses per Host
#
# This is an information document and does not specify any
# level of standard.
#
# 1680 - IPng Support for ATM Services
#
# This is an information document and does not specify any
# level of standard.
#
# 1679 - HPN Working Group Input to the IPng Requirements
# Solicitation
#
# This is an information document and does not specify any
# level of standard.
#
#
#
#
#
#
#
#
#
# 1678 - IPng Requirements of Large Corporate Networks
#
# This is an information document and does not specify any
# level of standard.
#
# 1677 - Tactical Radio Frequency Communication Requirments for IPng
#
# This is an information document and does not specify any
# level of standard.
#
# 1676 - INFN Requirements for an IPng
#
# This is an information document and does not specify any
# level of standard.
#
# 1675 - Security Concerns for IPng
#
# This is an information document and does not specify any
# level of standard.
#
# 1674 - Electric Power Research Institute Comments on IPng
#
# This is an information document and does not specify any
# level of standard.
#
# 1673 - Electric Power Research Institute Comments on IPng
#
# This is an information document and does not specify any
# level of standard.
#
# 1672 - Accounting Requirements for IPng
#
# This is an information document and does not specify any
# level of standard.
#
# 1671 - IPng White Paper on Transition and Other Considerations
#
# This is an information document and does not specify any
# level of standard.
#
# 1670 - Input to IPng Engineering Considerations
#
# This is an information document and does not specify any
# level of standard.
#
#
#
#
#
#
#
#
#
#
# 1669 - Market Viability as a IPng Criteria
#
# This is an information document and does not specify any
# level of standard.
#
# 1668 - Unified Routing Requirements for IPng
#
# This is an information document and does not specify any
# level of standard.
#
# 1667 - Modeling and Simulation Requirements for IPng
#
# This is an information document and does not specify any
# level of standard.
#
# 1666 - Definitions of Managed Objects for SNA NAUs using SMIv2
#
# A Proposed Standard protocol.
#
# 1665 - Definitions of Managed Objects for SNA NAUs using SMIv2
#
# A Proposed Standard protocol.
#
# 1664 - Using the Internet DNS to Distribute RFC1327 Mail Address
# Mapping Tables
#
# An Experimental protocol.
#
# 1663 - PPP Reliable Transmission
#
# A Proposed Standard protocol.
#
# 1662 - The Point-to-Point Protocol (PPP)
#
# A Standard protocol.
#
# 1661 - The Point-to-Point Protocol (PPP)
#
# A Standard protocol.
#
# 1660 - Definitions of Managed Objects for Parallel-printer-like
# Hardware Devices using SMIv2
#
# A Draft Standard protocol.
#
#
#
#
#
#
#
#
#
#
# 1659 - Definitions of Managed Objects for RS-232-like Hardware
# Devices using SMIv2
#
# A Draft Standard protocol.
#
# 1658 - Definitions of Managed Objects for Character Stream Devices
# using SMIv2
#
# A Draft Standard protocol.
#
# 1657 - Definitions of Managed Objects for the Fourth Version of
# the Border Gateway Protocol (BGP-4) using SMIv2
#
# A Proposed Standard protocol.
#
# 1656 - BGP-4 Protocol Document Roadmap and Implementation
# Experience
#
# This is an information document and does not specify any
# level of standard.
#
# 1655 - Application of the Border Gateway Protocol in the Internet
#
# A Proposed Standard protocol.
#
# 1654 - A Border Gateway Protocol 4 (BGP-4)
#
# A Proposed Standard protocol.
#
# 1653 - SMTP Service Extension for Message Size Declaration
#
# A Draft Standard protocol.
#
# 1652 - SMTP Service Extension for 8bit-MIMEtransport
#
# A Draft Standard protocol.
#
# 1651 - SMTP Service Extensions
#
# A Draft Standard protocol.
#
# 1650 - Definitions of Managed Objects for the Ethernet-like
# Interface Types using SMIv2
#
# A Proposed Standard protocol.
#
#
#
#
#
#
#
#
#
# 1649 - Operational Requirements for X.400 Management Domains in
# the GO-MHS Community
#
# This is an information document and does not specify any
# level of standard.
#
# 1648 - Postmaster Convention for X.400 Operations
#
# A Proposed Standard protocol.
#
# 1647 - TN3270 Enhancements
#
# A Proposed Standard protocol.
#
# 1646 - TN3270 Extensions for LUname and Printer Selection
#
# This is an information document and does not specify any
# level of standard.
#
# 1645 - Simple Network Paging Protocol - Version 2
#
# This is an information document and does not specify any
# level of standard.
#
# 1644 - T/TCP -- TCP Extensions for Transactions Functional
# Specification
#
# An Experimental protocol.
#
# 1643 - Definitions of Managed Objects for the Ethernet-like
# Interface Type
#
# A Standard protocol.
#
# 1642 - UTF-7 - A Mail-Safe Transformation Format of Unicode
#
# An Experimental protocol.
#
# 1641 - Using Unicode with MIME
#
# An Experimental protocol.
#
#
#
#
#
#
#
#
#
#
#
#
#
# 6.1.2.  Other Changes:
#
# The following are changes to protocols listed in the previous
# edition.
#
# 904 - Exterior Gateway Protocol
#
# Moved to Historic.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 6.2.  Standard Protocols
#
# Protocol   Name                                      Status    RFC STD *
# ========   =====================================     ======== ==== === =
# --------   Internet Official Protocol Standards      Req      1720   1
# --------   Assigned Numbers                          Req      1700   2
# --------   Host Requirements - Communications        Req      1122   3
# --------   Host Requirements - Applications          Req      1123   3
# --------   Gateway Requirements                      Req      1009   4
# IP         Internet Protocol                         Req       791   5
# as amended by:--------
# --------     IP Subnet Extension                     Req       950   5
# --------     IP Broadcast Datagrams                  Req       919   5
# --------     IP Broadcast Datagrams with Subnets     Req       922   5
# ICMP       Internet Control Message Protocol         Req       792   5
# IGMP       Internet Group Multicast Protocol         Rec      1112   5
# UDP        User Datagram Protocol                    Rec       768   6
# TCP        Transmission Control Protocol             Rec       793   7
# TELNET     Telnet Protocol                           Rec   854,855   8
# FTP        File Transfer Protocol                    Rec       959   9
# SMTP       Simple Mail Transfer Protocol             Rec       821  10
# MAIL       Format of Electronic Mail Messages        Rec       822  11
# CONTENT    Content Type Header Field                 Rec      1049  11
# NTPV2      Network Time Protocol (Version 2)         Rec      1119  12
# DOMAIN     Domain Name System                        Rec 1034,1035  13
# DNS-MX     Mail Routing and the Domain System        Rec       974  14
# SNMP       Simple Network Management Protocol        Rec      1157  15
# SMI        Structure of Management Information       Rec      1155  16
# Concise-MIB Concise MIB Definitions                  Rec      1212  16
# MIB-II     Management Information Base-II            Rec      1213  17
# NETBIOS    NetBIOS Service Protocols                 Ele 1001,1002  19
# ECHO       Echo Protocol                             Rec       862  20
# DISCARD    Discard Protocol                          Ele       863  21
# CHARGEN    Character Generator Protocol              Ele       864  22
# QUOTE      Quote of the Day Protocol                 Ele       865  23
# USERS      Active Users Protocol                     Ele       866  24
# DAYTIME    Daytime Protocol                          Ele       867  25
# TIME       Time Server Protocol                      Ele       868  26
# TFTP       Trivial File Transfer Protocol            Ele      1350  33
# RIP        Routing Information Protocol              Ele      1058  34
# TP-TCP     ISO Transport Service on top of the TCP   Ele      1006  35
# ETHER-MIB  Ethernet MIB                              Ele      1643  50*
# PPP        Point-to-Point Protocol (PPP)             Ele      1661  51*
# PPP-HDLC   PPP in HDLC Framing                       Ele      1662  51*
#
# [Note: an asterisk at the end of a line indicates a change from the
# previous edition of this document.]
#
#
#
#
#
#
#
# Applicability Statements:
#
# IGMP -- The Internet Architecture Board intends to move towards
# general adoption of IP multicasting, as a more efficient solution
# than broadcasting for many applications.  The host interface has been
# standardized in RFC-1112; however, multicast-routing gateways are in
# the experimental stage and are not widely available.  An Internet
# host should support all of RFC-1112, except for the IGMP protocol
# itself which is optional; see RFC-1122 for more details.  Even
# without IGMP, implementation of RFC-1112 will provide an important
# advance: IP-layer access to local network multicast addressing.  It
# is expected that IGMP will become recommended for all hosts and
# gateways at some future date.
#
# SMI, MIB-II SNMP -- The Internet Architecture Board recommends that
# all IP and TCP implementations be network manageable.  At the current
# time, this implies implementation of the Internet MIB-II (RFC-1213),
# and at least the recommended management protocol SNMP (RFC-1157).
#
# RIP -- The Routing Information Protocol (RIP) is widely implemented
# and used in the Internet.  However, both implementors and users
# should be aware that RIP has some serious technical limitations as a
# routing protocol.  The IETF is currently developing several
# candidates for a new standard "open" routing protocol with better
# properties than RIP.  The IAB urges the Internet community to track
# these developments, and to implement the new protocol when it is
# standardized; improved Internet service will result for many users.
#
# TP-TCP -- As OSI protocols become more widely implemented and used,
# there will be an increasing need to support interoperation with the
# TCP/IP protocols.  The Internet Engineering Task Force is formulating
# strategies for interoperation.  RFC-1006 provides one interoperation
# mode, in which TCP/IP is used to emulate TP0 in order to support OSI
# applications.  Hosts that wish to run OSI connection-oriented
# applications in this mode should use the procedure described in RFC-
# 1006.  In the future, the IAB expects that a major portion of the
# Internet will support both TCP/IP and OSI (inter-)network protocols
# in parallel, and it will then be possible to run OSI applications
# across the Internet using full OSI protocol "stacks".
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 6.3.  Network-Specific Standard Protocols
#
# All Network-Specific Standards have Elective status.
#
# Protocol   Name                                    State    RFC   STD *
# ========   =====================================   =====   =====  === =
# IP-ATM     Classical IP and ARP over ATM            Prop   1577
# IP-FR      Multiprotocol over Frame Relay           Draft  1490
# ATM-ENCAP  Multiprotocol Encapsulation over ATM     Prop   1483
# IP-TR-MC   IP Multicast over Token-Ring LANs        Prop   1469
# IP-FDDI    Transmission of IP and ARP over FDDI Net Std    1390    36
# IP-HIPPI   IP and ARP on HIPPI                      Prop   1374
# IP-X.25    X.25 and ISDN in the Packet Mode         Draft  1356
# IP-SMDS    IP Datagrams over the SMDS Service       Prop   1209
# IP-FDDI    Internet Protocol on FDDI Networks       Draft  1188
# ARP        Address Resolution Protocol              Std     826    37
# RARP       A Reverse Address Resolution Protocol    Std     903    38
# IP-ARPA    Internet Protocol on ARPANET             Std BBN1822    39
# IP-WB      Internet Protocol on Wideband Network    Std     907    40
# IP-E       Internet Protocol on Ethernet Networks   Std     894    41
# IP-EE      Internet Protocol on Exp. Ethernet Nets  Std     895    42
# IP-IEEE    Internet Protocol on IEEE 802            Std    1042    43
# IP-DC      Internet Protocol on DC Networks         Std     891    44
# IP-HC      Internet Protocol on Hyperchannel        Std    1044    45
# IP-ARC     Transmitting IP Traffic over ARCNET Nets Std    1201    46
# IP-SLIP    Transmission of IP over Serial Lines     Std    1055    47
# IP-NETBIOS Transmission of IP over NETBIOS          Std    1088    48
# IP-IPX     Transmission of 802.2 over IPX Networks  Std    1132    49
#
# [Note: an asterisk at the end of a line indicates a change from the
# previous edition of this document.]
#
# Applicability Statements:
#
# It is expected that a system will support one or more physical
# networks and for each physical network supported the appropriate
# protocols from the above list must be supported.  That is, it is
# elective to support any particular type of physical network, and for
# the physical networks actually supported it is required that they be
# supported exactly according to the protocols in the above list.  See
# also the Host and Gateway Requirements RFCs for more specific
# information on network-specific ("link layer") protocols.
#
#
#
#
#
#
#
#
#
#
#
#
# 6.4.  Draft Standard Protocols
#
# Protocol   Name                                     Status          RFC
# ========   =====================================    ============== =====
# POP3       Post Office Protocol, Version 3          Elective       1725*
# RIP2-MIB   RIP Version 2 MIB Extension              Elective       1724*
# RIP2       RIP Version 2-Carrying Additional Info.  Elective       1723*
# RIP2-APP   RIP Version 2 Protocol App. Statement    Elective       1722*
# SIP-MIB    SIP Interface Type MIB                   Elective       1694*
# -------    Def Man Objs Parallel-printer-like       Elective       1660*
# -------    Def Man Objs RS-232-like                 Elective       1659*
# -------    Def Man Objs Character Stream            Elective       1658*
# SMTP-SIZE  SMTP Service Ext for Message Size        Elective       1653*
# SMTP-8BIT  SMTP Service Ext or 8bit-MIMEtransport   Elective       1652*
# SMTP-EXT   SMTP Service Extensions                  Elective       1651*
# OSI-NSAP   Guidelines for OSI NSAP Allocation       Elective       1629
# OSPF2      Open Shortest Path First Routing V2      Elective       1583
# ISO-TS-ECHO Echo for ISO-8473                       Elective       1575
# DECNET-MIB DECNET MIB                               Elective       1559
# -------    Message Header Ext. of Non-ASCII Text    Elective       1522
# MIME       Multipurpose Internet Mail Extensions    Elective       1521
# 802.3-MIB  IEEE 802.3 Repeater MIB                  Elective       1516
# BRIDGE-MIB BRIDGE-MIB                               Elective       1493
# NTPV3      Network Time Protocol (Version 3)        Elective       1305
# IP-MTU     Path MTU Discovery                       Elective       1191
# FINGER     Finger Protocol                          Elective       1288
# BGP3       Border Gateway Protocol 3 (BGP-3)        Elective  1267,1268
# BOOTP      Bootstrap Protocol                      Recommended 951,1497
# NICNAME    WhoIs Protocol                           Elective        954
#
# [Note: an asterisk at the end of a line indicates a change from the
# previous edition of this document.]
#
# Applicability Statements:
#
# PPP -- Point to Point Protocol is a method of sending IP over serial
# lines, which are a type of physical network.  It is anticipated that
# PPP will be advanced to the network-specifics standard protocol state
# in the future.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 6.5.  Proposed Standard Protocols
#
# Protocol   Name                                     Status          RFC
# ========   =====================================    ============== =====
# PPP-MP     PPP Multilink Protocol                   Elective       1717*
# RDBMS-MIB  RDMS MIB - using SMIv2                   Elective       1697*
# MODEM-MIB  Modem MIB - using SMIv2                  Elective       1696*
# ATM-MIB    ATM Management Version 8.0 using SMIv2   Elective       1695*
# SNANAU-MIB SNA NAUs MIB using SMIv2                 Elective       1665*
# ...
# X500-CHART Charting Networks in the X.500 Directory                1609
# X500-DIR   Representing IP Information in the X.500 Directory      1608
# SNMP-DPI   SNMP Distributed Protocol Interface                     1592
# CLNP-TUBA  Use of ISO CLNP in TUBA Environments                    1561
# REM-PRINT  TPC.INT Subdomain Remote Printing - Technical           1528
# EHF-MAIL   Encoding Header Field for Internet Messages             1505
# REM-PRT    An Experiment in Remote Printing                        1486
# RAP        Internet Route Access Protocol                          1476
# TP/IX      TP/IX: The Next Internet                                1475
# X400       Routing Coordination for X.400 Services                 1465
# DNS        Storing Arbitrary Attributes in DNS                     1464
# IRCP       Internet Relay Chat Protocol                            1459
# TOS-LS     Link Security TOS                                       1455
# SIFT/UFT   Sender-Initiated/Unsolicited File Transfer              1440
# DIR-ARP    Directed ARP                                            1433
# TEL-SPX    Telnet Authentication: SPX                              1412
# TEL-KER    Telnet Authentication: Kerberos V4                      1411
# MAP-MAIL   X.400 Mapping and Mail-11                               1405
# TRACE-IP   Traceroute Using an IP Option                           1393
# DNS-IP     Experiment in DNS Based IP Routing                      1383
# RMCP       Remote Mail Checking Protocol                           1339
# TCP-HIPER  TCP Extensions for High Performance                     1323
# MSP2       Message Send Protocol 2                                 1312
# DSLCP      Dynamically Switched Link Control                       1307
# --------   X.500 and Domains                                       1279
# IN-ENCAP   Internet Encapsulation Protocol                         1241
# CLNS-MIB   CLNS-MIB                                                1238
# CFDP       Coherent File Distribution Protocol                     1235
# SNMP-DPI   SNMP Distributed Program Interface                      1228
# IP-AX.25   IP Encapsulation of AX.25 Frames                        1226
# ALERTS     Managing Asynchronously Generated Alerts                1224
#
#
#
#
#
#
# MPP        Message Posting Protocol                                1204
# ST-II      Stream Protocol                                         1190
# SNMP-BULK  Bulk Table Retrieval with the SNMP                      1187
# DNS-RR     New DNS RR Definitions                                  1183
# IMAP2      Interactive Mail Access Protocol                        1176
# NTP-OSI    NTP over OSI Remote Operations                          1165
# DMF-MAIL   Digest Message Format for Mail                          1153
# RDP        Reliable Data Protocol                              908,1151
# TCP-ACO    TCP Alternate Checksum Option                           1146
# --------   Mapping full 822 to Restricted 822                      1137
# IP-DVMRP   IP Distance Vector Multicast Routing                    1075
# VMTP       Versatile Message Transaction Protocol                  1045
# COOKIE-JAR Authentication Scheme                                   1004
# NETBLT     Bulk Data Transfer Protocol                              998
# IRTP       Internet Reliable Transaction Protocol                   938
# LDP        Loader Debugger Protocol                                 909
# RLP        Resource Location Protocol                               887
# NVP-II     Network Voice Protocol                              ISI-memo
# PVP        Packet Video Protocol                               ISI-memo
#
# [Note: an asterisk at the end of a line indicates a change from the
# previous edition of this document.]
#
# 6.8.  Informational Protocols
#
# Information protocols have no status.
#
# Protocol   Name                                                     RFC
# =======    ====================================                    =====
# RWHOIS     Referral Whois Protocol                                 1714*
# DNS-NSAP   DNS NSAP Resource Records                               1706*
# RADIO-PAGE TPC.INT Subdomain: Radio Paging -- Technical Procedures 1703*
# GRE-IPv4   Generic Routing Encapsulation over IPv4                 1702*
# GRE        Generic Routing Encapsulatio                            1701*
# TMUX       Transport Multiplexing Protocol                         1692*
# SNPP       Simple Network Paging Protocol - Version 2              1645*
# IPXWAN     Novell IPX Over Various WAN Media                       1634
# ADSNA-IP   Advanced SNA/IP: A Simple SNA Transport Protocol        1538
# AUBR       Appletalk Update-Based Routing Protocol...              1504
# TACACS     Terminal Access Control Protocol                        1492
# SUN-NFS    Network File System Protocol                            1094
# SUN-RPC    Remote Procedure Call Protocol Version 2                1057
# GOPHER     The Internet Gopher Protocol                            1436
# -------    Data Link Switching: Switch-to-Switch Protocol          1434
# LISTSERV   Listserv Distribute Protocol                            1429
# -------    Replication Requirements                                1275
# PCMAIL     Pcmail Transport Protocol                               1056
# MTP        Multicast Transport Protocol                            1301
#
#
#
#
#
#
# BSD Login  BSD Login                                               1282
# DIXIE      DIXIE Protocol Specification                            1249
# IP-X.121   IP to X.121 Address Mapping for DDN                     1236
# OSI-HYPER  OSI and LLC1 on HYPERchannel                            1223
# HAP2       Host Access Protocol                                    1221
# SUBNETASGN On the Assignment of Subnet Numbers                     1219
# SNMP-TRAPS Defining Traps for use with SNMP                        1215
# DAS        Directory Assistance Service                            1202
# MD4        MD4 Message Digest Algorithm                            1186
# LPDP       Line Printer Daemon Protocol                            1179
#
# [Note: an asterisk at the end of a line indicates a change from the
# previous edition of this document.]
#
# 6.9.  Historic Protocols
#
# All Historic protocols have Not Recommended status.
#
# Protocol   Name                                                RFC  STD
# ========   =====================================              ===== ===
# EGP        Exterior Gateway Protocol                 Rec       904  18*
# SNMP-MUX   SNMP MUX Protocol and MIB                          1227
# OIM-MIB-II OSI Internet Management: MIB-II                    1214
# IMAP3      Interactive Mail Access Protocol Version 3         1203
# SUN-RPC    Remote Procedure Call Protocol Version 1           1050
# 802.4-MIP  IEEE 802.4 Token Bus MIB                           1230
# CMOT       Common Management Information Services             1189
# --------   Mail Privacy: Procedures                           1113
# --------   Mail Privacy: Key Management                       1114
# --------   Mail Privacy: Algorithms                           1115
# NFILE      A File Access Protocol                             1037
# HOSTNAME   HOSTNAME Protocol                                   953
# SFTP       Simple File Transfer Protocol                       913
# SUPDUP     SUPDUP Protocol                                     734
# BGP        Border Gateway Protocol                       1163,1164
# MIB-I      MIB-I                                              1156
# SGMP       Simple Gateway Monitoring Protocol                 1028
# HEMS       High Level Entity Management Protocol              1021
# STATSRV    Statistics Server                                   996
# POP2       Post Office Protocol, Version 2                     937
# RATP       Reliable Asynchronous Transfer Protocol             916
# HFEP       Host - Front End Protocol                           929
# THINWIRE   Thinwire Protocol                                   914
# HMP        Host Monitoring Protocol                            869
# GGP        Gateway Gateway Protocol                            823
# RTELNET    Remote Telnet Service                               818
# CLOCK      DCNET Time Server Protocol                          778
# MPM        Internet Message Protocol                           759
#
#
#
#
#
#
# NETRJS     Remote Job Service                                  740
# NETED      Network Standard Text Editor                        569
# RJE        Remote Job Entry                                    407
# XNET       Cross Net Debugger                              IEN-158
# NAMESERVER Host Name Server Protocol                       IEN-116
# MUX        Multiplexing Protocol                            IEN-90
# GRAPHICS   Graphics Protocol                             NIC-24308
#
# [Note: an asterisk at the end of a line indicates a change from the
# previous edition of this document.]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 6.10.  Obsolete Protocols
#
# Some of the protocols listed in this memo are described in RFCs that are
# obsoleted by newer RFCs.  "Obsolete" or "obsoleted" is not an official
# state or status of protocols.  This subsection is for information only.
#
# While it may seem to be obviously wrong to have an obsoleted RFC in the
# list of standards, there may be cases when an older standard is in the
# process of being replaced.  This process may take a year or two.
#
# For example, the Network Time Protocol (NTP) [RFC 1119] is in its
# version 2 a full Standard, and in its version 3 is a Draft Standard [RFC
# 1305].  Once version 3 is a full Standard, version 2 will be made
# Historic.
#
# Many obsoleted protocols are of little interest and are dropped from
# this memo altogether.  Some obsoleted protocols have received enough
# recognition that it seems appropriate to list them under their current
# status and with the following reference to their current replacement.
#
# RFC            RFC   Status     Title                               *
# ====           ====  =========  =================================== =
# 1305 obsoletes 1119  Std  /Rec  Network Time Protocol (Version 2)
# 1533 obsoletes 1497  Draft/Rec  Bootstrap Protocol
# 1331 obsoletes 1171  Draft/Ele  Point to Point Protocol
# 1574 obsoletes 1139  Prop /Ele  Echo for ISO-8473
# 1573 obsoletes 1229  Prop /Ele  Extensions to the Generic-IF MIB
# 1559 obsoletes 1289  Prop /Ele  DECNET MIB
# 1548 obsoletes 1331  Prop /Ele  Point-to-Point Protocol (PPP)
# 1541 obsoletes 1531  Prop /Ele  Dynamic Host Configuration Protocol
# 1592 obsoletes 1228  Exper/Lim  SNMP Distributed Program Interface
# 1528 obsoletes 1486  Exper/Lim  An Experiment in Remote Printing
# 1320 obsoletes 1186  Info /     MD4 Message Digest Algorithm
# 1057 obsoletes 1050  Hist /Not  Remote Procedure Call Version 1
# 1421 obsoletes 1113  Hist /Not  Mail Privacy: Procedures
# 1422 obsoletes 1114  Hist /Not  Mail Privacy: Key Management
# 1423 obsoletes 1115  Hist /Not  Mail Privacy: Algorithms
# 1267 obsoletes 1163  Hist /Not  Border Gateway Protocol
# 1268 obsoletes 1164  Hist /Not  Border Gateway Protocol
#
# Thanks to Lynn Wheeler of Britton Lee for compiling the information in
# this subsection.
#
# [Note: an asterisk at the end of a line indicates a change from the
# previous edition of this document.]
#
#
#
#
#
#
#
#
#
# 7.  Contacts
#
# 7.1.  IAB, IETF, and IRTF Contacts
#
# 7.1.1.  Internet Architecture Board (IAB) Contact
#
# Please send your comments about this list of protocols and especially
# about the Draft Standard Protocols to the Internet Architecture Board
# care of Abel Winerib, IAB Executive Director.
#
# Contacts:
#
# Abel Winerib
# Executive Director of the IAB
# Intel, JF2-64
# 2111 NE 25th Avenue
# Hillsboro, OR 97124
#
# 1-503-696-8972
#
# AWeinrib@ibeam.intel.com
#
#
# Christian Huitema
# Chair of the IAB
# INRIA, Sophia-Antipolis
# 2004 Route des Lucioles
# BP 109
# F-06561 Valbonne Cedex
# France
#
# +33 93 65 77 15
#
# Christian.Huitema@MIRSA.INRIA.FR
#
# 7.1.2.  Internet Engineering Task Force (IETF) Contact
#
# Contacts:
#
# Paul Mockapetris
# Chair of the IETF
# USC/Information Sciences Institute
# 4676 Admiralty Way
# Marina del Rey, CA 90292-6695
#
# 1-310-822-1511
#
# pvm@ISI.EDU
#
#
#
#
#
#
# John Stewart
# IESG Secretary
# Corporation for National Research Initiatives
# 1895 Preston White Drive, Suite 100
# Reston, VA 22091
#
# 1-703-620-8990
#
# jstewart@CNRI.RESTON.VA.US
#
# Steve Coya
# Executive Director of the IETF
# Corporation for National Research Initiatives
# 1895 Preston White Drive, Suite 100
# Reston, VA 22091
#
# 1-703-620-8990
#
# scoya@CNRI.RESTON.VA.US
#
#
# 7.1.3.  Internet Research Task Force (IRTF) Contact
#
# Contact:
#
# Jon Postel
# Chair of the IRTF
# USC/Information Sciences Institute
# 4676 Admiralty Way
# Marina del Rey, CA  90292-6695
#
# 1-310-822-1511
#
# Postel@ISI.EDU
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 7.2.  Internet Assigned Numbers Authority Contact
#
# Contact:
#
# Joyce K. Reynolds
# Internet Assigned Numbers Authority
# USC/Information Sciences Institute
# 4676 Admiralty Way
# Marina del Rey, CA  90292-6695
#
# 1-310-822-1511
#
# IANA@ISI.EDU
#
# The protocol standards are managed by the Internet Assigned Numbers
# Authority.
#
# Please refer to the document "Assigned Numbers" (RFC-1700) for
# further information about the status of protocol documents.  There
# are two documents that summarize the requirements for host and
# gateways in the Internet, "Host Requirements" (RFC-1122 and RFC-1123)
# and "Gateway Requirements" (RFC-1009).
#
# How to obtain the most recent edition of this "Internet Official
# Protocol Standards" memo:
#
# The file "in-notes/std/std1.txt" may be copied via FTP from the
# FTP.ISI.EDU computer using the FTP username "anonymous" and FTP
# password "guest".
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 7.3.  Request for Comments Editor Contact
#
# Contact:
#
# Jon Postel
# RFC Editor
# USC/Information Sciences Institute
# 4676 Admiralty Way
# Marina del Rey, CA  90292-6695
#
# 1-310-822-1511
#
# RFC-Editor@ISI.EDU
#
# Documents may be submitted via electronic mail to the RFC Editor for
# consideration for publication as RFC.  If you are not familiar with
# the format or style requirements please request the "Instructions for
# RFC Authors".  In general, the style of any recent RFC may be used as
# a guide.
#
# 7.4.  The Network Information Center and
# Requests for Comments Distribution Contact
#
# RFC's may be obtained from DS.INTERNIC.NET via FTP, WAIS, and
# electronic mail.  Through FTP, RFC's are stored as rfc/rfcnnnn.txt
# or rfc/rfcnnnn.ps where 'nnnn' is the RFC number.  Login as
# "anonymous" and provide your e-mail address as the password.
# Through WAIS, you may use either your local WAIS client or telnet
# to DS.INTERNIC.NET and login as "wais" (no password required) to
# access a WAIS client.  Help information and a tutorial for using
# WAIS are available online.  The WAIS database to search is "rfcs".
#
# Directory and Database Services also provides a mail server
# interface.  Send a mail message to mailserv@ds.internic.net and
# include any of the following commands in the message body:
#
# document-by-name rfcnnnn      where 'nnnn' is the RFC number
# The text version is sent.
#
# file /ftp/rfc/rfcnnnn.yyy     where 'nnnn' is the RFC number.
# and 'yyy' is 'txt' or 'ps'.
#
# help                          to get information on how to use
# the mailserver.
#
# The InterNIC directory and database services collection of
# resource listings, internet documents such as RFCs, FYIs, STDs,
# and Internet Drafts, and publicly accessible databases are also
#
#
#
#
#
#
# now available via Gopher.  All our collections are WAIS indexed
# and can be searched from the Gopher menu.
#
# To access the InterNIC Gopher Servers, please connect to
# "internic.net" port 70.
#
# Contact: admin@ds.internic.net
#
# 7.5.  Sources for Requests for Comments
#
# Details on many sources of RFCs via FTP or EMAIL may be obtained by
# sending an EMAIL message to "rfc-info@ISI.EDU" with the message body
# "help: ways_to_get_rfcs".  For example:
#
# To: rfc-info@ISI.EDU
# Subject: getting rfcs
#
# help: ways_to_get_rfcs
#
# 8.  Security Considerations
#
# Security issues are not addressed in this memo.
#
# 9.  Author's Address
#
# Jon Postel
# USC/Information Sciences Institute
# 4676 Admiralty Way
# Marina del Rey, CA 90292
#
# Phone: 310-822-1511
# Fax:   310-823-6714
#
# Email: Postel@ISI.EDU

# %%
raw_text = re.sub(r'\n+', '\n', raw_text)
raw_text = re.sub(r'\s+', ' ', raw_text)
raw_text = raw_text.replace('\t', ' ')
raw_text
# Out:
# 'Network Working Group Internet Architecture BoardRequest for Comments: 1720 J. Postel, EditorObsoletes: RFCs 1610, 1600, 1540, 1500, November 19941410, 1360, 1280, 1250, 1100, 1083,1130, 1140, 1200STD: 1Category: Standards TrackINTERNET OFFICIAL PROTOCOL STANDARDSStatus of this MemoThis memo describes the state of standardization of protocols used inthe Internet as determined by the Internet Architecture Board (IAB).This memo is an Internet Standard. Distribution of this memo isunlimited.Table of ContentsIntroduction . . . . . . . . . . . . . . . . . . . . . . . . . . 21. The Standardization Process . . . . . . . . . . . . . . . . 32. The Request for Comments Documents . . . . . . . . . . . . . 53. Other Reference Documents . . . . . . . . . . . . . . . . . 63.1. Assigned Numbers . . . . . . . . . . . . . . . . . . . . . 63.2. Gateway Requirements . . . . . . . . . . . . . . . . . . . 63.3. Host Requirements . . . . . . . . . . . . . . . . . . . . 63.4. The MIL-STD Documents . . . . . . . . . . . . . . . . . . 64. Explanation of Terms . . . . . . . . . . . . . . . . . . . . 74.1. Definitions of Protocol State (Maturity Level) . . . . . . 84.1.1. Standard Protocol . . . . . . . . . . . . . . . . . . . 84.1.2. Draft Standard Protocol . . . . . . . . . . . . . . . . 94.1.3. Proposed Standard Protocol . . . . . . . . . . . . . . . 94.1.4. Experimental Protocol . . . . . . . . . . . . . . . . . 94.1.5. Informational Protocol . . . . . . . . . . . . . . . . . 94.1.6. Historic Protocol . . . . . . . . . . . . . . . . . . . 94.2. Definitions of Protocol Status (Requirement Level) . . . 94.2.1. Required Protocol . . . . . . . . . . . . . . . . . . 104.2.2. Recommended Protocol . . . . . . . . . . . . . . . . . 104.2.3. Elective Protocol . . . . . . . . . . . . . . . . . . 104.2.4. Limited Use Protocol . . . . . . . . . . . . . . . . . 104.2.5. Not Recommended Protocol . . . . . . . . . . . . . . . 105. The Standards Track . . . . . . . . . . . . . . . . . . . 105.1. The RFC Processing Decision Table . . . . . . . . . . . 105.2. The Standards Track Diagram . . . . . . . . . . . . . . 126. The Protocols . . . . . . . . . . . . . . . . . . . . . . 146.1. Recent Changes . . . . . . . . . . . . . . . . . . . . . 146.1.1. New RFCs . . . . . . . . . . . . . . . . . . . . . . . 146.1.2. Other Changes . . . . . . . . . . . . . . . . . . . . 236.2. Standard Protocols . . . . . . . . . . . . . . . . . . . 246.3. Network-Specific Standard Protocols . . . . . . . . . . 266.4. Draft Standard Protocols . . . . . . . . . . . . . . . . 276.5. Proposed Standard Protocols . . . . . . . . . . . . . . 286.6. Telnet Options . . . . . . . . . . . . . . . . . . . . . 316.7. Experimental Protocols . . . . . . . . . . . . . . . . . 326.8. Informational Protocols . . . . . . . . . . . . . . . . 336.9. Historic Protocols . . . . . . . . . . . . . . . . . . . 346.10 Obsolete Protocols . . . . . . . . . . . . . . . . . . . 367. Contacts . . . . . . . . . . . . . . . . . . . . . . . . . 377.1. IAB, IETF, and IRTF Contacts . . . . . . . . . . . . . . 377.1.1. Internet Architecture Board (IAB) Contact . . . . . . 377.1.2. Internet Engineering Task Force (IETF) Contact . . . . 387.1.3. Internet Research Task Force (IRTF) Contact . . . . . 397.2. Internet Assigned Numbers Authority (IANA) Contact . . . 397.3. Request for Comments Editor Contact . . . . . . . . . . 407.4. Network Information Center Contact . . . . . . . . . . . 407.5. Sources for Requests for Comments . . . . . . . . . . . 418. Security Considerations . . . . . . . . . . . . . . . . . 419. Author\'s Address . . . . . . . . . . . . . . . . . . . . . 41IntroductionA discussion of the standardization process and the RFC documentseries is presented first, followed by an explanation of the terms.Sections 6.2 - 6.10 contain the lists of protocols in each stage ofstandardization. Finally are pointers to references and contacts forfurther information.This memo is intended to be issued approximately quarterly; p ...

# %%
from langchain.document_loaders import TextLoader
from langchain.docstore.document import Document

loader = TextLoader(test_file)

# %%
loader.load()
# Out:
# [Document(page_content='\n\n\n\n\n\nNetwork Working Group                        Internet Architecture Board\nRequest for Comments: 1720                             J. Postel, Editor\nObsoletes: RFCs 1610, 1600, 1540, 1500,                    November 1994\n1410, 1360, 1280, 1250, 1100, 1083,\n1130, 1140, 1200\nSTD: 1\nCategory: Standards Track\n\n\n                  INTERNET OFFICIAL PROTOCOL STANDARDS\n\n\nStatus of this Memo\n\n   This memo describes the state of standardization of protocols used in\n   the Internet as determined by the Internet Architecture Board (IAB).\n   This memo is an Internet Standard.  Distribution of this memo is\n   unlimited.\n\nTable of Contents\n\n   Introduction . . . . . . . . . . . . . . . . . . . . . . . . . . 2\n   1.  The Standardization Process  . . . . . . . . . . . . . . . . 3\n   2.  The Request for Comments Documents . . . . . . . . . . . . . 5\n   3.  Other Reference Documents  . . . . . . . . . . . . . . . . . 6\n   3.1.  Assigned Numbers . . . . . . . . . . . . . . . . . . . . . 6\n   3.2.  Gateway Requirements . . . . . . . . . . . . . . . . . . . 6\n   3.3.  Host Requirements  . . . . . . . . . . . . . . . . . . . . 6\n   3.4.  The MIL-STD Documents  . . . . . . . . . . . . . . . . . . 6\n   4.  Explanation of Terms . . . . . . . . . . . . . . . . . . . . 7\n   4.1.  Definitions of Protocol State (Maturity Level) . . . . . . 8\n   4.1.1.  Standard Protocol  . . . . . . . . . . . . . . . . . . . 8\n   4.1.2.  Draft Standard Protocol  . . . . . . . . . . . . . . . . 9\n   4.1.3.  Proposed Standard Protocol . . . . . . . . . . . . . . . 9\n   4.1.4.  Experimental Protocol  . . . . . . . . . . . . . . . . . 9\n   4.1.5.  Informational Protocol . . . . . . . . . . . . . . . . . 9\n   4.1.6.  Historic Protocol  . . . . . . . . . . . . . . . . . . . 9\n   4.2.  Definitions of Protocol Status (Requirement Level) . . .   9\n   4.2.1.  Required Protocol  . . . . . . . . . . . . . . . . . .  10\n   4.2.2.  Recommended Protocol . . . . . . . . . . . . . . . . .  10\n   4.2.3.  Elective Protocol  . . . . . . . . . . . . . . . . . .  10\n   4.2.4.  Limited Use Protocol . . . . . . . . . . . . . . . . .  10\n   4.2.5.  Not Recommended Protocol . . . . . . . . . . . . . . .  10\n   5.  The Standards Track  . . . . . . . . . . . . . . . . . . .  10\n   5.1.  The RFC Processing Decision Table  . . . . . . . . . . .  10\n   5.2.  The Standards Track Diagram  . . . . . . . . . . . . . .  12\n   6.  The Protocols  . . . . . . . . . . . . . . . . . . . . . .  14\n   6.1.  Recent Changes . . . . . . . . . . . . . . . . . . . . .  14\n\n\n\nInternet Architecture Board                                     [Page 1]\n\x0c\nRFC 1720                   Internet Standards              November 1994\n\n\n   6.1.1.  New RFCs . . . . . . . . . . . . . . . . . . . . . . .  14\n   6.1.2.  Other Changes  . . . . . . . . . . . . . . . . . . . .  23\n   6.2.  Standard Protocols . . . . . . . . . . . . . . . . . . .  24\n   6.3.  Network-Specific Standard Protocols  . . . . . . . . . .  26\n   6.4.  Draft Standard Protocols . . . . . . . . . . . . . . . .  27\n   6.5.  Proposed Standard Protocols  . . . . . . . . . . . . . .  28\n   6.6.  Telnet Options . . . . . . . . . . . . . . . . . . . . .  31\n   6.7.  Experimental Protocols . . . . . . . . . . . . . . . . .  32\n   6.8.  Informational Protocols  . . . . . . . . . . . . . . . .  33\n   6.9.  Historic Protocols . . . . . . . . . . . . . . . . . . .  34\n   6.10  Obsolete Protocols . . . . . . . . . . . . . . . . . . .  36\n   7.  Contacts . . . . . . . . . . . . . . . . . . . . . . . . .  37\n   7.1.  IAB, IETF, and IRTF Contacts . . . . . . . . . . . . . .  37\n   7.1.1.  Internet Architecture Board (IAB) Contact  . . . . . .  37\n   7.1.2.  Internet Engineering Task Force (IETF) Contact . . . .  38\n   7.1.3.  Internet Research Task Force (IRTF) Contact  . . . . .  39\n   7.2.  Internet Assigned Numbers Authority (IANA) Contact . . .  39\n   7.3.  Request for Co ...

# %%
doc = Document(page_content=raw_text)

# %%
doc
# Out:
# Document(page_content='Network Working Group Internet Architecture BoardRequest for Comments: 1720 J. Postel, EditorObsoletes: RFCs 1610, 1600, 1540, 1500, November 19941410, 1360, 1280, 1250, 1100, 1083,1130, 1140, 1200STD: 1Category: Standards TrackINTERNET OFFICIAL PROTOCOL STANDARDSStatus of this MemoThis memo describes the state of standardization of protocols used inthe Internet as determined by the Internet Architecture Board (IAB).This memo is an Internet Standard. Distribution of this memo isunlimited.Table of ContentsIntroduction . . . . . . . . . . . . . . . . . . . . . . . . . . 21. The Standardization Process . . . . . . . . . . . . . . . . 32. The Request for Comments Documents . . . . . . . . . . . . . 53. Other Reference Documents . . . . . . . . . . . . . . . . . 63.1. Assigned Numbers . . . . . . . . . . . . . . . . . . . . . 63.2. Gateway Requirements . . . . . . . . . . . . . . . . . . . 63.3. Host Requirements . . . . . . . . . . . . . . . . . . . . 63.4. The MIL-STD Documents . . . . . . . . . . . . . . . . . . 64. Explanation of Terms . . . . . . . . . . . . . . . . . . . . 74.1. Definitions of Protocol State (Maturity Level) . . . . . . 84.1.1. Standard Protocol . . . . . . . . . . . . . . . . . . . 84.1.2. Draft Standard Protocol . . . . . . . . . . . . . . . . 94.1.3. Proposed Standard Protocol . . . . . . . . . . . . . . . 94.1.4. Experimental Protocol . . . . . . . . . . . . . . . . . 94.1.5. Informational Protocol . . . . . . . . . . . . . . . . . 94.1.6. Historic Protocol . . . . . . . . . . . . . . . . . . . 94.2. Definitions of Protocol Status (Requirement Level) . . . 94.2.1. Required Protocol . . . . . . . . . . . . . . . . . . 104.2.2. Recommended Protocol . . . . . . . . . . . . . . . . . 104.2.3. Elective Protocol . . . . . . . . . . . . . . . . . . 104.2.4. Limited Use Protocol . . . . . . . . . . . . . . . . . 104.2.5. Not Recommended Protocol . . . . . . . . . . . . . . . 105. The Standards Track . . . . . . . . . . . . . . . . . . . 105.1. The RFC Processing Decision Table . . . . . . . . . . . 105.2. The Standards Track Diagram . . . . . . . . . . . . . . 126. The Protocols . . . . . . . . . . . . . . . . . . . . . . 146.1. Recent Changes . . . . . . . . . . . . . . . . . . . . . 146.1.1. New RFCs . . . . . . . . . . . . . . . . . . . . . . . 146.1.2. Other Changes . . . . . . . . . . . . . . . . . . . . 236.2. Standard Protocols . . . . . . . . . . . . . . . . . . . 246.3. Network-Specific Standard Protocols . . . . . . . . . . 266.4. Draft Standard Protocols . . . . . . . . . . . . . . . . 276.5. Proposed Standard Protocols . . . . . . . . . . . . . . 286.6. Telnet Options . . . . . . . . . . . . . . . . . . . . . 316.7. Experimental Protocols . . . . . . . . . . . . . . . . . 326.8. Informational Protocols . . . . . . . . . . . . . . . . 336.9. Historic Protocols . . . . . . . . . . . . . . . . . . . 346.10 Obsolete Protocols . . . . . . . . . . . . . . . . . . . 367. Contacts . . . . . . . . . . . . . . . . . . . . . . . . . 377.1. IAB, IETF, and IRTF Contacts . . . . . . . . . . . . . . 377.1.1. Internet Architecture Board (IAB) Contact . . . . . . 377.1.2. Internet Engineering Task Force (IETF) Contact . . . . 387.1.3. Internet Research Task Force (IRTF) Contact . . . . . 397.2. Internet Assigned Numbers Authority (IANA) Contact . . . 397.3. Request for Comments Editor Contact . . . . . . . . . . 407.4. Network Information Center Contact . . . . . . . . . . . 407.5. Sources for Requests for Comments . . . . . . . . . . . 418. Security Considerations . . . . . . . . . . . . . . . . . 419. Author\'s Address . . . . . . . . . . . . . . . . . . . . . 41IntroductionA discussion of the standardization process and the RFC documentseries is presented first, followed by an explanation of the terms.Sections 6.2 - 6.10 contain the lists of protocols in each stage ofstandardization. Finally are pointers to references and contacts forfurther information.This memo is intended to be issued appr ...
